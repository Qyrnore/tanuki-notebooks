# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import generate_gathering_list
utils_dir = '../../utilities/'
data_dir = 'item_data/'
df_gathering_list = generate_gathering_list(
    total_csv=os.path.join(data_dir, 'total_viltgance_type_airship_parts.csv'),
    recipe_book_csv=os.path.join(utils_dir, 'recipe_book.csv'),
    recipe_gathering_csv=os.path.join(utils_dir, 'recipe_gathering.csv'),
    output_csv=os.path.join(data_dir, 'gathering_list.csv')
)
df_gathering_list
# Out:
#                          Ingredient  Total Quantity  \
# 0                    Adamantite Ore           120.0
# 52                     Ahriman Wing            24.0
# 2                   Amphiptere Skin            36.0
# 39                       Animal Fat           162.0
# 21                Aqueous Whetstone            54.0
# 15                   Astral Moraine            24.0
# 5                  Aurum Regis Sand           120.0
# 16                         Bear Fat            12.0
# 8                         Birch Log            60.0
# 40                     Black Alumen            54.0
# 9                        Cassia Log            36.0
# 10                       Cassia Log            36.0
# 38  Chemically Treated Chimera Hide            54.0
# 44                       Cloud Mica           240.0
# 23                       Cobalt Ore           204.0
# 33                             Coke           270.0
# 3                 Dark Chestnut Log            72.0
# 1                     Darksteel Ore           222.0
# 19             Dawnborne Aethersand            12.0
# 53                   Dhalmel Saliva            24.0
# 34                    Earth Cluster            78.0
# 4                     Earth Crystal            60.0
# 22                     Fire Cluster            66.0
# 28                     Fire Crystal          1176.0
# 26                       Fire Shard           660.0
# 48                             Flax            48.0
# 6                          Gold Ore            24.0
# 46                      Grenade Ash            66.0
# 11                     Hardened Sap           108.0
# 35                   Hardsilver Ore            96.0
# 36                  Hardsilver Sand           120.0
# 13                      Ice Cluster            24.0
# 27                        Ice Shard            60.0
# 25                         Iron Ore           138.0
# 24                         Iron Ore           138.0
# 18                Lightning Cluster            27.0
# 43                      Mythril Ore            42.0
# 41                     Mythrite Ore           120.0
# 42                    Mythrite Sand           210.0
# 30                           Potash           135.0
# 47                        Raw Amber            48.0
# 20                    Raw Celestine            18.0
# 29                   Red Moko Grass            45.0
# 14                   Seventh Heaven            24.0
# 37                       Silver Ore            24.0
# 32                       Sphalerite            60.0
# 50                        Terebinth            24.0
# 45                     Titanium Ore           330.0
# 31                        Vivianite            90.0
# 17                    Water Cluster            24.0
# 54                    Water Crystal            48.0
# 49                      Water Shard           192.0
# 12                     Wind Cluster            87.0
# 7                      Wind Crystal           444.0
# 51                      Wyvern Wing            36.0
#
#                                         Location Info
# 0        Azys Lla ( 23.2 / 5.8 ), Timed at 12AM/PM ET
# 52  Northern Thanalan ( 24 / 21 ), Dropped by vari...
# 2   The Churning Mists ( 11.3 / 31.8 ), Dropped by...
# 39       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 21       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 15  Coerthas Western Highlands ( 37.2 / 16.4 ), Ti...
# 5                   The Sea of Clouds ( 34.8 / 30.5 )
# 16  The Dravanian Hinterlands ( 4.7 / 27.8 ), Drop...
# 8               The Sea of Clouds ( 24 / 34 ), Hidden
# 40                       South Shroud ( 28.7 / 22.8 )
# 9   Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 10  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 38  Nowhere ( 0.0 / 0.0 ), Gathered by Company Wor...
# 44                 The Churning Mists ( 27.6 / 19.2 )
# 23                  Northern Thanalan ( 23.1 / 24.2 )
# 33       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 3             The Dravanian Forelands ( 26.6 / 27.1 )
# 1   Coerthas Central Highlands ( 27.5 / 20.0 ), Ti...
# 19  Nowhere ( 0.0 / 0.0 ), Aetherial Reduction fro...
# 53  The Sea of Clouds ( 17.3 / 32.2 ), Dropped by ...
# 34                                                NaN
# 4                                                 NaN
# 22                                                NaN
# 28                                                NaN
# 26                                                NaN
# 48                       South Shroud ( 17.6 / 28.6 )
# 6   Eastern Thanalan ( 27.3 / 21.3 ), Timed at 10:...
# 46  Nowhere ( 0.0 / 0.0 ), Purchased from Z'ranmai...
# 11       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 35              The Dravanian Forelands ( 25.3 / 25 )
# 36                 The Churning Mists ( 15.9 / 28.5 )
# 13                                                NaN
# 27                                                NaN
# 25   Nowhere ( 0.0 / 0.0 ), Sold by Material Supplier
# 24                   Western Thanalan ( 27.2 / 17.4 )
# 18                                                NaN
# 43                  Southern Thanalan ( 25.2 / 39.9 )
# 41         Coerthas Western Highlands ( 31.2 / 12.8 )
# 42         Coerthas Western Highlands ( 16.6 / 13.1 )
# 30       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 47                   Eastern Thanalan ( 12.7 / 19.1 )
# 20  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 29  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 14  The Churning Mists ( 16.7 / 36.8 ), Timed at 4...
# 37                       South Shroud ( 16.1 / 19.7 )
# 32     Nowhere ( 0.0 / 0.0 ), Sold by NPCs for Scrips
# 50      Nowhere ( 0.0 / 0.0 ), Sold by Main City NPCs
# 45            The Dravanian Forelands ( 30.3 / 15.1 )
# 31  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 17                                                NaN
# 54                                                NaN
# 49                                                NaN
# 12                                                NaN
# 7                                                 NaN
# 51  The Churning Mists ( 24 / 28 ), Dropped by var...

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import get_crafting_recipes
data_dir = 'item_data/'
df_crafting_recipes = get_crafting_recipes(os.path.join(data_dir, 'total_viltgance_type_airship_parts.csv'))
df_crafting_recipes
# Out:
#                          Product  Required Quantity  \
# 0              Adamantite Nugget                 24
# 1             Amphiptere Leather                 12
# 2             Aurum Regis Nugget                 24
# 3                   Birch Lumber                 12
# 4                   Cassia Block                 12
# 5                      Celestine                  6
# 6             Cobalt Joint Plate                 12
# 7                   Cobalt Nails                 12
# 8                  Cobalt Rivets                 48
# 9           Dark Chestnut Lumber                 12
# 10              Darksteel Rivets                 66
# 11               Farreach Canvas                 15
# 12      Galvanized Garlond Steel                 30
# 13              Hardsilver Ingot                 24
# 14  High Allagan Chimera Leather                 18
# 15                Mythrite Ingot                 30
# 16               Mythrite Nugget                 12
# 17                Titanium Ingot                 60
# 18               Titanium Nugget                  6
# 19                       Varnish                 24
# 20                     Wing Glue                 12
#
#                                   2  3                  4  5  \
# 0                    Adamantite Ore  5      Darksteel Ore  1
# 1                   Amphiptere Skin  3  Dark Chestnut Log  1
# 2                  Aurum Regis Sand  5           Gold Ore  1
# 3                         Birch Log  5       Wind Crystal  5
# 4                     Cassia Lumber  1         Astral Oil  1
# 5                     Raw Celestine  3  Aqueous Whetstone  9
# 6                      Cobalt Ingot  1          Ice Shard  5
# 7                      Cobalt Ingot  1         Fire Shard  5
# 8                      Cobalt Ingot  1         Fire Shard  5
# 9                 Dark Chestnut Log  5       Wind Crystal  4
# 10                 Darksteel Nugget  1       Fire Crystal  3
# 11                   Red Moko Grass  3             Potash  9
# 12                        Vivianite  3         Sphalerite  2
# 13                   Hardsilver Ore  4  Hardsilver Nugget  1
# 14  Chemically Treated Chimera Hide  3         Animal Fat  9
# 15                     Mythrite Ore  4    Mythrite Nugget  1
# 16                    Mythrite Sand  5        Mythril Ore  1
# 17                       Cloud Mica  4    Titanium Nugget  1
# 18                     Titanium Ore  5           Iron Ore  1
# 19                        Raw Amber  2        Linseed Oil  1
# 20                      Wyvern Wing  3       Ahriman Wing  2
#
#                        6    7              8    9            10   11  \
# 0                   None  NaN           None  NaN          None  NaN
# 1          Earth Crystal  5.0           None  NaN          None  NaN
# 2           Wind Crystal  5.0           None  NaN          None  NaN
# 3                   None  NaN           None  NaN          None  NaN
# 4   Dawnborne Aethersand  1.0   Wind Cluster  2.0   Ice Cluster  1.0
# 5           Wind Cluster  1.0   Fire Cluster  1.0          None  NaN
# 6                   None  NaN           None  NaN          None  NaN
# 7                   None  NaN           None  NaN          None  NaN
# 8                   None  NaN           None  NaN          None  NaN
# 9                   None  NaN           None  NaN          None  NaN
# 10                  None  NaN           None  NaN          None  NaN
# 11     Lightning Cluster  1.0   Wind Cluster  1.0          None  NaN
# 12            Cobalt Ore  2.0           Coke  9.0  Fire Cluster  2.0
# 13          Wind Crystal  5.0           None  NaN          None  NaN
# 14          Black Alumen  3.0  Earth Cluster  1.0  Wind Cluster  1.0
# 15          Fire Crystal  3.0           None  NaN          None  NaN
# 16          Fire Crystal  3.0           None  NaN          None  NaN
# 17          Fire Crystal  5.0           None  NaN          None  NaN
# 18           Grenade Ash  1.0   Fire Crystal  4.0          None  NaN
# 19             Terebinth  1.0    Water Shard  5.0          None  NaN
# 20        Dhalmel Saliva  2.0  Water Crystal  4.0          None  NaN
#
#                12   13
# 0            None  NaN
# 1            None  NaN
# 2            None  NaN
# 3            None  NaN
# 4            None  NaN
# 5            None  NaN
# 6            None  NaN
# 7            None  NaN
# 8            None  NaN
# 9            None  NaN
# 10           None  NaN
# 11           None  NaN
# 12  Earth Cluster  2.0
# 13           None  NaN
# 14           None  NaN
# 15           None  NaN
# 16           None  NaN
# 17           None  NaN
# 18           None  NaN
# 19           None  NaN
# 20           None  NaN

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import fetch_market_data_for_subparts
utils_dir = '../../utilities/'
data_dir = 'item_data/'
df_market_data = fetch_market_data_for_subparts(
    gathering_csv=os.path.join(data_dir, 'gathering_list.csv'),
    crafting_csv=os.path.join(utils_dir, 'recipe_book.csv'),
    item_ids_json=os.path.join(utils_dir, 'item_ids.json'),
    output_csv=os.path.join(data_dir, 'airship_parts_market_data.csv'),
    world="Seraph"
)
df_market_data
# Out:
#                         Item Name   Category Item ID minListing_world  \
# 0                  Adamantite Ore  Gathering   12538              119
# 1                    Ahriman Wing  Gathering    5553              897
# 2                 Amphiptere Skin  Gathering   12572              950
# 3                      Animal Fat  Gathering    5531              149
# 4               Aqueous Whetstone  Gathering    5261              441
# ..                            ...        ...     ...              ...
# 154                  Cobalt Nails   Crafting    7020              250
# 155                  Cobalt Rings   Crafting    5084               37
# 156               Dhalmel Leather   Crafting   12564             5000
# 157  High Allagan Chimera Leather   Crafting   12233             1495
# 158            Amphiptere Leather   Crafting   12566              275
#
#     minListing_dc recentPurchase_world recentPurchase_dc averageSalePrice_dc  \
# 0             119                  200               498          238.975917
# 1              89                  800               400          474.615385
# 2             100                  325               648          631.886792
# 3             149                  147               147          216.653614
# 4             274                  449               350          285.684545
# ..            ...                  ...               ...                 ...
# 154            20                   90               800                None
# 155            37                  155               730          469.888889
# 156          2999                 4123              3000         2780.477273
# 157           493                 2000              1000          713.727273
# 158            50                  323               500          328.926471
#
#     dailySaleVelocity_dc
# 0             475.552288
# 1              57.524258
# 2             151.749185
# 3              86.416152
# 4            2576.861518
# ..                   ...
# 154                 None
# 155             4.683662
# 156            57.244626
# 157             2.862225
# 158            17.693714
#
# [156 rows x 9 columns]
