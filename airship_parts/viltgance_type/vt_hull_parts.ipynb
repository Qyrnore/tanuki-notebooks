# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import generate_gathering_list
utils_dir = '../../utilities/'
data_dir = 'item_data/'
df_gathering_list = generate_gathering_list(
    total_csv=os.path.join(data_dir, 'viltgance_type_hull_parts.csv'),
    recipe_book_csv=os.path.join(utils_dir, 'recipe_book.csv'),
    recipe_gathering_csv=os.path.join(utils_dir, 'recipe_gathering.csv'),
    output_csv=os.path.join(data_dir, 'gathering_list.csv')
)
df_gathering_list
# Out:
#                          Ingredient  Total Quantity  \
# 23                   Adamantite Ore            30.0
# 29                     Ahriman Wing            24.0
# 37                       Animal Fat            81.0
# 18                   Astral Moraine             6.0
# 19                         Bear Fat             3.0
# 2                         Birch Log            60.0
# 38                     Black Alumen            27.0
# 13                       Cassia Log             9.0
# 12                       Cassia Log             9.0
# 36  Chemically Treated Chimera Hide            27.0
# 33                       Cloud Mica            48.0
# 3                        Cobalt Ore            36.0
# 9                              Coke            54.0
# 0                 Dark Chestnut Log            60.0
# 24                    Darksteel Ore            78.0
# 22             Dawnborne Aethersand             3.0
# 30                   Dhalmel Saliva            24.0
# 11                    Earth Cluster            21.0
# 10                     Fire Cluster            12.0
# 32                     Fire Crystal           252.0
# 6                        Fire Shard           120.0
# 40                             Flax            48.0
# 35                      Grenade Ash            12.0
# 14                     Hardened Sap            27.0
# 25                   Hardsilver Ore            48.0
# 26                  Hardsilver Sand            60.0
# 16                      Ice Cluster             6.0
# 5                          Iron Ore            24.0
# 4                          Iron Ore            24.0
# 21                Lightning Cluster             3.0
# 39                        Raw Amber            48.0
# 17                   Seventh Heaven             6.0
# 27                       Silver Ore            12.0
# 8                        Sphalerite            12.0
# 42                        Terebinth            24.0
# 34                     Titanium Ore            60.0
# 7                         Vivianite            18.0
# 20                    Water Cluster             6.0
# 31                    Water Crystal            48.0
# 41                      Water Shard           192.0
# 15                     Wind Cluster            21.0
# 1                      Wind Crystal           216.0
# 28                      Wyvern Wing            36.0
#
#                                         Location Info
# 23       Azys Lla ( 23.2 / 5.8 ), Timed at 12AM/PM ET
# 29  Northern Thanalan ( 24 / 21 ), Dropped by vari...
# 37       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 18  Coerthas Western Highlands ( 37.2 / 16.4 ), Ti...
# 19  The Dravanian Hinterlands ( 4.7 / 27.8 ), Drop...
# 2               The Sea of Clouds ( 24 / 34 ), Hidden
# 38                       South Shroud ( 28.7 / 22.8 )
# 13  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 12  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 36  Nowhere ( 0.0 / 0.0 ), Gathered by Company Wor...
# 33                 The Churning Mists ( 27.6 / 19.2 )
# 3                   Northern Thanalan ( 23.1 / 24.2 )
# 9        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 0             The Dravanian Forelands ( 26.6 / 27.1 )
# 24  Coerthas Central Highlands ( 27.5 / 20.0 ), Ti...
# 22  Nowhere ( 0.0 / 0.0 ), Aetherial Reduction fro...
# 30  The Sea of Clouds ( 17.3 / 32.2 ), Dropped by ...
# 11                                                NaN
# 10                                                NaN
# 32                                                NaN
# 6                                                 NaN
# 40                       South Shroud ( 17.6 / 28.6 )
# 35  Nowhere ( 0.0 / 0.0 ), Purchased from Z'ranmai...
# 14       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 25              The Dravanian Forelands ( 25.3 / 25 )
# 26                 The Churning Mists ( 15.9 / 28.5 )
# 16                                                NaN
# 5    Nowhere ( 0.0 / 0.0 ), Sold by Material Supplier
# 4                    Western Thanalan ( 27.2 / 17.4 )
# 21                                                NaN
# 39                   Eastern Thanalan ( 12.7 / 19.1 )
# 17  The Churning Mists ( 16.7 / 36.8 ), Timed at 4...
# 27                       South Shroud ( 16.1 / 19.7 )
# 8      Nowhere ( 0.0 / 0.0 ), Sold by NPCs for Scrips
# 42      Nowhere ( 0.0 / 0.0 ), Sold by Main City NPCs
# 34            The Dravanian Forelands ( 30.3 / 15.1 )
# 7   Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 20                                                NaN
# 31                                                NaN
# 41                                                NaN
# 15                                                NaN
# 1                                                 NaN
# 28  The Churning Mists ( 24 / 28 ), Dropped by var...

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import get_crafting_recipes
data_dir = 'item_data/'
df_crafting_recipes = get_crafting_recipes(os.path.join(data_dir, 'viltgance_type_hull_parts.csv'))
df_crafting_recipes
# Out:
#                          Product  Required Quantity
# 5              Adamantite Nugget                  6
# 1                   Birch Lumber                 12
# 4                   Cassia Block                  3
# 2                   Cobalt Nails                 12
# 0           Dark Chestnut Lumber                 12
# 8               Darksteel Rivets                 24
# 3       Galvanized Garlond Steel                  6
# 6               Hardsilver Ingot                 12
# 10  High Allagan Chimera Leather                  9
# 9                 Titanium Ingot                 12
# 11                       Varnish                 24
# 7                      Wing Glue                 12
