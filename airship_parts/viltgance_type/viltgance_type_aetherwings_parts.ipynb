# %%
from viltgance_type_airship_parts import generate_gathering_list

# Generate the gathering list and save to 'gathering_list.csv'
df_gathering_list = generate_gathering_list(
    total_csv='viltgance_type_aetherwings_parts.csv',
    recipe_book_csv='recipe_book.csv',
    recipe_gathering_csv='recipe_gathering.csv',
    output_csv='gathering_list.csv'
)

df_gathering_list  # Display the gathering list
# Out:
#               Ingredient  Total Quantity  \
# 23        Adamantite Ore            30.0
# 29       Amphiptere Skin            36.0
# 6         Astral Moraine             6.0
# 7               Bear Fat             3.0
# 0             Cassia Log             9.0
# 1             Cassia Log             9.0
# 26            Cloud Mica            48.0
# 16            Cobalt Ore            72.0
# 17                  Coke           108.0
# 30     Dark Chestnut Log            12.0
# 24         Darksteel Ore            24.0
# 10  Dawnborne Aethersand             3.0
# 19         Earth Cluster            24.0
# 31         Earth Crystal            60.0
# 18          Fire Cluster            24.0
# 13          Fire Crystal           216.0
# 22            Fire Shard           240.0
# 28           Grenade Ash            12.0
# 2           Hardened Sap            27.0
# 4            Ice Cluster             6.0
# 21              Iron Ore            36.0
# 20              Iron Ore            36.0
# 9      Lightning Cluster             9.0
# 12           Mythril Ore            18.0
# 25          Mythrite Ore            24.0
# 11         Mythrite Sand            90.0
# 33                Potash            54.0
# 32        Red Moko Grass            18.0
# 5         Seventh Heaven             6.0
# 15            Sphalerite            24.0
# 27          Titanium Ore            60.0
# 14             Vivianite            36.0
# 8          Water Cluster             6.0
# 3           Wind Cluster            18.0
#
#                                         Location Info
# 23       Azys Lla ( 23.2 / 5.8 ), Timed at 12AM/PM ET
# 29  The Churning Mists ( 11.3 / 31.8 ), Dropped by...
# 6   Coerthas Western Highlands ( 37.2 / 16.4 ), Ti...
# 7   The Dravanian Hinterlands ( 4.7 / 27.8 ), Drop...
# 0   Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 1   Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 26                 The Churning Mists ( 27.6 / 19.2 )
# 16                  Northern Thanalan ( 23.1 / 24.2 )
# 17       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 30            The Dravanian Forelands ( 26.6 / 27.1 )
# 24  Coerthas Central Highlands ( 27.5 / 20.0 ), Ti...
# 10  Nowhere ( 0.0 / 0.0 ), Aetherial Reduction fro...
# 19                                                NaN
# 31                                                NaN
# 18                                                NaN
# 13                                                NaN
# 22                                                NaN
# 28  Nowhere ( 0.0 / 0.0 ), Purchased from Z'ranmai...
# 2        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 4                                                 NaN
# 21   Nowhere ( 0.0 / 0.0 ), Sold by Material Supplier
# 20                   Western Thanalan ( 27.2 / 17.4 )
# 9                                                 NaN
# 12                  Southern Thanalan ( 25.2 / 39.9 )
# 25         Coerthas Western Highlands ( 31.2 / 12.8 )
# 11         Coerthas Western Highlands ( 16.6 / 13.1 )
# 33       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 32  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 5   The Churning Mists ( 16.7 / 36.8 ), Timed at 4...
# 15     Nowhere ( 0.0 / 0.0 ), Sold by NPCs for Scrips
# 27            The Dravanian Forelands ( 30.3 / 15.1 )
# 14  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 8                                                 NaN
# 3                                                 NaN

# %%
from viltgance_type_airship_parts import get_crafting_recipes

# Get the crafting recipes from total_viltgance_type_airship_parts.csv
df_crafting_recipes = get_crafting_recipes('viltgance_type_aetherwings_parts.csv')
df_crafting_recipes  # Display the crafting recipes list
# Out:
#                     Product  Required Quantity
# 4         Adamantite Nugget                  6
# 8        Amphiptere Leather                 12
# 0              Cassia Block                  3
# 3             Cobalt Rivets                 24
# 5          Darksteel Rivets                  6
# 9           Farreach Canvas                  6
# 2  Galvanized Garlond Steel                 12
# 6            Mythrite Ingot                  6
# 1           Mythrite Nugget                 12
# 7            Titanium Ingot                 12
