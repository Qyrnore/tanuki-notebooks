# %%
from viltgance_type_airship_parts import generate_gathering_list

# Generate the gathering list and save to 'gathering_list.csv'
df_gathering_list = generate_gathering_list(
    total_csv='viltgance_type_aftcastle_parts.csv',
    recipe_book_csv='recipe_book.csv',
    recipe_gathering_csv='recipe_gathering.csv',
    output_csv='gathering_list.csv'
)

df_gathering_list  # Display the gathering list
# Out:
#                          Ingredient  Total Quantity  \
# 4                    Adamantite Ore            30.0
# 34                       Animal Fat            81.0
# 25                   Astral Moraine             6.0
# 30                 Aurum Regis Sand            60.0
# 26                         Bear Fat             3.0
# 35                     Black Alumen            27.0
# 20                       Cassia Log             9.0
# 19                       Cassia Log             9.0
# 33  Chemically Treated Chimera Hide            27.0
# 6                        Cloud Mica            96.0
# 0                        Cobalt Ore            60.0
# 12                             Coke            54.0
# 5                     Darksteel Ore            42.0
# 29             Dawnborne Aethersand             3.0
# 14                    Earth Cluster            21.0
# 13                     Fire Cluster            12.0
# 9                      Fire Crystal           360.0
# 3                        Fire Shard           180.0
# 31                         Gold Ore            12.0
# 8                       Grenade Ash            24.0
# 21                     Hardened Sap            27.0
# 23                      Ice Cluster             6.0
# 15                        Ice Shard            60.0
# 2                          Iron Ore            48.0
# 1                          Iron Ore            48.0
# 28                Lightning Cluster            12.0
# 18                      Mythril Ore            12.0
# 16                     Mythrite Ore            48.0
# 17                    Mythrite Sand            60.0
# 37                           Potash            81.0
# 36                   Red Moko Grass            27.0
# 24                   Seventh Heaven             6.0
# 11                       Sphalerite            12.0
# 7                      Titanium Ore           120.0
# 10                        Vivianite            18.0
# 27                    Water Cluster             6.0
# 22                     Wind Cluster            30.0
# 32                     Wind Crystal            60.0
#
#                                         Location Info
# 4        Azys Lla ( 23.2 / 5.8 ), Timed at 12AM/PM ET
# 34       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 25  Coerthas Western Highlands ( 37.2 / 16.4 ), Ti...
# 30                  The Sea of Clouds ( 34.8 / 30.5 )
# 26  The Dravanian Hinterlands ( 4.7 / 27.8 ), Drop...
# 35                       South Shroud ( 28.7 / 22.8 )
# 20  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 19  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 33  Nowhere ( 0.0 / 0.0 ), Gathered by Company Wor...
# 6                  The Churning Mists ( 27.6 / 19.2 )
# 0                   Northern Thanalan ( 23.1 / 24.2 )
# 12       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 5   Coerthas Central Highlands ( 27.5 / 20.0 ), Ti...
# 29  Nowhere ( 0.0 / 0.0 ), Aetherial Reduction fro...
# 14                                                NaN
# 13                                                NaN
# 9                                                 NaN
# 3                                                 NaN
# 31  Eastern Thanalan ( 27.3 / 21.3 ), Timed at 10:...
# 8   Nowhere ( 0.0 / 0.0 ), Purchased from Z'ranmai...
# 21       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 23                                                NaN
# 15                                                NaN
# 2    Nowhere ( 0.0 / 0.0 ), Sold by Material Supplier
# 1                    Western Thanalan ( 27.2 / 17.4 )
# 28                                                NaN
# 18                  Southern Thanalan ( 25.2 / 39.9 )
# 16         Coerthas Western Highlands ( 31.2 / 12.8 )
# 17         Coerthas Western Highlands ( 16.6 / 13.1 )
# 37       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 36  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 24  The Churning Mists ( 16.7 / 36.8 ), Timed at 4...
# 11     Nowhere ( 0.0 / 0.0 ), Sold by NPCs for Scrips
# 7             The Dravanian Forelands ( 30.3 / 15.1 )
# 10  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 27                                                NaN
# 22                                                NaN
# 32                                                NaN

# %%
from viltgance_type_airship_parts import get_crafting_recipes

# Get the crafting recipes from total_viltgance_type_airship_parts.csv
df_crafting_recipes = get_crafting_recipes('viltgance_type_aftcastle_parts.csv')
df_crafting_recipes  # Display the crafting recipes list
# Out:
#                          Product  Required Quantity
# 1              Adamantite Nugget                  6
# 8             Aurum Regis Nugget                 12
# 7                   Cassia Block                  3
# 5             Cobalt Joint Plate                 12
# 0                  Cobalt Rivets                 12
# 4               Darksteel Rivets                 12
# 10               Farreach Canvas                  9
# 3       Galvanized Garlond Steel                  6
# 9   High Allagan Chimera Leather                  9
# 6                 Mythrite Ingot                 12
# 2                 Titanium Ingot                 24
