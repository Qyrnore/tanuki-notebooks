# %%
from viltgance_type_airship_parts import generate_gathering_list

# Generate the gathering list and save to 'gathering_list.csv'
df_gathering_list = generate_gathering_list(
    total_csv='viltgance_type_forecastle_parts.csv',
    recipe_book_csv='recipe_book.csv',
    recipe_gathering_csv='recipe_gathering.csv',
    output_csv='gathering_list.csv'
)

df_gathering_list  # Display the gathering list
# Out:
#               Ingredient  Total Quantity  \
# 4         Adamantite Ore            30.0
# 33     Aqueous Whetstone            54.0
# 27        Astral Moraine             6.0
# 18      Aurum Regis Sand            60.0
# 28              Bear Fat             3.0
# 22            Cassia Log             9.0
# 21            Cassia Log             9.0
# 15            Cloud Mica            48.0
# 0             Cobalt Ore            36.0
# 12                  Coke            54.0
# 5          Darksteel Ore            78.0
# 31  Dawnborne Aethersand             3.0
# 14         Earth Cluster            12.0
# 13          Fire Cluster            18.0
# 9           Fire Crystal           348.0
# 3             Fire Shard           120.0
# 19              Gold Ore            12.0
# 17           Grenade Ash            18.0
# 23          Hardened Sap            27.0
# 34        Hardsilver Ore            48.0
# 35       Hardsilver Sand            60.0
# 25           Ice Cluster             6.0
# 1               Iron Ore            30.0
# 2               Iron Ore            30.0
# 30     Lightning Cluster             3.0
# 8            Mythril Ore            12.0
# 6           Mythrite Ore            48.0
# 7          Mythrite Sand            60.0
# 32         Raw Celestine            18.0
# 26        Seventh Heaven             6.0
# 36            Silver Ore            12.0
# 11            Sphalerite            12.0
# 16          Titanium Ore            90.0
# 10             Vivianite            18.0
# 29         Water Cluster             6.0
# 24          Wind Cluster            18.0
# 20          Wind Crystal           168.0
#
#                                         Location Info
# 4        Azys Lla ( 23.2 / 5.8 ), Timed at 12AM/PM ET
# 33       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 27  Coerthas Western Highlands ( 37.2 / 16.4 ), Ti...
# 18                  The Sea of Clouds ( 34.8 / 30.5 )
# 28  The Dravanian Hinterlands ( 4.7 / 27.8 ), Drop...
# 22  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 21  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 15                 The Churning Mists ( 27.6 / 19.2 )
# 0                   Northern Thanalan ( 23.1 / 24.2 )
# 12       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 5   Coerthas Central Highlands ( 27.5 / 20.0 ), Ti...
# 31  Nowhere ( 0.0 / 0.0 ), Aetherial Reduction fro...
# 14                                                NaN
# 13                                                NaN
# 9                                                 NaN
# 3                                                 NaN
# 19  Eastern Thanalan ( 27.3 / 21.3 ), Timed at 10:...
# 17  Nowhere ( 0.0 / 0.0 ), Purchased from Z'ranmai...
# 23       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 34              The Dravanian Forelands ( 25.3 / 25 )
# 35                 The Churning Mists ( 15.9 / 28.5 )
# 25                                                NaN
# 1                    Western Thanalan ( 27.2 / 17.4 )
# 2    Nowhere ( 0.0 / 0.0 ), Sold by Material Supplier
# 30                                                NaN
# 8                   Southern Thanalan ( 25.2 / 39.9 )
# 6          Coerthas Western Highlands ( 31.2 / 12.8 )
# 7          Coerthas Western Highlands ( 16.6 / 13.1 )
# 32  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 26  The Churning Mists ( 16.7 / 36.8 ), Timed at 4...
# 36                       South Shroud ( 16.1 / 19.7 )
# 11     Nowhere ( 0.0 / 0.0 ), Sold by NPCs for Scrips
# 16            The Dravanian Forelands ( 30.3 / 15.1 )
# 10  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 29                                                NaN
# 24                                                NaN
# 20                                                NaN

# %%
from viltgance_type_airship_parts import get_crafting_recipes

# Get the crafting recipes from total_viltgance_type_airship_parts.csv
df_crafting_recipes = get_crafting_recipes('viltgance_type_forecastle_parts.csv')
df_crafting_recipes  # Display the crafting recipes list
# Out:
#                      Product  Required Quantity
# 1          Adamantite Nugget                  6
# 7         Aurum Regis Nugget                 12
# 8               Cassia Block                  3
# 9                  Celestine                  6
# 0              Cobalt Rivets                 12
# 4           Darksteel Rivets                 24
# 3   Galvanized Garlond Steel                  6
# 10          Hardsilver Ingot                 12
# 2             Mythrite Ingot                 12
# 5             Titanium Ingot                 12
# 6            Titanium Nugget                  6
