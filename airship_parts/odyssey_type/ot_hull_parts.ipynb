# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import generate_gathering_list
utils_dir = '../../utilities/'
data_dir = 'item_data/'
df_gathering_list = generate_gathering_list(
    total_csv=os.path.join(data_dir, 'odyssey_type_hull_parts.csv'),
    recipe_book_csv=os.path.join(utils_dir, 'recipe_book.csv'),
    recipe_gathering_csv=os.path.join(utils_dir, 'recipe_gathering.csv'),
    output_csv=os.path.join(data_dir, 'gathering_list.csv')
)
df_gathering_list
# Out:
#                          Ingredient  Total Quantity  \
# 35                     Ahriman Wing            18.0
# 25                       Animal Fat            81.0
# 26                     Black Alumen            27.0
# 24  Chemically Treated Chimera Hide            27.0
# 6                        Cobalt Ore            75.0
# 11                             Coke            81.0
# 16                       Copper Ore            48.0
# 14                Dark Chestnut Log            60.0
# 18                    Darksteel Ore           207.0
# 36                   Dhalmel Saliva            18.0
# 13                    Earth Cluster            18.0
# 12                     Fire Cluster             9.0
# 19                     Fire Crystal           414.0
# 9                        Fire Shard           288.0
# 31                             Flax            48.0
# 5                       Ice Cluster            24.0
# 20                      Ice Crystal            72.0
# 8                          Iron Ore            24.0
# 7                          Iron Ore            24.0
# 29                Lightning Cluster             9.0
# 23                      Mythril Ore            24.0
# 21                     Mythrite Ore            96.0
# 22                    Mythrite Sand           120.0
# 2                     Petrified Log            24.0
# 28                           Potash            81.0
# 30                        Raw Amber            48.0
# 27                   Red Moko Grass            27.0
# 0                      Rosewood Log            72.0
# 3                       Scarlet Sap            24.0
# 33                        Terebinth            24.0
# 17                          Tin Ore            24.0
# 10                        Vivianite            27.0
# 37                    Water Crystal            36.0
# 32                      Water Shard           192.0
# 4                      Wind Cluster            66.0
# 15                     Wind Crystal            48.0
# 1                        Wind Shard           144.0
# 34                      Wyvern Wing            27.0
#
#                                         Location Info
# 35  Northern Thanalan ( 24 / 21 ), Dropped by vari...
# 25       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 26                       South Shroud ( 28.7 / 22.8 )
# 24  Nowhere ( 0.0 / 0.0 ), Gathered by Company Wor...
# 6                   Northern Thanalan ( 23.1 / 24.2 )
# 11       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 16                   Central Thanalan ( 19.0 / 26.2 )
# 14            The Dravanian Forelands ( 26.6 / 27.1 )
# 18  Coerthas Central Highlands ( 27.5 / 20.0 ), Ti...
# 36  The Sea of Clouds ( 17.3 / 32.2 ), Dropped by ...
# 13                                                NaN
# 12                                                NaN
# 19                                                NaN
# 9                                                 NaN
# 31                       South Shroud ( 17.6 / 28.6 )
# 5                                                 NaN
# 20                                                NaN
# 8    Nowhere ( 0.0 / 0.0 ), Sold by Material Supplier
# 7                    Western Thanalan ( 27.2 / 17.4 )
# 29                                                NaN
# 23                  Southern Thanalan ( 25.2 / 39.9 )
# 21         Coerthas Western Highlands ( 31.2 / 12.8 )
# 22         Coerthas Western Highlands ( 16.6 / 13.1 )
# 2       Nowhere ( 0.0 / 0.0 ), Sold for 1500 GC Seals
# 28       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 30                   Eastern Thanalan ( 12.7 / 19.1 )
# 27  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 0                         East Shroud ( 16.7 / 23.3 )
# 3       North Shroud ( 17.7 / 27.7 ), Timed at 1:00am
# 33      Nowhere ( 0.0 / 0.0 ), Sold by Main City NPCs
# 17                   Central Thanalan ( 19.9 / 22.2 )
# 10  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 37                                                NaN
# 32                                                NaN
# 4                                                 NaN
# 15                                                NaN
# 1                                                 NaN
# 34  The Churning Mists ( 24 / 28 ), Dropped by var...

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import get_crafting_recipes
data_dir = 'item_data/'
df_crafting_recipes = get_crafting_recipes(os.path.join(data_dir, 'odyssey_type_hull_parts.csv'))
df_crafting_recipes
# Out:
#                          Product  Required Quantity
# 1                 Ancient Lumber                 24
# 5                  Bronze Rivets                 24
# 2                   Cobalt Nails                 24
# 4           Dark Chestnut Lumber                 12
# 6                Darksteel Plate                 24
# 8               Darksteel Rivets                 21
# 10               Farreach Canvas                  9
# 3                  Garlond Steel                  9
# 9   High Allagan Chimera Leather                  9
# 7                 Mythrite Ingot                 24
# 0                Rosewood Lumber                 24
# 11                       Varnish                 24
# 12                     Wing Glue                  9
