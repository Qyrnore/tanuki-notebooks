# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import generate_gathering_list
utils_dir = '../../utilities/'
data_dir = 'item_data/'
df_gathering_list = generate_gathering_list(
    total_csv=os.path.join(data_dir, 'odyssey_type_forecastle_parts.csv'),
    recipe_book_csv=os.path.join(utils_dir, 'recipe_book.csv'),
    recipe_gathering_csv=os.path.join(utils_dir, 'recipe_gathering.csv'),
    output_csv=os.path.join(data_dir, 'gathering_list.csv')
)
df_gathering_list
# Out:
#            Ingredient  Total Quantity  \
# 17  Aqueous Whetstone            81.0
# 0            Bomb Ash            30.0
# 8          Cobalt Ore           279.0
# 6                Coke           432.0
# 4       Darksteel Ore           342.0
# 11      Earth Cluster             9.0
# 7        Fire Cluster            57.0
# 5        Fire Crystal           450.0
# 3          Fire Shard          1020.0
# 19    Hardsilver Sand            75.0
# 15        Ice Crystal            54.0
# 9           Ice Shard           390.0
# 1            Iron Ore           186.0
# 2            Iron Ore           186.0
# 14        Mythril Ore            18.0
# 12       Mythrite Ore            72.0
# 13      Mythrite Sand            90.0
# 16      Raw Celestine            27.0
# 20         Silver Ore            15.0
# 10          Vivianite            27.0
# 18       Wind Cluster             9.0
# 21       Wind Crystal            60.0
#
#                                         Location Info
# 17       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 0                   Southern Thanalan ( 22.2 / 29.9 )
# 8                   Northern Thanalan ( 23.1 / 24.2 )
# 6        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 4   Coerthas Central Highlands ( 27.5 / 20.0 ), Ti...
# 11                                                NaN
# 7                                                 NaN
# 5                                                 NaN
# 3                                                 NaN
# 19                 The Churning Mists ( 15.9 / 28.5 )
# 15                                                NaN
# 9                                                 NaN
# 1                    Western Thanalan ( 27.2 / 17.4 )
# 2    Nowhere ( 0.0 / 0.0 ), Sold by Material Supplier
# 14                  Southern Thanalan ( 25.2 / 39.9 )
# 12         Coerthas Western Highlands ( 31.2 / 12.8 )
# 13         Coerthas Western Highlands ( 16.6 / 13.1 )
# 16  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 20                       South Shroud ( 16.1 / 19.7 )
# 10  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 18                                                NaN
# 21                                                NaN

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import get_crafting_recipes
data_dir = 'item_data/'
df_crafting_recipes = get_crafting_recipes(os.path.join(data_dir, 'odyssey_type_forecastle_parts.csv'))
df_crafting_recipes
# Out:
#               Product  Required Quantity
# 8           Celestine                  9
# 2  Cobalt Joint Plate                 60
# 6        Cobalt Rings                 18
# 4       Cobalt Rivets                 48
# 1     Darksteel Ingot                 39
# 7     Darksteel Plate                 18
# 3       Garlond Steel                  9
# 9   Hardsilver Nugget                 15
# 5      Mythrite Ingot                 18
# 0        Steel Rivets                 30
