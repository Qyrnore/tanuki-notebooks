# %%
from odyssey_type_airship_parts import generate_gathering_list

# Generate the gathering list and save to 'gathering_list.csv'
df_gathering_list = generate_gathering_list(
    total_csv='total_odyssey_type_airship_parts.csv',
    recipe_book_csv='recipe_book.csv',
    recipe_gathering_csv='recipe_gathering.csv',
    output_csv='gathering_list.csv'
)

df_gathering_list  # Display the gathering list
# Out:
#                          Ingredient  Total Quantity  \
# 43                     Ahriman Wing            18.0
# 30                       Animal Fat           162.0
# 8                 Aqueous Whetstone           162.0
# 31                     Black Alumen            54.0
# 37                         Bomb Ash            90.0
# 29  Chemically Treated Chimera Hide            54.0
# 10                       Cobalt Ore           837.0
# 18                             Coke          1053.0
# 4                        Copper Ore            48.0
# 14                Dark Chestnut Log            78.0
# 16                    Darksteel Ore          1107.0
# 20                     Dhalmel Hide            54.0
# 44                   Dhalmel Saliva            18.0
# 26                    Earth Cluster            63.0
# 21                    Earth Crystal            72.0
# 47                        Ferberite             9.0
# 9                      Fire Cluster           153.0
# 17                     Fire Crystal          1656.0
# 6                        Fire Shard          3498.0
# 39                             Flax            48.0
# 27                  Hardsilver Sand           165.0
# 3                       Ice Cluster            36.0
# 19                      Ice Crystal           216.0
# 13                        Ice Shard           690.0
# 12                         Iron Ore           540.0
# 11                         Iron Ore           540.0
# 24                Lightning Cluster            18.0
# 32                      Mythril Ore           240.0
# 33                     Mythrite Ore           240.0
# 34                    Mythrite Sand           300.0
# 0                     Petrified Log            36.0
# 23                           Potash           162.0
# 38                        Raw Amber            48.0
# 7                     Raw Celestine            54.0
# 22                   Red Moko Grass            54.0
# 35                     Rosewood Log            72.0
# 1                       Scarlet Sap            36.0
# 46                        Scheelite             9.0
# 28                       Silver Ore            33.0
# 41                        Terebinth            24.0
# 5                           Tin Ore            24.0
# 25                        Vivianite           108.0
# 45                    Water Crystal            36.0
# 40                      Water Shard           192.0
# 2                      Wind Cluster           126.0
# 15                     Wind Crystal           180.0
# 36                       Wind Shard           144.0
# 42                      Wyvern Wing            27.0
#
#                                         Location Info
# 43  Northern Thanalan ( 24 / 21 ), Dropped by vari...
# 30       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 8        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 31                       South Shroud ( 28.7 / 22.8 )
# 37                  Southern Thanalan ( 22.2 / 29.9 )
# 29  Nowhere ( 0.0 / 0.0 ), Gathered by Company Wor...
# 10                  Northern Thanalan ( 23.1 / 24.2 )
# 18       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 4                    Central Thanalan ( 19.0 / 26.2 )
# 14            The Dravanian Forelands ( 26.6 / 27.1 )
# 16  Coerthas Central Highlands ( 27.5 / 20.0 ), Ti...
# 20  The Sea of Clouds ( 17.3 / 32.2 ), Dropped by ...
# 44  The Sea of Clouds ( 17.3 / 32.2 ), Dropped by ...
# 26                                                NaN
# 21                                                NaN
# 47  Northern Thanalan ( 17.3 / 19.9 ), Timed at 3:...
# 9                                                 NaN
# 17                                                NaN
# 6                                                 NaN
# 39                       South Shroud ( 17.6 / 28.6 )
# 27                 The Churning Mists ( 15.9 / 28.5 )
# 3                                                 NaN
# 19                                                NaN
# 13                                                NaN
# 12   Nowhere ( 0.0 / 0.0 ), Sold by Material Supplier
# 11                   Western Thanalan ( 27.2 / 17.4 )
# 24                                                NaN
# 32                  Southern Thanalan ( 25.2 / 39.9 )
# 33         Coerthas Western Highlands ( 31.2 / 12.8 )
# 34         Coerthas Western Highlands ( 16.6 / 13.1 )
# 0       Nowhere ( 0.0 / 0.0 ), Sold for 1500 GC Seals
# 23       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 38                   Eastern Thanalan ( 12.7 / 19.1 )
# 7   Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 22  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 35                        East Shroud ( 16.7 / 23.3 )
# 1       North Shroud ( 17.7 / 27.7 ), Timed at 1:00am
# 46      Nowhere ( 0.0 / 0.0 ), Sold for 1500 GC Seals
# 28                       South Shroud ( 16.1 / 19.7 )
# 41      Nowhere ( 0.0 / 0.0 ), Sold by Main City NPCs
# 5                    Central Thanalan ( 19.9 / 22.2 )
# 25  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 45                                                NaN
# 40                                                NaN
# 2                                                 NaN
# 15                                                NaN
# 36                                                NaN
# 42  The Churning Mists ( 24 / 28 ), Dropped by var...

# %%
from odyssey_type_airship_parts import get_crafting_recipes

# Get the crafting recipes from total_odyssey_type_airship_parts.csv
df_crafting_recipes = get_crafting_recipes('total_odyssey_type_airship_parts.csv')
df_crafting_recipes  # Display the crafting recipes list
# Out:
#                          Product  Required Quantity  \
# 0                 Ancient Lumber                 36
# 1                  Bronze Rivets                 24
# 2                      Celestine                 18
# 3                   Cobalt Ingot                 30
# 4             Cobalt Joint Plate                120
# 5                   Cobalt Nails                 54
# 6                   Cobalt Rings                 18
# 7                  Cobalt Rivets                138
# 8           Dark Chestnut Lumber                 12
# 9                Darksteel Ingot                 81
# 10               Darksteel Plate                 72
# 11              Darksteel Rivets                 63
# 12               Dhalmel Leather                 18
# 13               Farreach Canvas                 18
# 14                 Garlond Steel                 36
# 15             Hardsilver Nugget                 33
# 16  High Allagan Chimera Leather                 18
# 17                 Mythril Ingot                 30
# 18                Mythril Rivets                 30
# 19                Mythrite Ingot                 60
# 20               Rosewood Lumber                 24
# 21                   Steel Ingot                 30
# 22                  Steel Rivets                 60
# 23                       Varnish                 24
# 24                     Wing Glue                  9
# 25                 Wolfram Ingot                  9
#
#                                   2  3                  4  5  \
# 0                     Petrified Log  1        Scarlet Sap  1
# 1                      Bronze Ingot  1         Fire Shard  1
# 2                     Raw Celestine  3  Aqueous Whetstone  9
# 3                        Cobalt Ore  2           Iron Ore  1
# 4                      Cobalt Ingot  1          Ice Shard  5
# 5                      Cobalt Ingot  1         Fire Shard  5
# 6                      Cobalt Ingot  1          Ice Shard  5
# 7                      Cobalt Ingot  1         Fire Shard  5
# 8                 Dark Chestnut Log  5       Wind Crystal  4
# 9                  Darksteel Nugget  2               Coke  9
# 10                 Darksteel Nugget  2        Ice Crystal  3
# 11                 Darksteel Nugget  1       Fire Crystal  3
# 12                     Dhalmel Hide  3  Dark Chestnut Log  1
# 13                   Red Moko Grass  3             Potash  9
# 14                        Vivianite  3               Coke  9
# 15                  Hardsilver Sand  5         Silver Ore  1
# 16  Chemically Treated Chimera Hide  3         Animal Fat  9
# 17                      Mythril Ore  3         Fire Shard  3
# 18                    Mythril Ingot  1         Fire Shard  5
# 19                     Mythrite Ore  4    Mythrite Nugget  1
# 20                     Rosewood Log  3         Wind Shard  6
# 21                         Bomb Ash  1           Iron Ore  2
# 22                      Steel Ingot  1         Fire Shard  3
# 23                        Raw Amber  2        Linseed Oil  1
# 24                      Wyvern Wing  3       Ahriman Wing  2
# 25                        Scheelite  1          Ferberite  1
#
#                     6    7              8    9             10   11
# 0        Wind Cluster  2.0    Ice Cluster  1.0           None  NaN
# 1                None  NaN           None  NaN           None  NaN
# 2        Wind Cluster  1.0   Fire Cluster  1.0           None  NaN
# 3          Fire Shard  5.0           None  NaN           None  NaN
# 4                None  NaN           None  NaN           None  NaN
# 5                None  NaN           None  NaN           None  NaN
# 6                None  NaN           None  NaN           None  NaN
# 7                None  NaN           None  NaN           None  NaN
# 8                None  NaN           None  NaN           None  NaN
# 9        Fire Cluster  1.0           None  NaN           None  NaN
# 10               None  NaN           None  NaN           None  NaN
# 11               None  NaN           None  NaN           None  NaN
# 12      Earth Crystal  4.0           None  NaN           None  NaN
# 13  Lightning Cluster  1.0   Wind Cluster  1.0           None  NaN
# 14         Cobalt Ore  3.0   Fire Cluster  1.0  Earth Cluster  1.0
# 15       Wind Crystal  4.0           None  NaN           None  NaN
# 16       Black Alumen  3.0  Earth Cluster  1.0   Wind Cluster  1.0
# 17               None  NaN           None  NaN           None  NaN
# 18               None  NaN           None  NaN           None  NaN
# 19       Fire Crystal  3.0           None  NaN           None  NaN
# 20               None  NaN           None  NaN           None  NaN
# 21         Fire Shard  2.0           None  NaN           None  NaN
# 22               None  NaN           None  NaN           None  NaN
# 23          Terebinth  1.0    Water Shard  5.0           None  NaN
# 24     Dhalmel Saliva  2.0  Water Crystal  4.0           None  NaN
# 25         Cobalt Ore  1.0   Fire Cluster  2.0  Earth Cluster  1.0

# %%
from odyssey_type_airship_parts import fetch_market_data_for_subparts

# Combine items from the gathering list (from 'gathering_list.csv') and the crafting recipes (from 'recipe_book.csv'),
# fetch market data from the Universalis API, and save the results to 'airship_parts_market_data.csv'.
df_market_data = fetch_market_data_for_subparts(
    gathering_csv='gathering_list.csv',
    crafting_csv='recipe_book.csv', 
    item_ids_json='item_ids.json',
    output_csv='airship_parts_market_data.csv',
    world="Seraph"
)

df_market_data  # Display the market data for airship parts
# Out:
#                         Item Name   Category Item ID minListing_world  \
# 0                    Ahriman Wing  Gathering    5553              897
# 1                      Animal Fat  Gathering    5531              149
# 2               Aqueous Whetstone  Gathering    5261              441
# 3                    Black Alumen  Gathering    5525              280
# 4                        Bomb Ash  Gathering    5528              400
# ..                            ...        ...     ...              ...
# 146              Clear Glass Lens   Crafting    5512              100
# 147                  Cobalt Nails   Crafting    7020              250
# 148                  Cobalt Rings   Crafting    5084               37
# 149               Dhalmel Leather   Crafting   12564             5000
# 150  High Allagan Chimera Leather   Crafting   12233             1495
#
#     minListing_dc recentPurchase_world recentPurchase_dc averageSalePrice_dc  \
# 0              89                  800               400          499.348571
# 1             149                  147               147           236.11828
# 2             274                  449               350          284.979305
# 3              45                  288                56          182.489077
# 4             199                  499               220          311.509177
# ..            ...                  ...               ...                 ...
# 146            54                  200                77          130.433533
# 147            20                   90               800                None
# 148            37                  155               730          469.888889
# 149          2999                 4123              3000         2697.111364
# 150           493                 2000              1000          713.727273
#
#     dailySaleVelocity_dc
# 0              91.664945
# 1              97.426531
# 2            3821.887866
# 3             371.633446
# 4            4623.015892
# ..                   ...
# 146           218.615748
# 147                 None
# 148             4.712653
# 149           115.197939
# 150             2.879942
#
# [149 rows x 9 columns]
