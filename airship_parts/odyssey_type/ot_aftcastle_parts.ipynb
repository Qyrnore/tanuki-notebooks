# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import generate_gathering_list
utils_dir = '../../utilities/'
data_dir = 'item_data/'
df_gathering_list = generate_gathering_list(
    total_csv=os.path.join(data_dir, 'odyssey_type_aftcastle_parts.csv'),
    recipe_book_csv=os.path.join(utils_dir, 'recipe_book.csv'),
    recipe_gathering_csv=os.path.join(utils_dir, 'recipe_gathering.csv'),
    output_csv=os.path.join(data_dir, 'gathering_list.csv')
)
df_gathering_list
# Out:
#            Ingredient  Total Quantity  \
# 21  Aqueous Whetstone            81.0
# 2          Cobalt Ore           276.0
# 7                Coke           351.0
# 13      Darksteel Ore           360.0
# 9       Earth Cluster            18.0
# 15          Ferberite             9.0
# 8        Fire Cluster            66.0
# 12       Fire Crystal           468.0
# 1          Fire Shard          1230.0
# 17    Hardsilver Sand            90.0
# 16        Ice Crystal            90.0
# 5           Ice Shard           300.0
# 3            Iron Ore           120.0
# 4            Iron Ore           120.0
# 0         Mythril Ore           198.0
# 10       Mythrite Ore            72.0
# 11      Mythrite Sand            90.0
# 20      Raw Celestine            27.0
# 14          Scheelite             9.0
# 18         Silver Ore            18.0
# 6           Vivianite            27.0
# 22       Wind Cluster             9.0
# 19       Wind Crystal            72.0
#
#                                         Location Info
# 21       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 2                   Northern Thanalan ( 23.1 / 24.2 )
# 7        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 13  Coerthas Central Highlands ( 27.5 / 20.0 ), Ti...
# 9                                                 NaN
# 15  Northern Thanalan ( 17.3 / 19.9 ), Timed at 3:...
# 8                                                 NaN
# 12                                                NaN
# 1                                                 NaN
# 17                 The Churning Mists ( 15.9 / 28.5 )
# 16                                                NaN
# 5                                                 NaN
# 3                    Western Thanalan ( 27.2 / 17.4 )
# 4    Nowhere ( 0.0 / 0.0 ), Sold by Material Supplier
# 0                   Southern Thanalan ( 25.2 / 39.9 )
# 10         Coerthas Western Highlands ( 31.2 / 12.8 )
# 11         Coerthas Western Highlands ( 16.6 / 13.1 )
# 20  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 14      Nowhere ( 0.0 / 0.0 ), Sold for 1500 GC Seals
# 18                       South Shroud ( 16.1 / 19.7 )
# 6   Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 22                                                NaN
# 19                                                NaN

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import get_crafting_recipes
data_dir = 'item_data/'
df_crafting_recipes = get_crafting_recipes(os.path.join(data_dir, 'odyssey_type_aftcastle_parts.csv'))
df_crafting_recipes
# Out:
#                Product  Required Quantity
# 10           Celestine                  9
# 2   Cobalt Joint Plate                 60
# 4        Cobalt Rivets                 60
# 6      Darksteel Ingot                 30
# 8      Darksteel Plate                 30
# 3        Garlond Steel                  9
# 9    Hardsilver Nugget                 18
# 1        Mythril Ingot                 30
# 0       Mythril Rivets                 30
# 5       Mythrite Ingot                 18
# 7        Wolfram Ingot                  9
