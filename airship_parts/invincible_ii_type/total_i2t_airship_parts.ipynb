# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import generate_gathering_list
utils_dir = '../../utilities/'
data_dir = 'item_data/'
df_gathering_list = generate_gathering_list(
    total_csv=os.path.join(data_dir, 'total_invincible_ii_type_airship_parts.csv'),
    recipe_book_csv=os.path.join(utils_dir, 'recipe_book.csv'),
    recipe_gathering_csv=os.path.join(utils_dir, 'recipe_gathering.csv'),
    output_csv=os.path.join(data_dir, 'gathering_list.csv')
)
df_gathering_list
# Out:
#            Ingredient  Total Quantity  \
# 5   Aqueous Whetstone           324.0
# 27           Bomb Ash           270.0
# 17          Cedar Log           180.0
# 7          Cobalt Ore           648.0
# 14               Coke           972.0
# 24         Copper Ore            96.0
# 12      Darksteel Ore           648.0
# 16      Earth Cluster            36.0
# 6        Fire Cluster           144.0
# 13       Fire Crystal          1170.0
# 10         Fire Shard          3228.0
# 29               Flax            60.0
# 32       Gelato Flesh            36.0
# 23           Gold Ore           288.0
# 19         Holy Water            72.0
# 3         Ice Cluster            12.0
# 11          Ice Shard           720.0
# 9            Iron Ore           882.0
# 8            Iron Ore           882.0
# 20        Mythril Ore           156.0
# 21       Mythrite Ore           264.0
# 22      Mythrite Sand           330.0
# 25        Peacock Ore           432.0
# 0       Petrified Log            12.0
# 33      Pudding Flesh            24.0
# 28          Raw Amber            60.0
# 4       Raw Celestine           108.0
# 1         Scarlet Sap            12.0
# 26         Spruce Log            72.0
# 31          Terebinth            30.0
# 15          Vivianite           108.0
# 35         Walnut Log            72.0
# 34      Water Crystal            36.0
# 30        Water Shard           240.0
# 2        Wind Cluster           108.0
# 18       Wind Crystal           576.0
# 36         Wind Shard            48.0
#
#                                         Location Info
# 5        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 27                  Southern Thanalan ( 22.2 / 29.9 )
# 17         Coerthas Western Highlands ( 31.3 / 32.1 )
# 7                   Northern Thanalan ( 23.1 / 24.2 )
# 14       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 24                   Central Thanalan ( 19.0 / 26.2 )
# 12  Coerthas Central Highlands ( 27.5 / 20.0 ), Ti...
# 16                                                NaN
# 6                                                 NaN
# 13                                                NaN
# 10                                                NaN
# 29                       South Shroud ( 17.6 / 28.6 )
# 32  Coerthas Western Highlands ( 9.4 / 18.8 ),  Dr...
# 23  Eastern Thanalan ( 27.3 / 21.3 ), Timed at 10:...
# 19  Nowhere ( 0.0 / 0.0 ), Sold by Idyllshire Scra...
# 3                                                 NaN
# 11                                                NaN
# 9    Nowhere ( 0.0 / 0.0 ), Sold by Material Supplier
# 8                    Western Thanalan ( 27.2 / 17.4 )
# 20                  Southern Thanalan ( 25.2 / 39.9 )
# 21         Coerthas Western Highlands ( 31.2 / 12.8 )
# 22         Coerthas Western Highlands ( 16.6 / 13.1 )
# 25       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 0       Nowhere ( 0.0 / 0.0 ), Sold for 1500 GC Seals
# 33       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 28                   Eastern Thanalan ( 12.7 / 19.1 )
# 4   Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 1       North Shroud ( 17.7 / 27.7 ), Timed at 1:00am
# 26  Coerthas Central Highlands ( 29.5 / 13.1 ), Ti...
# 31      Nowhere ( 0.0 / 0.0 ), Sold by Main City NPCs
# 15  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 35                       South Shroud ( 23.1 / 21.6 )
# 34                                                NaN
# 30                                                NaN
# 2                                                 NaN
# 18                                                NaN
# 36                                                NaN

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import get_crafting_recipes
data_dir = 'item_data/'
df_crafting_recipes = get_crafting_recipes(os.path.join(data_dir, 'total_invincible_ii_type_airship_parts.csv'))
df_crafting_recipes
# Out:
#                Product  Required Quantity                 2  3  \
# 0       Ancient Lumber                 12     Petrified Log  1
# 1            Celestine                 36     Raw Celestine  3
# 2   Cobalt Joint Plate                120      Cobalt Ingot  1
# 3         Cobalt Plate                 24      Cobalt Ingot  2
# 4        Cobalt Rivets                102      Cobalt Ingot  1
# 5      Darksteel Ingot                 72  Darksteel Nugget  2
# 6     Darksteel Nugget                 30     Darksteel Ore  3
# 7     Darksteel Rivets                 42  Darksteel Nugget  1
# 8        Garlond Steel                 36         Vivianite  3
# 9    Holy Cedar Lumber                 36      Cedar Lumber  1
# 10          Iron Nails                 24        Iron Ingot  1
# 11      Mythril Rivets                 30     Mythril Ingot  1
# 12      Mythrite Ingot                 66      Mythrite Ore  4
# 13     Rose Gold Ingot                 48  Rose Gold Nugget  2
# 14       Spruce Lumber                 24        Spruce Log  3
# 15         Steel Ingot                 90          Bomb Ash  1
# 16         Steel Nails                 30       Steel Ingot  1
# 17        Steel Rivets                150       Steel Ingot  1
# 18             Varnish                 30         Raw Amber  2
# 19           Void Glue                 12      Gelato Flesh  3
# 20       Walnut Lumber                 24        Walnut Log  3
#
#                     4  5              6    7             8    9  \
# 0         Scarlet Sap  1   Wind Cluster  2.0   Ice Cluster  1.0
# 1   Aqueous Whetstone  9   Wind Cluster  1.0  Fire Cluster  1.0
# 2           Ice Shard  5           None  NaN          None  NaN
# 3           Ice Shard  5           None  NaN          None  NaN
# 4          Fire Shard  5           None  NaN          None  NaN
# 5                Coke  9   Fire Cluster  1.0          None  NaN
# 6        Fire Crystal  3           None  NaN          None  NaN
# 7        Fire Crystal  3           None  NaN          None  NaN
# 8                Coke  9     Cobalt Ore  3.0  Fire Cluster  1.0
# 9          Holy Water  2   Wind Crystal  3.0          None  NaN
# 10         Fire Shard  1           None  NaN          None  NaN
# 11         Fire Shard  5           None  NaN          None  NaN
# 12    Mythrite Nugget  1   Fire Crystal  3.0          None  NaN
# 13        Peacock Ore  9   Wind Cluster  1.0          None  NaN
# 14       Wind Crystal  3           None  NaN          None  NaN
# 15           Iron Ore  2     Fire Shard  2.0          None  NaN
# 16         Fire Shard  3           None  NaN          None  NaN
# 17         Fire Shard  3           None  NaN          None  NaN
# 18        Linseed Oil  1      Terebinth  1.0   Water Shard  5.0
# 19      Pudding Flesh  2  Water Crystal  3.0          None  NaN
# 20         Wind Shard  2           None  NaN          None  NaN
#
#                10   11
# 0            None  NaN
# 1            None  NaN
# 2            None  NaN
# 3            None  NaN
# 4            None  NaN
# 5            None  NaN
# 6            None  NaN
# 7            None  NaN
# 8   Earth Cluster  1.0
# 9            None  NaN
# 10           None  NaN
# 11           None  NaN
# 12           None  NaN
# 13           None  NaN
# 14           None  NaN
# 15           None  NaN
# 16           None  NaN
# 17           None  NaN
# 18           None  NaN
# 19           None  NaN
# 20           None  NaN

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import fetch_market_data_for_subparts
utils_dir = '../../utilities/'
data_dir = 'item_data/'
df_market_data = fetch_market_data_for_subparts(
    gathering_csv=os.path.join(data_dir, 'gathering_list.csv'),
    crafting_csv=os.path.join(utils_dir, 'recipe_book.csv'),
    item_ids_json=os.path.join(utils_dir, 'item_ids.json'),
    output_csv=os.path.join(data_dir, 'airship_parts_market_data.csv'),
    world="Seraph"
)
df_market_data
# Out:
#                         Item Name   Category Item ID minListing_world  \
# 0               Aqueous Whetstone  Gathering    5261              441
# 1                        Bomb Ash  Gathering    5528              400
# 2                       Cedar Log  Gathering    5384              263
# 3                      Cobalt Ore  Gathering    5116              200
# 4                            Coke  Gathering    5530              213
# ..                            ...        ...     ...              ...
# 136                  Cobalt Nails   Crafting    7020              250
# 137                  Cobalt Rings   Crafting    5084               37
# 138               Dhalmel Leather   Crafting   12564             5000
# 139  High Allagan Chimera Leather   Crafting   12233             1495
# 140            Amphiptere Leather   Crafting   12566              275
#
#     minListing_dc recentPurchase_world recentPurchase_dc averageSalePrice_dc  \
# 0             274                  449               350          285.684545
# 1             199                  499               220          298.920598
# 2             224                  264               264           344.16073
# 3             200                  200               292          281.530793
# 4             150                  213               223          211.395106
# ..            ...                  ...               ...                 ...
# 136            20                   90               800                None
# 137            37                  155               730          469.888889
# 138          2999                 4123              3000         2780.477273
# 139           493                 2000              1000          713.727273
# 140            50                  323               500          328.926471
#
#     dailySaleVelocity_dc
# 0            2605.273586
# 1            3380.532403
# 2             923.420673
# 3            8080.241849
# 4           11657.048343
# ..                   ...
# 136                 None
# 137             4.735422
# 138            57.877248
# 139             2.893856
# 140            17.889251
#
# [139 rows x 9 columns]
