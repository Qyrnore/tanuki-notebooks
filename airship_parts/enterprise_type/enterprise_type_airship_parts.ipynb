# %%
from enterprise_type_airship_parts import generate_gathering_list

# Generate the gathering list and save to 'gathering_list.csv'
df_gathering_list = generate_gathering_list(
    total_csv='total_enterprise_type_airship_parts.csv',
    recipe_book_csv='recipe_book.csv',
    recipe_gathering_csv='recipe_gathering.csv',
    output_csv='gathering_list.csv'
)

df_gathering_list  # Display the gathering list
# Out:
#              Ingredient  Total Quantity  \
# 37         Black Alumen            24.0
# 34             Bomb Ash           294.0
# 8            Cobalt Ore           492.0
# 48  Coerthan Tea Leaves            18.0
# 15                 Coke           648.0
# 30           Copper Ore            36.0
# 13        Darksteel Ore           441.0
# 24        Earth Cluster            54.0
# 38        Earth Crystal            78.0
# 5    Effervescent Water            60.0
# 18         Electrum Ore            96.0
# 46            Ferberite            18.0
# 16         Fire Cluster           108.0
# 14         Fire Crystal           720.0
# 11           Fire Shard          3288.0
# 40                 Flax            36.0
# 42         Gelato Flesh            27.0
# 29             Gold Ore           108.0
# 35         Hardened Sap           108.0
# 3           Ice Cluster            24.0
# 17          Ice Crystal            81.0
# 12            Ice Shard           462.0
# 10             Iron Ore           843.0
# 9              Iron Ore           843.0
# 22    Lightning Cluster            18.0
# 25          Mythril Ore           540.0
# 26         Mythrite Ore           144.0
# 27        Mythrite Sand           180.0
# 28              Oak Log            72.0
# 32          Peacock Ore           162.0
# 0         Petrified Log            24.0
# 21               Potash           162.0
# 43        Pudding Flesh            18.0
# 39            Raw Amber            36.0
# 20       Red Moko Grass            54.0
# 6             Rock Salt            60.0
# 1           Scarlet Sap            24.0
# 45            Scheelite            18.0
# 4                 Silex            60.0
# 33           Spruce Log           144.0
# 41            Terebinth            18.0
# 36          Uraeus Skin            24.0
# 23            Vivianite           108.0
# 44        Water Crystal            27.0
# 7           Water Shard           444.0
# 2          Wind Cluster            96.0
# 31         Wind Crystal           252.0
# 19           Wind Shard           192.0
# 47          Wyvern Skin            54.0
#
#                                         Location Info
# 37                       South Shroud ( 28.7 / 22.8 )
# 34                  Southern Thanalan ( 22.2 / 29.9 )
# 8                   Northern Thanalan ( 23.1 / 24.2 )
# 48  Coerthas Western Highlands ( 31.7 / 19.6 ), Ti...
# 15       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 30                   Central Thanalan ( 19.0 / 26.2 )
# 13  Coerthas Central Highlands ( 27.5 / 20.0 ), Ti...
# 24                                                NaN
# 38                                                NaN
# 5                        South Shroud ( 16.0 / 19.7 )
# 18                    Upper La Noscea ( 30.4 / 25.4 )
# 46  Northern Thanalan ( 17.3 / 19.9 ), Timed at 3:...
# 16                                                NaN
# 14                                                NaN
# 11                                                NaN
# 40                       South Shroud ( 17.6 / 28.6 )
# 42  Coerthas Western Highlands ( 9.4 / 18.8 ),  Dr...
# 29  Eastern Thanalan ( 27.3 / 21.3 ), Timed at 10:...
# 35       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 3                                                 NaN
# 17                                                NaN
# 12                                                NaN
# 10   Nowhere ( 0.0 / 0.0 ), Sold by Material Supplier
# 9                    Western Thanalan ( 27.2 / 17.4 )
# 22                                                NaN
# 25                  Southern Thanalan ( 25.2 / 39.9 )
# 26         Coerthas Western Highlands ( 31.2 / 12.8 )
# 27         Coerthas Western Highlands ( 16.6 / 13.1 )
# 28                       South Shroud ( 16.6 / 30.2 )
# 32       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 0       Nowhere ( 0.0 / 0.0 ), Sold for 1500 GC Seals
# 21       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 43       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 39                   Eastern Thanalan ( 12.7 / 19.1 )
# 20  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 6                    Central Thanalan ( 14.5 / 22.7 )
# 1       North Shroud ( 17.7 / 27.7 ), Timed at 1:00am
# 45      Nowhere ( 0.0 / 0.0 ), Sold for 1500 GC Seals
# 4                   Southern Thanalan ( 22.4 / 29.7 )
# 33  Coerthas Central Highlands ( 29.5 / 13.1 ), Ti...
# 41      Nowhere ( 0.0 / 0.0 ), Sold by Main City NPCs
# 36  Nowhere ( 0.0 / 0.0 ), Found in The Wanderer's...
# 23  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 44                                                NaN
# 7                                                 NaN
# 2                                                 NaN
# 31                                                NaN
# 19                                                NaN
# 47  Coerthas Western Highlands (X:19.5 Y:35.9), Ra...

# %%
from enterprise_type_airship_parts import get_crafting_recipes

# Get the crafting recipes from total_enterprise_type_airship_parts.csv
df_crafting_recipes = get_crafting_recipes('total_enterprise_type_airship_parts.csv')
df_crafting_recipes  # Display the crafting recipes list
# Out:
#                   Product  Required Quantity                 2  3  \
# 0          Ancient Lumber                 24     Petrified Log  1
# 1        Clear Glass Lens                 60             Silex  1
# 2            Cobalt Ingot                 69        Cobalt Ore  2
# 3      Cobalt Joint Plate                 60      Cobalt Ingot  1
# 4           Cobalt Rivets                 54      Cobalt Ingot  1
# 5         Darksteel Ingot                 36  Darksteel Nugget  2
# 6         Darksteel Plate                 27  Darksteel Nugget  2
# 7        Darksteel Rivets                 21  Darksteel Nugget  1
# 8          Electrum Ingot                 24      Electrum Ore  4
# 9         Farreach Canvas                 18    Red Moko Grass  3
# 10          Garlond Steel                 36         Vivianite  3
# 11            Iron Rivets                 24        Iron Ingot  1
# 12          Mythril Ingot                 60       Mythril Ore  3
# 13         Mythril Rivets                108     Mythril Ingot  1
# 14         Mythrite Ingot                 36      Mythrite Ore  4
# 15             Oak Lumber                 24           Oak Log  3
# 16        Rose Gold Ingot                 18  Rose Gold Nugget  2
# 17          Spruce Lumber                 24        Spruce Log  3
# 18            Steel Ingot                 75          Bomb Ash  1
# 19      Steel Joint Plate                 30       Steel Ingot  1
# 20            Steel Nails                 45       Steel Ingot  1
# 21            Steel Plate                 24       Steel Ingot  2
# 22           Steel Rivets                 96       Steel Ingot  1
# 23  Treated Spruce Lumber                 12     Spruce Lumber  2
# 24         Uraeus Leather                 24       Uraeus Skin  1
# 25                Varnish                 18         Raw Amber  2
# 26              Void Glue                  9      Gelato Flesh  3
# 27          Wolfram Ingot                 18         Scheelite  1
# 28         Wyvern Leather                 18       Wyvern Skin  3
#
#                       4  5                  6    7             8    9  \
# 0           Scarlet Sap  1       Wind Cluster  2.0   Ice Cluster  1.0
# 1                Natron  1        Water Shard  3.0          None  NaN
# 2              Iron Ore  1         Fire Shard  5.0          None  NaN
# 3             Ice Shard  5               None  NaN          None  NaN
# 4            Fire Shard  5               None  NaN          None  NaN
# 5                  Coke  9       Fire Cluster  1.0          None  NaN
# 6           Ice Crystal  3               None  NaN          None  NaN
# 7          Fire Crystal  3               None  NaN          None  NaN
# 8            Wind Shard  5               None  NaN          None  NaN
# 9                Potash  9  Lightning Cluster  1.0  Wind Cluster  1.0
# 10                 Coke  9         Cobalt Ore  3.0  Fire Cluster  1.0
# 11           Fire Shard  1               None  NaN          None  NaN
# 12           Fire Shard  3               None  NaN          None  NaN
# 13           Fire Shard  5               None  NaN          None  NaN
# 14      Mythrite Nugget  1       Fire Crystal  3.0          None  NaN
# 15           Wind Shard  3               None  NaN          None  NaN
# 16          Peacock Ore  9       Wind Cluster  1.0          None  NaN
# 17         Wind Crystal  3               None  NaN          None  NaN
# 18             Iron Ore  2         Fire Shard  2.0          None  NaN
# 19            Ice Shard  3               None  NaN          None  NaN
# 20           Fire Shard  3               None  NaN          None  NaN
# 21            Ice Shard  3               None  NaN          None  NaN
# 22           Fire Shard  3               None  NaN          None  NaN
# 23         Hardened Sap  9       Wind Cluster  1.0          None  NaN
# 24         Black Alumen  1      Earth Crystal  1.0          None  NaN
# 25          Linseed Oil  1          Terebinth  1.0   Water Shard  5.0
# 26        Pudding Flesh  2      Water Crystal  3.0          None  NaN
# 27            Ferberite  1         Cobalt Ore  1.0  Fire Cluster  2.0
# 28  Coerthan Tea Leaves  1      Earth Crystal  3.0          None  NaN
#
#                10   11
# 0            None  NaN
# 1            None  NaN
# 2            None  NaN
# 3            None  NaN
# 4            None  NaN
# 5            None  NaN
# 6            None  NaN
# 7            None  NaN
# 8            None  NaN
# 9            None  NaN
# 10  Earth Cluster  1.0
# 11           None  NaN
# 12           None  NaN
# 13           None  NaN
# 14           None  NaN
# 15           None  NaN
# 16           None  NaN
# 17           None  NaN
# 18           None  NaN
# 19           None  NaN
# 20           None  NaN
# 21           None  NaN
# 22           None  NaN
# 23           None  NaN
# 24           None  NaN
# 25           None  NaN
# 26           None  NaN
# 27  Earth Cluster  1.0
# 28           None  NaN

# %%
from enterprise_type_airship_parts import fetch_market_data_for_subparts

# Combine items from the gathering list (from 'gathering_list.csv') and the crafting recipes (from 'recipe_book.csv'),
# fetch market data from the Universalis API, and save the results to 'airship_parts_market_data.csv'.
df_market_data = fetch_market_data_for_subparts(
    gathering_csv='gathering_list.csv',
    crafting_csv='recipe_book.csv', 
    item_ids_json='item_ids.json',
    output_csv='airship_parts_market_data.csv',
    world="Seraph"
)

df_market_data  # Display the market data for airship parts
# Out:
#                     Item Name   Category Item ID minListing_world  \
# 0                Black Alumen  Gathering    5525              280
# 1                    Bomb Ash  Gathering    5528              400
# 2                  Cobalt Ore  Gathering    5116              200
# 3         Coerthan Tea Leaves  Gathering   12882              485
# 4                        Coke  Gathering    5530              213
# ..                        ...        ...     ...              ...
# 143                  Triphane   Crafting   19962              200
# 144  Hallowed Chestnut Lumber   Crafting   12582             None
# 145            Wolfram Square   Crafting    8029              995
# 146            Hallowed Water   Crafting   12605               70
# 147          Clear Glass Lens   Crafting    5512              100
#
#     minListing_dc recentPurchase_world recentPurchase_dc averageSalePrice_dc  \
# 0              45                  288                56          182.489077
# 1             199                  499               220          311.509177
# 2             200                  200               292          289.355514
# 3             250                  799               424         1099.659574
# 4             150                  213               223          216.003922
# ..            ...                  ...               ...                 ...
# 143           200                  585               900          552.068493
# 144           495                 1000              2500         1422.235849
# 145           200                 1200               189               656.5
# 146            70                   80               209          480.376238
# 147            54                  200                77          130.433533
#
#     dailySaleVelocity_dc
# 0             375.069208
# 1            4665.755587
# 2             12028.0649
# 3             285.727354
# 4           20826.068038
# ..                   ...
# 143            19.289001
# 144            28.008602
# 145             3.170778
# 146            26.687304
# 147           220.632179
#
# [146 rows x 9 columns]
