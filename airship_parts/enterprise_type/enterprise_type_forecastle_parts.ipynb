# %%
from enterprise_type_airship_parts import generate_gathering_list

# Generate the gathering list and save to 'gathering_list.csv'
df_gathering_list = generate_gathering_list(
    total_csv='enterprise_type_forecastle_parts.csv',
    recipe_book_csv='recipe_book.csv',
    recipe_gathering_csv='recipe_gathering.csv',
    output_csv='gathering_list.csv'
)

df_gathering_list  # Display the gathering list
# Out:
#             Ingredient  Total Quantity  \
# 0             Bomb Ash            90.0
# 4           Cobalt Ore           147.0
# 7                 Coke           162.0
# 17          Copper Ore            36.0
# 14       Darksteel Ore           108.0
# 9        Earth Cluster             9.0
# 22  Effervescent Water            30.0
# 8         Fire Cluster            18.0
# 13        Fire Crystal           216.0
# 3           Fire Shard          1050.0
# 16            Gold Ore           108.0
# 15         Ice Crystal            27.0
# 5            Ice Shard           240.0
# 1             Iron Ore           240.0
# 2             Iron Ore           240.0
# 12         Mythril Ore           198.0
# 10        Mythrite Ore            72.0
# 11       Mythrite Sand            90.0
# 19         Peacock Ore           162.0
# 23           Rock Salt            30.0
# 21               Silex            30.0
# 6            Vivianite            27.0
# 24         Water Shard           150.0
# 20        Wind Cluster            18.0
# 18        Wind Crystal           108.0
#
#                                         Location Info
# 0                   Southern Thanalan ( 22.2 / 29.9 )
# 4                   Northern Thanalan ( 23.1 / 24.2 )
# 7        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 17                   Central Thanalan ( 19.0 / 26.2 )
# 14  Coerthas Central Highlands ( 27.5 / 20.0 ), Ti...
# 9                                                 NaN
# 22                       South Shroud ( 16.0 / 19.7 )
# 8                                                 NaN
# 13                                                NaN
# 3                                                 NaN
# 16  Eastern Thanalan ( 27.3 / 21.3 ), Timed at 10:...
# 15                                                NaN
# 5                                                 NaN
# 1                    Western Thanalan ( 27.2 / 17.4 )
# 2    Nowhere ( 0.0 / 0.0 ), Sold by Material Supplier
# 12                  Southern Thanalan ( 25.2 / 39.9 )
# 10         Coerthas Western Highlands ( 31.2 / 12.8 )
# 11         Coerthas Western Highlands ( 16.6 / 13.1 )
# 19       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 23                   Central Thanalan ( 14.5 / 22.7 )
# 21                  Southern Thanalan ( 22.4 / 29.7 )
# 6   Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 24                                                NaN
# 20                                                NaN
# 18                                                NaN

# %%
from enterprise_type_airship_parts import get_crafting_recipes

# Get the crafting recipes from total_enterprise_type_airship_parts.csv
df_crafting_recipes = get_crafting_recipes('enterprise_type_forecastle_parts.csv')
df_crafting_recipes  # Display the crafting recipes list
# Out:
#                Product  Required Quantity
# 12    Clear Glass Lens                 30
# 2   Cobalt Joint Plate                 30
# 1        Cobalt Rivets                 30
# 7      Darksteel Ingot                  9
# 9      Darksteel Plate                  9
# 3        Garlond Steel                  9
# 10       Mythril Ingot                 30
# 8       Mythril Rivets                 30
# 5       Mythrite Ingot                 18
# 11     Rose Gold Ingot                 18
# 0          Steel Ingot                 30
# 6    Steel Joint Plate                 30
# 4         Steel Rivets                 30
