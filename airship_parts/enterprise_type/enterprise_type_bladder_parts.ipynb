# %%
from enterprise_type_airship_parts import generate_gathering_list

# Generate the gathering list and save to 'gathering_list.csv'
df_gathering_list = generate_gathering_list(
    total_csv='enterprise_type_bladder_parts.csv',
    recipe_book_csv='recipe_book.csv',
    recipe_gathering_csv='recipe_gathering.csv',
    output_csv='gathering_list.csv'
)

df_gathering_list  # Display the gathering list
# Out:
#              Ingredient  Total Quantity  \
# 9              Bomb Ash            84.0
# 6            Cobalt Ore            69.0
# 17  Coerthan Tea Leaves            18.0
# 5                  Coke           243.0
# 13        Darksteel Ore           171.0
# 8         Earth Cluster             9.0
# 18        Earth Crystal            54.0
# 7          Fire Cluster            27.0
# 14         Fire Crystal           234.0
# 12           Fire Shard           606.0
# 2          Hardened Sap           108.0
# 10             Iron Ore           189.0
# 11             Iron Ore           189.0
# 21    Lightning Cluster             9.0
# 15          Mythril Ore            54.0
# 20               Potash            81.0
# 19       Red Moko Grass            27.0
# 0            Spruce Log            72.0
# 4             Vivianite            27.0
# 3          Wind Cluster            21.0
# 1          Wind Crystal            72.0
# 16          Wyvern Skin            54.0
#
#                                         Location Info
# 9                   Southern Thanalan ( 22.2 / 29.9 )
# 6                   Northern Thanalan ( 23.1 / 24.2 )
# 17  Coerthas Western Highlands ( 31.7 / 19.6 ), Ti...
# 5        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 13  Coerthas Central Highlands ( 27.5 / 20.0 ), Ti...
# 8                                                 NaN
# 18                                                NaN
# 7                                                 NaN
# 14                                                NaN
# 12                                                NaN
# 2        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 10                   Western Thanalan ( 27.2 / 17.4 )
# 11   Nowhere ( 0.0 / 0.0 ), Sold by Material Supplier
# 21                                                NaN
# 15                  Southern Thanalan ( 25.2 / 39.9 )
# 20       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 19  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 0   Coerthas Central Highlands ( 29.5 / 13.1 ), Ti...
# 4   Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 3                                                 NaN
# 1                                                 NaN
# 16  Coerthas Western Highlands (X:19.5 Y:35.9), Ra...

# %%
from enterprise_type_airship_parts import get_crafting_recipes

# Get the crafting recipes from total_enterprise_type_airship_parts.csv
df_crafting_recipes = get_crafting_recipes('enterprise_type_bladder_parts.csv')
df_crafting_recipes  # Display the crafting recipes list
# Out:
#                   Product  Required Quantity
# 5            Cobalt Ingot                 21
# 7         Darksteel Ingot                 18
# 6        Darksteel Rivets                 21
# 10        Farreach Canvas                  9
# 1           Garlond Steel                  9
# 8          Mythril Rivets                 18
# 4             Steel Ingot                 21
# 2             Steel Nails                 21
# 3            Steel Rivets                 42
# 0   Treated Spruce Lumber                 12
# 9          Wyvern Leather                 18
