# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import generate_gathering_list
utils_dir = '../../utilities/'
data_dir = 'item_data/'
df_gathering_list = generate_gathering_list(
    total_csv=os.path.join(data_dir, 'invincible_type_propellers_parts.csv'),
    recipe_book_csv=os.path.join(utils_dir, 'recipe_book.csv'),
    recipe_gathering_csv=os.path.join(utils_dir, 'recipe_gathering.csv'),
    output_csv=os.path.join(data_dir, 'gathering_list.csv')
)
df_gathering_list
# Out:
#        Ingredient  Total Quantity  \
# 9        Bomb Ash            63.0
# 12     Cobalt Ore            69.0
# 10           Coke           297.0
# 4   Darksteel Ore           207.0
# 14  Earth Cluster             9.0
# 15   Electrum Ore            84.0
# 11   Fire Cluster            33.0
# 5    Fire Crystal           207.0
# 8      Fire Shard           546.0
# 2    Hardened Sap           108.0
# 6        Iron Ore           273.0
# 7        Iron Ore           273.0
# 0      Spruce Log            72.0
# 13      Vivianite            27.0
# 3    Wind Cluster            12.0
# 1    Wind Crystal            72.0
# 16     Wind Shard           105.0
#
#                                         Location Info
# 9                   Southern Thanalan ( 22.2 / 29.9 )
# 12                  Northern Thanalan ( 23.1 / 24.2 )
# 10       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 4   Coerthas Central Highlands ( 27.5 / 20.0 ), Ti...
# 14                                                NaN
# 15                    Upper La Noscea ( 30.4 / 25.4 )
# 11                                                NaN
# 5                                                 NaN
# 8                                                 NaN
# 2        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 6                    Western Thanalan ( 27.2 / 17.4 )
# 7    Nowhere ( 0.0 / 0.0 ), Sold by Material Supplier
# 0   Coerthas Central Highlands ( 29.5 / 13.1 ), Ti...
# 13  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 3                                                 NaN
# 1                                                 NaN
# 16                                                NaN

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import get_crafting_recipes
data_dir = 'item_data/'
df_crafting_recipes = get_crafting_recipes(os.path.join(data_dir, 'invincible_type_propellers_parts.csv'))
df_crafting_recipes
# Out:
#                  Product  Required Quantity
# 7          Cobalt Rivets                 21
# 6        Darksteel Ingot                 24
# 1       Darksteel Nugget                 21
# 9         Electrum Ingot                 21
# 8          Garlond Steel                  9
# 2             Iron Nails                 21
# 3            Iron Rivets                 21
# 4            Steel Ingot                 21
# 5           Steel Rivets                 42
# 0  Treated Spruce Lumber                 12
