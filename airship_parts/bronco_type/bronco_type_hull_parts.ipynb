# %%
from bronco_type_airship_parts import generate_gathering_list

# Generate the gathering list and save to 'gathering_list.csv'
df_gathering_list = generate_gathering_list(
    total_csv='bronco_type_hull_parts.csv',
    recipe_book_csv='recipe_book.csv',
    recipe_gathering_csv='recipe_gathering.csv',
    output_csv='gathering_list.csv'
)

df_gathering_list  # Display the gathering list
# Out:
#          Ingredient  Total Quantity  \
# 27     Aldgoat Horn            36.0
# 18           Alumen            18.0
# 23     Beehive Chip            54.0
# 17        Boar Hide            18.0
# 6        Cobalt Ore            72.0
# 9        Copper Ore            36.0
# 22      Cotton Boll            36.0
# 14    Darksteel Ore           108.0
# 19      Earth Shard            72.0
# 13     Electrum Ore            72.0
# 15     Fire Crystal           108.0
# 5        Fire Shard           450.0
# 20             Flax           108.0
# 16      Ice Crystal            54.0
# 12        Ice Shard            72.0
# 4          Iron Ore            90.0
# 3          Iron Ore            90.0
# 21  Lightning Shard           162.0
# 2      Mahogany Log            54.0
# 11      Mythril Ore           108.0
# 25        Raw Amber            36.0
# 7        Spruce Log            54.0
# 26        Terebinth            18.0
# 10          Tin Ore            18.0
# 24      Water Shard           216.0
# 8      Wind Crystal            54.0
# 1        Wind Shard           216.0
# 0           Yew Log            54.0
#
#                                         Location Info
# 27  Eastern Thanalan ( 18.2 / 22.7 ), Dropped by M...
# 18                   Eastern Thanalan ( 18.3 / 20.9 )
# 23                       North Shroud ( 26.3 / 27.6 )
# 17  East Shroud ( 14.5 / 22.7 ), Dropped by Wild Boar
# 6                   Northern Thanalan ( 23.1 / 24.2 )
# 9                    Central Thanalan ( 19.0 / 26.2 )
# 22                     Central Shroud ( 22.5 / 24.3 )
# 14  Coerthas Central Highlands ( 27.5 / 20.0 ), Ti...
# 19                                                NaN
# 13                    Upper La Noscea ( 30.4 / 25.4 )
# 15                                                NaN
# 5                                                 NaN
# 20                       South Shroud ( 17.6 / 28.6 )
# 16                                                NaN
# 12                                                NaN
# 4    Nowhere ( 0.0 / 0.0 ), Sold by Material Supplier
# 3                    Western Thanalan ( 27.2 / 17.4 )
# 21                                                NaN
# 2                   Eastern La Noscea ( 19.4 / 25.6 )
# 11                  Southern Thanalan ( 25.2 / 39.9 )
# 25                   Eastern Thanalan ( 12.7 / 19.1 )
# 7   Coerthas Central Highlands ( 29.5 / 13.1 ), Ti...
# 26      Nowhere ( 0.0 / 0.0 ), Sold by Main City NPCs
# 10                   Central Thanalan ( 19.9 / 22.2 )
# 24                                                NaN
# 8                                                 NaN
# 1                                                 NaN
# 0                         East Shroud ( 15.2 / 27.4 )

# %%
from bronco_type_airship_parts import get_crafting_recipes

# Get the crafting recipes from total_bronco_type_airship_parts.csv
df_crafting_recipes = get_crafting_recipes('bronco_type_hull_parts.csv')
df_crafting_recipes  # Display the crafting recipes list
# Out:
#             Product  Required Quantity
# 10     Boar Leather                 18
# 5     Bronze Rivets                 18
# 3      Cobalt Ingot                 18
# 8     Cobalt Rivets                 18
# 9   Darksteel Plate                 18
# 7    Electrum Ingot                 18
# 13        Horn Glue                 18
# 2        Iron Nails                 18
# 11     Linen Canvas                 18
# 1   Mahogany Lumber                 18
# 6     Mythril Plate                 18
# 4     Spruce Lumber                 18
# 12          Varnish                 18
# 0        Yew Lumber                 18
