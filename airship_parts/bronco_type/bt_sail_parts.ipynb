# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import generate_gathering_list
utils_dir = '../../utilities/'
data_dir = 'item_data/'
df_gathering_list = generate_gathering_list(
    total_csv=os.path.join(data_dir, 'bronco_type_sail_parts.csv'),
    recipe_book_csv=os.path.join(utils_dir, 'recipe_book.csv'),
    recipe_gathering_csv=os.path.join(utils_dir, 'recipe_gathering.csv'),
    output_csv=os.path.join(data_dir, 'gathering_list.csv')
)
df_gathering_list
# Out:
#             Ingredient  Total Quantity  \
# 17          Animal Fat            54.0
# 21        Beehive Chip            36.0
# 15        Black Alumen            12.0
# 7             Bomb Ash            54.0
# 8                 Coke            54.0
# 20         Cotton Boll            24.0
# 2        Darksteel Ore            99.0
# 12       Earth Cluster            18.0
# 16       Earth Crystal            36.0
# 24  Effervescent Water            12.0
# 9         Fire Cluster             6.0
# 3         Fire Crystal            99.0
# 6           Fire Shard           354.0
# 18                Flax            48.0
# 14     Hippogryph Skin            12.0
# 5             Iron Ore           360.0
# 4             Iron Ore           360.0
# 27   Lightning Cluster             6.0
# 25   Lightning Crystal            36.0
# 19     Lightning Shard           108.0
# 26              Potash            54.0
# 0         Rosewood Log            63.0
# 10        Saurian Skin             6.0
# 11   Shroud Tea Leaves             6.0
# 23     Silkworm Cocoon            24.0
# 22         Water Shard            12.0
# 13        Wind Cluster             6.0
# 1           Wind Shard           126.0
#
#                                         Location Info
# 17       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 21                       North Shroud ( 26.3 / 27.6 )
# 15                       South Shroud ( 28.7 / 22.8 )
# 7                   Southern Thanalan ( 22.2 / 29.9 )
# 8        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 20                     Central Shroud ( 22.5 / 24.3 )
# 2   Coerthas Central Highlands ( 27.5 / 20.0 ), Ti...
# 12                                                NaN
# 16                                                NaN
# 24                       South Shroud ( 16.0 / 19.7 )
# 9                                                 NaN
# 3                                                 NaN
# 6                                                 NaN
# 18                       South Shroud ( 17.6 / 28.6 )
# 14    Mor Dhona ( 26.8 / 8.3 ), Dropped by Hippogryph
# 5    Nowhere ( 0.0 / 0.0 ), Sold by Material Supplier
# 4                    Western Thanalan ( 27.2 / 17.4 )
# 27                                                NaN
# 25                                                NaN
# 19                                                NaN
# 26       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 0                         East Shroud ( 16.7 / 23.3 )
# 10      Nowhere ( 0.0 / 0.0 ), Sold for 1500 GC Seals
# 11                             Central Shroud ( ??? )
# 23    East Shroud ( 21.6 / 26.6 ), Timed at 1:00am ET
# 22                                                NaN
# 13                                                NaN
# 1                                                 NaN

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import get_crafting_recipes
data_dir = 'item_data/'
df_crafting_recipes = get_crafting_recipes(os.path.join(data_dir, 'bronco_type_sail_parts.csv'))
df_crafting_recipes
# Out:
#                     Product  Required Quantity
# 7           Darksteel Ingot                  6
# 1          Darksteel Nugget                 21
# 9   Hard Hippogryph Leather                  6
# 4                Iron Ingot                 21
# 2                Iron Nails                 21
# 3               Iron Rivets                 42
# 10             Linen Canvas                 12
# 0           Rosewood Lumber                 21
# 8           Saurian Leather                  6
# 5               Steel Ingot                 21
# 6              Steel Rivets                 33
# 11               Vanya Silk                  6
