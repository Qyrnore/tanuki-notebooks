# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import generate_gathering_list
utils_dir = '../../utilities/'
data_dir = 'item_data/'
df_gathering_list = generate_gathering_list(
    total_csv=os.path.join(data_dir, 'tatanora_type_hull_parts.csv'),
    recipe_book_csv=os.path.join(utils_dir, 'recipe_book.csv'),
    recipe_gathering_csv=os.path.join(utils_dir, 'recipe_gathering.csv'),
    output_csv=os.path.join(data_dir, 'gathering_list.csv')
)
df_gathering_list
# Out:
#                          Ingredient  Total Quantity  \
# 19                   Adamantite Ore           120.0
# 32                       Animal Fat            81.0
# 30                Aqueous Whetstone            81.0
# 0                         Birch Log           120.0
# 33                     Black Alumen            27.0
# 15                       Cassia Log            27.0
# 14                       Cassia Log            27.0
# 31  Chemically Treated Chimera Hide            27.0
# 26                       Cloud Mica            48.0
# 6                        Cobalt Ore           123.0
# 11                             Coke            81.0
# 21                       Copper Ore            48.0
# 17                    Darksteel Ore            96.0
# 13                    Earth Cluster            18.0
# 12                     Fire Cluster            18.0
# 18                     Fire Crystal           372.0
# 9                        Fire Shard           480.0
# 35                             Flax            48.0
# 23                     Gelato Flesh           270.0
# 20                         Gold Ore           144.0
# 28                      Grenade Ash            12.0
# 16                     Hardened Sap            81.0
# 5                       Ice Cluster            21.0
# 7                          Iron Ore            60.0
# 8                          Iron Ore            60.0
# 22                      Peacock Ore           216.0
# 2                     Petrified Log            12.0
# 24                    Pudding Flesh           180.0
# 34                        Raw Amber            48.0
# 29                    Raw Celestine            27.0
# 3                       Scarlet Sap            12.0
# 37                        Terebinth            24.0
# 27                     Titanium Ore            60.0
# 10                        Vivianite            27.0
# 25                    Water Crystal           270.0
# 36                      Water Shard           192.0
# 4                      Wind Cluster            84.0
# 1                      Wind Crystal           264.0
#
#                                         Location Info
# 19       Azys Lla ( 23.2 / 5.8 ), Timed at 12AM/PM ET
# 32       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 30       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 0               The Sea of Clouds ( 24 / 34 ), Hidden
# 33                       South Shroud ( 28.7 / 22.8 )
# 15  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 14  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 31  Nowhere ( 0.0 / 0.0 ), Gathered by Company Wor...
# 26                 The Churning Mists ( 27.6 / 19.2 )
# 6                   Northern Thanalan ( 23.1 / 24.2 )
# 11       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 21                   Central Thanalan ( 19.0 / 26.2 )
# 17  Coerthas Central Highlands ( 27.5 / 20.0 ), Ti...
# 13                                                NaN
# 12                                                NaN
# 18                                                NaN
# 9                                                 NaN
# 35                       South Shroud ( 17.6 / 28.6 )
# 23  Coerthas Western Highlands ( 9.4 / 18.8 ),  Dr...
# 20  Eastern Thanalan ( 27.3 / 21.3 ), Timed at 10:...
# 28  Nowhere ( 0.0 / 0.0 ), Purchased from Z'ranmai...
# 16       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 5                                                 NaN
# 7                    Western Thanalan ( 27.2 / 17.4 )
# 8    Nowhere ( 0.0 / 0.0 ), Sold by Material Supplier
# 22       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 2       Nowhere ( 0.0 / 0.0 ), Sold for 1500 GC Seals
# 24       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 34                   Eastern Thanalan ( 12.7 / 19.1 )
# 29  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 3       North Shroud ( 17.7 / 27.7 ), Timed at 1:00am
# 37      Nowhere ( 0.0 / 0.0 ), Sold by Main City NPCs
# 27            The Dravanian Forelands ( 30.3 / 15.1 )
# 10  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 25                                                NaN
# 36                                                NaN
# 4                                                 NaN
# 1                                                 NaN

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import get_crafting_recipes
data_dir = 'item_data/'
df_crafting_recipes = get_crafting_recipes(os.path.join(data_dir, 'tatanora_type_hull_parts.csv'))
df_crafting_recipes
# Out:
#                          Product  Required Quantity
# 6              Adamantite Rivets                 24
# 1                 Ancient Lumber                 12
# 0                   Birch Lumber                 24
# 4                  Cassia Lumber                  9
# 11                     Celestine                  9
# 2                   Cobalt Nails                 24
# 9                  Cobalt Rivets                 24
# 5               Darksteel Rivets                 24
# 3                  Garlond Steel                  9
# 12  High Allagan Chimera Leather                  9
# 7                Rose Gold Ingot                 24
# 10                Titanium Ingot                 12
# 13                       Varnish                 24
# 8                      Void Glue                 90
