# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import generate_gathering_list
utils_dir = '../../utilities/'
data_dir = 'item_data/'
df_gathering_list = generate_gathering_list(
    total_csv=os.path.join(data_dir, 'total_tatanora_type_airship_parts.csv'),
    recipe_book_csv=os.path.join(utils_dir, 'recipe_book.csv'),
    recipe_gathering_csv=os.path.join(utils_dir, 'recipe_gathering.csv'),
    output_csv=os.path.join(data_dir, 'gathering_list.csv')
)
df_gathering_list
# Out:
#                          Ingredient  Total Quantity  \
# 0                    Adamantite Ore           525.0
# 26                       Animal Fat           162.0
# 15                Aqueous Whetstone           324.0
# 7                  Aurum Regis Sand            90.0
# 10                        Birch Log           120.0
# 27                     Black Alumen            54.0
# 12                       Cassia Log           135.0
# 11                       Cassia Log           135.0
# 25  Chemically Treated Chimera Hide            54.0
# 33                       Cloud Mica           252.0
# 17                       Cobalt Ore           684.0
# 22                             Coke           756.0
# 31                       Copper Ore            48.0
# 1                     Darksteel Ore           978.0
# 24                    Earth Cluster            54.0
# 16                     Fire Cluster           120.0
# 2                      Fire Crystal          2253.0
# 20                       Fire Shard          2520.0
# 37                             Flax            48.0
# 40                     Gelato Flesh           270.0
# 8                          Gold Ore           162.0
# 35                      Grenade Ash            63.0
# 13                     Hardened Sap           405.0
# 6                       Ice Cluster            57.0
# 21                        Ice Shard           600.0
# 19                         Iron Ore           351.0
# 18                         Iron Ore           351.0
# 28                      Mythril Ore           123.0
# 29                     Mythrite Ore           132.0
# 30                    Mythrite Sand           165.0
# 32                      Peacock Ore           216.0
# 3                     Petrified Log            12.0
# 41                    Pudding Flesh           180.0
# 36                        Raw Amber            48.0
# 14                    Raw Celestine           108.0
# 4                       Scarlet Sap            12.0
# 39                        Terebinth            24.0
# 34                     Titanium Ore           315.0
# 23                        Vivianite           108.0
# 42                    Water Crystal           270.0
# 38                      Water Shard           192.0
# 5                      Wind Cluster           192.0
# 9                      Wind Crystal           354.0
#
#                                         Location Info
# 0        Azys Lla ( 23.2 / 5.8 ), Timed at 12AM/PM ET
# 26       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 15       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 7                   The Sea of Clouds ( 34.8 / 30.5 )
# 10              The Sea of Clouds ( 24 / 34 ), Hidden
# 27                       South Shroud ( 28.7 / 22.8 )
# 12  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 11  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 25  Nowhere ( 0.0 / 0.0 ), Gathered by Company Wor...
# 33                 The Churning Mists ( 27.6 / 19.2 )
# 17                  Northern Thanalan ( 23.1 / 24.2 )
# 22       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 31                   Central Thanalan ( 19.0 / 26.2 )
# 1   Coerthas Central Highlands ( 27.5 / 20.0 ), Ti...
# 24                                                NaN
# 16                                                NaN
# 2                                                 NaN
# 20                                                NaN
# 37                       South Shroud ( 17.6 / 28.6 )
# 40  Coerthas Western Highlands ( 9.4 / 18.8 ),  Dr...
# 8   Eastern Thanalan ( 27.3 / 21.3 ), Timed at 10:...
# 35  Nowhere ( 0.0 / 0.0 ), Purchased from Z'ranmai...
# 13       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 6                                                 NaN
# 21                                                NaN
# 19   Nowhere ( 0.0 / 0.0 ), Sold by Material Supplier
# 18                   Western Thanalan ( 27.2 / 17.4 )
# 28                  Southern Thanalan ( 25.2 / 39.9 )
# 29         Coerthas Western Highlands ( 31.2 / 12.8 )
# 30         Coerthas Western Highlands ( 16.6 / 13.1 )
# 32       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 3       Nowhere ( 0.0 / 0.0 ), Sold for 1500 GC Seals
# 41       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 36                   Eastern Thanalan ( 12.7 / 19.1 )
# 14  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 4       North Shroud ( 17.7 / 27.7 ), Timed at 1:00am
# 39      Nowhere ( 0.0 / 0.0 ), Sold by Main City NPCs
# 34            The Dravanian Forelands ( 30.3 / 15.1 )
# 23  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 42                                                NaN
# 38                                                NaN
# 5                                                 NaN
# 9                                                 NaN

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import get_crafting_recipes
data_dir = 'item_data/'
df_crafting_recipes = get_crafting_recipes(os.path.join(data_dir, 'total_tatanora_type_airship_parts.csv'))
df_crafting_recipes
# Out:
#                          Product  Required Quantity  \
# 0              Adamantite Nugget                 81
# 1              Adamantite Rivets                 24
# 2                 Ancient Lumber                 12
# 3             Aurum Regis Nugget                 18
# 4                   Birch Lumber                 24
# 5                  Cassia Lumber                 45
# 6                      Celestine                 36
# 7             Cobalt Joint Plate                120
# 8                   Cobalt Nails                 54
# 9                  Cobalt Rivets                114
# 10               Darksteel Ingot                 48
# 11              Darksteel Nugget                 30
# 12              Darksteel Rivets                165
# 13                 Garlond Steel                 36
# 14  High Allagan Chimera Leather                 18
# 15                Mythril Rivets                 30
# 16                Mythrite Ingot                 33
# 17               Rose Gold Ingot                 24
# 18                Titanium Ingot                 63
# 19                       Varnish                 24
# 20                     Void Glue                 90
#
#                                   2  3                  4  5              6  \
# 0                    Adamantite Ore  5      Darksteel Ore  1           None
# 1                 Adamantite Nugget  1       Fire Crystal  5           None
# 2                     Petrified Log  1        Scarlet Sap  1   Wind Cluster
# 3                  Aurum Regis Sand  5           Gold Ore  1   Wind Crystal
# 4                         Birch Log  5       Wind Crystal  5           None
# 5                        Cassia Log  3       Hardened Sap  9   Wind Cluster
# 6                     Raw Celestine  3  Aqueous Whetstone  9   Wind Cluster
# 7                      Cobalt Ingot  1          Ice Shard  5           None
# 8                      Cobalt Ingot  1         Fire Shard  5           None
# 9                      Cobalt Ingot  1         Fire Shard  5           None
# 10                 Darksteel Nugget  2               Coke  9   Fire Cluster
# 11                    Darksteel Ore  3       Fire Crystal  3           None
# 12                 Darksteel Nugget  1       Fire Crystal  3           None
# 13                        Vivianite  3               Coke  9     Cobalt Ore
# 14  Chemically Treated Chimera Hide  3         Animal Fat  9   Black Alumen
# 15                    Mythril Ingot  1         Fire Shard  5           None
# 16                     Mythrite Ore  4    Mythrite Nugget  1   Fire Crystal
# 17                 Rose Gold Nugget  2        Peacock Ore  9   Wind Cluster
# 18                       Cloud Mica  4    Titanium Nugget  1   Fire Crystal
# 19                        Raw Amber  2        Linseed Oil  1      Terebinth
# 20                     Gelato Flesh  3      Pudding Flesh  2  Water Crystal
#
#       7              8    9             10   11
# 0   NaN           None  NaN           None  NaN
# 1   NaN           None  NaN           None  NaN
# 2   2.0    Ice Cluster  1.0           None  NaN
# 3   5.0           None  NaN           None  NaN
# 4   NaN           None  NaN           None  NaN
# 5   2.0    Ice Cluster  1.0           None  NaN
# 6   1.0   Fire Cluster  1.0           None  NaN
# 7   NaN           None  NaN           None  NaN
# 8   NaN           None  NaN           None  NaN
# 9   NaN           None  NaN           None  NaN
# 10  1.0           None  NaN           None  NaN
# 11  NaN           None  NaN           None  NaN
# 12  NaN           None  NaN           None  NaN
# 13  3.0   Fire Cluster  1.0  Earth Cluster  1.0
# 14  3.0  Earth Cluster  1.0   Wind Cluster  1.0
# 15  NaN           None  NaN           None  NaN
# 16  3.0           None  NaN           None  NaN
# 17  1.0           None  NaN           None  NaN
# 18  5.0           None  NaN           None  NaN
# 19  1.0    Water Shard  5.0           None  NaN
# 20  3.0           None  NaN           None  NaN

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import fetch_market_data_for_subparts
utils_dir = '../../utilities/'
data_dir = 'item_data/'
df_market_data = fetch_market_data_for_subparts(
    gathering_csv=os.path.join(data_dir, 'gathering_list.csv'),
    crafting_csv=os.path.join(utils_dir, 'recipe_book.csv'),
    item_ids_json=os.path.join(utils_dir, 'item_ids.json'),
    output_csv=os.path.join(data_dir, 'airship_parts_market_data.csv'),
    world="Seraph"
)
df_market_data
# Out:
#                         Item Name   Category Item ID minListing_world  \
# 0                  Adamantite Ore  Gathering   12538              119
# 1                      Animal Fat  Gathering    5531              149
# 2               Aqueous Whetstone  Gathering    5261              441
# 3                Aurum Regis Sand  Gathering   12533              270
# 4                       Birch Log  Gathering   12579                1
# ..                            ...        ...     ...              ...
# 142                  Cobalt Nails   Crafting    7020              250
# 143                  Cobalt Rings   Crafting    5084               37
# 144               Dhalmel Leather   Crafting   12564             5000
# 145  High Allagan Chimera Leather   Crafting   12233             1495
# 146            Amphiptere Leather   Crafting   12566              275
#
#     minListing_dc recentPurchase_world recentPurchase_dc averageSalePrice_dc  \
# 0             119                  200               498          238.975917
# 1             149                  147               147          216.653614
# 2             274                  449               350          285.684545
# 3             132                  200               450          218.789157
# 4               1                  100               100          139.278986
# ..            ...                  ...               ...                 ...
# 142            20                   90               800                None
# 143            37                  155               730          469.888889
# 144          2999                 4123              3000         2780.477273
# 145           493                 2000              1000          713.727273
# 146            50                  323               500          328.926471
#
#     dailySaleVelocity_dc
# 0              476.19308
# 1              86.532981
# 2            2580.345231
# 3             129.798905
# 4             143.873175
# ..                   ...
# 142                 None
# 143             4.690096
# 144            57.323272
# 145             2.866157
# 146            17.718023
#
# [144 rows x 9 columns]
