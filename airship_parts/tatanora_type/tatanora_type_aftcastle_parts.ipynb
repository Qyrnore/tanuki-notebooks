# %%
from tatanora_type_airship_parts import generate_gathering_list

# Generate the gathering list and save to 'gathering_list.csv'
df_gathering_list = generate_gathering_list(
    total_csv='tatanora_type_aftcastle_parts.csv',
    recipe_book_csv='recipe_book.csv',
    recipe_gathering_csv='recipe_gathering.csv',
    output_csv='gathering_list.csv'
)

df_gathering_list  # Display the gathering list
# Out:
#                          Ingredient  Total Quantity  \
# 0                    Adamantite Ore           150.0
# 26                       Animal Fat            81.0
# 24                Aqueous Whetstone            81.0
# 20                 Aurum Regis Sand            90.0
# 27                     Black Alumen            27.0
# 16                       Cassia Log            27.0
# 15                       Cassia Log            27.0
# 25  Chemically Treated Chimera Hide            27.0
# 12                       Cloud Mica            72.0
# 2                        Cobalt Ore           207.0
# 8                              Coke           189.0
# 1                     Darksteel Ore           246.0
# 10                    Earth Cluster            18.0
# 9                      Fire Cluster            30.0
# 11                     Fire Crystal           522.0
# 5                        Fire Shard           600.0
# 21                         Gold Ore            18.0
# 14                      Grenade Ash            18.0
# 17                     Hardened Sap            81.0
# 19                      Ice Cluster             9.0
# 6                         Ice Shard           300.0
# 4                          Iron Ore           108.0
# 3                          Iron Ore           108.0
# 23                    Raw Celestine            27.0
# 13                     Titanium Ore            90.0
# 7                         Vivianite            27.0
# 18                     Wind Cluster            36.0
# 22                     Wind Crystal            90.0
#
#                                         Location Info
# 0        Azys Lla ( 23.2 / 5.8 ), Timed at 12AM/PM ET
# 26       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 24       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 20                  The Sea of Clouds ( 34.8 / 30.5 )
# 27                       South Shroud ( 28.7 / 22.8 )
# 16  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 15  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 25  Nowhere ( 0.0 / 0.0 ), Gathered by Company Wor...
# 12                 The Churning Mists ( 27.6 / 19.2 )
# 2                   Northern Thanalan ( 23.1 / 24.2 )
# 8        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 1   Coerthas Central Highlands ( 27.5 / 20.0 ), Ti...
# 10                                                NaN
# 9                                                 NaN
# 11                                                NaN
# 5                                                 NaN
# 21  Eastern Thanalan ( 27.3 / 21.3 ), Timed at 10:...
# 14  Nowhere ( 0.0 / 0.0 ), Purchased from Z'ranmai...
# 17       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 19                                                NaN
# 6                                                 NaN
# 4    Nowhere ( 0.0 / 0.0 ), Sold by Material Supplier
# 3                    Western Thanalan ( 27.2 / 17.4 )
# 23  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 13            The Dravanian Forelands ( 30.3 / 15.1 )
# 7   Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 18                                                NaN
# 22                                                NaN

# %%
from tatanora_type_airship_parts import get_crafting_recipes

# Get the crafting recipes from total_tatanora_type_airship_parts.csv
df_crafting_recipes = get_crafting_recipes('tatanora_type_aftcastle_parts.csv')
df_crafting_recipes  # Display the crafting recipes list
# Out:
#                          Product  Required Quantity
# 0              Adamantite Nugget                 30
# 8             Aurum Regis Nugget                 18
# 7                  Cassia Lumber                  9
# 9                      Celestine                  9
# 1             Cobalt Joint Plate                 60
# 2                  Cobalt Rivets                 30
# 6                Darksteel Ingot                 12
# 4               Darksteel Rivets                 48
# 3                  Garlond Steel                  9
# 10  High Allagan Chimera Leather                  9
# 5                 Titanium Ingot                 18
