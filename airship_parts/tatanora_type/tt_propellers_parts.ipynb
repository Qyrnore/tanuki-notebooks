# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import generate_gathering_list
utils_dir = '../../utilities/'
data_dir = 'item_data/'
df_gathering_list = generate_gathering_list(
    total_csv=os.path.join(data_dir, 'tatanora_type_propellers_parts.csv'),
    recipe_book_csv=os.path.join(utils_dir, 'recipe_book.csv'),
    recipe_gathering_csv=os.path.join(utils_dir, 'recipe_gathering.csv'),
    output_csv=os.path.join(data_dir, 'gathering_list.csv')
)
df_gathering_list
# Out:
#            Ingredient  Total Quantity  \
# 11     Adamantite Ore           150.0
# 21  Aqueous Whetstone            81.0
# 0          Cassia Log            27.0
# 1          Cassia Log            27.0
# 17         Cloud Mica            60.0
# 5          Cobalt Ore           207.0
# 12               Coke           243.0
# 9       Darksteel Ore           363.0
# 23      Earth Cluster             9.0
# 13       Fire Cluster            36.0
# 10       Fire Crystal           693.0
# 8          Fire Shard           900.0
# 19        Grenade Ash            15.0
# 2        Hardened Sap            81.0
# 4         Ice Cluster             9.0
# 7            Iron Ore           105.0
# 6            Iron Ore           105.0
# 16        Mythril Ore            15.0
# 14       Mythrite Ore            60.0
# 15      Mythrite Sand            75.0
# 20      Raw Celestine            27.0
# 18       Titanium Ore            75.0
# 22          Vivianite            27.0
# 3        Wind Cluster            27.0
#
#                                         Location Info
# 11       Azys Lla ( 23.2 / 5.8 ), Timed at 12AM/PM ET
# 21       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 0   Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 1   Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 17                 The Churning Mists ( 27.6 / 19.2 )
# 5                   Northern Thanalan ( 23.1 / 24.2 )
# 12       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 9   Coerthas Central Highlands ( 27.5 / 20.0 ), Ti...
# 23                                                NaN
# 13                                                NaN
# 10                                                NaN
# 8                                                 NaN
# 19  Nowhere ( 0.0 / 0.0 ), Purchased from Z'ranmai...
# 2        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 4                                                 NaN
# 7    Nowhere ( 0.0 / 0.0 ), Sold by Material Supplier
# 6                    Western Thanalan ( 27.2 / 17.4 )
# 16                  Southern Thanalan ( 25.2 / 39.9 )
# 14         Coerthas Western Highlands ( 31.2 / 12.8 )
# 15         Coerthas Western Highlands ( 16.6 / 13.1 )
# 20  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 18            The Dravanian Forelands ( 30.3 / 15.1 )
# 22  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 3                                                 NaN

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import get_crafting_recipes
data_dir = 'item_data/'
df_crafting_recipes = get_crafting_recipes(os.path.join(data_dir, 'tatanora_type_propellers_parts.csv'))
df_crafting_recipes
# Out:
#               Product  Required Quantity
# 4   Adamantite Nugget                 30
# 0       Cassia Lumber                  9
# 9           Celestine                  9
# 1        Cobalt Nails                 30
# 3       Cobalt Rivets                 60
# 5     Darksteel Ingot                 18
# 2    Darksteel Nugget                 30
# 6    Darksteel Rivets                 45
# 10      Garlond Steel                  9
# 7      Mythrite Ingot                 15
# 8      Titanium Ingot                 15
