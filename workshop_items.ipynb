# %%
from workshop_items import consolidate_csv_files
consolidated_data = consolidate_csv_files()
if consolidated_data is not None:
    display(consolidated_data)
# Out:
# Consolidated CSV saved to utilities/workshop_output.csv (without headers)
#                      Item  Quantity
# 0          Ancient Lumber       144
# 1            Cedar Lumber        72
# 2            Cobalt Ingot      1200
# 3      Cobalt Joint Plate       432
# 4           Cobalt Rivets       168
# 5         Darksteel Ingot       360
# 6        Darksteel Nugget       168
# 7          Electrum Ingot       312
# 8               Horn Glue       144
# 9              Iron Nails       312
# 10            Iron Rivets       312
# 11          Mythril Plate       144
# 12         Mythril Rivets       624
# 13        Rose Gold Ingot       168
# 14           Silver Ingot       480
# 15          Spruce Lumber       144
# 16            Steel Ingot       840
# 17      Steel Joint Plate       480
# 18           Steel Rivets      1008
# 19  Treated Spruce Lumber        96
# 20                Varnish       144
# 21          Walnut Lumber       144

# %%
import os
from workshop_items import generate_gathering_list
utils_dir = 'utilities/'
df_gathering_list = generate_gathering_list(
    total_csv=os.path.join(utils_dir, 'workshop_output.csv'),
    recipe_book_csv=os.path.join(utils_dir, 'recipe_book.csv'),
    recipe_gathering_csv=os.path.join(utils_dir, 'recipe_gathering.csv'),
    output_csv=os.path.join(utils_dir, 'gathering_list.csv')
)
for method, group in df_gathering_list.groupby('Method'):
    print(f"\n=== {method} ===")
    print(group.to_markdown(index=False))
# Out:
# === crystal ===
# | Ingredient   |   Total Quantity | Method   | Location Info   |
# |:-------------|-----------------:|:---------|:----------------|
# | Fire Cluster |              360 | crystal  |                 |
# | Fire Crystal |             2664 | crystal  |                 |
# | Fire Shard   |            24624 | crystal  |                 |
# | Ice Cluster  |              144 | crystal  |                 |
# | Ice Shard    |             4176 | crystal  |                 |
# | Water Shard  |             1584 | crystal  |                 |
#
# === drop ===
# | Ingredient   |   Total Quantity | Method   | Location Info                                                |
# |:-------------|-----------------:|:---------|:-------------------------------------------------------------|
# | Aldgoat Horn |              288 | drop     | Eastern Thanalan ( 18.2 / 22.7 ), Dropped by Myotragus Billy |
#
# === gc seals ===
# | Ingredient    |   Total Quantity | Method   | Location Info                                 |
# |:--------------|-----------------:|:---------|:----------------------------------------------|
# | Coke          |             3240 | gc seals | Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals  |
# | Hardened Sap  |              864 | gc seals | Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals  |
# | Peacock Ore   |             1512 | gc seals | Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals  |
# | Petrified Log |              144 | gc seals | Nowhere ( 0.0 / 0.0 ), Sold for 1500 GC Seals |
#
# === normal ===
# | Ingredient   |   Total Quantity | Method   | Location Info                              |
# |:-------------|-----------------:|:---------|:-------------------------------------------|
# | Bomb Ash     |             2328 | normal   | Southern Thanalan ( 22.2 / 29.9 )          |
# | Cedar Log    |              360 | normal   | Coerthas Western Highlands ( 31.3 / 32.1 ) |
# | Cobalt Ore   |             3600 | normal   | Northern Thanalan ( 23.1 / 24.2 )          |
# | Electrum Ore |             1248 | normal   | Upper La Noscea ( 30.4 / 25.4 )            |
# | Flax         |              288 | normal   | South Shroud ( 17.6 / 28.6 )               |
# | Mythril Ore  |             2736 | normal   | Southern Thanalan ( 25.2 / 39.9 )          |
# | Raw Amber    |              288 | normal   | Eastern Thanalan ( 12.7 / 19.1 )           |
# | Silver Ore   |             1440 | normal   | South Shroud ( 16.1 / 19.7 )               |
# | Walnut Log   |              432 | normal   | South Shroud ( 23.1 / 21.6 )               |
#
# === npc ===
# | Ingredient   |   Total Quantity | Method   | Location Info                                                      |
# |:-------------|-----------------:|:---------|:-------------------------------------------------------------------|
# | Copper Ore   |              336 | npc      | Purchased from BSM/ARM Guild Vendor Outside                        |
# | Iron Ore     |             8328 | npc      | Nowhere ( 0.0 / 0.0 ), Purchased from BSM/ARM Guild Vendor Outside |
# | Terebinth    |              144 | npc      | Nowhere ( 0.0 / 0.0 ), Sold by Main City NPCs                      |
#
# === timed node ===
# | Ingredient    |   Total Quantity | Method     | Location Info                                                |
# |:--------------|-----------------:|:-----------|:-------------------------------------------------------------|
# | Darksteel Ore |             2664 | timed node | Coerthas Central Highlands ( 27.5 / 20.0 ), Timed at 1:00am  |
# | Gold Ore      |             1008 | timed node | Eastern Thanalan ( 27.3 / 21.3 ), Timed at 10:00am           |
# | Scarlet Sap   |              144 | timed node | North Shroud ( 17.7 / 27.7 ), Timed at 1:00am                |
# | Spruce Log    |             1008 | timed node | Coerthas Central Highlands ( 29.5 / 13.1 ), Timed at 10:00am |

# %%
from workshop_items import print_recipe_tree

utils = "utilities"
print_recipe_tree(
    recipe_book_csv=os.path.join(utils, 'recipe_book.csv'),
    recipe_gathering_csv=os.path.join(utils, 'recipe_gathering.csv'),
    total_csv=os.path.join(utils, 'workshop_output.csv')
)
# Out:
# === Recipe Breakdown ===
# ├── Ancient Lumber (x 144)
# │   ├── Petrified Log (x 144)  [gc seals @ Nowhere ( 0.0 / 0.0 ), Sold for 1500 GC Seals]
# │   ├── Scarlet Sap (x 144)  [timed node @ North Shroud ( 17.7 / 27.7 ), Timed at 1:00am]
# │   ├── Wind Cluster (x 288)  [nan @ ]
# │   └── Ice Cluster (x 144)  [crystal @ ]
# ├── Cedar Lumber (x 72)
# │   ├── Cedar Log (x 360)  [normal @ Coerthas Western Highlands ( 31.3 / 32.1 )]
# │   └── Wind Crystal (x 216)  [nan @ ]
# ├── Cobalt Ingot (x 1200)
# │   ├── Cobalt Ore (x 2400)  [normal @ Northern Thanalan ( 23.1 / 24.2 )]
# │   ├── Iron Ore (x 1200)  [npc @ Nowhere ( 0.0 / 0.0 ), Purchased from BSM/ARM Guild Vendor Outside]
# │   └── Fire Shard (x 6000)  [crystal @ ]
# ├── Cobalt Joint Plate (x 432)
# │   ├── Cobalt Ingot (x 432)
# │   │   ├── Cobalt Ore (x 864)  [normal @ Northern Thanalan ( 23.1 / 24.2 )]
# │   │   ├── Iron Ore (x 432)  [npc @ Nowhere ( 0.0 / 0.0 ), Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Fire Shard (x 2160)  [crystal @ ]
# │   └── Ice Shard (x 2160)  [crystal @ ]
# ├── Cobalt Rivets (x 168)
# │   ├── Cobalt Ingot (x 168)
# │   │   ├── Cobalt Ore (x 336)  [normal @ Northern Thanalan ( 23.1 / 24.2 )]
# │   │   ├── Iron Ore (x 168)  [npc @ Nowhere ( 0.0 / 0.0 ), Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Fire Shard (x 840)  [crystal @ ]
# │   └── Fire Shard (x 840)  [crystal @ ]
# ├── Darksteel Ingot (x 360)
# │   ├── Darksteel Nugget (x 720)
# │   │   ├── Darksteel Ore (x 2160)  [timed node @ Coerthas Central Highlands ( 27.5 / 20.0 ), Timed at 1:00am]
# │   │   └── Fire Crystal (x 2160)  [crystal @ ]
# │   ├── Coke (x 3240)  [gc seals @ Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals]
# │   └── Fire Cluster (x 360)  [crystal @ ]
# ├── Darksteel Nugget (x 168)
# │   ├── Darksteel Ore (x 504)  [timed node @ Coerthas Central Highlands ( 27.5 / 20.0 ), Timed at 1:00am]
# │   └── Fire Crystal (x 504)  [crystal @ ]
# ├── Electrum Ingot (x 312)
# │   ├── Electrum Ore (x 1248)  [normal @ Upper La Noscea ( 30.4 / 25.4 )]
# │   └── Wind Shard (x 1560)  [nan @ ]
# ├── Horn Glue (x 144)
# │   ├── Aldgoat Horn (x 288)  [drop @ Eastern Thanalan ( 18.2 / 22.7 ), Dropped by Myotragus Billy]
# │   └── Water Shard (x 432)  [crystal @ ]
# ├── Iron Nails (x 312)
# │   ├── Iron Ingot (x 312)
# │   │   ├── Iron Ore (x 936)  [npc @ Nowhere ( 0.0 / 0.0 ), Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Fire Shard (x 312)  [crystal @ ]
# │   └── Fire Shard (x 312)  [crystal @ ]
# ├── Iron Rivets (x 312)
# │   ├── Iron Ingot (x 312)
# │   │   ├── Iron Ore (x 936)  [npc @ Nowhere ( 0.0 / 0.0 ), Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Fire Shard (x 312)  [crystal @ ]
# │   └── Fire Shard (x 312)  [crystal @ ]
# ├── Mythril Plate (x 144)
# │   ├── Mythril Ingot (x 288)
# │   │   ├── Mythril Ore (x 864)  [normal @ Southern Thanalan ( 25.2 / 39.9 )]
# │   │   └── Fire Shard (x 864)  [crystal @ ]
# │   └── Ice Shard (x 576)  [crystal @ ]
# ├── Mythril Rivets (x 624)
# │   ├── Mythril Ingot (x 624)
# │   │   ├── Mythril Ore (x 1872)  [normal @ Southern Thanalan ( 25.2 / 39.9 )]
# │   │   └── Fire Shard (x 1872)  [crystal @ ]
# │   └── Fire Shard (x 3120)  [crystal @ ]
# ├── Rose Gold Ingot (x 168)
# │   ├── Rose Gold Nugget (x 336)
# │   │   ├── Gold Ore (x 1008)  [timed node @ Eastern Thanalan ( 27.3 / 21.3 ), Timed at 10:00am]
# │   │   ├── Copper Ore (x 336)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Wind Crystal (x 1008)  [nan @ ]
# │   ├── Peacock Ore (x 1512)  [gc seals @ Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals]
# │   └── Wind Cluster (x 168)  [nan @ ]
# ├── Silver Ingot (x 480)
# │   ├── Silver Ore (x 1440)  [normal @ South Shroud ( 16.1 / 19.7 )]
# │   └── Wind Shard (x 960)  [nan @ ]
# ├── Spruce Lumber (x 144)
# │   ├── Spruce Log (x 432)  [timed node @ Coerthas Central Highlands ( 29.5 / 13.1 ), Timed at 10:00am]
# │   └── Wind Crystal (x 432)  [nan @ ]
# ├── Steel Ingot (x 840)
# │   ├── Bomb Ash (x 840)  [normal @ Southern Thanalan ( 22.2 / 29.9 )]
# │   ├── Iron Ore (x 1680)  [npc @ Nowhere ( 0.0 / 0.0 ), Purchased from BSM/ARM Guild Vendor Outside]
# │   └── Fire Shard (x 1680)  [crystal @ ]
# ├── Steel Joint Plate (x 480)
# │   ├── Steel Ingot (x 480)
# │   │   ├── Bomb Ash (x 480)  [normal @ Southern Thanalan ( 22.2 / 29.9 )]
# │   │   ├── Iron Ore (x 960)  [npc @ Nowhere ( 0.0 / 0.0 ), Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Fire Shard (x 960)  [crystal @ ]
# │   └── Ice Shard (x 1440)  [crystal @ ]
# ├── Steel Rivets (x 1008)
# │   ├── Steel Ingot (x 1008)
# │   │   ├── Bomb Ash (x 1008)  [normal @ Southern Thanalan ( 22.2 / 29.9 )]
# │   │   ├── Iron Ore (x 2016)  [npc @ Nowhere ( 0.0 / 0.0 ), Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Fire Shard (x 2016)  [crystal @ ]
# │   └── Fire Shard (x 3024)  [crystal @ ]
# ├── Treated Spruce Lumber (x 96)
# │   ├── Spruce Lumber (x 192)
# │   │   ├── Spruce Log (x 576)  [timed node @ Coerthas Central Highlands ( 29.5 / 13.1 ), Timed at 10:00am]
# │   │   └── Wind Crystal (x 576)  [nan @ ]
# │   ├── Hardened Sap (x 864)  [gc seals @ Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals]
# │   └── Wind Cluster (x 96)  [nan @ ]
# ├── Varnish (x 144)
# │   ├── Raw Amber (x 288)  [normal @ Eastern Thanalan ( 12.7 / 19.1 )]
# │   ├── Linseed Oil (x 144)
# │   │   ├── Flax (x 288)  [normal @ South Shroud ( 17.6 / 28.6 )]
# │   │   └── Water Shard (x 432)  [crystal @ ]
# │   ├── Terebinth (x 144)  [npc @ Nowhere ( 0.0 / 0.0 ), Sold by Main City NPCs]
# │   └── Water Shard (x 720)  [crystal @ ]
# └── Walnut Lumber (x 144)
#     ├── Walnut Log (x 432)  [normal @ South Shroud ( 23.1 / 21.6 )]
#     └── Wind Shard (x 288)  [nan @ ]
