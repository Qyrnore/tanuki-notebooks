# %%
from workshop_items import consolidate_csv_files
consolidated_data = consolidate_csv_files()
if consolidated_data is not None:
    display(consolidated_data)
# Out:
# Consolidated CSV saved to utilities/workshop_output.csv (without headers)
#                      Item  Quantity
# 0          Ancient Lumber        36
# 1            Cedar Lumber        18
# 2            Cobalt Ingot       300
# 3      Cobalt Joint Plate       108
# 4           Cobalt Rivets        42
# 5         Darksteel Ingot        90
# 6        Darksteel Nugget        42
# 7          Electrum Ingot        78
# 8               Horn Glue        36
# 9              Iron Nails        78
# 10            Iron Rivets        78
# 11          Mythril Plate        36
# 12         Mythril Rivets       156
# 13        Rose Gold Ingot        42
# 14           Silver Ingot       120
# 15          Spruce Lumber        36
# 16            Steel Ingot       210
# 17      Steel Joint Plate       120
# 18           Steel Rivets       252
# 19  Treated Spruce Lumber        24
# 20                Varnish        36
# 21          Walnut Lumber        36

# %%
import os
from workshop_items import generate_gathering_list
utils_dir = 'utilities/'
df_gathering_list = generate_gathering_list(
    total_csv=os.path.join(utils_dir, 'workshop_output.csv'),
    recipe_book_csv=os.path.join(utils_dir, 'recipe_book.csv'),
    recipe_gathering_csv=os.path.join(utils_dir, 'recipe_gathering.csv'),
    output_csv=os.path.join(utils_dir, 'gathering_list.csv')
)
for method, group in df_gathering_list.groupby('Method'):
    print(f"\n=== {method} ===")
    print(group.to_markdown(index=False))
# Out:
# === drop ===
#   Ingredient  Total Quantity Method                                                Location Info
# Aldgoat Horn            72.0   drop Eastern Thanalan ( 18.2 / 22.7 ), Dropped by Myotragus Billy
#
# === gc seals ===
#    Ingredient  Total Quantity   Method                                 Location Info
#          Coke           810.0 gc seals  Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
#  Hardened Sap           216.0 gc seals  Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
#   Peacock Ore           378.0 gc seals  Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# Petrified Log            36.0 gc seals Nowhere ( 0.0 / 0.0 ), Sold for 1500 GC Seals
#
# === normal ===
#   Ingredient  Total Quantity Method                              Location Info
#     Bomb Ash           582.0 normal          Southern Thanalan ( 22.2 / 29.9 )
#    Cedar Log            90.0 normal Coerthas Western Highlands ( 31.3 / 32.1 )
#   Cobalt Ore           900.0 normal          Northern Thanalan ( 23.1 / 24.2 )
# Electrum Ore           312.0 normal            Upper La Noscea ( 30.4 / 25.4 )
#         Flax            72.0 normal               South Shroud ( 17.6 / 28.6 )
#  Mythril Ore           684.0 normal          Southern Thanalan ( 25.2 / 39.9 )
#    Raw Amber            72.0 normal           Eastern Thanalan ( 12.7 / 19.1 )
#   Silver Ore           360.0 normal               South Shroud ( 16.1 / 19.7 )
#   Walnut Log           108.0 normal               South Shroud ( 23.1 / 21.6 )
#
# === npc ===
# Ingredient  Total Quantity Method                                                      Location Info
# Copper Ore            84.0    npc                        Purchased from BSM/ARM Guild Vendor Outside
#   Iron Ore          2082.0    npc Nowhere ( 0.0 / 0.0 ), Purchased from BSM/ARM Guild Vendor Outside
#  Terebinth            36.0    npc                      Nowhere ( 0.0 / 0.0 ), Sold by Main City NPCs
#
# === timed node ===
#    Ingredient  Total Quantity     Method                                                Location Info
# Darksteel Ore           666.0 timed node  Coerthas Central Highlands ( 27.5 / 20.0 ), Timed at 1:00am
#      Gold Ore           252.0 timed node           Eastern Thanalan ( 27.3 / 21.3 ), Timed at 10:00am
#   Scarlet Sap            36.0 timed node                North Shroud ( 17.7 / 27.7 ), Timed at 1:00am
#    Spruce Log           252.0 timed node Coerthas Central Highlands ( 29.5 / 13.1 ), Timed at 10:00am
