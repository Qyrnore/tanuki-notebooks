# %%
from workshop_items import consolidate_csv_files
consolidated_data = consolidate_csv_files()
if consolidated_data is not None:
    display(consolidated_data)
# Out:
# Consolidated CSV saved to utilities/workshop_output.csv (without headers)
#                      Item  Quantity
# 0          Ancient Lumber        72
# 1            Cedar Lumber        36
# 2            Cobalt Ingot       600
# 3      Cobalt Joint Plate       216
# 4           Cobalt Rivets        84
# 5         Darksteel Ingot       180
# 6        Darksteel Nugget        84
# 7          Electrum Ingot       156
# 8               Horn Glue        72
# 9              Iron Nails       156
# 10            Iron Rivets       156
# 11          Mythril Plate        72
# 12         Mythril Rivets       312
# 13        Rose Gold Ingot        84
# 14           Silver Ingot       240
# 15          Spruce Lumber        72
# 16            Steel Ingot       420
# 17      Steel Joint Plate       240
# 18           Steel Rivets       504
# 19  Treated Spruce Lumber        48
# 20                Varnish        72
# 21          Walnut Lumber        72

# %%
import os
from workshop_items import generate_gathering_list
utils_dir = 'utilities/'
df_gathering_list = generate_gathering_list(
    total_csv=os.path.join(utils_dir, 'workshop_output.csv'),
    recipe_book_csv=os.path.join(utils_dir, 'recipe_book.csv'),
    recipe_gathering_csv=os.path.join(utils_dir, 'recipe_gathering.csv'),
    output_csv=os.path.join(utils_dir, 'gathering_list.csv')
)
for method, group in df_gathering_list.groupby('Method'):
    print(f"\n=== {method} ===")
    print(group.to_markdown(index=False))
# Out:
# === drop ===
# | Ingredient   |   Total Quantity | Method   | Location Info                                                |
# |:-------------|-----------------:|:---------|:-------------------------------------------------------------|
# | Aldgoat Horn |              144 | drop     | Eastern Thanalan ( 18.2 / 22.7 ), Dropped by Myotragus Billy |
#
# === gc seals ===
# | Ingredient    |   Total Quantity | Method   | Location Info                                 |
# |:--------------|-----------------:|:---------|:----------------------------------------------|
# | Coke          |             1620 | gc seals | Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals  |
# | Hardened Sap  |              432 | gc seals | Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals  |
# | Peacock Ore   |              756 | gc seals | Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals  |
# | Petrified Log |               72 | gc seals | Nowhere ( 0.0 / 0.0 ), Sold for 1500 GC Seals |
#
# === normal ===
# | Ingredient   |   Total Quantity | Method   | Location Info                              |
# |:-------------|-----------------:|:---------|:-------------------------------------------|
# | Bomb Ash     |             1164 | normal   | Southern Thanalan ( 22.2 / 29.9 )          |
# | Cedar Log    |              180 | normal   | Coerthas Western Highlands ( 31.3 / 32.1 ) |
# | Cobalt Ore   |             1800 | normal   | Northern Thanalan ( 23.1 / 24.2 )          |
# | Electrum Ore |              624 | normal   | Upper La Noscea ( 30.4 / 25.4 )            |
# | Flax         |              144 | normal   | South Shroud ( 17.6 / 28.6 )               |
# | Mythril Ore  |             1368 | normal   | Southern Thanalan ( 25.2 / 39.9 )          |
# | Raw Amber    |              144 | normal   | Eastern Thanalan ( 12.7 / 19.1 )           |
# | Silver Ore   |              720 | normal   | South Shroud ( 16.1 / 19.7 )               |
# | Walnut Log   |              216 | normal   | South Shroud ( 23.1 / 21.6 )               |
#
# === npc ===
# | Ingredient   |   Total Quantity | Method   | Location Info                                                      |
# |:-------------|-----------------:|:---------|:-------------------------------------------------------------------|
# | Copper Ore   |              168 | npc      | Purchased from BSM/ARM Guild Vendor Outside                        |
# | Iron Ore     |             4164 | npc      | Nowhere ( 0.0 / 0.0 ), Purchased from BSM/ARM Guild Vendor Outside |
# | Terebinth    |               72 | npc      | Nowhere ( 0.0 / 0.0 ), Sold by Main City NPCs                      |
#
# === timed node ===
# | Ingredient    |   Total Quantity | Method     | Location Info                                                |
# |:--------------|-----------------:|:-----------|:-------------------------------------------------------------|
# | Darksteel Ore |             1332 | timed node | Coerthas Central Highlands ( 27.5 / 20.0 ), Timed at 1:00am  |
# | Gold Ore      |              504 | timed node | Eastern Thanalan ( 27.3 / 21.3 ), Timed at 10:00am           |
# | Scarlet Sap   |               72 | timed node | North Shroud ( 17.7 / 27.7 ), Timed at 1:00am                |
# | Spruce Log    |              504 | timed node | Coerthas Central Highlands ( 29.5 / 13.1 ), Timed at 10:00am |

# %%
from workshop_items import print_recipe_tree

utils = "utilities"
print_recipe_tree(
    recipe_book_csv=os.path.join(utils, 'recipe_book.csv'),
    recipe_gathering_csv=os.path.join(utils, 'recipe_gathering.csv'),
    total_csv=os.path.join(utils, 'workshop_output.csv')
)
# Out:
# === Recipe Breakdown ===
# ├── Ancient Lumber (x 72)
# │   ├── Petrified Log (x 72)  [gc seals @ Nowhere ( 0.0 / 0.0 ), Sold for 1500 GC Seals]
# │   ├── Scarlet Sap (x 72)  [timed node @ North Shroud ( 17.7 / 27.7 ), Timed at 1:00am]
# │   ├── Wind Cluster (x 144)
# │   └── Ice Cluster (x 72)
# ├── Cedar Lumber (x 36)
# │   ├── Cedar Log (x 180)  [normal @ Coerthas Western Highlands ( 31.3 / 32.1 )]
# │   └── Wind Crystal (x 108)
# ├── Cobalt Ingot (x 600)
# │   ├── Cobalt Ore (x 1200)  [normal @ Northern Thanalan ( 23.1 / 24.2 )]
# │   ├── Iron Ore (x 600)  [npc @ Nowhere ( 0.0 / 0.0 ), Purchased from BSM/ARM Guild Vendor Outside]
# │   └── Fire Shard (x 3000)
# ├── Cobalt Joint Plate (x 216)
# │   ├── Cobalt Ingot (x 216)
# │   │   ├── Cobalt Ore (x 432)  [normal @ Northern Thanalan ( 23.1 / 24.2 )]
# │   │   ├── Iron Ore (x 216)  [npc @ Nowhere ( 0.0 / 0.0 ), Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Fire Shard (x 1080)
# │   └── Ice Shard (x 1080)
# ├── Cobalt Rivets (x 84)
# │   ├── Cobalt Ingot (x 84)
# │   │   ├── Cobalt Ore (x 168)  [normal @ Northern Thanalan ( 23.1 / 24.2 )]
# │   │   ├── Iron Ore (x 84)  [npc @ Nowhere ( 0.0 / 0.0 ), Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Fire Shard (x 420)
# │   └── Fire Shard (x 420)
# ├── Darksteel Ingot (x 180)
# │   ├── Darksteel Nugget (x 360)
# │   │   ├── Darksteel Ore (x 1080)  [timed node @ Coerthas Central Highlands ( 27.5 / 20.0 ), Timed at 1:00am]
# │   │   └── Fire Crystal (x 1080)
# │   ├── Coke (x 1620)  [gc seals @ Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals]
# │   └── Fire Cluster (x 180)
# ├── Darksteel Nugget (x 84)
# │   ├── Darksteel Ore (x 252)  [timed node @ Coerthas Central Highlands ( 27.5 / 20.0 ), Timed at 1:00am]
# │   └── Fire Crystal (x 252)
# ├── Electrum Ingot (x 156)
# │   ├── Electrum Ore (x 624)  [normal @ Upper La Noscea ( 30.4 / 25.4 )]
# │   └── Wind Shard (x 780)
# ├── Horn Glue (x 72)
# │   ├── Aldgoat Horn (x 144)  [drop @ Eastern Thanalan ( 18.2 / 22.7 ), Dropped by Myotragus Billy]
# │   └── Water Shard (x 216)
# ├── Iron Nails (x 156)
# │   ├── Iron Ingot (x 156)
# │   │   ├── Iron Ore (x 468)  [npc @ Nowhere ( 0.0 / 0.0 ), Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Fire Shard (x 156)
# │   └── Fire Shard (x 156)
# ├── Iron Rivets (x 156)
# │   ├── Iron Ingot (x 156)
# │   │   ├── Iron Ore (x 468)  [npc @ Nowhere ( 0.0 / 0.0 ), Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Fire Shard (x 156)
# │   └── Fire Shard (x 156)
# ├── Mythril Plate (x 72)
# │   ├── Mythril Ingot (x 144)
# │   │   ├── Mythril Ore (x 432)  [normal @ Southern Thanalan ( 25.2 / 39.9 )]
# │   │   └── Fire Shard (x 432)
# │   └── Ice Shard (x 288)
# ├── Mythril Rivets (x 312)
# │   ├── Mythril Ingot (x 312)
# │   │   ├── Mythril Ore (x 936)  [normal @ Southern Thanalan ( 25.2 / 39.9 )]
# │   │   └── Fire Shard (x 936)
# │   └── Fire Shard (x 1560)
# ├── Rose Gold Ingot (x 84)
# │   ├── Rose Gold Nugget (x 168)
# │   │   ├── Gold Ore (x 504)  [timed node @ Eastern Thanalan ( 27.3 / 21.3 ), Timed at 10:00am]
# │   │   ├── Copper Ore (x 168)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Wind Crystal (x 504)
# │   ├── Peacock Ore (x 756)  [gc seals @ Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals]
# │   └── Wind Cluster (x 84)
# ├── Silver Ingot (x 240)
# │   ├── Silver Ore (x 720)  [normal @ South Shroud ( 16.1 / 19.7 )]
# │   └── Wind Shard (x 480)
# ├── Spruce Lumber (x 72)
# │   ├── Spruce Log (x 216)  [timed node @ Coerthas Central Highlands ( 29.5 / 13.1 ), Timed at 10:00am]
# │   └── Wind Crystal (x 216)
# ├── Steel Ingot (x 420)
# │   ├── Bomb Ash (x 420)  [normal @ Southern Thanalan ( 22.2 / 29.9 )]
# │   ├── Iron Ore (x 840)  [npc @ Nowhere ( 0.0 / 0.0 ), Purchased from BSM/ARM Guild Vendor Outside]
# │   └── Fire Shard (x 840)
# ├── Steel Joint Plate (x 240)
# │   ├── Steel Ingot (x 240)
# │   │   ├── Bomb Ash (x 240)  [normal @ Southern Thanalan ( 22.2 / 29.9 )]
# │   │   ├── Iron Ore (x 480)  [npc @ Nowhere ( 0.0 / 0.0 ), Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Fire Shard (x 480)
# │   └── Ice Shard (x 720)
# ├── Steel Rivets (x 504)
# │   ├── Steel Ingot (x 504)
# │   │   ├── Bomb Ash (x 504)  [normal @ Southern Thanalan ( 22.2 / 29.9 )]
# │   │   ├── Iron Ore (x 1008)  [npc @ Nowhere ( 0.0 / 0.0 ), Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Fire Shard (x 1008)
# │   └── Fire Shard (x 1512)
# ├── Treated Spruce Lumber (x 48)
# │   ├── Spruce Lumber (x 96)
# │   │   ├── Spruce Log (x 288)  [timed node @ Coerthas Central Highlands ( 29.5 / 13.1 ), Timed at 10:00am]
# │   │   └── Wind Crystal (x 288)
# │   ├── Hardened Sap (x 432)  [gc seals @ Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals]
# │   └── Wind Cluster (x 48)
# ├── Varnish (x 72)
# │   ├── Raw Amber (x 144)  [normal @ Eastern Thanalan ( 12.7 / 19.1 )]
# │   ├── Linseed Oil (x 72)
# │   │   ├── Flax (x 144)  [normal @ South Shroud ( 17.6 / 28.6 )]
# │   │   └── Water Shard (x 216)
# │   ├── Terebinth (x 72)  [npc @ Nowhere ( 0.0 / 0.0 ), Sold by Main City NPCs]
# │   └── Water Shard (x 360)
# └── Walnut Lumber (x 72)
#     ├── Walnut Log (x 216)  [normal @ South Shroud ( 23.1 / 21.6 )]
#     └── Wind Shard (x 144)
