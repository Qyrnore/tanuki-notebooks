# %%
# Print total crafted items (consolidated CSV files)
import importlib, workshop_items as w; importlib.reload(w); import pandas as p; c=w.consolidate_csv_files(); c is not None and print("\n=== Total Crafted Items ===\n"+c[["Item","Quantity"]].dropna(subset=["Quantity"]).to_markdown(index=False))
# Out:
# === Total Crafted Items ===
# | Item                             |   Quantity |
# |:---------------------------------|-----------:|
# | Adamantite Rivets                |         60 |
# | Ancient Lumber                   |        297 |
# | Aurum Regis Nugget               |         72 |
# | Birch Lumber                     |         84 |
# | Cassia Block                     |         48 |
# | Cassia Lumber                    |        171 |
# | Cedar Lumber                     |        153 |
# | Celestine                        |        270 |
# | Clear Glass Lens                 |          0 |
# | Cobalt Ingot                     |       2660 |
# | Cobalt Joint Plate               |       3030 |
# | Cobalt Plate                     |        630 |
# | Cobalt Rivets                    |       2448 |
# | Coelacanth-Class Bridge Frame    |          4 |
# | Cryptomeria Lumber               |        132 |
# | Dark Chestnut Lumber             |        120 |
# | Darksteel Ingot                  |       1222 |
# | Darksteel Nugget                 |        420 |
# | Darksteel Plate                  |        195 |
# | Darksteel Rivets                 |        600 |
# | Electrum Ingot                   |        583 |
# | Enchanted Hardsilver Ink         |        234 |
# | Galvanized Garlond Steel         |        168 |
# | Garlond Steel                    |        450 |
# | Gold Ingot                       |          0 |
# | Hallowed Chestnut Lumber         |        120 |
# | Hardsilver Ingot                 |         80 |
# | Hardsilver Nugget                |         37 |
# | High Mythrite Ingot              |        204 |
# | Holy Cedar Lumber                |        348 |
# | Horn Glue                        |        306 |
# | Iron Ingot                       |      -1121 |
# | Iron Nails                       |       1121 |
# | Iron Rivets                      |          0 |
# | Kamacite                         |         36 |
# | Larimar                          |        180 |
# | Molybdenum Ingot                 |         90 |
# | Mythril Ingot                    |       -600 |
# | Mythril Plate                    |        300 |
# | Mythril Rivets                   |          0 |
# | Mythrite Ingot                   |       1696 |
# | Mythrite Rivets                  |        147 |
# | Platinum Ingot                   |          0 |
# | Platinum Nugget                  |        180 |
# | Pure Titanium Plate              |        117 |
# | Rhodonite                        |        180 |
# | Rose Gold Ingot                  |       1223 |
# | Rose Gold Nugget                 |        450 |
# | Shark-Class Stern Frame          |          4 |
# | Silver Ingot                     |        990 |
# | Spruce Lumber                    |        648 |
# | Steel Ingot                      |      -1720 |
# | Steel Joint Plate                |       1720 |
# | Steel Rivets                     |          0 |
# | Syldra-Class Pressure Hull Frame |          4 |
# | Tempered Glass                   |        120 |
# | Titanium Ingot                   |        640 |
# | Topaz                            |         90 |
# | Treated Spruce Lumber            |        240 |
# | Triphane                         |         24 |
# | Unkiu-Class Bow Frame            |          4 |
# | Varnish                          |        760 |
# | Void Glue                        |        220 |
# | Walnut Lumber                    |        702 |
# | Wing Glue                        |         48 |
# | Wolfram Ingot                    |         29 |

# %%
# Print gathering list (no location info)
from workshop_items import generate_gathering_list as g; import os, pandas as p; d='utilities'; df=g(os.path.join(d,'workshop_output.csv'), os.path.join(d,'recipe_book.csv'), os.path.join(d,'recipe_gathering.csv'), os.path.join(d,'gathering_list.csv')); exec("for m, gp in df.groupby('Method'): print(f'\\n=== {m} ===\\n' + gp[['Ingredient','Total Quantity']].to_markdown(index=False))")
# Out:
# === aetherial reduction ===
# | Ingredient           |   Total Quantity |
# |:---------------------|-----------------:|
# | Dawnborne Aethersand |               48 |
#
# === crystal ===
# | Ingredient        |   Total Quantity |
# |:------------------|-----------------:|
# | Earth Cluster     |           1223   |
# | Earth Crystal     |            954   |
# | Fire Cluster      |           1908   |
# | Fire Crystal      |          14448.5 |
# | Fire Shard        |          30736   |
# | Ice Cluster       |           1874   |
# | Ice Crystal       |          15573.5 |
# | Ice Shard         |          54275   |
# | Lightning Cluster |             48   |
# | Lightning Crystal |            840   |
# | Water Cluster     |             96   |
# | Water Crystal     |           3828   |
# | Water Shard       |           7238   |
# | Wind Cluster      |           3401   |
# | Wind Crystal      |          24030   |
# | Wind Shard        |           7199   |
#
# === drop ===
# | Ingredient     |   Total Quantity |
# |:---------------|-----------------:|
# | Ahriman Wing   |               96 |
# | Aldgoat Horn   |              612 |
# | Bear Fat       |               48 |
# | Dhalmel Saliva |              564 |
# | Gelato Flesh   |              660 |
# | Wyvern Wing    |              144 |
#
# === gc seals ===
# | Ingredient        |   Total Quantity |
# |:------------------|-----------------:|
# | Aqueous Whetstone |             2430 |
# | Coke              |            17937 |
# | Emery             |               90 |
# | Glass Fiber       |              120 |
# | Hardened Sap      |             5319 |
# | Peacock Ore       |            11007 |
# | Petrified Log     |              297 |
# | Pudding Flesh     |              440 |
# | Raziqsand         |                0 |
# | Raziqsap          |                0 |
# | Scheelite         |               29 |
#
# === normal ===
# | Ingredient              |   Total Quantity |
# |:------------------------|-----------------:|
# | Abalathian Spring Water |              480 |
# | Aurum Regis Sand        |              360 |
# | Basilisk Egg            |              180 |
# | Birch Log               |              420 |
# | Birch Log               |              420 |
# | Cedar Log               |             2505 |
# | Cloud Mica              |             2560 |
# | Cobalt Ore              |            20709 |
# | Dark Chestnut Log       |             1200 |
# | Dravanian Spring Water  |              234 |
# | Effervescent Water      |              120 |
# | Electrum Ore            |             2332 |
# | Flax                    |             1520 |
# | Hardsilver Ore          |              320 |
# | Hardsilver Sand         |             1521 |
# | Molybdenum Ore          |              360 |
# | Mythril Ore             |             1843 |
# | Mythrite Ore            |             7192 |
# | Mythrite Sand           |             9215 |
# | Raw Amber               |             1520 |
# | Raw Larimar             |              540 |
# | Rock Salt               |              120 |
# | Silex                   |              360 |
# | Silver Ore              |             3087 |
# | Stiperstone             |              204 |
# | Titanium Ore            |             3200 |
# | Walnut Log              |             2106 |
#
# === npc ===
# | Ingredient     |   Total Quantity |
# |:---------------|-----------------:|
# | Bomb Ash       |                0 |
# | Carbon Fiber   |              120 |
# | Copper Ore     |             2896 |
# | Eikon Mythrite |              408 |
# | Grenade Ash    |              640 |
# | Holy Water     |              696 |
# | Iron Ore       |            10038 |
# | Sphalerite     |              336 |
# | Terebinth      |              760 |
#
# === timed node ===
# | Ingredient           |   Total Quantity |
# |:---------------------|-----------------:|
# | Abalathian Mistletoe |              480 |
# | Adamantite Ore       |              300 |
# | Astral Moraine       |               96 |
# | Darksteel Ore        |            11622 |
# | Ferberite            |               29 |
# | Gold Ore             |             8760 |
# | Lumythrite Ore       |              612 |
# | Native Gold          |                0 |
# | Platinum Ore         |              540 |
# | Raw Rhodonite        |              540 |
# | Raw Topaz            |               90 |
# | Raw Triphane         |               72 |
# | Scarlet Sap          |              297 |
# | Seventh Heaven       |               96 |
# | Spruce Log           |             3384 |
#
# === unknown ===
# | Ingredient                       |   Total Quantity |
# |:---------------------------------|-----------------:|
# | Coelacanth-Class Bridge Frame    |                4 |
# | Shark-Class Stern Frame          |                4 |
# | Syldra-Class Pressure Hull Frame |                4 |
# | Unkiu-Class Bow Frame            |                4 |
#
# === voyages ===
# | Ingredient        |   Total Quantity |
# |:------------------|-----------------:|
# | Cassia Log        |              657 |
# | Cryptomeria Log   |              396 |
# | Kamacite Ore      |              108 |
# | Pure Titanium Ore |              351 |
# | Raw Celestine     |              810 |
# | Vivianite         |             1854 |

# %%
# Print project recipe tree
from workshop_items import print_recipe_tree as r; import os; u='utilities'; print(r(os.path.join(u,'workshop_output.csv'), os.path.join(u,'recipe_book.csv'), os.path.join(u,'recipe_gathering.csv')))
# Out:
# === Recipe Breakdown ===
# ├── (60) Adamantite Rivets
# │   ├── (60) Adamantite Nugget
# │   │   ├── (300) Adamantite Ore
# │   │   ├── (60) Darksteel Ore
# │   │   └── (300) Ice Crystal|Fire Crystal
# │   └── (300) Ice Crystal|Fire Crystal
# |
# ├── (297) Ancient Lumber
# │   ├── (297) Petrified Log
# │   ├── (297) Scarlet Sap
# │   ├── (594) Wind Cluster
# │   └── (297) Ice Cluster
# |
# ├── (72) Aurum Regis Nugget
# │   ├── (360) Aurum Regis Sand
# │   ├── (72) Gold Ore
# │   └── (360) Wind Crystal
# |
# ├── (84) Birch Lumber
# │   ├── (420) Birch Log
# │   └── (420) Wind Crystal
# |
# ├── (48) Cassia Block
# │   ├── (48) Cassia Lumber
# │   │   ├── (144) Cassia Log
# │   │   ├── (432) Hardened Sap
# │   │   ├── (96) Wind Cluster
# │   │   └── (48) Ice Cluster
# │   ├── (48) Astral Oil
# │   │   ├── (96) Seventh Heaven
# │   │   ├── (96) Astral Moraine
# │   │   ├── (48) Bear Fat
# │   │   ├── (96) Water Cluster
# │   │   └── (48) Lightning Cluster
# │   ├── (48) Dawnborne Aethersand
# │   ├── (96) Wind Cluster
# │   └── (48) Ice Cluster
# |
# ├── (171) Cassia Lumber
# │   ├── (513) Cassia Log
# │   ├── (1539) Hardened Sap
# │   ├── (342) Wind Cluster
# │   └── (171) Ice Cluster
# |
# ├── (153) Cedar Lumber
# │   ├── (765) Cedar Log
# │   └── (459) Wind Crystal
# |
# ├── (270) Celestine
# │   ├── (810) Raw Celestine
# │   ├── (2430) Aqueous Whetstone
# │   ├── (270) Wind Cluster
# │   └── (270) Fire Cluster
# |
# ├── (0) Clear Glass Lens
# │   ├── (0) Silex
# │   ├── (0) Natron
# │   │   ├── (0) Effervescent Water
# │   │   ├── (0) Rock Salt
# │   │   └── (0) Water Shard
# │   └── (0) Water Shard
# |
# ├── (2660) Cobalt Ingot
# │   ├── (5320) Cobalt Ore
# │   ├── (2660) Iron Ore
# │   └── (13300) Ice Shard|Fire Shard
# |
# ├── (3030) Cobalt Joint Plate
# │   ├── (3030) Cobalt Ingot
# │   │   ├── (6060) Cobalt Ore
# │   │   ├── (3030) Iron Ore
# │   │   └── (15150) Ice Shard|Fire Shard
# │   └── (15150) Ice Shard
# |
# ├── (630) Cobalt Plate
# │   ├── (1260) Cobalt Ingot
# │   │   ├── (2520) Cobalt Ore
# │   │   ├── (1260) Iron Ore
# │   │   └── (6300) Ice Shard|Fire Shard
# │   └── (3150) Ice Shard
# |
# ├── (2448) Cobalt Rivets
# │   ├── (2448) Cobalt Ingot
# │   │   ├── (4896) Cobalt Ore
# │   │   ├── (2448) Iron Ore
# │   │   └── (12240) Ice Shard|Fire Shard
# │   └── (12240) Ice Shard|Fire Shard
# |
# ├── (4) Coelacanth-Class Bridge Frame
# |
# ├── (132) Cryptomeria Lumber
# │   ├── (396) Cryptomeria Log
# │   ├── (1188) Hardened Sap
# │   ├── (792) Wind Crystal
# │   └── (792) Ice Crystal
# |
# ├── (120) Dark Chestnut Lumber
# │   ├── (600) Dark Chestnut Log
# │   └── (480) Wind Crystal
# |
# ├── (1222) Darksteel Ingot
# │   ├── (2444) Darksteel Nugget
# │   │   ├── (7332) Darksteel Ore
# │   │   └── (7332) Ice Crystal|Fire Crystal
# │   ├── (10998) Coke
# │   └── (1222) Ice Cluster|Fire Cluster
# |
# ├── (420) Darksteel Nugget
# │   ├── (1260) Darksteel Ore
# │   └── (1260) Ice Crystal|Fire Crystal
# |
# ├── (195) Darksteel Plate
# │   ├── (390) Darksteel Nugget
# │   │   ├── (1170) Darksteel Ore
# │   │   └── (1170) Ice Crystal|Fire Crystal
# │   └── (585) Ice Crystal
# |
# ├── (600) Darksteel Rivets
# │   ├── (600) Darksteel Nugget
# │   │   ├── (1800) Darksteel Ore
# │   │   └── (1800) Ice Crystal|Fire Crystal
# │   └── (1800) Ice Crystal|Fire Crystal
# |
# ├── (583) Electrum Ingot
# │   ├── (2332) Electrum Ore
# │   └── (2915) Wind Shard
# |
# ├── (234) Enchanted Hardsilver Ink
# │   ├── (936) Hardsilver Sand
# │   ├── (468) Dhalmel Saliva
# │   ├── (234) Dravanian Spring Water
# │   └── (936) Water Crystal
# |
# ├── (168) Galvanized Garlond Steel
# │   ├── (504) Vivianite
# │   ├── (336) Sphalerite
# │   ├── (336) Cobalt Ore
# │   ├── (1512) Coke
# │   ├── (336) Ice Cluster|Fire Cluster
# │   └── (336) Earth Cluster
# |
# ├── (450) Garlond Steel
# │   ├── (1350) Vivianite
# │   ├── (4050) Coke
# │   ├── (1350) Cobalt Ore
# │   ├── (450) Ice Cluster|Fire Cluster
# │   └── (450) Earth Cluster
# |
# ├── (0) Gold Ingot
# │   ├── (0) Raziqsand
# │   ├── (0) Native Gold
# │   ├── (0) Gold Ore
# │   ├── (0) Wind Cluster
# │   └── (0) Fire Cluster
# |
# ├── (120) Hallowed Chestnut Lumber
# │   ├── (120) Dark Chestnut Lumber
# │   │   ├── (600) Dark Chestnut Log
# │   │   └── (480) Wind Crystal
# │   ├── (240) Hallowed Water
# │   │   ├── (480) Abalathian Spring Water
# │   │   ├── (480) Abalathian Mistletoe
# │   │   └── (1200) Water Crystal
# │   └── (600) Wind Crystal
# |
# ├── (80) Hardsilver Ingot
# │   ├── (320) Hardsilver Ore
# │   ├── (80) Hardsilver Nugget
# │   │   ├── (400) Hardsilver Sand
# │   │   ├── (80) Silver Ore
# │   │   └── (320) Wind Crystal
# │   └── (400) Wind Crystal
# |
# ├── (37) Hardsilver Nugget
# │   ├── (185) Hardsilver Sand
# │   ├── (37) Silver Ore
# │   └── (148) Wind Crystal
# |
# ├── (204) High Mythrite Ingot
# │   ├── (408) Eikon Mythrite
# │   ├── (612) Lumythrite Ore
# │   ├── (408) Mythrite Ore
# │   ├── (612) Ice Cluster|Fire Cluster
# │   └── (408) Earth Cluster
# |
# ├── (348) Holy Cedar Lumber
# │   ├── (348) Cedar Lumber
# │   │   ├── (1740) Cedar Log
# │   │   └── (1044) Wind Crystal
# │   ├── (696) Holy Water
# │   └── (1044) Wind Crystal
# |
# ├── (306) Horn Glue
# │   ├── (612) Aldgoat Horn
# │   └── (918) Water Shard
# |
# ├── (-1121) Iron Ingot
# │   ├── (-3363) Iron Ore
# │   └── (-1121) Ice Shard|Fire Shard
# |
# ├── (1121) Iron Nails
# │   ├── (1121) Iron Ingot
# │   │   ├── (3363) Iron Ore
# │   │   └── (1121) Ice Shard|Fire Shard
# │   └── (1121) Fire Shard
# |
# ├── (0) Iron Rivets
# │   ├── (0) Iron Ingot
# │   │   ├── (0) Iron Ore
# │   │   └── (0) Ice Shard|Fire Shard
# │   └── (0) Ice Shard|Fire Shard
# |
# ├── (36) Kamacite
# │   ├── (108) Kamacite Ore
# │   ├── (324) Coke
# │   ├── (108) Cobalt Ore
# │   ├── (252) Fire Crystal
# │   └── (252) Earth Crystal
# |
# ├── (180) Larimar
# │   ├── (540) Raw Larimar
# │   ├── (180) Basilisk Whetstone
# │   │   ├── (180) Basilisk Egg
# │   │   └── (900) Wind Shard
# │   └── (720) Wind Crystal
# |
# ├── (90) Molybdenum Ingot
# │   ├── (360) Molybdenum Ore
# │   ├── (90) Cobalt Ore
# │   └── (450) Ice Crystal|Fire Crystal
# |
# ├── (-600) Mythril Ingot
# │   ├── (-1800) Mythril Ore
# │   └── (-2400) Ice Shard|Wind Shard|Fire Shard
# |
# ├── (300) Mythril Plate
# │   ├── (600) Mythril Ingot
# │   │   ├── (1800) Mythril Ore
# │   │   └── (2400) Ice Shard|Wind Shard|Fire Shard
# │   └── (1200) Ice Shard
# |
# ├── (0) Mythril Rivets
# │   ├── (0) Mythril Ingot
# │   │   ├── (0) Mythril Ore
# │   │   └── (0) Ice Shard|Wind Shard|Fire Shard
# │   └── (0) Ice Shard|Fire Shard
# |
# ├── (1696) Mythrite Ingot
# │   ├── (6784) Mythrite Ore
# │   ├── (1696) Mythrite Nugget
# │   │   ├── (8480) Mythrite Sand
# │   │   ├── (1696) Mythril Ore
# │   │   └── (5088) Ice Crystal|Wind Crystal|Fire Crystal
# │   └── (5088) Ice Crystal|Wind Crystal|Fire Crystal
# |
# ├── (147) Mythrite Rivets
# │   ├── (147) Mythrite Nugget
# │   │   ├── (735) Mythrite Sand
# │   │   ├── (147) Mythril Ore
# │   │   └── (441) Ice Crystal|Wind Crystal|Fire Crystal
# │   └── (441) Fire Crystal|Ice Crystal
# |
# ├── (0) Platinum Ingot
# │   ├── (0) Platinum Ore
# │   ├── (0) Raziqsap
# │   ├── (0) Wind Cluster
# │   └── (0) Fire Cluster
# |
# ├── (180) Platinum Nugget
# │   ├── (540) Platinum Ore
# │   ├── (360) Wind Cluster
# │   └── (180) Fire Cluster
# |
# ├── (117) Pure Titanium Plate
# │   ├── (351) Pure Titanium Ore
# │   ├── (1053) Coke
# │   ├── (702) Ice Crystal|Fire Crystal
# │   └── (702) Earth Crystal
# |
# ├── (180) Rhodonite
# │   ├── (540) Raw Rhodonite
# │   ├── (180) Stiperstone
# │   └── (1080) Wind Crystal
# |
# ├── (1223) Rose Gold Ingot
# │   ├── (2446) Rose Gold Nugget
# │   │   ├── (7338) Gold Ore
# │   │   ├── (2446) Copper Ore
# │   │   └── (7338) Wind Crystal
# │   ├── (11007) Peacock Ore
# │   └── (1223) Wind Cluster
# |
# ├── (450) Rose Gold Nugget
# │   ├── (1350) Gold Ore
# │   ├── (450) Copper Ore
# │   └── (1350) Wind Crystal
# |
# ├── (4) Shark-Class Stern Frame
# |
# ├── (990) Silver Ingot
# │   ├── (2970) Silver Ore
# │   └── (1980) Wind Shard
# |
# ├── (648) Spruce Lumber
# │   ├── (1944) Spruce Log
# │   └── (1944) Wind Crystal
# |
# ├── (-1720) Steel Ingot
# │   ├── (-1720) Bomb Ash
# │   ├── (-3440) Iron Ore
# │   └── (-3440) Ice Shard|Fire Shard
# |
# ├── (1720) Steel Joint Plate
# │   ├── (1720) Steel Ingot
# │   │   ├── (1720) Bomb Ash
# │   │   ├── (3440) Iron Ore
# │   │   └── (3440) Ice Shard|Fire Shard
# │   └── (5160) Ice Shard
# |
# ├── (0) Steel Rivets
# │   ├── (0) Steel Ingot
# │   │   ├── (0) Bomb Ash
# │   │   ├── (0) Iron Ore
# │   │   └── (0) Ice Shard|Fire Shard
# │   └── (0) Ice Shard|Fire Shard
# |
# ├── (4) Syldra-Class Pressure Hull Frame
# |
# ├── (120) Tempered Glass
# │   ├── (120) Glass Fiber
# │   ├── (120) Carbon Fiber
# │   ├── (360) Silex
# │   ├── (120) Natron
# │   │   ├── (120) Effervescent Water
# │   │   ├── (120) Rock Salt
# │   │   └── (240) Water Shard
# │   ├── (840) Water Crystal
# │   └── (840) Lightning Crystal
# |
# ├── (640) Titanium Ingot
# │   ├── (2560) Cloud Mica
# │   ├── (640) Titanium Nugget
# │   │   ├── (3200) Titanium Ore
# │   │   ├── (640) Iron Ore
# │   │   ├── (640) Grenade Ash
# │   │   └── (2560) Ice Crystal|Fire Crystal
# │   └── (3200) Ice Crystal|Fire Crystal
# |
# ├── (90) Topaz
# │   ├── (90) Emery
# │   ├── (90) Raw Topaz
# │   ├── (180) Wind Cluster
# │   └── (90) Fire Cluster
# |
# ├── (240) Treated Spruce Lumber
# │   ├── (480) Spruce Lumber
# │   │   ├── (1440) Spruce Log
# │   │   └── (1440) Wind Crystal
# │   ├── (2160) Hardened Sap
# │   └── (240) Wind Cluster
# |
# ├── (24) Triphane
# │   ├── (72) Raw Triphane
# │   ├── (24) Stiperstone
# │   └── (72) Wind Crystal
# |
# ├── (4) Unkiu-Class Bow Frame
# |
# ├── (760) Varnish
# │   ├── (1520) Raw Amber
# │   ├── (760) Linseed Oil
# │   │   ├── (1520) Flax
# │   │   └── (2280) Water Shard
# │   ├── (760) Terebinth
# │   └── (3800) Water Shard
# |
# ├── (220) Void Glue
# │   ├── (660) Gelato Flesh
# │   ├── (440) Pudding Flesh
# │   └── (660) Water Crystal
# |
# ├── (702) Walnut Lumber
# │   ├── (2106) Walnut Log
# │   └── (1404) Wind Shard
# |
# ├── (48) Wing Glue
# │   ├── (144) Wyvern Wing
# │   ├── (96) Ahriman Wing
# │   ├── (96) Dhalmel Saliva
# │   └── (192) Water Crystal
# |
# └── (29) Wolfram Ingot
#     ├── (29) Scheelite
#     ├── (29) Ferberite
#     ├── (29) Cobalt Ore
#     ├── (58) Fire Cluster
#     └── (29) Earth Cluster
# |

# %%
# Generate gathering list with location info included.
from workshop_items import generate_gathering_list as g;import os,pandas as p;d='utilities';df=g(os.path.join(d,'workshop_output.csv'),os.path.join(d,'recipe_book.csv'),os.path.join(d,'recipe_gathering.csv'),os.path.join(d,'gathering_list.csv'));exec("for m,g in df.groupby('Method'):print(f'\\n=== {m} ===\\n'+g.drop(columns='Method').to_markdown(index=False))")
# Out:
# === aetherial reduction ===
# | Ingredient           |   Total Quantity | Location Info                                        |
# |:---------------------|-----------------:|:-----------------------------------------------------|
# | Dawnborne Aethersand |               48 | ffxiv.consolegameswiki.com/wiki/Dawnborne_Aethersand |
#
# === crystal ===
# | Ingredient        |   Total Quantity | Location Info             |
# |:------------------|-----------------:|:--------------------------|
# | Earth Cluster     |           1223   | universalis.app/market/17 |
# | Earth Crystal     |            954   | universalis.app/market/11 |
# | Fire Cluster      |           1908   | universalis.app/market/14 |
# | Fire Crystal      |          14448.5 | universalis.app/market/8  |
# | Fire Shard        |          30736   | universalis.app/market/2  |
# | Ice Cluster       |           1874   | universalis.app/market/15 |
# | Ice Crystal       |          15573.5 | universalis.app/market/9  |
# | Ice Shard         |          54275   | universalis.app/market/3  |
# | Lightning Cluster |             48   | universalis.app/market/18 |
# | Lightning Crystal |            840   | universalis.app/market/12 |
# | Water Cluster     |             96   | universalis.app/market/19 |
# | Water Crystal     |           3828   | universalis.app/market/13 |
# | Water Shard       |           7238   | universalis.app/market/7  |
# | Wind Cluster      |           3401   | universalis.app/market/16 |
# | Wind Crystal      |          24030   | universalis.app/market/10 |
# | Wind Shard        |           7199   | universalis.app/market/4  |
#
# === drop ===
# | Ingredient     |   Total Quantity | Location Info                                  |
# |:---------------|-----------------:|:-----------------------------------------------|
# | Ahriman Wing   |               96 | ffxiv.consolegameswiki.com/wiki/Ahriman_Wing   |
# | Aldgoat Horn   |              612 | ffxiv.consolegameswiki.com/wiki/Aldgoat_Horn   |
# | Bear Fat       |               48 | ffxiv.consolegameswiki.com/wiki/Bear_Fat       |
# | Dhalmel Saliva |              564 | ffxiv.consolegameswiki.com/wiki/Dhalmel_Saliva |
# | Gelato Flesh   |              660 | ffxiv.consolegameswiki.com/wiki/Gelato_Flesh   |
# | Wyvern Wing    |              144 | ffxiv.consolegameswiki.com/wiki/Wyvern_Wing    |
#
# === gc seals ===
# | Ingredient        |   Total Quantity | Location Info                    |
# |:------------------|-----------------:|:---------------------------------|
# | Aqueous Whetstone |             2430 | old for 200 GC Seals             |
# | Coke              |            17937 | Sold for 200 GC Seals            |
# | Emery             |               90 | Sold for 1500 GC Seals           |
# | Glass Fiber       |              120 | Sold for 7000 GC Seals (captain) |
# | Hardened Sap      |             5319 | Sold for 200 GC Seals            |
# | Peacock Ore       |            11007 | Sold for 200 GC Seals            |
# | Petrified Log     |              297 | Sold for 1500 GC Seals           |
# | Pudding Flesh     |              440 | Sold for 200 GC Seals            |
# | Raziqsand         |                0 | Sold for 1500 GC Seals           |
# | Raziqsap          |                0 | Sold for 250 GC Seals            |
# | Scheelite         |               29 | Sold for 1500 GC Seals           |
#
# === normal ===
# | Ingredient              |   Total Quantity | Location Info                                        |
# |:------------------------|-----------------:|:-----------------------------------------------------|
# | Abalathian Spring Water |              480 | The Sea of Clouds ( 34.8 / 30.5 )                    |
# | Aurum Regis Sand        |              360 | The Sea of Clouds ( 34.8 / 30.5 )                    |
# | Basilisk Egg            |              180 | Northern Thanalan ( 22.4 / 24.4 )                    |
# | Birch Log               |              420 | The Sea of Clouds ( 24 / 34 ), Hidden                |
# | Birch Log               |              420 | The Sea of Clouds ( 26.5 / 33.4 )                    |
# | Cedar Log               |             2505 | Coerthas Western Highlands ( 31.3 / 32.1 )           |
# | Cloud Mica              |             2560 | The Churning Mists ( 27.6 / 19.2 )                   |
# | Cobalt Ore              |            20709 | Northern Thanalan ( 23.1 / 24.2 )                    |
# | Dark Chestnut Log       |             1200 | The Dravanian Forelands ( 26.6 / 27.1 )              |
# | Dravanian Spring Water  |              234 | The Dravanian Forelands ( 27.4 / 31.8 )              |
# | Effervescent Water      |              120 | South Shroud ( 16.0 / 19.7 )                         |
# | Electrum Ore            |             2332 | Upper La Noscea ( 30.4 / 25.4 )                      |
# | Flax                    |             1520 | South Shroud ( 17.6 / 28.6 )                         |
# | Hardsilver Ore          |              320 | The Dravanian Hinterlands ( 25.3 / 25 )              |
# | Hardsilver Sand         |             1521 | The Churning Mists ( 27.9 / 19.5 )                   |
# | Molybdenum Ore          |              360 | The Lochs ( 11.4 / 16.6 )                            |
# | Mythril Ore             |             1843 | Southern Thanalan ( 25.2 / 39.9 )                    |
# | Mythrite Ore            |             7192 | Coerthas Western Highlands ( 31.2 / 12.8 ), (Hidden) |
# | Mythrite Sand           |             9215 | Coerthas Western Highlands ( 16.6 / 13.1 )           |
# | Raw Amber               |             1520 | Eastern Thanalan ( 12.7 / 19.1 )                     |
# | Raw Larimar             |              540 | Coerthas Western Highlands ( 31.3 / 12.6 )           |
# | Rock Salt               |              120 | Central Thanalan ( 14.5 / 22.7 )                     |
# | Silex                   |              360 | Southern Thanalan ( 22.4 / 29.7 )                    |
# | Silver Ore              |             3087 | South Shroud ( 16.1 / 19.7 )                         |
# | Stiperstone             |              204 | The Peaks ( 23.3 / 13.1 )                            |
# | Titanium Ore            |             3200 | The Dravanian Forelands ( 30.3 / 15.1 )              |
# | Walnut Log              |             2106 | South Shroud ( 23.1 / 21.6 )                         |
#
# === npc ===
# | Ingredient     |   Total Quantity | Location Info                                  |
# |:---------------|-----------------:|:-----------------------------------------------|
# | Bomb Ash       |                0 | ffxiv.consolegameswiki.com/wiki/Bomb_Ash       |
# | Carbon Fiber   |              120 | ffxiv.consolegameswiki.com/wiki/Carbon_Fiber   |
# | Copper Ore     |             2896 | ffxiv.consolegameswiki.com/wiki/Copper_Ore     |
# | Eikon Mythrite |              408 | ffxiv.consolegameswiki.com/wiki/Eikon_Mythrite |
# | Grenade Ash    |              640 | ffxiv.consolegameswiki.com/wiki/Grenade_Ash    |
# | Holy Water     |              696 | ffxiv.consolegameswiki.com/wiki/Holy_Water     |
# | Iron Ore       |            10038 | ffxiv.consolegameswiki.com/wiki/Iron_Ore       |
# | Sphalerite     |              336 | ffxiv.consolegameswiki.com/wiki/Sphalerite     |
# | Terebinth      |              760 | ffxiv.consolegameswiki.com/wiki/Terebinth      |
#
# === timed node ===
# | Ingredient           |   Total Quantity | Location Info                                                   |
# |:---------------------|-----------------:|:----------------------------------------------------------------|
# | Abalathian Mistletoe |              480 | The Sea of Clouds ( 35.8 / 21.4 ), Timed at 6AM/PM ET           |
# | Adamantite Ore       |              300 | Azys Lla ( 23.2 / 5.8 ), Timed at 12AM/PM ET                    |
# | Astral Moraine       |               96 | Coerthas Western Highlands ( 37.2 / 16.4 ), Timed at 12AM/PM ET |
# | Darksteel Ore        |            11622 | Coerthas Central Highlands ( 27.5 / 20.0 ), Timed at 1:00am     |
# | Ferberite            |               29 | Northern Thanalan ( 17.3 / 19.9 ), Timed at 3:00am ET           |
# | Gold Ore             |             8760 | Eastern Thanalan ( 27.3 / 21.3 ), Timed at 9:00am               |
# | Lumythrite Ore       |              612 | The Churning Mists ( 9.3 / 38.5 ), Timed at 2AM/PM ET           |
# | Native Gold          |                0 | Central Thanalan ( 25.2 / 15.8 ), Timed at 4:00am ET            |
# | Platinum Ore         |              540 | Southern Thanalan ( 16.7 / 10.7 ), Timed at 4:00am ET           |
# | Raw Rhodonite        |              540 | The Peaks ( 26.9 / 12.5 ), Timed at 8AM/PM ET                   |
# | Raw Topaz            |               90 | Northern Thanalan ( 18.0 / 20.0 ), Timed at 3:00am ET           |
# | Raw Triphane         |               72 | The Fringes ( 25.2 / 8.3 ), Timed at 2AM/PM                     |
# | Scarlet Sap          |              297 | North Shroud ( 17.7 / 27.7 ), Timed at 3:00am                   |
# | Seventh Heaven       |               96 | The Churning Mists ( 16.7 / 36.8 ), Timed at 4:00AM/PM ET       |
# | Spruce Log           |             3384 | Coerthas Central Highlands ( 29.5 / 13.1 ), Timed at 9:00am     |
#
# === unknown ===
# | Ingredient                       |   Total Quantity | Location Info   |
# |:---------------------------------|-----------------:|:----------------|
# | Coelacanth-Class Bridge Frame    |                4 |                 |
# | Shark-Class Stern Frame          |                4 |                 |
# | Syldra-Class Pressure Hull Frame |                4 |                 |
# | Unkiu-Class Bow Frame            |                4 |                 |
#
# === voyages ===
# | Ingredient        |   Total Quantity | Location Info                                     |
# |:------------------|-----------------:|:--------------------------------------------------|
# | Cassia Log        |              657 | ffxiv.consolegameswiki.com/wiki/Cassia_Log        |
# | Cryptomeria Log   |              396 | ffxiv.consolegameswiki.com/wiki/Cryptomeria_Log   |
# | Kamacite Ore      |              108 | ffxiv.consolegameswiki.com/wiki/Kamacite_Ore      |
# | Pure Titanium Ore |              351 | ffxiv.consolegameswiki.com/wiki/Pure_Titanium_Ore |
# | Raw Celestine     |              810 | ffxiv.consolegameswiki.com/wiki/Raw_Celestine     |
# | Vivianite         |             1854 | ffxiv.consolegameswiki.com/wiki/Vivianite         |
