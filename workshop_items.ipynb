# %%
# Print total crafted items (consolidated CSV files)
import importlib, workshop_items as w; importlib.reload(w); import pandas as p; c=w.consolidate_csv_files(); c is not None and print("\n=== Total Crafted Items ===\n"+c[["Item","Quantity"]].dropna(subset=["Quantity"]).to_markdown(index=False))
# Out:
# === Total Crafted Items ===
# | Item                  |   Quantity |
# |:----------------------|-----------:|
# | Ancient Lumber        |        436 |
# | Cassia Lumber         |        126 |
# | Cedar Lumber          |        -30 |
# | Celestine             |        213 |
# | Clear Glass Lens      |          0 |
# | Cobalt Ingot          |       3060 |
# | Cobalt Joint Plate    |       3540 |
# | Cobalt Plate          |        420 |
# | Cobalt Rivets         |       2045 |
# | Darksteel Ingot       |       1401 |
# | Darksteel Nugget      |        417 |
# | Darksteel Plate       |        153 |
# | Darksteel Rivets      |        410 |
# | Electrum Ingot        |        304 |
# | Garlond Steel         |        450 |
# | Holy Cedar Lumber     |        292 |
# | Iron Ingot            |      -1080 |
# | Iron Nails            |        660 |
# | Iron Rivets           |        360 |
# | Larimar               |        128 |
# | Mythril Ingot         |        -90 |
# | Mythril Rivets        |          0 |
# | Mythrite Ingot        |       1402 |
# | Platinum Nugget       |        168 |
# | Rose Gold Ingot       |        652 |
# | Rose Gold Nugget      |        320 |
# | Silver Ingot          |       1450 |
# | Spruce Lumber         |        240 |
# | Steel Ingot           |      -2100 |
# | Steel Joint Plate     |       1930 |
# | Steel Rivets          |          0 |
# | Titanium Ingot        |        260 |
# | Topaz                 |         64 |
# | Treated Spruce Lumber |        240 |
# | Varnish               |        183 |
# | Void Glue             |         92 |
# | Walnut Lumber         |        240 |

# %%
# Print gathering list (no location info)
from workshop_items import generate_gathering_list as g; import os, pandas as p; d='utilities'; df=g(os.path.join(d,'workshop_output.csv'), os.path.join(d,'recipe_book.csv'), os.path.join(d,'recipe_gathering.csv'), os.path.join(d,'gathering_list.csv')); exec("for m, gp in df.groupby('Method'): print(f'\\n=== {m} ===\\n' + gp[['Ingredient','Total Quantity']].to_markdown(index=False))")
# Out:
# === crystal ===
# | Ingredient    |   Total Quantity |
# |:--------------|-----------------:|
# | Earth Cluster |            450   |
# | Fire Cluster  |           1370.5 |
# | Fire Crystal  |          10491.5 |
# | Fire Shard    |          29345   |
# | Ice Cluster   |           1487.5 |
# | Ice Crystal   |          10950.5 |
# | Ice Shard     |          54275   |
# | Water Crystal |            276   |
# | Water Shard   |           1464   |
# | Wind Cluster  |           2693   |
# | Wind Crystal  |          12010   |
# | Wind Shard    |           5420   |
#
# === drop ===
# | Ingredient   |   Total Quantity |
# |:-------------|-----------------:|
# | Gelato Flesh |              276 |
#
# === gc seals ===
# | Ingredient        |   Total Quantity |
# |:------------------|-----------------:|
# | Aqueous Whetstone |             1917 |
# | Coke              |            16659 |
# | Emery             |               64 |
# | Hardened Sap      |             3294 |
# | Peacock Ore       |             5868 |
# | Petrified Log     |              436 |
# | Pudding Flesh     |              184 |
#
# === normal ===
# | Ingredient         |   Total Quantity |
# |:-------------------|-----------------:|
# | Basilisk Egg       |              128 |
# | Cedar Log          |             1310 |
# | Cloud Mica         |             1040 |
# | Cobalt Ore         |            20320 |
# | Effervescent Water |                0 |
# | Electrum Ore       |             1216 |
# | Flax               |              366 |
# | Mythril Ore        |             1132 |
# | Mythrite Ore       |             5608 |
# | Mythrite Sand      |             7010 |
# | Raw Amber          |              366 |
# | Raw Larimar        |              384 |
# | Rock Salt          |                0 |
# | Silex              |                0 |
# | Silver Ore         |             4350 |
# | Titanium Ore       |             1300 |
# | Walnut Log         |              720 |
#
# === npc ===
# | Ingredient   |   Total Quantity |
# |:-------------|-----------------:|
# | Bomb Ash     |             -170 |
# | Copper Ore   |             1624 |
# | Grenade Ash  |              260 |
# | Holy Water   |              584 |
# | Iron Ore     |             9225 |
# | Terebinth    |              183 |
#
# === timed node ===
# | Ingredient    |   Total Quantity |
# |:--------------|-----------------:|
# | Darksteel Ore |            11805 |
# | Gold Ore      |             4872 |
# | Platinum Ore  |              504 |
# | Raw Topaz     |               64 |
# | Scarlet Sap   |              436 |
# | Spruce Log    |             2160 |
#
# === voyages ===
# | Ingredient    |   Total Quantity |
# |:--------------|-----------------:|
# | Cassia Log    |              378 |
# | Raw Celestine |              639 |
# | Vivianite     |             1350 |

# %%
# Print project recipe tree
from workshop_items import print_recipe_tree as r; import os; u='utilities'; print(r(os.path.join(u,'workshop_output.csv'), os.path.join(u,'recipe_book.csv'), os.path.join(u,'recipe_gathering.csv')))
# Out:
# === Recipe Breakdown ===
# ├── (436) Ancient Lumber
# │   ├── (436) Petrified Log
# │   ├── (436) Scarlet Sap
# │   ├── (872) Wind Cluster
# │   └── (436) Ice Cluster
# |
# ├── (126) Cassia Lumber
# │   ├── (378) Cassia Log
# │   ├── (1134) Hardened Sap
# │   ├── (252) Wind Cluster
# │   └── (126) Ice Cluster
# |
# ├── (-30) Cedar Lumber
# │   ├── (-150) Cedar Log
# │   └── (-90) Wind Crystal
# |
# ├── (213) Celestine
# │   ├── (639) Raw Celestine
# │   ├── (1917) Aqueous Whetstone
# │   ├── (213) Wind Cluster
# │   └── (213) Fire Cluster
# |
# ├── (0) Clear Glass Lens
# │   ├── (0) Silex
# │   ├── (0) Natron
# │   │   ├── (0) Effervescent Water
# │   │   ├── (0) Rock Salt
# │   │   └── (0) Water Shard
# │   └── (0) Water Shard
# |
# ├── (3060) Cobalt Ingot
# │   ├── (6120) Cobalt Ore
# │   ├── (3060) Iron Ore
# │   └── (15300) Ice Shard|Fire Shard
# |
# ├── (3540) Cobalt Joint Plate
# │   ├── (3540) Cobalt Ingot
# │   │   ├── (7080) Cobalt Ore
# │   │   ├── (3540) Iron Ore
# │   │   └── (17700) Ice Shard|Fire Shard
# │   └── (17700) Ice Shard
# |
# ├── (420) Cobalt Plate
# │   ├── (840) Cobalt Ingot
# │   │   ├── (1680) Cobalt Ore
# │   │   ├── (840) Iron Ore
# │   │   └── (4200) Ice Shard|Fire Shard
# │   └── (2100) Ice Shard
# |
# ├── (2045) Cobalt Rivets
# │   ├── (2045) Cobalt Ingot
# │   │   ├── (4090) Cobalt Ore
# │   │   ├── (2045) Iron Ore
# │   │   └── (10225) Ice Shard|Fire Shard
# │   └── (10225) Ice Shard|Fire Shard
# |
# ├── (1401) Darksteel Ingot
# │   ├── (2802) Darksteel Nugget
# │   │   ├── (8406) Darksteel Ore
# │   │   └── (8406) Ice Crystal|Fire Crystal
# │   ├── (12609) Coke
# │   └── (1401) Ice Cluster|Fire Cluster
# |
# ├── (417) Darksteel Nugget
# │   ├── (1251) Darksteel Ore
# │   └── (1251) Ice Crystal|Fire Crystal
# |
# ├── (153) Darksteel Plate
# │   ├── (306) Darksteel Nugget
# │   │   ├── (918) Darksteel Ore
# │   │   └── (918) Ice Crystal|Fire Crystal
# │   └── (459) Ice Crystal
# |
# ├── (410) Darksteel Rivets
# │   ├── (410) Darksteel Nugget
# │   │   ├── (1230) Darksteel Ore
# │   │   └── (1230) Ice Crystal|Fire Crystal
# │   └── (1230) Ice Crystal|Fire Crystal
# |
# ├── (304) Electrum Ingot
# │   ├── (1216) Electrum Ore
# │   └── (1520) Wind Shard
# |
# ├── (450) Garlond Steel
# │   ├── (1350) Vivianite
# │   ├── (4050) Coke
# │   ├── (1350) Cobalt Ore
# │   ├── (450) Ice Cluster|Fire Cluster
# │   └── (450) Earth Cluster
# |
# ├── (292) Holy Cedar Lumber
# │   ├── (292) Cedar Lumber
# │   │   ├── (1460) Cedar Log
# │   │   └── (876) Wind Crystal
# │   ├── (584) Holy Water
# │   └── (876) Wind Crystal
# |
# ├── (-1080) Iron Ingot
# │   ├── (-3240) Iron Ore
# │   └── (-1080) Ice Shard|Fire Shard
# |
# ├── (660) Iron Nails
# │   ├── (660) Iron Ingot
# │   │   ├── (1980) Iron Ore
# │   │   └── (660) Ice Shard|Fire Shard
# │   └── (660) Fire Shard
# |
# ├── (360) Iron Rivets
# │   ├── (360) Iron Ingot
# │   │   ├── (1080) Iron Ore
# │   │   └── (360) Ice Shard|Fire Shard
# │   └── (360) Ice Shard|Fire Shard
# |
# ├── (128) Larimar
# │   ├── (384) Raw Larimar
# │   ├── (128) Basilisk Whetstone
# │   │   ├── (128) Basilisk Egg
# │   │   └── (640) Wind Shard
# │   └── (512) Wind Crystal
# |
# ├── (-90) Mythril Ingot
# │   ├── (-270) Mythril Ore
# │   └── (-360) Ice Shard|Wind Shard|Fire Shard
# |
# ├── (0) Mythril Rivets
# │   ├── (0) Mythril Ingot
# │   │   ├── (0) Mythril Ore
# │   │   └── (0) Ice Shard|Wind Shard|Fire Shard
# │   └── (0) Ice Shard|Fire Shard
# |
# ├── (1402) Mythrite Ingot
# │   ├── (5608) Mythrite Ore
# │   ├── (1402) Mythrite Nugget
# │   │   ├── (7010) Mythrite Sand
# │   │   ├── (1402) Mythril Ore
# │   │   └── (4206) Ice Crystal|Wind Crystal|Fire Crystal
# │   └── (4206) Ice Crystal|Wind Crystal|Fire Crystal
# |
# ├── (168) Platinum Nugget
# │   ├── (504) Platinum Ore
# │   ├── (336) Wind Cluster
# │   └── (168) Fire Cluster
# |
# ├── (652) Rose Gold Ingot
# │   ├── (1304) Rose Gold Nugget
# │   │   ├── (3912) Gold Ore
# │   │   ├── (1304) Copper Ore
# │   │   └── (3912) Wind Crystal
# │   ├── (5868) Peacock Ore
# │   └── (652) Wind Cluster
# |
# ├── (320) Rose Gold Nugget
# │   ├── (960) Gold Ore
# │   ├── (320) Copper Ore
# │   └── (960) Wind Crystal
# |
# ├── (1450) Silver Ingot
# │   ├── (4350) Silver Ore
# │   └── (2900) Wind Shard
# |
# ├── (240) Spruce Lumber
# │   ├── (720) Spruce Log
# │   └── (720) Wind Crystal
# |
# ├── (-2100) Steel Ingot
# │   ├── (-2100) Bomb Ash
# │   ├── (-4200) Iron Ore
# │   └── (-4200) Ice Shard|Fire Shard
# |
# ├── (1930) Steel Joint Plate
# │   ├── (1930) Steel Ingot
# │   │   ├── (1930) Bomb Ash
# │   │   ├── (3860) Iron Ore
# │   │   └── (3860) Ice Shard|Fire Shard
# │   └── (5790) Ice Shard
# |
# ├── (0) Steel Rivets
# │   ├── (0) Steel Ingot
# │   │   ├── (0) Bomb Ash
# │   │   ├── (0) Iron Ore
# │   │   └── (0) Ice Shard|Fire Shard
# │   └── (0) Ice Shard|Fire Shard
# |
# ├── (260) Titanium Ingot
# │   ├── (1040) Cloud Mica
# │   ├── (260) Titanium Nugget
# │   │   ├── (1300) Titanium Ore
# │   │   ├── (260) Iron Ore
# │   │   ├── (260) Grenade Ash
# │   │   └── (1040) Ice Crystal|Fire Crystal
# │   └── (1300) Ice Crystal|Fire Crystal
# |
# ├── (64) Topaz
# │   ├── (64) Emery
# │   ├── (64) Raw Topaz
# │   ├── (128) Wind Cluster
# │   └── (64) Fire Cluster
# |
# ├── (240) Treated Spruce Lumber
# │   ├── (480) Spruce Lumber
# │   │   ├── (1440) Spruce Log
# │   │   └── (1440) Wind Crystal
# │   ├── (2160) Hardened Sap
# │   └── (240) Wind Cluster
# |
# ├── (183) Varnish
# │   ├── (366) Raw Amber
# │   ├── (183) Linseed Oil
# │   │   ├── (366) Flax
# │   │   └── (549) Water Shard
# │   ├── (183) Terebinth
# │   └── (915) Water Shard
# |
# ├── (92) Void Glue
# │   ├── (276) Gelato Flesh
# │   ├── (184) Pudding Flesh
# │   └── (276) Water Crystal
# |
# └── (240) Walnut Lumber
#     ├── (720) Walnut Log
#     └── (480) Wind Shard
# |

# %%
# Generate gathering list with location info included.
from workshop_items import generate_gathering_list as g;import os,pandas as p;d='utilities';df=g(os.path.join(d,'workshop_output.csv'),os.path.join(d,'recipe_book.csv'),os.path.join(d,'recipe_gathering.csv'),os.path.join(d,'gathering_list.csv'));exec("for m,g in df.groupby('Method'):print(f'\\n=== {m} ===\\n'+g.drop(columns='Method').to_markdown(index=False))")
# Out:
# === crystal ===
# | Ingredient    |   Total Quantity | Location Info             |
# |:--------------|-----------------:|:--------------------------|
# | Earth Cluster |            450   | universalis.app/market/17 |
# | Fire Cluster  |           1370.5 | universalis.app/market/14 |
# | Fire Crystal  |          10491.5 | universalis.app/market/8  |
# | Fire Shard    |          29345   | universalis.app/market/2  |
# | Ice Cluster   |           1487.5 | universalis.app/market/15 |
# | Ice Crystal   |          10950.5 | universalis.app/market/9  |
# | Ice Shard     |          54275   | universalis.app/market/3  |
# | Water Crystal |            276   | universalis.app/market/13 |
# | Water Shard   |           1464   | universalis.app/market/7  |
# | Wind Cluster  |           2693   | universalis.app/market/16 |
# | Wind Crystal  |          12010   | universalis.app/market/10 |
# | Wind Shard    |           5420   | universalis.app/market/4  |
#
# === drop ===
# | Ingredient   |   Total Quantity | Location Info                                |
# |:-------------|-----------------:|:---------------------------------------------|
# | Gelato Flesh |              276 | ffxiv.consolegameswiki.com/wiki/Gelato_Flesh |
#
# === gc seals ===
# | Ingredient        |   Total Quantity | Location Info          |
# |:------------------|-----------------:|:-----------------------|
# | Aqueous Whetstone |             1917 | old for 200 GC Seals   |
# | Coke              |            16659 | Sold for 200 GC Seals  |
# | Emery             |               64 | Sold for 1500 GC Seals |
# | Hardened Sap      |             3294 | Sold for 200 GC Seals  |
# | Peacock Ore       |             5868 | Sold for 200 GC Seals  |
# | Petrified Log     |              436 | Sold for 1500 GC Seals |
# | Pudding Flesh     |              184 | Sold for 200 GC Seals  |
#
# === normal ===
# | Ingredient         |   Total Quantity | Location Info                                        |
# |:-------------------|-----------------:|:-----------------------------------------------------|
# | Basilisk Egg       |              128 | Northern Thanalan ( 22.4 / 24.4 )                    |
# | Cedar Log          |             1310 | Coerthas Western Highlands ( 31.3 / 32.1 )           |
# | Cloud Mica         |             1040 | The Churning Mists ( 27.6 / 19.2 )                   |
# | Cobalt Ore         |            20320 | Northern Thanalan ( 23.1 / 24.2 )                    |
# | Effervescent Water |                0 | South Shroud ( 16.0 / 19.7 )                         |
# | Electrum Ore       |             1216 | Upper La Noscea ( 30.4 / 25.4 )                      |
# | Flax               |              366 | South Shroud ( 17.6 / 28.6 )                         |
# | Mythril Ore        |             1132 | Southern Thanalan ( 25.2 / 39.9 )                    |
# | Mythrite Ore       |             5608 | Coerthas Western Highlands ( 31.2 / 12.8 ), (Hidden) |
# | Mythrite Sand      |             7010 | Coerthas Western Highlands ( 16.6 / 13.1 )           |
# | Raw Amber          |              366 | Eastern Thanalan ( 12.7 / 19.1 )                     |
# | Raw Larimar        |              384 | Coerthas Western Highlands ( 31.3 / 12.6 )           |
# | Rock Salt          |                0 | Central Thanalan ( 14.5 / 22.7 )                     |
# | Silex              |                0 | Southern Thanalan ( 22.4 / 29.7 )                    |
# | Silver Ore         |             4350 | South Shroud ( 16.1 / 19.7 )                         |
# | Titanium Ore       |             1300 | The Dravanian Forelands ( 30.3 / 15.1 )              |
# | Walnut Log         |              720 | South Shroud ( 23.1 / 21.6 )                         |
#
# === npc ===
# | Ingredient   |   Total Quantity | Location Info                               |
# |:-------------|-----------------:|:--------------------------------------------|
# | Bomb Ash     |             -170 | ffxiv.consolegameswiki.com/wiki/Bomb_Ash    |
# | Copper Ore   |             1624 | ffxiv.consolegameswiki.com/wiki/Copper_Ore  |
# | Grenade Ash  |              260 | ffxiv.consolegameswiki.com/wiki/Grenade_Ash |
# | Holy Water   |              584 | ffxiv.consolegameswiki.com/wiki/Holy_Water  |
# | Iron Ore     |             9225 | ffxiv.consolegameswiki.com/wiki/Iron_Ore    |
# | Terebinth    |              183 | ffxiv.consolegameswiki.com/wiki/Terebinth   |
#
# === timed node ===
# | Ingredient    |   Total Quantity | Location Info                                               |
# |:--------------|-----------------:|:------------------------------------------------------------|
# | Darksteel Ore |            11805 | Coerthas Central Highlands ( 27.5 / 20.0 ), Timed at 1:00am |
# | Gold Ore      |             4872 | Eastern Thanalan ( 27.3 / 21.3 ), Timed at 9:00am           |
# | Platinum Ore  |              504 | Southern Thanalan ( 16.7 / 10.7 ), Timed at 4:00am ET       |
# | Raw Topaz     |               64 | Northern Thanalan ( 18.0 / 20.0 ), Timed at 3:00am ET       |
# | Scarlet Sap   |              436 | North Shroud ( 17.7 / 27.7 ), Timed at 3:00am               |
# | Spruce Log    |             2160 | Coerthas Central Highlands ( 29.5 / 13.1 ), Timed at 9:00am |
#
# === voyages ===
# | Ingredient    |   Total Quantity | Location Info                                 |
# |:--------------|-----------------:|:----------------------------------------------|
# | Cassia Log    |              378 | ffxiv.consolegameswiki.com/wiki/Cassia_Log    |
# | Raw Celestine |              639 | ffxiv.consolegameswiki.com/wiki/Raw_Celestine |
# | Vivianite     |             1350 | ffxiv.consolegameswiki.com/wiki/Vivianite     |
