# %%
from workshop_items import consolidate_csv_files
consolidated_data = consolidate_csv_files()
if consolidated_data is not None:
    display(consolidated_data)
# Out:
# Consolidated CSV saved to utilities/workshop_output.csv (without headers)
#                      Item  Quantity
# 0          Ancient Lumber        69
# 1      Aurum Regis Nugget        18
# 2           Cassia Lumber         9
# 3            Cedar Lumber        18
# 4               Celestine        18
# 5            Cobalt Ingot       462
# 6      Cobalt Joint Plate       252
# 7            Cobalt Plate        60
# 8           Cobalt Rivets       195
# 9    Dark Chestnut Lumber        30
# 10        Darksteel Ingot       171
# 11       Darksteel Nugget        63
# 12       Darksteel Rivets       108
# 13         Electrum Ingot       123
# 14        Farreach Canvas        27
# 15          Garlond Steel        45
# 16          Garlond Stell         9
# 17      Hardsilver Nugget        18
# 18      Holy Cedar Lumber        24
# 19              Horn Glue        36
# 20             Iron Nails       123
# 21            Iron Rivets       123
# 22                Larimar        12
# 23          Mythril Plate        36
# 24         Mythril Rivets       222
# 25         Mythrite Ingot       132
# 26             Oak Lumber        24
# 27        Platinum Nugget        12
# 28        Rose Gold Ingot        78
# 29       Rose Gold Nugget        30
# 30           Silver Ingot       150
# 31          Spruce Lumber        84
# 32            Steel Ingot       357
# 33      Steel Joint Plate       150
# 34            Steel Nails        66
# 35            Steel Plate        24
# 36           Steel Rivets       462
# 37         Titanium Ingot        60
# 38                  Topaz         6
# 39  Treated Spruce Lumber        60
# 40         Uraeus Leather        24
# 41                Varnish        84
# 42              Void Glue        33
# 43          Walnut Lumber        60
# 44         Wyvern Leather        36

# %%
import os
from workshop_items import generate_gathering_list
utils_dir = 'utilities/'
df_gathering_list = generate_gathering_list(
    total_csv=os.path.join(utils_dir, 'workshop_output.csv'),
    recipe_book_csv=os.path.join(utils_dir, 'recipe_book.csv'),
    recipe_gathering_csv=os.path.join(utils_dir, 'recipe_gathering.csv'),
    output_csv=os.path.join(utils_dir, 'gathering_list.csv')
)
for method, group in df_gathering_list.groupby('Method'):
    print(f"\n=== {method} ===")
    print(group.to_markdown(index=False))
# Out:
# === drop ===
# | Ingredient   |   Total Quantity | Method   | Location Info                                                      |
# |:-------------|-----------------:|:---------|:-------------------------------------------------------------------|
# | Aldgoat Horn |               72 | drop     | Eastern Thanalan ( 18.2 / 22.7 ), Dropped by Myotragus Billy       |
# | Gelato Flesh |               99 | drop     | Coerthas Western Highlands ( 9.4 / 18.8 ), Dropped by Gelato       |
# | Uraeus Skin  |               24 | drop     | Nowhere ( 0.0 / 0.0 ), Found in The Wanderer's Palace              |
# | Wyvern Skin  |              108 | drop     | Coerthas Western Highlands (X:19.5 Y:35.9), Rare drop from wyverns |
#
# === gc seals ===
# | Ingredient        |   Total Quantity | Method   | Location Info                                 |
# |:------------------|-----------------:|:---------|:----------------------------------------------|
# | Aqueous Whetstone |              162 | gc seals | Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals  |
# | Coke              |             1944 | gc seals | Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals  |
# | Emery             |                6 | gc seals | Nowhere ( 0.0 / 0.0 ), Sold for 1500 GC Seals |
# | Hardened Sap      |              621 | gc seals | Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals  |
# | Peacock Ore       |              702 | gc seals | Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals  |
# | Petrified Log     |               69 | gc seals | Nowhere ( 0.0 / 0.0 ), Sold for 1500 GC Seals |
# | Potash            |              243 | gc seals | Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals  |
# | Pudding Flesh     |               66 | gc seals | Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals  |
#
# === normal ===
# | Ingredient        |   Total Quantity | Method   | Location Info                              |
# |:------------------|-----------------:|:---------|:-------------------------------------------|
# | Aurum Regis Sand  |               90 | normal   | The Sea of Clouds ( 34.8 / 30.5 )          |
# | Basilisk Egg      |               12 | normal   | Northern Thanalan ( 22.4 / 24.4 )          |
# | Black Alumen      |               24 | normal   | South Shroud ( 28.7 / 22.8 )               |
# | Bomb Ash          |             1083 | normal   | Southern Thanalan ( 22.2 / 29.9 )          |
# | Cedar Log         |              210 | normal   | Coerthas Western Highlands ( 31.3 / 32.1 ) |
# | Cloud Mica        |              240 | normal   | The Churning Mists ( 27.6 / 19.2 )         |
# | Cobalt Ore        |             2193 | normal   | Northern Thanalan ( 23.1 / 24.2 )          |
# | Dark Chestnut Log |              150 | normal   | The Dravanian Forelands ( 26.6 / 27.1 )    |
# | Electrum Ore      |              492 | normal   | Upper La Noscea ( 30.4 / 25.4 )            |
# | Flax              |              168 | normal   | South Shroud ( 17.6 / 28.6 )               |
# | Hardsilver Sand   |               90 | normal   | The Churning Mists ( 15.9 / 28.5 )         |
# | Mythril Ore       |             1014 | normal   | Southern Thanalan ( 25.2 / 39.9 )          |
# | Mythrite Ore      |              528 | normal   | Coerthas Western Highlands ( 31.2 / 12.8 ) |
# | Mythrite Sand     |              660 | normal   | Coerthas Western Highlands ( 16.6 / 13.1 ) |
# | Oak Log           |               72 | normal   | South Shroud ( 16.6 / 30.2 )               |
# | Raw Amber         |              168 | normal   | Eastern Thanalan ( 12.7 / 19.1 )           |
# | Raw Larimar       |               36 | normal   | Coerthas Western Highlands ( 31.3 / 12.6 ) |
# | Silver Ore        |              468 | normal   | South Shroud ( 16.1 / 19.7 )               |
# | Titanium Ore      |              300 | normal   | The Dravanian Forelands ( 30.3 / 15.1 )    |
# | Walnut Log        |              180 | normal   | South Shroud ( 23.1 / 21.6 )               |
#
# === npc ===
# | Ingredient   |   Total Quantity | Method   | Location Info                                                      |
# |:-------------|-----------------:|:---------|:-------------------------------------------------------------------|
# | Copper Ore   |              186 | npc      | Purchased from BSM/ARM Guild Vendor Outside                        |
# | Grenade Ash  |               60 | npc      | Nowhere ( 0.0 / 0.0 ), Purchased from Z'ranmaia (Limsa NPC)        |
# | Holy Water   |               48 | npc      | Nowhere ( 0.0 / 0.0 ), Sold by Idyllshire Scrap Salvager           |
# | Iron Ore     |             3993 | npc      | Nowhere ( 0.0 / 0.0 ), Purchased from BSM/ARM Guild Vendor Outside |
# | Terebinth    |               84 | npc      | Nowhere ( 0.0 / 0.0 ), Sold by Main City NPCs                      |
#
# === timed node ===
# | Ingredient          |   Total Quantity | Method     | Location Info                                                   |
# |:--------------------|-----------------:|:-----------|:----------------------------------------------------------------|
# | Coerthan Tea Leaves |               36 | timed node | Coerthas Western Highlands ( 31.7 / 19.6 ), Timed at 10:00am/pm |
# | Darksteel Ore       |             1539 | timed node | Coerthas Central Highlands ( 27.5 / 20.0 ), Timed at 1:00am     |
# | Gold Ore            |              576 | timed node | Eastern Thanalan ( 27.3 / 21.3 ), Timed at 10:00am              |
# | Platinum Ore        |               36 | timed node | Southern Thanalan ( 16.7 / 10.7 ), Timed at 4:00am ET           |
# | Raw Topaz           |                6 | timed node | Northern Thanalan ( 18.0 / 20.0 ), Timed at 3:00am ET           |
# | Scarlet Sap         |               69 | timed node | North Shroud ( 17.7 / 27.7 ), Timed at 1:00am                   |
# | Spruce Log          |              612 | timed node | Coerthas Central Highlands ( 29.5 / 13.1 ), Timed at 10:00am    |
#
# === voyages ===
# | Ingredient     |   Total Quantity | Method   | Location Info                                                  |
# |:---------------|-----------------:|:---------|:---------------------------------------------------------------|
# | Cassia Log     |               27 | voyages  | Nowhere ( 0.0 / 0.0 ), Collected from Company Workshop Voyages |
# | Cassia Log     |               27 | voyages  | Nowhere ( 0.0 / 0.0 ), Collected from Company Workshop Voyages |
# | Raw Celestine  |               54 | voyages  | Nowhere ( 0.0 / 0.0 ), Collected from Company Workshop Voyages |
# | Red Moko Grass |               81 | voyages  | Nowhere ( 0.0 / 0.0 ), Collected from Company Workshop Voyages |
# | Vivianite      |              135 | voyages  | Nowhere ( 0.0 / 0.0 ), Collected from Company Workshop Voyages |

# %%
from workshop_items import print_recipe_tree

utils = "utilities"
print_recipe_tree(
    recipe_book_csv=os.path.join(utils, 'recipe_book.csv'),
    recipe_gathering_csv=os.path.join(utils, 'recipe_gathering.csv'),
    total_csv=os.path.join(utils, 'workshop_output.csv')
)
# Out:
# === Recipe Breakdown ===
# ├── Ancient Lumber (x 69)
# │   ├── Petrified Log (x 69)  [gc seals @ Nowhere ( 0.0 / 0.0 ), Sold for 1500 GC Seals]
# │   ├── Scarlet Sap (x 69)  [timed node @ North Shroud ( 17.7 / 27.7 ), Timed at 1:00am]
# │   ├── Wind Cluster (x 138)
# │   └── Ice Cluster (x 69)
# ├── Aurum Regis Nugget (x 18)
# │   ├── Aurum Regis Sand (x 90)  [normal @ The Sea of Clouds ( 34.8 / 30.5 )]
# │   ├── Gold Ore (x 18)  [timed node @ Eastern Thanalan ( 27.3 / 21.3 ), Timed at 10:00am]
# │   └── Wind Crystal (x 90)
# ├── Cassia Lumber (x 9)
# │   ├── Cassia Log (x 27)  [voyages @ Nowhere ( 0.0 / 0.0 ), Collected from Company Workshop Voyages]
# │   ├── Hardened Sap (x 81)  [gc seals @ Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals]
# │   ├── Wind Cluster (x 18)
# │   └── Ice Cluster (x 9)
# ├── Cedar Lumber (x 18)
# │   ├── Cedar Log (x 90)  [normal @ Coerthas Western Highlands ( 31.3 / 32.1 )]
# │   └── Wind Crystal (x 54)
# ├── Celestine (x 18)
# │   ├── Raw Celestine (x 54)  [voyages @ Nowhere ( 0.0 / 0.0 ), Collected from Company Workshop Voyages]
# │   ├── Aqueous Whetstone (x 162)  [gc seals @ Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals]
# │   ├── Wind Cluster (x 18)
# │   └── Fire Cluster (x 18)
# ├── Cobalt Ingot (x 462)
# │   ├── Cobalt Ore (x 924)  [normal @ Northern Thanalan ( 23.1 / 24.2 )]
# │   ├── Iron Ore (x 462)  [npc @ Nowhere ( 0.0 / 0.0 ), Purchased from BSM/ARM Guild Vendor Outside]
# │   └── Fire Shard (x 2310)
# ├── Cobalt Joint Plate (x 252)
# │   ├── Cobalt Ingot (x 252)
# │   │   ├── Cobalt Ore (x 504)  [normal @ Northern Thanalan ( 23.1 / 24.2 )]
# │   │   ├── Iron Ore (x 252)  [npc @ Nowhere ( 0.0 / 0.0 ), Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Fire Shard (x 1260)
# │   └── Ice Shard (x 1260)
# ├── Cobalt Plate (x 60)
# │   ├── Cobalt Ingot (x 120)
# │   │   ├── Cobalt Ore (x 240)  [normal @ Northern Thanalan ( 23.1 / 24.2 )]
# │   │   ├── Iron Ore (x 120)  [npc @ Nowhere ( 0.0 / 0.0 ), Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Fire Shard (x 600)
# │   └── Ice Shard (x 300)
# ├── Cobalt Rivets (x 195)
# │   ├── Cobalt Ingot (x 195)
# │   │   ├── Cobalt Ore (x 390)  [normal @ Northern Thanalan ( 23.1 / 24.2 )]
# │   │   ├── Iron Ore (x 195)  [npc @ Nowhere ( 0.0 / 0.0 ), Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Fire Shard (x 975)
# │   └── Fire Shard (x 975)
# ├── Dark Chestnut Lumber (x 30)
# │   ├── Dark Chestnut Log (x 150)  [normal @ The Dravanian Forelands ( 26.6 / 27.1 )]
# │   └── Wind Crystal (x 120)
# ├── Darksteel Ingot (x 171)
# │   ├── Darksteel Nugget (x 342)
# │   │   ├── Darksteel Ore (x 1026)  [timed node @ Coerthas Central Highlands ( 27.5 / 20.0 ), Timed at 1:00am]
# │   │   └── Fire Crystal (x 1026)
# │   ├── Coke (x 1539)  [gc seals @ Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals]
# │   └── Fire Cluster (x 171)
# ├── Darksteel Nugget (x 63)
# │   ├── Darksteel Ore (x 189)  [timed node @ Coerthas Central Highlands ( 27.5 / 20.0 ), Timed at 1:00am]
# │   └── Fire Crystal (x 189)
# ├── Darksteel Rivets (x 108)
# │   ├── Darksteel Nugget (x 108)
# │   │   ├── Darksteel Ore (x 324)  [timed node @ Coerthas Central Highlands ( 27.5 / 20.0 ), Timed at 1:00am]
# │   │   └── Fire Crystal (x 324)
# │   └── Fire Crystal (x 324)
# ├── Electrum Ingot (x 123)
# │   ├── Electrum Ore (x 492)  [normal @ Upper La Noscea ( 30.4 / 25.4 )]
# │   └── Wind Shard (x 615)
# ├── Farreach Canvas (x 27)
# │   ├── Red Moko Grass (x 81)  [voyages @ Nowhere ( 0.0 / 0.0 ), Collected from Company Workshop Voyages]
# │   ├── Potash (x 243)  [gc seals @ Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals]
# │   ├── Lightning Cluster (x 27)
# │   └── Wind Cluster (x 27)
# ├── Garlond Steel (x 45)
# │   ├── Vivianite (x 135)  [voyages @ Nowhere ( 0.0 / 0.0 ), Collected from Company Workshop Voyages]
# │   ├── Coke (x 405)  [gc seals @ Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals]
# │   ├── Cobalt Ore (x 135)  [normal @ Northern Thanalan ( 23.1 / 24.2 )]
# │   ├── Fire Cluster (x 45)
# │   └── Earth Cluster (x 45)
# ├── Garlond Stell (x 9)
# ├── Hardsilver Nugget (x 18)
# │   ├── Hardsilver Sand (x 90)  [normal @ The Churning Mists ( 15.9 / 28.5 )]
# │   ├── Silver Ore (x 18)  [normal @ South Shroud ( 16.1 / 19.7 )]
# │   └── Wind Crystal (x 72)
# ├── Holy Cedar Lumber (x 24)
# │   ├── Cedar Lumber (x 24)
# │   │   ├── Cedar Log (x 120)  [normal @ Coerthas Western Highlands ( 31.3 / 32.1 )]
# │   │   └── Wind Crystal (x 72)
# │   ├── Holy Water (x 48)  [npc @ Nowhere ( 0.0 / 0.0 ), Sold by Idyllshire Scrap Salvager]
# │   └── Wind Crystal (x 72)
# ├── Horn Glue (x 36)
# │   ├── Aldgoat Horn (x 72)  [drop @ Eastern Thanalan ( 18.2 / 22.7 ), Dropped by Myotragus Billy]
# │   └── Water Shard (x 108)
# ├── Iron Nails (x 123)
# │   ├── Iron Ingot (x 123)
# │   │   ├── Iron Ore (x 369)  [npc @ Nowhere ( 0.0 / 0.0 ), Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Fire Shard (x 123)
# │   └── Fire Shard (x 123)
# ├── Iron Rivets (x 123)
# │   ├── Iron Ingot (x 123)
# │   │   ├── Iron Ore (x 369)  [npc @ Nowhere ( 0.0 / 0.0 ), Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Fire Shard (x 123)
# │   └── Fire Shard (x 123)
# ├── Larimar (x 12)
# │   ├── Raw Larimar (x 36)  [normal @ Coerthas Western Highlands ( 31.3 / 12.6 )]
# │   ├── Basilisk Whetstone (x 12)
# │   │   ├── Basilisk Egg (x 12)  [normal @ Northern Thanalan ( 22.4 / 24.4 )]
# │   │   └── Wind Shard (x 60)
# │   └── Wind Crystal (x 48)
# ├── Mythril Plate (x 36)
# │   ├── Mythril Ingot (x 72)
# │   │   ├── Mythril Ore (x 216)  [normal @ Southern Thanalan ( 25.2 / 39.9 )]
# │   │   └── Fire Shard (x 216)
# │   └── Ice Shard (x 144)
# ├── Mythril Rivets (x 222)
# │   ├── Mythril Ingot (x 222)
# │   │   ├── Mythril Ore (x 666)  [normal @ Southern Thanalan ( 25.2 / 39.9 )]
# │   │   └── Fire Shard (x 666)
# │   └── Fire Shard (x 1110)
# ├── Mythrite Ingot (x 132)
# │   ├── Mythrite Ore (x 528)  [normal @ Coerthas Western Highlands ( 31.2 / 12.8 )]
# │   ├── Mythrite Nugget (x 132)
# │   │   ├── Mythrite Sand (x 660)  [normal @ Coerthas Western Highlands ( 16.6 / 13.1 )]
# │   │   ├── Mythril Ore (x 132)  [normal @ Southern Thanalan ( 25.2 / 39.9 )]
# │   │   └── Fire Crystal (x 396)
# │   └── Fire Crystal (x 396)
# ├── Oak Lumber (x 24)
# │   ├── Oak Log (x 72)  [normal @ South Shroud ( 16.6 / 30.2 )]
# │   └── Wind Shard (x 72)
# ├── Platinum Nugget (x 12)
# │   ├── Platinum Ore (x 36)  [timed node @ Southern Thanalan ( 16.7 / 10.7 ), Timed at 4:00am ET]
# │   ├── Wind Cluster (x 24)
# │   └── Fire Cluster (x 12)
# ├── Rose Gold Ingot (x 78)
# │   ├── Rose Gold Nugget (x 156)
# │   │   ├── Gold Ore (x 468)  [timed node @ Eastern Thanalan ( 27.3 / 21.3 ), Timed at 10:00am]
# │   │   ├── Copper Ore (x 156)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Wind Crystal (x 468)
# │   ├── Peacock Ore (x 702)  [gc seals @ Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals]
# │   └── Wind Cluster (x 78)
# ├── Rose Gold Nugget (x 30)
# │   ├── Gold Ore (x 90)  [timed node @ Eastern Thanalan ( 27.3 / 21.3 ), Timed at 10:00am]
# │   ├── Copper Ore (x 30)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   └── Wind Crystal (x 90)
# ├── Silver Ingot (x 150)
# │   ├── Silver Ore (x 450)  [normal @ South Shroud ( 16.1 / 19.7 )]
# │   └── Wind Shard (x 300)
# ├── Spruce Lumber (x 84)
# │   ├── Spruce Log (x 252)  [timed node @ Coerthas Central Highlands ( 29.5 / 13.1 ), Timed at 10:00am]
# │   └── Wind Crystal (x 252)
# ├── Steel Ingot (x 357)
# │   ├── Bomb Ash (x 357)  [normal @ Southern Thanalan ( 22.2 / 29.9 )]
# │   ├── Iron Ore (x 714)  [npc @ Nowhere ( 0.0 / 0.0 ), Purchased from BSM/ARM Guild Vendor Outside]
# │   └── Fire Shard (x 714)
# ├── Steel Joint Plate (x 150)
# │   ├── Steel Ingot (x 150)
# │   │   ├── Bomb Ash (x 150)  [normal @ Southern Thanalan ( 22.2 / 29.9 )]
# │   │   ├── Iron Ore (x 300)  [npc @ Nowhere ( 0.0 / 0.0 ), Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Fire Shard (x 300)
# │   └── Ice Shard (x 450)
# ├── Steel Nails (x 66)
# │   ├── Steel Ingot (x 66)
# │   │   ├── Bomb Ash (x 66)  [normal @ Southern Thanalan ( 22.2 / 29.9 )]
# │   │   ├── Iron Ore (x 132)  [npc @ Nowhere ( 0.0 / 0.0 ), Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Fire Shard (x 132)
# │   └── Fire Shard (x 198)
# ├── Steel Plate (x 24)
# │   ├── Steel Ingot (x 48)
# │   │   ├── Bomb Ash (x 48)  [normal @ Southern Thanalan ( 22.2 / 29.9 )]
# │   │   ├── Iron Ore (x 96)  [npc @ Nowhere ( 0.0 / 0.0 ), Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Fire Shard (x 96)
# │   └── Ice Shard (x 72)
# ├── Steel Rivets (x 462)
# │   ├── Steel Ingot (x 462)
# │   │   ├── Bomb Ash (x 462)  [normal @ Southern Thanalan ( 22.2 / 29.9 )]
# │   │   ├── Iron Ore (x 924)  [npc @ Nowhere ( 0.0 / 0.0 ), Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Fire Shard (x 924)
# │   └── Fire Shard (x 1386)
# ├── Titanium Ingot (x 60)
# │   ├── Cloud Mica (x 240)  [normal @ The Churning Mists ( 27.6 / 19.2 )]
# │   ├── Titanium Nugget (x 60)
# │   │   ├── Titanium Ore (x 300)  [normal @ The Dravanian Forelands ( 30.3 / 15.1 )]
# │   │   ├── Iron Ore (x 60)  [npc @ Nowhere ( 0.0 / 0.0 ), Purchased from BSM/ARM Guild Vendor Outside]
# │   │   ├── Grenade Ash (x 60)  [npc @ Nowhere ( 0.0 / 0.0 ), Purchased from Z'ranmaia (Limsa NPC)]
# │   │   └── Fire Crystal (x 240)
# │   └── Fire Crystal (x 300)
# ├── Topaz (x 6)
# │   ├── Emery (x 6)  [gc seals @ Nowhere ( 0.0 / 0.0 ), Sold for 1500 GC Seals]
# │   ├── Raw Topaz (x 6)  [timed node @ Northern Thanalan ( 18.0 / 20.0 ), Timed at 3:00am ET]
# │   ├── Wind Cluster (x 12)
# │   └── Fire Cluster (x 6)
# ├── Treated Spruce Lumber (x 60)
# │   ├── Spruce Lumber (x 120)
# │   │   ├── Spruce Log (x 360)  [timed node @ Coerthas Central Highlands ( 29.5 / 13.1 ), Timed at 10:00am]
# │   │   └── Wind Crystal (x 360)
# │   ├── Hardened Sap (x 540)  [gc seals @ Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals]
# │   └── Wind Cluster (x 60)
# ├── Uraeus Leather (x 24)
# │   ├── Uraeus Skin (x 24)  [drop @ Nowhere ( 0.0 / 0.0 ), Found in The Wanderer's Palace]
# │   ├── Black Alumen (x 24)  [normal @ South Shroud ( 28.7 / 22.8 )]
# │   └── Earth Crystal (x 24)
# ├── Varnish (x 84)
# │   ├── Raw Amber (x 168)  [normal @ Eastern Thanalan ( 12.7 / 19.1 )]
# │   ├── Linseed Oil (x 84)
# │   │   ├── Flax (x 168)  [normal @ South Shroud ( 17.6 / 28.6 )]
# │   │   └── Water Shard (x 252)
# │   ├── Terebinth (x 84)  [npc @ Nowhere ( 0.0 / 0.0 ), Sold by Main City NPCs]
# │   └── Water Shard (x 420)
# ├── Void Glue (x 33)
# │   ├── Gelato Flesh (x 99)  [drop @ Coerthas Western Highlands ( 9.4 / 18.8 ), Dropped by Gelato]
# │   ├── Pudding Flesh (x 66)  [gc seals @ Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals]
# │   └── Water Crystal (x 99)
# ├── Walnut Lumber (x 60)
# │   ├── Walnut Log (x 180)  [normal @ South Shroud ( 23.1 / 21.6 )]
# │   └── Wind Shard (x 120)
# └── Wyvern Leather (x 36)
#     ├── Wyvern Skin (x 108)  [drop @ Coerthas Western Highlands (X:19.5 Y:35.9), Rare drop from wyverns]
#     ├── Coerthan Tea Leaves (x 36)  [timed node @ Coerthas Western Highlands ( 31.7 / 19.6 ), Timed at 10:00am/pm]
#     └── Earth Crystal (x 108)
