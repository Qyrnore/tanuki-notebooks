# %%
import timed_nodes as tn

if __name__ == "__main__":
    input_file = "unspoiled_nodes"      
    output_file = "cleaned_nodes.csv"    
    tn.clean_unspoiled_data(input_file, output_file)
    print(f"Processed '{input_file}' and wrote results to '{output_file}'.")
# Out:
# Processed 'unspoiled_nodes' and wrote results to 'cleaned_nodes.csv'.

# %%
if __name__ == "__main__":
    input_file = "cleaned_nodes.csv"      
    output_file = "final_nodes_with_ids.csv"    
    tn.assign_ids(input_file, output_file)
    print(f"Merged CSV '{input_file}' and wrote results to '{output_file}'.")
# Out:
# Merged CSV written to 'final_nodes_with_ids.csv'.
# Merged CSV 'cleaned_nodes.csv' and wrote results to 'final_nodes_with_ids.csv'.

# %%
if __name__ == "__main__":
    input_file = "final_nodes_with_ids.csv"      
    output_file = "final_nodes_with_ids_sorted.csv"    
    tn.sort_for_current_time(input_file, output_file)
    print("")
    print(f"Sorted CSV '{input_file}' and wrote results to '{output_file}'.")
# Out:
# Current Eorzean time (raw): 01:31
#
# Active nodes (with time difference in minutes):
#         ID   Time                         Item Name  \
# 42    5350  01:00                   Silkworm Cocoon
# 104   5121  01:00                     Darksteel Ore
# 105   9519  01:00                            Pumice
# 3    33005  02:00             Rarefied Sandteak Log
# 27   13765  02:00               Old World Fig Seeds
# 28   12896  02:00                     Old World Fig
# 15   19852  02:00                    Othardian Plum
# 2    33007  02:00             Rarefied Amber Cloves
# 43    7611  02:00                      Fragrant Log
# 44    7591  02:00                 Shroud Tea Leaves
# 97   32973  02:00  Rarefied Abalathian Spring Water
# 98   32974  02:00         Rarefied Aurum Regis Sand
# 75   27726  02:00                      Raw Hematite
# 74   32986  02:00             Rarefied Tungsten Ore
#
#                        Location Coordinates  time_diff
# 42                  East Shroud   (x22,y26)        -31
# 104  Coerthas Central Highlands   (x27,y19)        -31
# 105           Eastern La Noscea   (x17,y26)        -31
# 3                    Amh Araeng   (x19,y20)         29
# 27      The Dravanian Forelands   (x26,y12)         29
# 28      The Dravanian Forelands   (x26,y12)         29
# 15              The Azim Steppe   (x23,y16)         29
# 2                    Amh Araeng   (x19,y20)         29
# 43                 South Shroud   (x18,y23)         29
# 44               Central Shroud   (x16,y20)         29
# 97            The Sea of Clouds   (x21,y12)         29
# 98            The Sea of Clouds   (x21,y12)         29
# 75                     Kholusia   (x33,y23)         29
# 74                  The Tempest   (x33,y21)         29
#
# Sorted CSV 'final_nodes_with_ids.csv' and wrote results to 'final_nodes_with_ids_sorted.csv'.

# %%
from IPython.display import display
import pandas as pd
import os
from contextlib import redirect_stdout

if __name__ == "__main__":
    input_file = "final_nodes_with_ids_sorted.csv"
    output_file = "final_nodes_with_ids_market.csv"
    with open(os.devnull, 'w') as fnull:
        with redirect_stdout(fnull):
            tn.generate_market_data(input_file, output_file)
    print("")
    print(f"Generated market data for '{input_file}' and wrote results to '{output_file}'.")
    df_market = pd.read_csv("final_nodes_with_ids_market.csv")
    display(df_market)
# Out:
# Generated market data for 'final_nodes_with_ids_sorted.csv' and wrote results to 'final_nodes_with_ids_market.csv'.
#       ID   Time            Item Name                    Location Coordinates  \
# 0   5350  01:00      Silkworm Cocoon                 East Shroud   (x22,y26)
# 1   5121  01:00        Darksteel Ore  Coerthas Central Highlands   (x27,y19)
# 2   9519  01:00               Pumice           Eastern La Noscea   (x17,y26)
# 3  13765  02:00  Old World Fig Seeds     The Dravanian Forelands   (x26,y12)
# 4  12896  02:00        Old World Fig     The Dravanian Forelands   (x26,y12)
# 5  19852  02:00       Othardian Plum             The Azim Steppe   (x23,y16)
# 6   7611  02:00         Fragrant Log                South Shroud   (x18,y23)
# 7   7591  02:00    Shroud Tea Leaves              Central Shroud   (x16,y20)
# 8  27726  02:00         Raw Hematite                    Kholusia   (x33,y23)
#
#            Parsed Time  time_diff  minListing_world  minListing_dc  \
# 0  1900-01-01 01:00:00        -31             380.0           40.0
# 1  1900-01-01 01:00:00        -31             696.0          696.0
# 2  1900-01-01 01:00:00        -31             150.0          127.0
# 3  1900-01-01 02:00:00         29            1300.0         1299.0
# 4  1900-01-01 02:00:00         29               3.0            1.0
# 5  1900-01-01 02:00:00         29              42.0            2.0
# 6  1900-01-01 02:00:00         29               NaN            NaN
# 7  1900-01-01 02:00:00         29             118.0            1.0
# 8  1900-01-01 02:00:00         29              84.0           20.0
#
#    recentPurchase_world  recentPurchase_dc  averageSalePrice_dc  \
# 0                 444.0              444.0           299.101765
# 1                 697.0              450.0           710.637276
# 2                 152.0              368.0           297.700000
# 3                1400.0             1400.0          1513.107629
# 4                   8.0               25.0            25.942857
# 5                 100.0              100.0                  NaN
# 6                   NaN                NaN                  NaN
# 7                 100.0             1000.0           166.949686
# 8                 200.0               80.0                  NaN
#
#    dailySaleVelocity_dc
# 0            433.698980
# 1          10450.863375
# 2             10.204669
# 3            187.255572
# 4             26.787225
# 5                   NaN
# 6                   NaN
# 7             40.563437
# 8                   NaN
