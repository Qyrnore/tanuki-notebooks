# %%
import timed_nodes as tn

if __name__ == "__main__":
    input_file = "unspoiled_nodes"      
    output_file = "cleaned_nodes.csv"    
    tn.clean_unspoiled_data(input_file, output_file)
    print(f"Processed '{input_file}' and wrote results to '{output_file}'.")
# Out:
# Processed 'unspoiled_nodes' and wrote results to 'cleaned_nodes.csv'.

# %%
if __name__ == "__main__":
    input_file = "cleaned_nodes.csv"      
    output_file = "final_nodes_with_ids.csv"    
    tn.assign_ids(input_file, output_file)
    print(f"Merged CSV '{input_file}' and wrote results to '{output_file}'.")
# Out:
# Merged CSV written to 'final_nodes_with_ids.csv'.
# Merged CSV 'cleaned_nodes.csv' and wrote results to 'final_nodes_with_ids.csv'.

# %%
if __name__ == "__main__":
    input_file = "final_nodes_with_ids.csv"      
    output_file = "final_nodes_with_ids_sorted.csv"    
    tn.sort_for_current_time(input_file, output_file)
    print("")
    print(f"Sorted CSV '{input_file}' and wrote results to '{output_file}'.")
# Out:
# Current Eorzean time (raw): 23:03
#
# Active nodes (with time difference in minutes):
#        ID   Time                     Item Name                 Location  \
# 0   27833  00:00                   Broad Beans                  Il Mheg
# 1   27828  00:00                  Mist Spinach   The Rak'tika Greatwood
# 14  33000  00:00           Rarefied Pine Resin                   Yanxia
# 13  33001  00:00             Rarefied Pine Log                   Yanxia
# 12  33009  00:00          Rarefied Urunday Log                The Peaks
# 25  12943  00:00           Dravanian Mistletoe       The Churning Mists
# 26  12899  00:00                       Porcini       The Churning Mists
# 23  32995  00:00        Rarefied Dark Chestnut  The Dravanian Forelands
# 24  32996  00:00  Rarefied Dark Chestnut Resin  The Dravanian Forelands
# 71  27729  00:00                  Raw Triplite               Amh Araeng
# 72  27731  00:00                      Raw Onyx              The Tempest
# 85  19970  00:00               Raw Star Spinel             The Ruby Sea
# 84  19907  00:00       Ala Mhigan Salt Crystal                The Lochs
# 96  12538  00:00                Adamantite Ore                 Azys Lla
#
#    Coordinates  time_diff
# 0    (x24,y36)         57
# 1    (x34,y21)         57
# 14   (x19,y14)         57
# 13   (x19,y14)         57
# 12    (x31,y7)         57
# 25    (x24,y6)         57
# 26    (x24,y6)         57
# 23   (x16,y36)         57
# 24   (x16,y36)         57
# 71   (x20,y29)         57
# 72   (x16,y21)         57
# 85    (x15,y5)         57
# 84   (x21,y29)         57
# 96    (x24,y6)         57
#
# Sorted CSV 'final_nodes_with_ids.csv' and wrote results to 'final_nodes_with_ids_sorted.csv'.

# %%
from IPython.display import display
import pandas as pd
import os
from contextlib import redirect_stdout

if __name__ == "__main__":
    input_file = "final_nodes_with_ids_sorted.csv"
    output_file = "final_nodes_with_ids_market.csv"
    with open(os.devnull, 'w') as fnull:
        with redirect_stdout(fnull):
            tn.generate_market_data(input_file, output_file)
    print("")
    print(f"Generated market data for '{input_file}' and wrote results to '{output_file}'.")
    df_market = pd.read_csv("final_nodes_with_ids_market.csv")
    display(df_market)
# Out:
# Generated market data for 'final_nodes_with_ids_sorted.csv' and wrote results to 'final_nodes_with_ids_market.csv'.
#       ID   Time                Item Name                Location Coordinates  \
# 0  27833  00:00              Broad Beans                 Il Mheg   (x24,y36)
# 1  27828  00:00             Mist Spinach  The Rak'tika Greatwood   (x34,y21)
# 2  12943  00:00      Dravanian Mistletoe      The Churning Mists    (x24,y6)
# 3  12899  00:00                  Porcini      The Churning Mists    (x24,y6)
# 4  27729  00:00             Raw Triplite              Amh Araeng   (x20,y29)
# 5  27731  00:00                 Raw Onyx             The Tempest   (x16,y21)
# 6  19970  00:00          Raw Star Spinel            The Ruby Sea    (x15,y5)
# 7  19907  00:00  Ala Mhigan Salt Crystal               The Lochs   (x21,y29)
# 8  12538  00:00           Adamantite Ore                Azys Lla    (x24,y6)
#
#   Parsed Time  time_diff  minListing_world  minListing_dc  \
# 0  1900-01-01         57                18              5
# 1  1900-01-01         57                29              7
# 2  1900-01-01         57              1000            900
# 3  1900-01-01         57               797             15
# 4  1900-01-01         57                 9              7
# 5  1900-01-01         57              1084           1000
# 6  1900-01-01         57                30              4
# 7  1900-01-01         57               150            124
# 8  1900-01-01         57               169            160
#
#    recentPurchase_world  recentPurchase_dc  averageSalePrice_dc  \
# 0                    15                  6             6.000000
# 1                     7                100            60.700000
# 2                  1000               1000           925.786914
# 3                    50                  2            86.063830
# 4                    42                 14            14.489933
# 5                   900                900           895.070485
# 6                    25                348                  NaN
# 7                   150                537           421.139535
# 8                   166                166           193.893977
#
#    dailySaleVelocity_dc
# 0              5.256294
# 1             30.919351
# 2            349.697589
# 3             14.532073
# 4             46.069725
# 5             70.186710
# 6                   NaN
# 7             66.476298
# 8            621.166425
