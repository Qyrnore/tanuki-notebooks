# %%
import timed_nodes as tn

if __name__ == "__main__":
    input_file = "unspoiled_nodes"      
    output_file = "cleaned_nodes.csv"    
    tn.clean_unspoiled_data(input_file, output_file)
    print(f"Processed '{input_file}' and wrote results to '{output_file}'.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import timed_nodes.timed_nodes as tn
#       3 if __name__ == "__main__":
#       4     input_file = "unspoiled_nodes"
#
# ModuleNotFoundError: No module named 'timed_nodes.timed_nodes'; 'timed_nodes' is not a package

# %%
if __name__ == "__main__":
    input_file = "cleaned_nodes.csv"      
    output_file = "final_nodes_with_ids.csv"    
    tn.assign_ids(input_file, output_file)
    print(f"Merged CSV '{input_file}' and wrote results to '{output_file}'.")
# Out:
# Merged CSV written to 'final_nodes_with_ids.csv'.
# Merged CSV 'cleaned_nodes.csv' and wrote results to 'final_nodes_with_ids.csv'.

# %%
if __name__ == "__main__":
    input_file = "final_nodes_with_ids.csv"      
    output_file = "final_nodes_with_ids_sorted.csv"    
    tn.sort_for_current_time(input_file, output_file)
    print("")
    print(f"Sorted CSV '{input_file}' and wrote results to '{output_file}'.")
# Out:
# Current Eorzean time (raw): 18:28
#
# Active nodes (with time difference in minutes):
#         ID   Time                 Item Name                    Location  \
# 6    27835  18:00                 Lemonette                    Kholusia
# 20   19918  18:00            Hallowed Basil                   The Peaks
# 32   12944  18:00      Abalathian Mistletoe           The Sea of Clouds
# 31   12889  18:00             Heavens Lemon           The Sea of Clouds
# 88   19972  18:00         Raw Imperial Jade                      Yanxia
# 81   27730  18:00              Raw Petalite                    Lakeland
# 80   27727  18:00              Raw Diaspore                     Il Mheg
# 79   32981  18:00     Rarefied Raw Lazurite      The Rak'tika Greatwood
# 120   5146  18:00                  Raw Ruby             Lower La Noscea
# 121   5151  18:00              Raw Sapphire             Lower La Noscea
# 89   32978  18:00      Rarefied Raw Azurite                 Azim Steppe
# 90   32979  18:00  Rarefied Silvergrace Ore                 Azim Steppe
# 21   19865  20:00                Lotus Root                      Yanxia
# 33   12900  20:00            Chysahl Greens  Coerthas Western Highlands
#
#     Coordinates  time_diff
# 6     (x20,y27)        -28
# 20    (x23,y16)        -28
# 32    (x35,y23)        -28
# 31    (x35,y23)        -28
# 88     (x29,y9)        -28
# 81    (x29,y33)        -28
# 80    (x26,y13)        -28
# 79    (x16,y18)        -28
# 120   (x23,y21)        -28
# 121   (x23,y21)        -28
# 89    (x36,y26)        -28
# 90    (x36,y26)        -28
# 21     (x28,y7)         92
# 33      (x8,y9)         92
#
# Sorted CSV 'final_nodes_with_ids.csv' and wrote results to 'final_nodes_with_ids_sorted.csv'.

# %%
from IPython.display import display
import pandas as pd
import os
from contextlib import redirect_stdout

if __name__ == "__main__":
    input_file = "final_nodes_with_ids_sorted.csv"
    output_file = "final_nodes_with_ids_market.csv"
    with open(os.devnull, 'w') as fnull:
        with redirect_stdout(fnull):
            tn.generate_market_data(input_file, output_file)
    print("")
    print(f"Generated market data for '{input_file}' and wrote results to '{output_file}'.")
    df_market = pd.read_csv("final_nodes_with_ids_market.csv")
    display(df_market)
# Out:
# Generated market data for 'final_nodes_with_ids_sorted.csv' and wrote results to 'final_nodes_with_ids_market.csv'.
#        ID   Time             Item Name                    Location  \
# 0   27835  18:00             Lemonette                    Kholusia
# 1   19918  18:00        Hallowed Basil                   The Peaks
# 2   12944  18:00  Abalathian Mistletoe           The Sea of Clouds
# 3   12889  18:00         Heavens Lemon           The Sea of Clouds
# 4   19972  18:00     Raw Imperial Jade                      Yanxia
# 5   27730  18:00          Raw Petalite                    Lakeland
# 6   27727  18:00          Raw Diaspore                     Il Mheg
# 7    5146  18:00              Raw Ruby             Lower La Noscea
# 8    5151  18:00          Raw Sapphire             Lower La Noscea
# 9   19865  20:00            Lotus Root                      Yanxia
# 10  12900  20:00        Chysahl Greens  Coerthas Western Highlands
#
#    Coordinates          Parsed Time  time_diff  minListing_world  \
# 0    (x20,y27)  1900-01-01 18:00:00        -28               424
# 1    (x23,y16)  1900-01-01 18:00:00        -28                 1
# 2    (x35,y23)  1900-01-01 18:00:00        -28               788
# 3    (x35,y23)  1900-01-01 18:00:00        -28               400
# 4     (x29,y9)  1900-01-01 18:00:00        -28                86
# 5    (x29,y33)  1900-01-01 18:00:00        -28               198
# 6    (x26,y13)  1900-01-01 18:00:00        -28                37
# 7    (x23,y21)  1900-01-01 18:00:00        -28                30
# 8    (x23,y21)  1900-01-01 18:00:00        -28               100
# 9     (x28,y7)  1900-01-01 20:00:00         92                10
# 10     (x8,y9)  1900-01-01 20:00:00         92               100
#
#     minListing_dc  recentPurchase_world  recentPurchase_dc  \
# 0             424                   399                299
# 1               1                     1                  6
# 2             145                    60               1100
# 3              99                    69                201
# 4              50                    75                 75
# 5              35                   178                178
# 6               5                    28                 28
# 7               2                   150                180
# 8              40                   100                 50
# 9              10                    10                 10
# 10             12                   800                250
#
#     averageSalePrice_dc  dailySaleVelocity_dc
# 0           1053.520293            412.730088
# 1                   NaN                   NaN
# 2            828.692308             74.966836
# 3            487.000000              6.315883
# 4             70.137725             45.858769
# 5            104.652968             60.138103
# 6                   NaN                   NaN
# 7            173.294118              4.668248
# 8                   NaN                   NaN
# 9             10.000000              2.746025
# 10           154.597701             23.890396
