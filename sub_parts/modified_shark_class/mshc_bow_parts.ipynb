# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import generate_gathering_list
utils_dir = '../../utilities/'
data_dir = 'item_data/'
df_gathering_list = generate_gathering_list(
    total_csv=os.path.join(data_dir, 'modified_shark_class_bow_parts.csv'),
    recipe_book_csv=os.path.join(utils_dir, 'recipe_book.csv'),
    recipe_gathering_csv=os.path.join(utils_dir, 'recipe_gathering.csv'),
    output_csv=os.path.join(data_dir, 'gathering_list.csv')
)
df_gathering_list
# Out:
#                 Ingredient  Total Quantity  \
# 11                Bomb Ash            30.0
# 3               Cobalt Ore            30.0
# 4                     Coke           162.0
# 7          Cryptomeria Log            27.0
# 26          Dhalmel Saliva            36.0
# 27  Dravanian Spring Water            18.0
# 6            Earth Cluster            30.0
# 20           Earth Crystal            54.0
# 17               Ferberite            12.0
# 5             Fire Cluster            42.0
# 19            Fire Crystal            54.0
# 14              Fire Shard            60.0
# 8             Hardened Sap            81.0
# 21          Hardsilver Ore           120.0
# 22         Hardsilver Sand           222.0
# 10             Ice Crystal            54.0
# 15               Ice Shard            90.0
# 12                Iron Ore            60.0
# 13                Iron Ore            60.0
# 18       Pure Titanium Ore            27.0
# 24           Raw Rhodonite            36.0
# 16               Scheelite            12.0
# 0          Shark-Class Bow             1.0
# 23              Silver Ore            30.0
# 2               Sphalerite            18.0
# 25             Stiperstone            12.0
# 1                Vivianite            27.0
# 28           Water Crystal            72.0
# 9             Wind Crystal           396.0
#
#                                         Location Info
# 11                  Southern Thanalan ( 22.2 / 29.9 )
# 3                   Northern Thanalan ( 23.1 / 24.2 )
# 4        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 7   Nowhere ( 0.0 / 0.0 ), Collected from Submarin...
# 26  The Sea of Clouds ( 17.3 / 32.2 ), Dropped by ...
# 27            The Dravanian Forelands ( 27.4 / 31.8 )
# 6                                                 NaN
# 20                                                NaN
# 17  Northern Thanalan ( 17.3 / 19.9 ), Timed at 3:...
# 5                                                 NaN
# 19                                                NaN
# 14                                                NaN
# 8        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 21              The Dravanian Forelands ( 25.3 / 25 )
# 22                 The Churning Mists ( 15.9 / 28.5 )
# 10                                                NaN
# 15                                                NaN
# 12                   Western Thanalan ( 27.2 / 17.4 )
# 13   Nowhere ( 0.0 / 0.0 ), Sold by Material Supplier
# 18  Nowhere ( 0.0 / 0.0 ), Collected from Submarin...
# 24      The Peaks ( 26.9 / 12.5 ), Timed at 8AM/PM ET
# 16      Nowhere ( 0.0 / 0.0 ), Sold for 1500 GC Seals
# 0                                                 NaN
# 23                       South Shroud ( 16.1 / 19.7 )
# 2      Nowhere ( 0.0 / 0.0 ), Sold by NPCs for Scrips
# 25                          The Peaks ( 23.3 / 13.1 )
# 1   Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 28                                                NaN
# 9                                                 NaN

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import get_crafting_recipes
data_dir = 'item_data/'
df_crafting_recipes = get_crafting_recipes(os.path.join(data_dir, 'modified_shark_class_bow_parts.csv'))
df_crafting_recipes
# Out:
#                     Product  Required Quantity
# 2        Cryptomeria Lumber                  9
# 8  Enchanted Hardsilver Ink                 18
# 1  Galvanized Garlond Steel                  9
# 6          Hardsilver Ingot                 30
# 5       Pure Titanium Plate                  9
# 7                 Rhodonite                 12
# 0           Shark-Class Bow                  1
# 3         Steel Joint Plate                 30
# 4             Wolfram Ingot                 12
