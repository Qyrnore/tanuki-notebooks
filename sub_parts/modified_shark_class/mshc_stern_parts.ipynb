# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import generate_gathering_list
utils_dir = '../../utilities/'
data_dir = 'item_data/'
df_gathering_list = generate_gathering_list(
    total_csv=os.path.join(data_dir, 'modified_shark_class_stern_parts.csv'),
    recipe_book_csv=os.path.join(utils_dir, 'recipe_book.csv'),
    recipe_gathering_csv=os.path.join(utils_dir, 'recipe_gathering.csv'),
    output_csv=os.path.join(data_dir, 'gathering_list.csv')
)
df_gathering_list
# Out:
#                 Ingredient  Total Quantity  \
# 13                Bomb Ash            30.0
# 18              Cloud Mica           240.0
# 3               Cobalt Ore            27.0
# 4                     Coke           162.0
# 7          Cryptomeria Log            27.0
# 29          Dhalmel Saliva            36.0
# 30  Dravanian Spring Water            18.0
# 6            Earth Cluster            27.0
# 23           Earth Crystal            54.0
# 12               Ferberite             9.0
# 5             Fire Cluster            36.0
# 21            Fire Crystal           594.0
# 16              Fire Shard            60.0
# 20             Grenade Ash            60.0
# 8             Hardened Sap            81.0
# 24          Hardsilver Ore           120.0
# 25         Hardsilver Sand           222.0
# 10             Ice Crystal            54.0
# 17               Ice Shard            90.0
# 15                Iron Ore           120.0
# 14                Iron Ore           120.0
# 22       Pure Titanium Ore            27.0
# 27           Raw Rhodonite            36.0
# 11               Scheelite             9.0
# 0        Shark-Class Stern             1.0
# 26              Silver Ore            30.0
# 2               Sphalerite            18.0
# 28             Stiperstone            12.0
# 19            Titanium Ore           300.0
# 1                Vivianite            27.0
# 31           Water Crystal            72.0
# 9             Wind Crystal           396.0
#
#                                         Location Info
# 13                  Southern Thanalan ( 22.2 / 29.9 )
# 18                 The Churning Mists ( 27.6 / 19.2 )
# 3                   Northern Thanalan ( 23.1 / 24.2 )
# 4        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 7   Nowhere ( 0.0 / 0.0 ), Collected from Submarin...
# 29  The Sea of Clouds ( 17.3 / 32.2 ), Dropped by ...
# 30            The Dravanian Forelands ( 27.4 / 31.8 )
# 6                                                 NaN
# 23                                                NaN
# 12  Northern Thanalan ( 17.3 / 19.9 ), Timed at 3:...
# 5                                                 NaN
# 21                                                NaN
# 16                                                NaN
# 20  Nowhere ( 0.0 / 0.0 ), Purchased from Z'ranmai...
# 8        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 24              The Dravanian Forelands ( 25.3 / 25 )
# 25                 The Churning Mists ( 15.9 / 28.5 )
# 10                                                NaN
# 17                                                NaN
# 15   Nowhere ( 0.0 / 0.0 ), Sold by Material Supplier
# 14                   Western Thanalan ( 27.2 / 17.4 )
# 22  Nowhere ( 0.0 / 0.0 ), Collected from Submarin...
# 27      The Peaks ( 26.9 / 12.5 ), Timed at 8AM/PM ET
# 11      Nowhere ( 0.0 / 0.0 ), Sold for 1500 GC Seals
# 0                                                 NaN
# 26                       South Shroud ( 16.1 / 19.7 )
# 2      Nowhere ( 0.0 / 0.0 ), Sold by NPCs for Scrips
# 28                          The Peaks ( 23.3 / 13.1 )
# 19            The Dravanian Forelands ( 30.3 / 15.1 )
# 1   Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 31                                                NaN
# 9                                                 NaN

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import get_crafting_recipes
data_dir = 'item_data/'
df_crafting_recipes = get_crafting_recipes(os.path.join(data_dir, 'modified_shark_class_stern_parts.csv'))
df_crafting_recipes
# Out:
#                     Product  Required Quantity
# 2        Cryptomeria Lumber                  9
# 9  Enchanted Hardsilver Ink                 18
# 1  Galvanized Garlond Steel                  9
# 7          Hardsilver Ingot                 30
# 6       Pure Titanium Plate                  9
# 8                 Rhodonite                 12
# 0         Shark-Class Stern                  1
# 4         Steel Joint Plate                 30
# 5            Titanium Ingot                 60
# 3             Wolfram Ingot                  9
