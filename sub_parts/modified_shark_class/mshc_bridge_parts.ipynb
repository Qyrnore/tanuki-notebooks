# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import generate_gathering_list
utils_dir = '../../utilities/'
data_dir = 'item_data/'
df_gathering_list = generate_gathering_list(
    total_csv=os.path.join(data_dir, 'modified_shark_class_bridge_parts.csv'),
    recipe_book_csv=os.path.join(utils_dir, 'recipe_book.csv'),
    recipe_gathering_csv=os.path.join(utils_dir, 'recipe_gathering.csv'),
    output_csv=os.path.join(data_dir, 'gathering_list.csv')
)
df_gathering_list
# Out:
#                 Ingredient  Total Quantity  \
# 3               Cobalt Ore            84.0
# 4                     Coke           162.0
# 20              Copper Ore            42.0
# 7          Cryptomeria Log            27.0
# 26          Dhalmel Saliva            36.0
# 27  Dravanian Spring Water            18.0
# 6            Earth Cluster            42.0
# 18           Earth Crystal            54.0
# 15               Ferberite            24.0
# 5             Fire Cluster            66.0
# 17            Fire Crystal            54.0
# 13              Fire Shard           105.0
# 19                Gold Ore           126.0
# 8             Hardened Sap            81.0
# 25         Hardsilver Sand            72.0
# 10             Ice Crystal            54.0
# 11                Iron Ore            21.0
# 12                Iron Ore            21.0
# 21             Peacock Ore           189.0
# 16       Pure Titanium Ore            27.0
# 23           Raw Rhodonite            18.0
# 14               Scheelite            24.0
# 0       Shark-Class Bridge             1.0
# 2               Sphalerite            18.0
# 24             Stiperstone             6.0
# 1                Vivianite            27.0
# 28           Water Crystal            72.0
# 22            Wind Cluster            21.0
# 9             Wind Crystal           216.0
#
#                                         Location Info
# 3                   Northern Thanalan ( 23.1 / 24.2 )
# 4        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 20                   Central Thanalan ( 19.0 / 26.2 )
# 7   Nowhere ( 0.0 / 0.0 ), Collected from Submarin...
# 26  The Sea of Clouds ( 17.3 / 32.2 ), Dropped by ...
# 27            The Dravanian Forelands ( 27.4 / 31.8 )
# 6                                                 NaN
# 18                                                NaN
# 15  Northern Thanalan ( 17.3 / 19.9 ), Timed at 3:...
# 5                                                 NaN
# 17                                                NaN
# 13                                                NaN
# 19  Eastern Thanalan ( 27.3 / 21.3 ), Timed at 10:...
# 8        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 25                 The Churning Mists ( 15.9 / 28.5 )
# 10                                                NaN
# 11                   Western Thanalan ( 27.2 / 17.4 )
# 12   Nowhere ( 0.0 / 0.0 ), Sold by Material Supplier
# 21       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 16  Nowhere ( 0.0 / 0.0 ), Collected from Submarin...
# 23      The Peaks ( 26.9 / 12.5 ), Timed at 8AM/PM ET
# 14      Nowhere ( 0.0 / 0.0 ), Sold for 1500 GC Seals
# 0                                                 NaN
# 2      Nowhere ( 0.0 / 0.0 ), Sold by NPCs for Scrips
# 24                          The Peaks ( 23.3 / 13.1 )
# 1   Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 28                                                NaN
# 22                                                NaN
# 9                                                 NaN

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import get_crafting_recipes
data_dir = 'item_data/'
df_crafting_recipes = get_crafting_recipes(os.path.join(data_dir, 'modified_shark_class_bridge_parts.csv'))
df_crafting_recipes
# Out:
#                     Product  Required Quantity
# 3              Cobalt Ingot                 21
# 2        Cryptomeria Lumber                  9
# 8  Enchanted Hardsilver Ink                 18
# 1  Galvanized Garlond Steel                  9
# 5       Pure Titanium Plate                  9
# 7                 Rhodonite                  6
# 6           Rose Gold Ingot                 21
# 0        Shark-Class Bridge                  1
# 4             Wolfram Ingot                 24
