# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import generate_gathering_list
utils_dir = '../../utilities/'
data_dir = 'item_data/'
df_gathering_list = generate_gathering_list(
    total_csv=os.path.join(data_dir, 'total_modified_shark_class_sub_parts.csv'),
    recipe_book_csv=os.path.join(utils_dir, 'recipe_book.csv'),
    recipe_gathering_csv=os.path.join(utils_dir, 'recipe_gathering.csv'),
    output_csv=os.path.join(data_dir, 'gathering_list.csv')
)
df_gathering_list
# Out:
#                    Ingredient  Total Quantity  \
# 36                   Bomb Ash            84.0
# 37                 Cloud Mica           240.0
# 0                  Cobalt Ore           159.0
# 14                       Coke           648.0
# 30                 Copper Ore            90.0
# 4             Cryptomeria Log           108.0
# 9              Dhalmel Saliva           144.0
# 10     Dravanian Spring Water            72.0
# 16              Earth Cluster           117.0
# 26              Earth Crystal           216.0
# 47                  Ferberite            45.0
# 15               Fire Cluster           210.0
# 25               Fire Crystal           756.0
# 3                  Fire Shard           453.0
# 41                       Flax            60.0
# 44               Gelato Flesh            54.0
# 29                   Gold Ore           270.0
# 39                Grenade Ash            60.0
# 5                Hardened Sap           324.0
# 17             Hardsilver Ore           240.0
# 8             Hardsilver Sand           588.0
# 7                 Ice Crystal           216.0
# 20                  Ice Shard           252.0
# 1                    Iron Ore           249.0
# 2                    Iron Ore           249.0
# 19                Mythril Ore           108.0
# 31                Peacock Ore           405.0
# 21               Platinum Ore            48.0
# 45              Pudding Flesh            36.0
# 24          Pure Titanium Ore           108.0
# 40                  Raw Amber            60.0
# 27              Raw Rhodonite           135.0
# 22                   Raziqsap           216.0
# 46                  Scheelite            45.0
# 32            Shark-Class Bow             1.0
# 33         Shark-Class Bridge             1.0
# 34  Shark-Class Pressure Hull             1.0
# 35          Shark-Class Stern             1.0
# 18                 Silver Ore            60.0
# 13                 Sphalerite            72.0
# 28                Stiperstone            45.0
# 43                  Terebinth            30.0
# 38               Titanium Ore           300.0
# 12                  Vivianite           108.0
# 11              Water Crystal           342.0
# 42                Water Shard           240.0
# 23               Wind Cluster            93.0
# 6                Wind Crystal          1296.0
#
#                                         Location Info
# 36                  Southern Thanalan ( 22.2 / 29.9 )
# 37                 The Churning Mists ( 27.6 / 19.2 )
# 0                   Northern Thanalan ( 23.1 / 24.2 )
# 14       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 30                   Central Thanalan ( 19.0 / 26.2 )
# 4   Nowhere ( 0.0 / 0.0 ), Collected from Submarin...
# 9   The Sea of Clouds ( 17.3 / 32.2 ), Dropped by ...
# 10            The Dravanian Forelands ( 27.4 / 31.8 )
# 16                                                NaN
# 26                                                NaN
# 47  Northern Thanalan ( 17.3 / 19.9 ), Timed at 3:...
# 15                                                NaN
# 25                                                NaN
# 3                                                 NaN
# 41                       South Shroud ( 17.6 / 28.6 )
# 44  Coerthas Western Highlands ( 9.4 / 18.8 ),  Dr...
# 29  Eastern Thanalan ( 27.3 / 21.3 ), Timed at 10:...
# 39  Nowhere ( 0.0 / 0.0 ), Purchased from Z'ranmai...
# 5        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 17              The Dravanian Forelands ( 25.3 / 25 )
# 8                  The Churning Mists ( 15.9 / 28.5 )
# 7                                                 NaN
# 20                                                NaN
# 1                    Western Thanalan ( 27.2 / 17.4 )
# 2    Nowhere ( 0.0 / 0.0 ), Sold by Material Supplier
# 19                  Southern Thanalan ( 25.2 / 39.9 )
# 31       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 21  Southern Thanalan ( 16.7 / 10.7 ), Timed at 4:...
# 45       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 24  Nowhere ( 0.0 / 0.0 ), Collected from Submarin...
# 40                   Eastern Thanalan ( 12.7 / 19.1 )
# 27      The Peaks ( 26.9 / 12.5 ), Timed at 8AM/PM ET
# 22       Nowhere ( 0.0 / 0.0 ), Sold for 250 GC Seals
# 46      Nowhere ( 0.0 / 0.0 ), Sold for 1500 GC Seals
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 18                       South Shroud ( 16.1 / 19.7 )
# 13     Nowhere ( 0.0 / 0.0 ), Sold by NPCs for Scrips
# 28                          The Peaks ( 23.3 / 13.1 )
# 43      Nowhere ( 0.0 / 0.0 ), Sold by Main City NPCs
# 38            The Dravanian Forelands ( 30.3 / 15.1 )
# 12  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 11                                                NaN
# 42                                                NaN
# 23                                                NaN
# 6                                                 NaN

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import get_crafting_recipes
data_dir = 'item_data/'
df_crafting_recipes = get_crafting_recipes(os.path.join(data_dir, 'total_modified_shark_class_sub_parts.csv'))
df_crafting_recipes
# Out:
#                       Product  Required Quantity                  2    3  \
# 0                Cobalt Ingot                 21         Cobalt Ore  2.0
# 1          Cryptomeria Lumber                 36    Cryptomeria Log  3.0
# 2    Enchanted Hardsilver Ink                 72    Hardsilver Sand  4.0
# 3    Galvanized Garlond Steel                 36          Vivianite  3.0
# 4            Hardsilver Ingot                 60     Hardsilver Ore  4.0
# 5               Mythril Plate                 18      Mythril Ingot  2.0
# 6              Platinum Ingot                 24       Platinum Ore  2.0
# 7         Pure Titanium Plate                 36  Pure Titanium Ore  3.0
# 8                   Rhodonite                 45      Raw Rhodonite  3.0
# 9             Rose Gold Ingot                 45   Rose Gold Nugget  2.0
# 10            Shark-Class Bow                  1               None  NaN
# 11         Shark-Class Bridge                  1               None  NaN
# 12  Shark-Class Pressure Hull                  1               None  NaN
# 13          Shark-Class Stern                  1               None  NaN
# 14          Steel Joint Plate                 60        Steel Ingot  1.0
# 15               Steel Rivets                 24        Steel Ingot  1.0
# 16             Titanium Ingot                 60         Cloud Mica  4.0
# 17                    Varnish                 30          Raw Amber  2.0
# 18                  Void Glue                 18       Gelato Flesh  3.0
# 19              Wolfram Ingot                 45          Scheelite  1.0
#
#                     4    5                       6    7              8    9  \
# 0            Iron Ore  1.0              Fire Shard  5.0           None  NaN
# 1        Hardened Sap  9.0            Wind Crystal  6.0    Ice Crystal  6.0
# 2      Dhalmel Saliva  2.0  Dravanian Spring Water  1.0  Water Crystal  4.0
# 3          Sphalerite  2.0              Cobalt Ore  2.0           Coke  9.0
# 4   Hardsilver Nugget  1.0            Wind Crystal  5.0           None  NaN
# 5           Ice Shard  4.0                    None  NaN           None  NaN
# 6            Raziqsap  9.0            Wind Cluster  2.0   Fire Cluster  2.0
# 7                Coke  9.0            Fire Crystal  6.0  Earth Crystal  6.0
# 8         Stiperstone  1.0            Wind Crystal  6.0           None  NaN
# 9         Peacock Ore  9.0            Wind Cluster  1.0           None  NaN
# 10               None  NaN                    None  NaN           None  NaN
# 11               None  NaN                    None  NaN           None  NaN
# 12               None  NaN                    None  NaN           None  NaN
# 13               None  NaN                    None  NaN           None  NaN
# 14          Ice Shard  3.0                    None  NaN           None  NaN
# 15         Fire Shard  3.0                    None  NaN           None  NaN
# 16    Titanium Nugget  1.0            Fire Crystal  5.0           None  NaN
# 17        Linseed Oil  1.0               Terebinth  1.0    Water Shard  5.0
# 18      Pudding Flesh  2.0           Water Crystal  3.0           None  NaN
# 19          Ferberite  1.0              Cobalt Ore  1.0   Fire Cluster  2.0
#
#                10   11             12   13
# 0            None  NaN           None  NaN
# 1            None  NaN           None  NaN
# 2            None  NaN           None  NaN
# 3    Fire Cluster  2.0  Earth Cluster  2.0
# 4            None  NaN           None  NaN
# 5            None  NaN           None  NaN
# 6            None  NaN           None  NaN
# 7            None  NaN           None  NaN
# 8            None  NaN           None  NaN
# 9            None  NaN           None  NaN
# 10           None  NaN           None  NaN
# 11           None  NaN           None  NaN
# 12           None  NaN           None  NaN
# 13           None  NaN           None  NaN
# 14           None  NaN           None  NaN
# 15           None  NaN           None  NaN
# 16           None  NaN           None  NaN
# 17           None  NaN           None  NaN
# 18           None  NaN           None  NaN
# 19  Earth Cluster  1.0           None  NaN

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import fetch_market_data_for_subparts
utils_dir = '../../utilities/'
data_dir = 'item_data/'
df_market_data = fetch_market_data_for_subparts(
    gathering_csv=os.path.join(data_dir, 'gathering_list.csv'),
    crafting_csv=os.path.join(utils_dir, 'recipe_book.csv'),
    item_ids_json=os.path.join(utils_dir, 'item_ids.json'),
    output_csv=os.path.join(data_dir, 'airship_parts_market_data.csv'),
    world="Seraph"
)
df_market_data
# Out:
#                         Item Name   Category Item ID minListing_world  \
# 0                        Bomb Ash  Gathering    5528              400
# 1                      Cloud Mica  Gathering   12539              245
# 2                      Cobalt Ore  Gathering    5116              200
# 3                            Coke  Gathering    5530              213
# 4                      Copper Ore  Gathering    5106              248
# ..                            ...        ...     ...              ...
# 147                  Cobalt Nails   Crafting    7020              250
# 148                  Cobalt Rings   Crafting    5084               37
# 149               Dhalmel Leather   Crafting   12564             5000
# 150  High Allagan Chimera Leather   Crafting   12233             1495
# 151            Amphiptere Leather   Crafting   12566              275
#
#     minListing_dc recentPurchase_world recentPurchase_dc averageSalePrice_dc  \
# 0             199                  499               220          298.920598
# 1             145                  200               190           162.83871
# 2             200                  200               292          281.530793
# 3             150                  213               223          211.395106
# 4               4                  200                17           39.493766
# ..            ...                  ...               ...                 ...
# 147            20                   90               800                None
# 148            37                  155               730          469.888889
# 149          2999                 4123              3000         2780.477273
# 150           493                 2000              1000          713.727273
# 151            50                  323               500          328.926471
#
#     dailySaleVelocity_dc
# 0            3327.032133
# 1             184.662048
# 2            7952.364301
# 3           11472.565628
# 4             415.422169
# ..                   ...
# 147                 None
# 148             4.660386
# 149            56.960151
# 150             2.848001
# 151            17.605788
#
# [150 rows x 9 columns]
