# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import generate_gathering_list
utils_dir = '../../utilities/'
data_dir = 'item_data/'
df_gathering_list = generate_gathering_list(
    total_csv=os.path.join(data_dir, 'modified_shark_class_pressure_hull_parts.csv'),
    recipe_book_csv=os.path.join(utils_dir, 'recipe_book.csv'),
    recipe_gathering_csv=os.path.join(utils_dir, 'recipe_gathering.csv'),
    output_csv=os.path.join(data_dir, 'gathering_list.csv')
)
df_gathering_list
# Out:
#                    Ingredient  Total Quantity  \
# 11                   Bomb Ash            24.0
# 3                  Cobalt Ore            18.0
# 4                        Coke           162.0
# 18                 Copper Ore            48.0
# 7             Cryptomeria Log            27.0
# 36             Dhalmel Saliva            36.0
# 37     Dravanian Spring Water            18.0
# 6               Earth Cluster            18.0
# 26              Earth Crystal            54.0
# 5                Fire Cluster            66.0
# 25               Fire Crystal            54.0
# 14                 Fire Shard           228.0
# 30                       Flax            60.0
# 21               Gelato Flesh            54.0
# 17                   Gold Ore           144.0
# 8                Hardened Sap            81.0
# 35            Hardsilver Sand            72.0
# 10                Ice Crystal            54.0
# 16                  Ice Shard            72.0
# 12                   Iron Ore            48.0
# 13                   Iron Ore            48.0
# 15                Mythril Ore           108.0
# 19                Peacock Ore           216.0
# 27               Platinum Ore            48.0
# 22              Pudding Flesh            36.0
# 24          Pure Titanium Ore            27.0
# 29                  Raw Amber            60.0
# 33              Raw Rhodonite            45.0
# 28                   Raziqsap           216.0
# 0   Shark-Class Pressure Hull             1.0
# 2                  Sphalerite            18.0
# 34                Stiperstone            15.0
# 32                  Terebinth            30.0
# 1                   Vivianite            27.0
# 23              Water Crystal           126.0
# 31                Water Shard           240.0
# 20               Wind Cluster            72.0
# 9                Wind Crystal           288.0
#
#                                         Location Info
# 11                  Southern Thanalan ( 22.2 / 29.9 )
# 3                   Northern Thanalan ( 23.1 / 24.2 )
# 4        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 18                   Central Thanalan ( 19.0 / 26.2 )
# 7   Nowhere ( 0.0 / 0.0 ), Collected from Submarin...
# 36  The Sea of Clouds ( 17.3 / 32.2 ), Dropped by ...
# 37            The Dravanian Forelands ( 27.4 / 31.8 )
# 6                                                 NaN
# 26                                                NaN
# 5                                                 NaN
# 25                                                NaN
# 14                                                NaN
# 30                       South Shroud ( 17.6 / 28.6 )
# 21  Coerthas Western Highlands ( 9.4 / 18.8 ),  Dr...
# 17  Eastern Thanalan ( 27.3 / 21.3 ), Timed at 10:...
# 8        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 35                 The Churning Mists ( 15.9 / 28.5 )
# 10                                                NaN
# 16                                                NaN
# 12                   Western Thanalan ( 27.2 / 17.4 )
# 13   Nowhere ( 0.0 / 0.0 ), Sold by Material Supplier
# 15                  Southern Thanalan ( 25.2 / 39.9 )
# 19       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 27  Southern Thanalan ( 16.7 / 10.7 ), Timed at 4:...
# 22       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 24  Nowhere ( 0.0 / 0.0 ), Collected from Submarin...
# 29                   Eastern Thanalan ( 12.7 / 19.1 )
# 33      The Peaks ( 26.9 / 12.5 ), Timed at 8AM/PM ET
# 28       Nowhere ( 0.0 / 0.0 ), Sold for 250 GC Seals
# 0                                                 NaN
# 2      Nowhere ( 0.0 / 0.0 ), Sold by NPCs for Scrips
# 34                          The Peaks ( 23.3 / 13.1 )
# 32      Nowhere ( 0.0 / 0.0 ), Sold by Main City NPCs
# 1   Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 23                                                NaN
# 31                                                NaN
# 20                                                NaN
# 9                                                 NaN

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import get_crafting_recipes
data_dir = 'item_data/'
df_crafting_recipes = get_crafting_recipes(os.path.join(data_dir, 'modified_shark_class_pressure_hull_parts.csv'))
df_crafting_recipes
# Out:
#                       Product  Required Quantity
# 2          Cryptomeria Lumber                  9
# 11   Enchanted Hardsilver Ink                 18
# 1    Galvanized Garlond Steel                  9
# 4               Mythril Plate                 18
# 8              Platinum Ingot                 24
# 7         Pure Titanium Plate                  9
# 10                  Rhodonite                 15
# 5             Rose Gold Ingot                 24
# 0   Shark-Class Pressure Hull                  1
# 3                Steel Rivets                 24
# 9                     Varnish                 30
# 6                   Void Glue                 18
