# %%
from unkiu_class_sub_parts import generate_gathering_list

# Generate the gathering list and save to 'gathering_list.csv'
df_gathering_list = generate_gathering_list(
    total_csv='total_unkiu_class_sub_parts.csv',
    recipe_book_csv='recipe_book.csv',
    recipe_gathering_csv='recipe_gathering.csv',
    output_csv='gathering_list.csv'
)

df_gathering_list  # Display the gathering list
# Out:
#              Ingredient  Total Quantity  \
# 34         Black Alumen            24.0
# 31             Bomb Ash           294.0
# 4      Clear Glass Lens            60.0
# 5            Cobalt Ore           444.0
# 46  Coerthan Tea Leaves            18.0
# 11                 Coke           648.0
# 27           Copper Ore            36.0
# 9         Darksteel Ore           441.0
# 20        Earth Cluster            54.0
# 35        Earth Crystal            78.0
# 14         Electrum Ore            96.0
# 44            Ferberite            18.0
# 12         Fire Cluster           108.0
# 10         Fire Crystal           720.0
# 7            Fire Shard          3024.0
# 37                 Flax            36.0
# 40         Gelato Flesh            27.0
# 26             Gold Ore           108.0
# 32         Hardened Sap           108.0
# 3           Ice Cluster            24.0
# 13          Ice Crystal            81.0
# 8             Ice Shard           462.0
# 21           Iron Ingot            24.0
# 6              Iron Ore           747.0
# 18    Lightning Cluster            18.0
# 22          Mythril Ore           540.0
# 23         Mythrite Ore           144.0
# 24        Mythrite Sand           180.0
# 25              Oak Log            72.0
# 29          Peacock Ore           162.0
# 0         Petrified Log            24.0
# 17               Potash           162.0
# 41        Pudding Flesh            18.0
# 36            Raw Amber            36.0
# 16       Red Moko Grass            54.0
# 1           Scarlet Sap            24.0
# 43            Scheelite            18.0
# 30           Spruce Log           144.0
# 39            Terebinth            18.0
# 33          Uraeus Skin            24.0
# 19            Vivianite           108.0
# 42        Water Crystal            27.0
# 38          Water Shard           144.0
# 2          Wind Cluster            96.0
# 28         Wind Crystal           252.0
# 15           Wind Shard           192.0
# 45          Wyvern Skin            54.0
#
#                                         Location Info
# 34                       South Shroud ( 28.7 / 22.8 )
# 31                  Southern Thanalan ( 22.2 / 29.9 )
# 4                                                 NaN
# 5                   Northern Thanalan ( 23.1 / 24.2 )
# 46  Coerthas Western Highlands ( 31.7 / 19.6 ), Ti...
# 11       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 27                   Central Thanalan ( 19.0 / 26.2 )
# 9   Coerthas Central Highlands ( 27.5 / 20.0 ), Ti...
# 20                                                NaN
# 35                                                NaN
# 14                    Upper La Noscea ( 30.4 / 25.4 )
# 44  Northern Thanalan ( 17.3 / 19.9 ), Timed at 3:...
# 12                                                NaN
# 10                                                NaN
# 7                                                 NaN
# 37                       South Shroud ( 17.6 / 28.6 )
# 40  Coerthas Western Highlands ( 9.4 / 18.8 ),  Dr...
# 26  Eastern Thanalan ( 27.3 / 21.3 ), Timed at 10:...
# 32       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 3                                                 NaN
# 13                                                NaN
# 8                                                 NaN
# 21                                                NaN
# 6                    Western Thanalan ( 27.2 / 17.4 )
# 18                                                NaN
# 22                  Southern Thanalan ( 25.2 / 39.9 )
# 23         Coerthas Western Highlands ( 31.2 / 12.8 )
# 24         Coerthas Western Highlands ( 16.6 / 13.1 )
# 25                       South Shroud ( 16.6 / 30.2 )
# 29       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 0       Nowhere ( 0.0 / 0.0 ), Sold for 1500 GC Seals
# 17       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 41       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 36                   Eastern Thanalan ( 12.7 / 19.1 )
# 16  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 1       North Shroud ( 17.7 / 27.7 ), Timed at 1:00am
# 43      Nowhere ( 0.0 / 0.0 ), Sold for 1500 GC Seals
# 30  Coerthas Central Highlands ( 29.5 / 13.1 ), Ti...
# 39      Nowhere ( 0.0 / 0.0 ), Sold by Main City NPCs
# 33  Nowhere ( 0.0 / 0.0 ), Found in The Wanderer's...
# 19  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 42                                                NaN
# 38                                                NaN
# 2                                                 NaN
# 28                                                NaN
# 15                                                NaN
# 45  Coerthas Western Highlands (X:19.5 Y:35.9), Ra...

# %%
from unkiu_class_sub_parts import get_crafting_recipes

# Get the crafting recipes from total_unkiu_class_sub_parts.csv
df_crafting_recipes = get_crafting_recipes('total_unkiu_class_sub_parts.csv')
df_crafting_recipes  # Display the crafting recipes list
# Out:
#                   Product  Required Quantity                 2  3  \
# 0          Ancient Lumber                 24     Petrified Log  1
# 1        Clear Glass Lens                 60             Silex  1
# 2            Cobalt Ingot                 69        Cobalt Ore  2
# 3      Cobalt Joint Plate                 60      Cobalt Ingot  1
# 4           Cobalt Rivets                 30      Cobalt Ingot  1
# 5         Darksteel Ingot                 36  Darksteel Nugget  2
# 6         Darksteel Plate                 27  Darksteel Nugget  2
# 7        Darksteel Rivets                 21  Darksteel Nugget  1
# 8          Electrum Ingot                 24      Electrum Ore  4
# 9         Farreach Canvas                 18    Red Moko Grass  3
# 10          Garlond Steel                 36         Vivianite  3
# 11            Iron Rivets                 24        Iron Ingot  1
# 12          Mythril Ingot                 60       Mythril Ore  3
# 13         Mythril Rivets                108     Mythril Ingot  1
# 14         Mythrite Ingot                 36      Mythrite Ore  4
# 15             Oak Lumber                 24           Oak Log  3
# 16        Rose Gold Ingot                 18  Rose Gold Nugget  2
# 17          Spruce Lumber                 24        Spruce Log  3
# 18            Steel Ingot                 75          Bomb Ash  1
# 19      Steel Joint Plate                 30       Steel Ingot  1
# 20            Steel Nails                 45       Steel Ingot  1
# 21            Steel Plate                 24       Steel Ingot  2
# 22           Steel Rivets                 96       Steel Ingot  1
# 23  Treated Spruce Lumber                 12     Spruce Lumber  2
# 24         Uraeus Leather                 24       Uraeus Skin  1
# 25                Varnish                 18         Raw Amber  2
# 26              Void Glue                  9      Gelato Flesh  3
# 27          Wolfram Ingot                 18         Scheelite  1
# 28         Wyvern Leather                 18       Wyvern Skin  3
#
#                       4  5                      6    7             8    9  \
# 0           Scarlet Sap  1           Wind Cluster  2.0   Ice Cluster  1.0
# 1                Natron  1            Water Shard  3.0          None  NaN
# 2              Iron Ore  1         Ice/Fire Shard  5.0          None  NaN
# 3             Ice Shard  5                   None  NaN          None  NaN
# 4        Ice/Fire Shard  5                   None  NaN          None  NaN
# 5                  Coke  9       Ice/Fire Cluster  1.0          None  NaN
# 6           Ice Crystal  3                   None  NaN          None  NaN
# 7      Ice/Fire Crystal  3                   None  NaN          None  NaN
# 8            Wind Shard  5                   None  NaN          None  NaN
# 9                Potash  9      Lightning Cluster  1.0  Wind Cluster  1.0
# 10                 Coke  9             Cobalt Ore  3.0  Fire Cluster  1.0
# 11       Ice/Fire Shard  1                   None  NaN          None  NaN
# 12  Ice/Fire/Wind Shard  4                   None  NaN          None  NaN
# 13       Ice/Fire Shard  5                   None  NaN          None  NaN
# 14      Mythrite Nugget  1  Ice/Fire/Wind Crystal  3.0          None  NaN
# 15           Wind Shard  3                   None  NaN          None  NaN
# 16          Peacock Ore  9           Wind Cluster  1.0          None  NaN
# 17         Wind Crystal  3                   None  NaN          None  NaN
# 18             Iron Ore  2         Ice/Fire Shard  2.0          None  NaN
# 19            Ice Shard  3                   None  NaN          None  NaN
# 20           Fire Shard  3                   None  NaN          None  NaN
# 21            Ice Shard  3                   None  NaN          None  NaN
# 22       Ice/Fire Shard  3                   None  NaN          None  NaN
# 23         Hardened Sap  9           Wind Cluster  1.0          None  NaN
# 24         Black Alumen  1          Earth Crystal  1.0          None  NaN
# 25          Linseed Oil  1              Terebinth  1.0   Water Shard  5.0
# 26        Pudding Flesh  2          Water Crystal  3.0          None  NaN
# 27            Ferberite  1             Cobalt Ore  1.0  Fire Cluster  2.0
# 28  Coerthan Tea Leaves  1          Earth Crystal  3.0          None  NaN
#
#                10   11
# 0            None  NaN
# 1            None  NaN
# 2            None  NaN
# 3            None  NaN
# 4            None  NaN
# 5            None  NaN
# 6            None  NaN
# 7            None  NaN
# 8            None  NaN
# 9            None  NaN
# 10  Earth Cluster  1.0
# 11           None  NaN
# 12           None  NaN
# 13           None  NaN
# 14           None  NaN
# 15           None  NaN
# 16           None  NaN
# 17           None  NaN
# 18           None  NaN
# 19           None  NaN
# 20           None  NaN
# 21           None  NaN
# 22           None  NaN
# 23           None  NaN
# 24           None  NaN
# 25           None  NaN
# 26           None  NaN
# 27  Earth Cluster  1.0
# 28           None  NaN

# %%
from unkiu_class_sub_parts import fetch_market_data_for_subparts

# Combine items from the gathering list (from 'gathering_list.csv') and the crafting recipes (from 'recipe_book.csv'),
# fetch market data from the Universalis API, and save the results to 'sub_parts_market_data.csv'.
df_market_data = fetch_market_data_for_subparts(
    gathering_csv='gathering_list.csv',
    crafting_csv='recipe_book.csv', 
    item_ids_json='item_ids.json',
    output_csv='sub_parts_market_data.csv',
    world="Seraph"
)

df_market_data  # Display the market data for sub parts
# Out:
#               Item Name   Category Item ID minListing_world minListing_dc  \
# 0          Black Alumen  Gathering    5525              280            50
# 1              Bomb Ash  Gathering    5528              400           199
# 2      Clear Glass Lens  Gathering    5512              189            54
# 3            Cobalt Ore  Gathering    5116              200           200
# 4   Coerthan Tea Leaves  Gathering   12882              500           250
# ..                  ...        ...     ...              ...           ...
# 81      Darksteel Plate   Crafting    5075             2999          2500
# 82       Uraeus Leather   Crafting    5287            10000          9999
# 83            Void Glue   Crafting    5506             7399          3002
# 84        Wolfram Ingot   Crafting    7607             5000          2500
# 85       Wyvern Leather   Crafting   12563             3998          1390
#
#    recentPurchase_world recentPurchase_dc averageSalePrice_dc  \
# 0                   288                56          182.489077
# 1                   499               295          320.568683
# 2                   200                90          137.620924
# 3                   353               303          289.287491
# 4                   799               424         1099.659574
# ..                  ...               ...                 ...
# 81                 8999              2000         6280.714286
# 82                14998             12000        11560.576271
# 83                 3102             10003            5064.125
# 84                 5000              5000            4655.928
# 85                 4000              1500         1824.845638
#
#    dailySaleVelocity_dc
# 0            442.158367
# 1           5026.694757
# 2            229.335121
# 3          13532.913966
# 4            336.834084
# ..                  ...
# 81              6.54211
# 82            36.760332
# 83            24.922193
# 84            38.940825
# 85           139.252015
#
# [86 rows x 9 columns]
