# %%
from unkiu_class_sub_parts import generate_gathering_list

# Generate the gathering list and save to 'gathering_list.csv'
df_gathering_list = generate_gathering_list(
    total_csv='unkiu_class_bow_parts.csv',
    recipe_book_csv='recipe_book.csv',
    recipe_gathering_csv='recipe_gathering.csv',
    output_csv='gathering_list.csv'
)

df_gathering_list  # Display the gathering list
# Out:
#           Ingredient  Total Quantity  \
# 0           Bomb Ash            90.0
# 20  Clear Glass Lens            30.0
# 3         Cobalt Ore           147.0
# 6               Coke           162.0
# 16        Copper Ore            36.0
# 13     Darksteel Ore           108.0
# 8      Earth Cluster             9.0
# 7       Fire Cluster            18.0
# 12      Fire Crystal           216.0
# 2         Fire Shard          1050.0
# 15          Gold Ore           108.0
# 14       Ice Crystal            27.0
# 4          Ice Shard           240.0
# 1           Iron Ore           240.0
# 11       Mythril Ore           198.0
# 9       Mythrite Ore            72.0
# 10     Mythrite Sand            90.0
# 18       Peacock Ore           162.0
# 5          Vivianite            27.0
# 19      Wind Cluster            18.0
# 17      Wind Crystal           108.0
#
#                                         Location Info
# 0                   Southern Thanalan ( 22.2 / 29.9 )
# 20                                                NaN
# 3                   Northern Thanalan ( 23.1 / 24.2 )
# 6        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 16                   Central Thanalan ( 19.0 / 26.2 )
# 13  Coerthas Central Highlands ( 27.5 / 20.0 ), Ti...
# 8                                                 NaN
# 7                                                 NaN
# 12                                                NaN
# 2                                                 NaN
# 15  Eastern Thanalan ( 27.3 / 21.3 ), Timed at 10:...
# 14                                                NaN
# 4                                                 NaN
# 1                    Western Thanalan ( 27.2 / 17.4 )
# 11                  Southern Thanalan ( 25.2 / 39.9 )
# 9          Coerthas Western Highlands ( 31.2 / 12.8 )
# 10         Coerthas Western Highlands ( 16.6 / 13.1 )
# 18       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 5   Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 19                                                NaN
# 17                                                NaN

# %%
from unkiu_class_sub_parts import get_crafting_recipes

# Get the crafting recipes from total_unkiu_class_sub_parts.csv
df_crafting_recipes = get_crafting_recipes('unkiu_class_bow_parts.csv')
df_crafting_recipes  # Display the crafting recipes list
# Out:
#                Product  Required Quantity
# 12    Clear Glass Lens                 30
# 2   Cobalt Joint Plate                 30
# 1        Cobalt Rivets                 30
# 7      Darksteel Ingot                  9
# 9      Darksteel Plate                  9
# 3        Garlond Steel                  9
# 10       Mythril Ingot                 30
# 8       Mythril Rivets                 30
# 5       Mythrite Ingot                 18
# 11     Rose Gold Ingot                 18
# 0          Steel Ingot                 30
# 6    Steel Joint Plate                 30
# 4         Steel Rivets                 30
