# %%
from syldra_class_sub_parts import generate_gathering_list

# Generate the gathering list and save to 'gathering_list.csv'
df_gathering_list = generate_gathering_list(
    total_csv='syldra_class_bridge_parts.csv',
    recipe_book_csv='recipe_book.csv',
    recipe_gathering_csv='recipe_gathering.csv',
    output_csv='gathering_list.csv'
)

df_gathering_list  # Display the gathering list
# Out:
#               Ingredient  Total Quantity  \
# 34        Adamantite Ore            75.0
# 29        Astral Moraine            12.0
# 8       Aurum Regis Sand           300.0
# 30              Bear Fat             6.0
# 20             Birch Log            75.0
# 25            Cassia Log            18.0
# 24            Cassia Log            18.0
# 17            Cloud Mica           120.0
# 4             Cobalt Ore            87.0
# 22                  Coke            81.0
# 15         Darksteel Ore           114.0
# 33  Dawnborne Aethersand             6.0
# 23         Earth Crystal            63.0
# 14          Fire Cluster            15.0
# 3           Fire Crystal           732.0
# 7             Fire Shard           300.0
# 9               Gold Ore            75.0
# 19           Grenade Ash            30.0
# 26          Hardened Sap            54.0
# 27           Ice Cluster            12.0
# 16           Ice Crystal            27.0
# 6               Iron Ore            60.0
# 5               Iron Ore            60.0
# 21          Kamacite Ore            27.0
# 32     Lightning Cluster             6.0
# 2            Mythril Ore            30.0
# 0           Mythrite Ore           120.0
# 1          Mythrite Sand           150.0
# 12           Native Gold            15.0
# 11             Raziqsand            15.0
# 28        Seventh Heaven            12.0
# 18          Titanium Ore           150.0
# 31         Water Cluster            12.0
# 13          Wind Cluster            54.0
# 10          Wind Crystal           375.0
#
#                                         Location Info
# 34       Azys Lla ( 23.2 / 5.8 ), Timed at 12AM/PM ET
# 29  Coerthas Western Highlands ( 37.2 / 16.4 ), Ti...
# 8                   The Sea of Clouds ( 34.8 / 30.5 )
# 30  The Dravanian Hinterlands ( 4.7 / 27.8 ), Drop...
# 20              The Sea of Clouds ( 24 / 34 ), Hidden
# 25  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 24  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 17                 The Churning Mists ( 27.6 / 19.2 )
# 4                   Northern Thanalan ( 23.1 / 24.2 )
# 22       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 15  Coerthas Central Highlands ( 27.5 / 20.0 ), Ti...
# 33  Nowhere ( 0.0 / 0.0 ), Aetherial Reduction fro...
# 23                                                NaN
# 14                                                NaN
# 3                                                 NaN
# 7                                                 NaN
# 9   Eastern Thanalan ( 27.3 / 21.3 ), Timed at 10:...
# 19  Nowhere ( 0.0 / 0.0 ), Purchased from Z'ranmai...
# 26       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 27                                                NaN
# 16                                                NaN
# 6    Nowhere ( 0.0 / 0.0 ), Sold by Material Supplier
# 5                    Western Thanalan ( 27.2 / 17.4 )
# 21  Nowhere ( 0.0 / 0.0 ), Collected from Submarin...
# 32                                                NaN
# 2                   Southern Thanalan ( 25.2 / 39.9 )
# 0          Coerthas Western Highlands ( 31.2 / 12.8 )
# 1          Coerthas Western Highlands ( 16.6 / 13.1 )
# 12  Central Thanalan ( 25.2 / 15.8 ), Timed at 4:0...
# 11      Nowhere ( 0.0 / 0.0 ), Sold for 1500 GC Seals
# 28  The Churning Mists ( 16.7 / 36.8 ), Timed at 4...
# 18            The Dravanian Forelands ( 30.3 / 15.1 )
# 31                                                NaN
# 13                                                NaN
# 10                                                NaN

# %%
from syldra_class_sub_parts import get_crafting_recipes

# Get the crafting recipes from total_syldra_class_sub_parts.csv
df_crafting_recipes = get_crafting_recipes('syldra_class_bridge_parts.csv')
df_crafting_recipes  # Display the crafting recipes list
# Out:
#                Product  Required Quantity
# 10   Adamantite Rivets                 15
# 2   Aurum Regis Nugget                 60
# 7         Birch Lumber                 15
# 9         Cassia Block                  6
# 1        Cobalt Rivets                 30
# 4      Darksteel Plate                  9
# 6     Darksteel Rivets                 15
# 3           Gold Ingot                 15
# 8             Kamacite                  9
# 0       Mythrite Ingot                 30
# 5       Titanium Ingot                 30
