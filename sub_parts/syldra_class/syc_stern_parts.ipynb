# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import generate_gathering_list
utils_dir = '../../utilities/'
data_dir = 'item_data/'
df_gathering_list = generate_gathering_list(
    total_csv=os.path.join(data_dir, 'syldra_class_stern_parts.csv'),
    recipe_book_csv=os.path.join(utils_dir, 'recipe_book.csv'),
    recipe_gathering_csv=os.path.join(utils_dir, 'recipe_gathering.csv'),
    output_csv=os.path.join(data_dir, 'gathering_list.csv')
)
df_gathering_list
# Out:
#               Ingredient  Total Quantity  \
# 23        Adamantite Ore            75.0
# 32        Astral Moraine            12.0
# 24      Aurum Regis Sand            75.0
# 33              Bear Fat             6.0
# 12             Birch Log           150.0
# 27            Cassia Log            18.0
# 26            Cassia Log            18.0
# 0             Cloud Mica           120.0
# 7             Cobalt Ore            78.0
# 21                  Coke            81.0
# 6          Darksteel Ore           150.0
# 36  Dawnborne Aethersand             6.0
# 17         Earth Cluster             9.0
# 22         Earth Crystal            63.0
# 15             Ferberite             9.0
# 16          Fire Cluster            18.0
# 5           Fire Crystal           693.0
# 8             Fire Shard           210.0
# 25              Gold Ore            15.0
# 4            Grenade Ash            30.0
# 28          Hardened Sap            54.0
# 18       Hardsilver Sand            90.0
# 30           Ice Cluster            12.0
# 3               Iron Ore            51.0
# 2               Iron Ore            51.0
# 20          Kamacite Ore            27.0
# 35     Lightning Cluster             6.0
# 11           Mythril Ore            30.0
# 9           Mythrite Ore           120.0
# 10         Mythrite Sand           150.0
# 14             Scheelite             9.0
# 31        Seventh Heaven            12.0
# 19            Silver Ore            18.0
# 1           Titanium Ore           150.0
# 34         Water Cluster            12.0
# 29          Wind Cluster            24.0
# 13          Wind Crystal           297.0
#
#                                         Location Info
# 23       Azys Lla ( 23.2 / 5.8 ), Timed at 12AM/PM ET
# 32  Coerthas Western Highlands ( 37.2 / 16.4 ), Ti...
# 24                  The Sea of Clouds ( 34.8 / 30.5 )
# 33  The Dravanian Hinterlands ( 4.7 / 27.8 ), Drop...
# 12              The Sea of Clouds ( 24 / 34 ), Hidden
# 27  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 26  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 0                  The Churning Mists ( 27.6 / 19.2 )
# 7                   Northern Thanalan ( 23.1 / 24.2 )
# 21       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 6   Coerthas Central Highlands ( 27.5 / 20.0 ), Ti...
# 36  Nowhere ( 0.0 / 0.0 ), Aetherial Reduction fro...
# 17                                                NaN
# 22                                                NaN
# 15  Northern Thanalan ( 17.3 / 19.9 ), Timed at 3:...
# 16                                                NaN
# 5                                                 NaN
# 8                                                 NaN
# 25  Eastern Thanalan ( 27.3 / 21.3 ), Timed at 10:...
# 4   Nowhere ( 0.0 / 0.0 ), Purchased from Z'ranmai...
# 28       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 18                 The Churning Mists ( 15.9 / 28.5 )
# 30                                                NaN
# 3    Nowhere ( 0.0 / 0.0 ), Sold by Material Supplier
# 2                    Western Thanalan ( 27.2 / 17.4 )
# 20  Nowhere ( 0.0 / 0.0 ), Collected from Submarin...
# 35                                                NaN
# 11                  Southern Thanalan ( 25.2 / 39.9 )
# 9          Coerthas Western Highlands ( 31.2 / 12.8 )
# 10         Coerthas Western Highlands ( 16.6 / 13.1 )
# 14      Nowhere ( 0.0 / 0.0 ), Sold for 1500 GC Seals
# 31  The Churning Mists ( 16.7 / 36.8 ), Timed at 4...
# 19                       South Shroud ( 16.1 / 19.7 )
# 1             The Dravanian Forelands ( 30.3 / 15.1 )
# 34                                                NaN
# 29                                                NaN
# 13                                                NaN

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import get_crafting_recipes
data_dir = 'item_data/'
df_crafting_recipes = get_crafting_recipes(os.path.join(data_dir, 'syldra_class_stern_parts.csv'))
df_crafting_recipes
# Out:
#                Product  Required Quantity
# 9    Adamantite Nugget                 15
# 10  Aurum Regis Nugget                 15
# 4         Birch Lumber                 30
# 11        Cassia Block                  6
# 2        Cobalt Rivets                 21
# 1     Darksteel Nugget                 30
# 6     Darksteel Rivets                 15
# 7    Hardsilver Nugget                 18
# 8             Kamacite                  9
# 3       Mythrite Ingot                 30
# 0       Titanium Ingot                 30
# 5        Wolfram Ingot                  9
