# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import generate_gathering_list
utils_dir = '../../utilities/'
data_dir = 'item_data/'
df_gathering_list = generate_gathering_list(
    total_csv=os.path.join(data_dir, 'shark_class_pressure_hull_parts.csv'),
    recipe_book_csv=os.path.join(utils_dir, 'recipe_book.csv'),
    recipe_gathering_csv=os.path.join(utils_dir, 'recipe_gathering.csv'),
    output_csv=os.path.join(data_dir, 'gathering_list.csv')
)
df_gathering_list
# Out:
#       Ingredient  Total Quantity  \
# 12  Aldgoat Horn            36.0
# 8      Cedar Log            45.0
# 7     Cobalt Ore            72.0
# 15    Copper Ore            42.0
# 11  Electrum Ore            72.0
# 6     Fire Shard           504.0
# 19          Flax            36.0
# 14      Gold Ore           126.0
# 10     Ice Shard            72.0
# 4       Iron Ore           144.0
# 5       Iron Ore           144.0
# 9    Mythril Ore           162.0
# 16   Peacock Ore           189.0
# 18     Raw Amber            36.0
# 2     Spruce Log            54.0
# 20     Terebinth            18.0
# 0     Walnut Log            54.0
# 13   Water Shard           198.0
# 17  Wind Cluster            21.0
# 3   Wind Crystal           207.0
# 1     Wind Shard           126.0
#
#                                         Location Info
# 12  Eastern Thanalan ( 18.2 / 22.7 ), Dropped by M...
# 8          Coerthas Western Highlands ( 31.3 / 32.1 )
# 7                   Northern Thanalan ( 23.1 / 24.2 )
# 15                   Central Thanalan ( 19.0 / 26.2 )
# 11                    Upper La Noscea ( 30.4 / 25.4 )
# 6                                                 NaN
# 19                       South Shroud ( 17.6 / 28.6 )
# 14  Eastern Thanalan ( 27.3 / 21.3 ), Timed at 10:...
# 10                                                NaN
# 4                    Western Thanalan ( 27.2 / 17.4 )
# 5    Nowhere ( 0.0 / 0.0 ), Sold by Material Supplier
# 9                   Southern Thanalan ( 25.2 / 39.9 )
# 16       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 18                   Eastern Thanalan ( 12.7 / 19.1 )
# 2   Coerthas Central Highlands ( 29.5 / 13.1 ), Ti...
# 20      Nowhere ( 0.0 / 0.0 ), Sold by Main City NPCs
# 0                        South Shroud ( 23.1 / 21.6 )
# 13                                                NaN
# 17                                                NaN
# 3                                                 NaN
# 1                                                 NaN

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import get_crafting_recipes
data_dir = 'item_data/'
df_crafting_recipes = get_crafting_recipes(os.path.join(data_dir, 'shark_class_pressure_hull_parts.csv'))
df_crafting_recipes
# Out:
#             Product  Required Quantity
# 4      Cedar Lumber                  9
# 3      Cobalt Ingot                 36
# 7    Electrum Ingot                 18
# 8         Horn Glue                 18
# 2        Iron Nails                 18
# 5       Iron Rivets                 18
# 6     Mythril Plate                 18
# 9    Mythril Rivets                 18
# 10  Rose Gold Ingot                 21
# 1     Spruce Lumber                 18
# 11          Varnish                 18
# 0     Walnut Lumber                 18
