# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import generate_gathering_list
utils_dir = '../../utilities/'
data_dir = 'item_data/'
df_gathering_list = generate_gathering_list(
    total_csv=os.path.join(data_dir, 'shark_class_bow_parts.csv'),
    recipe_book_csv=os.path.join(utils_dir, 'recipe_book.csv'),
    recipe_gathering_csv=os.path.join(utils_dir, 'recipe_gathering.csv'),
    output_csv=os.path.join(data_dir, 'gathering_list.csv')
)
df_gathering_list
# Out:
#        Ingredient  Total Quantity  \
# 0        Bomb Ash           120.0
# 5      Cobalt Ore            96.0
# 8            Coke           108.0
# 6   Darksteel Ore            72.0
# 9    Fire Cluster            12.0
# 7    Fire Crystal            72.0
# 3      Fire Shard           900.0
# 13    Ice Cluster             9.0
# 4       Ice Shard           240.0
# 1        Iron Ore           288.0
# 2        Iron Ore           288.0
# 14    Mythril Ore            90.0
# 10  Petrified Log             9.0
# 11    Scarlet Sap             9.0
# 15     Silver Ore            90.0
# 12   Wind Cluster            18.0
# 16     Wind Shard            60.0
#
#                                         Location Info
# 0                   Southern Thanalan ( 22.2 / 29.9 )
# 5                   Northern Thanalan ( 23.1 / 24.2 )
# 8        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 6   Coerthas Central Highlands ( 27.5 / 20.0 ), Ti...
# 9                                                 NaN
# 7                                                 NaN
# 3                                                 NaN
# 13                                                NaN
# 4                                                 NaN
# 1                    Western Thanalan ( 27.2 / 17.4 )
# 2    Nowhere ( 0.0 / 0.0 ), Sold by Material Supplier
# 14                  Southern Thanalan ( 25.2 / 39.9 )
# 10      Nowhere ( 0.0 / 0.0 ), Sold for 1500 GC Seals
# 11      North Shroud ( 17.7 / 27.7 ), Timed at 1:00am
# 15                       South Shroud ( 16.1 / 19.7 )
# 12                                                NaN
# 16                                                NaN

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import get_crafting_recipes
data_dir = 'item_data/'
df_crafting_recipes = get_crafting_recipes(os.path.join(data_dir, 'shark_class_bow_parts.csv'))
df_crafting_recipes
# Out:
#               Product  Required Quantity
# 6      Ancient Lumber                  9
# 4        Cobalt Ingot                 18
# 3  Cobalt Joint Plate                 30
# 5     Darksteel Ingot                 12
# 7      Mythril Rivets                 30
# 8        Silver Ingot                 30
# 0         Steel Ingot                 30
# 2   Steel Joint Plate                 30
# 1        Steel Rivets                 60
