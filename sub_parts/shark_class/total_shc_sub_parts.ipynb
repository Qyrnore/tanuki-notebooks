# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import generate_gathering_list
utils_dir = '../../utilities/'
data_dir = 'item_data/'
df_gathering_list = generate_gathering_list(
    total_csv=os.path.join(data_dir, 'total_shark_class_sub_parts.csv'),
    recipe_book_csv=os.path.join(utils_dir, 'recipe_book.csv'),
    recipe_gathering_csv=os.path.join(utils_dir, 'recipe_gathering.csv'),
    output_csv=os.path.join(data_dir, 'gathering_list.csv')
)
df_gathering_list
# Out:
#        Ingredient  Total Quantity  \
# 12   Aldgoat Horn            36.0
# 21       Bomb Ash           291.0
# 8       Cedar Log            45.0
# 7      Cobalt Ore           450.0
# 29           Coke           405.0
# 15     Copper Ore            42.0
# 27  Darksteel Ore           333.0
# 11   Electrum Ore           156.0
# 30   Fire Cluster            45.0
# 28   Fire Crystal           333.0
# 6      Fire Shard          3078.0
# 19           Flax            36.0
# 14       Gold Ore           126.0
# 26   Hardened Sap           108.0
# 24    Ice Cluster            18.0
# 10      Ice Shard           522.0
# 5        Iron Ore          1041.0
# 4        Iron Ore          1041.0
# 9     Mythril Ore           342.0
# 16    Peacock Ore           189.0
# 22  Petrified Log            18.0
# 18      Raw Amber            36.0
# 23    Scarlet Sap            18.0
# 25     Silver Ore           180.0
# 2      Spruce Log           126.0
# 20      Terebinth            18.0
# 0      Walnut Log            54.0
# 13    Water Shard           198.0
# 17   Wind Cluster            69.0
# 3    Wind Crystal           279.0
# 1      Wind Shard           351.0
#
#                                         Location Info
# 12  Eastern Thanalan ( 18.2 / 22.7 ), Dropped by M...
# 21                  Southern Thanalan ( 22.2 / 29.9 )
# 8          Coerthas Western Highlands ( 31.3 / 32.1 )
# 7                   Northern Thanalan ( 23.1 / 24.2 )
# 29       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 15                   Central Thanalan ( 19.0 / 26.2 )
# 27  Coerthas Central Highlands ( 27.5 / 20.0 ), Ti...
# 11                    Upper La Noscea ( 30.4 / 25.4 )
# 30                                                NaN
# 28                                                NaN
# 6                                                 NaN
# 19                       South Shroud ( 17.6 / 28.6 )
# 14  Eastern Thanalan ( 27.3 / 21.3 ), Timed at 10:...
# 26       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 24                                                NaN
# 10                                                NaN
# 5    Nowhere ( 0.0 / 0.0 ), Sold by Material Supplier
# 4                    Western Thanalan ( 27.2 / 17.4 )
# 9                   Southern Thanalan ( 25.2 / 39.9 )
# 16       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 22      Nowhere ( 0.0 / 0.0 ), Sold for 1500 GC Seals
# 18                   Eastern Thanalan ( 12.7 / 19.1 )
# 23      North Shroud ( 17.7 / 27.7 ), Timed at 1:00am
# 25                       South Shroud ( 16.1 / 19.7 )
# 2   Coerthas Central Highlands ( 29.5 / 13.1 ), Ti...
# 20      Nowhere ( 0.0 / 0.0 ), Sold by Main City NPCs
# 0                        South Shroud ( 23.1 / 21.6 )
# 13                                                NaN
# 17                                                NaN
# 3                                                 NaN
# 1                                                 NaN

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import get_crafting_recipes
data_dir = 'item_data/'
df_crafting_recipes = get_crafting_recipes(os.path.join(data_dir, 'total_shark_class_sub_parts.csv'))
df_crafting_recipes
# Out:
#                   Product  Required Quantity                 2  3  \
# 16         Ancient Lumber                 18     Petrified Log  1
# 4            Cedar Lumber                  9         Cedar Log  5
# 3            Cobalt Ingot                150        Cobalt Ore  2
# 14     Cobalt Joint Plate                 54      Cobalt Ingot  1
# 20          Cobalt Rivets                 21      Cobalt Ingot  1
# 21        Darksteel Ingot                 45  Darksteel Nugget  2
# 19       Darksteel Nugget                 21     Darksteel Ore  3
# 7          Electrum Ingot                 39      Electrum Ore  4
# 8               Horn Glue                 18      Aldgoat Horn  2
# 2              Iron Nails                 39        Iron Ingot  1
# 5             Iron Rivets                 39        Iron Ingot  1
# 6           Mythril Plate                 18     Mythril Ingot  2
# 9          Mythril Rivets                 78     Mythril Ingot  1
# 10        Rose Gold Ingot                 21  Rose Gold Nugget  2
# 17           Silver Ingot                 60        Silver Ore  3
# 1           Spruce Lumber                 18        Spruce Log  3
# 13            Steel Ingot                105          Bomb Ash  1
# 15      Steel Joint Plate                 60       Steel Ingot  1
# 12           Steel Rivets                126       Steel Ingot  1
# 18  Treated Spruce Lumber                 12     Spruce Lumber  2
# 11                Varnish                 18         Raw Amber  2
# 0           Walnut Lumber                 18        Walnut Log  3
#
#                    4  5                 6    7            8    9
# 16       Scarlet Sap  1      Wind Cluster  2.0  Ice Cluster  1.0
# 4       Wind Crystal  3              None  NaN         None  NaN
# 3           Iron Ore  1    Ice/Fire Shard  5.0         None  NaN
# 14         Ice Shard  5              None  NaN         None  NaN
# 20    Ice/Fire Shard  5              None  NaN         None  NaN
# 21              Coke  9  Ice/Fire Cluster  1.0         None  NaN
# 19  Ice/Fire Crystal  3              None  NaN         None  NaN
# 7         Wind Shard  5              None  NaN         None  NaN
# 8        Water Shard  3              None  NaN         None  NaN
# 2     Ice/Fire Shard  1              None  NaN         None  NaN
# 5     Ice/Fire Shard  1              None  NaN         None  NaN
# 6          Ice Shard  4              None  NaN         None  NaN
# 9     Ice/Fire Shard  5              None  NaN         None  NaN
# 10       Peacock Ore  9      Wind Cluster  1.0         None  NaN
# 17        Wind Shard  2              None  NaN         None  NaN
# 1       Wind Crystal  3              None  NaN         None  NaN
# 13          Iron Ore  2    Ice/Fire Shard  2.0         None  NaN
# 15         Ice Shard  3              None  NaN         None  NaN
# 12    Ice/Fire Shard  3              None  NaN         None  NaN
# 18      Hardened Sap  9      Wind Cluster  1.0         None  NaN
# 11       Linseed Oil  1         Terebinth  1.0  Water Shard  5.0
# 0         Wind Shard  2              None  NaN         None  NaN

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import fetch_market_data_for_subparts
utils_dir = '../../utilities/'
data_dir = 'item_data/'
df_market_data = fetch_market_data_for_subparts(
    gathering_csv=os.path.join(data_dir, 'gathering_list.csv'),
    crafting_csv=os.path.join(utils_dir, 'recipe_book.csv'),
    item_ids_json=os.path.join(utils_dir, 'item_ids.json'),
    output_csv=os.path.join(data_dir, 'airship_parts_market_data.csv'),
    world="Seraph"
)
df_market_data
# Out:
#                         Item Name   Category Item ID minListing_world  \
# 0                    Aldgoat Horn  Gathering    5436              599
# 1                        Bomb Ash  Gathering    5528              400
# 2                       Cedar Log  Gathering    5384              263
# 3                      Cobalt Ore  Gathering    5116              200
# 4                            Coke  Gathering    5530              213
# ..                            ...        ...     ...              ...
# 130                  Cobalt Nails   Crafting    7020              250
# 131                  Cobalt Rings   Crafting    5084               37
# 132               Dhalmel Leather   Crafting   12564             5000
# 133  High Allagan Chimera Leather   Crafting   12233             1495
# 134            Amphiptere Leather   Crafting   12566              275
#
#     minListing_dc recentPurchase_world recentPurchase_dc averageSalePrice_dc  \
# 0             450                  599               400          583.242295
# 1             199                  499               220          298.920598
# 2             224                  264               264           344.16073
# 3             200                  200               292          281.530793
# 4             150                  213               223          211.395106
# ..            ...                  ...               ...                 ...
# 130            20                   90               800                None
# 131            37                  155               730          469.888889
# 132          2999                 4123              3000         2780.477273
# 133           493                 2000              1000          713.727273
# 134            50                  323               500          328.926471
#
#     dailySaleVelocity_dc
# 0             484.112049
# 1            3304.404824
# 2             902.625817
# 3            7898.280438
# 4           11394.540251
# ..                   ...
# 130                 None
# 131             4.628878
# 132            56.575056
# 133             2.828747
# 134            17.486759
#
# [133 rows x 9 columns]
