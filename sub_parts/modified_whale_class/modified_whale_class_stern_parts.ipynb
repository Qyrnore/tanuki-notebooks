# %%
from modified_whale_class_sub_parts import generate_gathering_list

# Generate the gathering list and save to 'gathering_list.csv'
df_gathering_list = generate_gathering_list(
    total_csv='modified_whale_class_stern_parts.csv',
    recipe_book_csv='recipe_book.csv',
    recipe_gathering_csv='recipe_gathering.csv',
    output_csv='gathering_list.csv'
)

df_gathering_list  # Display the gathering list
# Out:
#                 Ingredient  Total Quantity  \
# 3               Cobalt Ore            87.0
# 4                     Coke           162.0
# 7          Cryptomeria Log            27.0
# 27          Dhalmel Saliva            36.0
# 28  Dravanian Spring Water            18.0
# 6            Earth Cluster            51.0
# 19           Earth Crystal            54.0
# 21          Eikon Mythrite            24.0
# 16               Ferberite             9.0
# 5             Fire Cluster            72.0
# 18            Fire Crystal            99.0
# 13              Fire Shard           390.0
# 8             Hardened Sap            81.0
# 26         Hardsilver Sand            72.0
# 10             Ice Crystal            99.0
# 12                Iron Ore            30.0
# 11                Iron Ore            30.0
# 22          Lumythrite Ore            36.0
# 14             Mythril Ore           105.0
# 23            Mythrite Ore            24.0
# 20           Mythrite Sand            75.0
# 17       Pure Titanium Ore            27.0
# 24           Raw Rhodonite            36.0
# 15               Scheelite             9.0
# 2               Sphalerite            18.0
# 25             Stiperstone            12.0
# 1                Vivianite            27.0
# 29           Water Crystal            72.0
# 0        Whale-Class Stern             1.0
# 9             Wind Crystal           126.0
#
#                                         Location Info
# 3                   Northern Thanalan ( 23.1 / 24.2 )
# 4        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 7   Nowhere ( 0.0 / 0.0 ), Collected from Submarin...
# 27  The Sea of Clouds ( 17.3 / 32.2 ), Dropped by ...
# 28            The Dravanian Forelands ( 27.4 / 31.8 )
# 6                                                 NaN
# 19                                                NaN
# 21    Nowhere ( 0.0 / 0.0 ), Sold by Spoils Collector
# 16  Northern Thanalan ( 17.3 / 19.9 ), Timed at 3:...
# 5                                                 NaN
# 18                                                NaN
# 13                                                NaN
# 8        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 26                 The Churning Mists ( 15.9 / 28.5 )
# 10                                                NaN
# 12   Nowhere ( 0.0 / 0.0 ), Sold by Material Supplier
# 11                   Western Thanalan ( 27.2 / 17.4 )
# 22  The Churning Mists ( 9.3 / 38.5 ), Timed at 2A...
# 14                  Southern Thanalan ( 25.2 / 39.9 )
# 23         Coerthas Western Highlands ( 31.2 / 12.8 )
# 20         Coerthas Western Highlands ( 16.6 / 13.1 )
# 17  Nowhere ( 0.0 / 0.0 ), Collected from Submarin...
# 24      The Peaks ( 26.9 / 12.5 ), Timed at 8AM/PM ET
# 15      Nowhere ( 0.0 / 0.0 ), Sold for 1500 GC Seals
# 2      Nowhere ( 0.0 / 0.0 ), Sold by NPCs for Scrips
# 25                          The Peaks ( 23.3 / 13.1 )
# 1   Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 29                                                NaN
# 0                                                 NaN
# 9                                                 NaN

# %%
from modified_whale_class_sub_parts import get_crafting_recipes

# Get the crafting recipes from total_whale_class_sub_parts.csv
df_crafting_recipes = get_crafting_recipes('modified_whale_class_stern_parts.csv')
df_crafting_recipes  # Display the crafting recipes list
# Out:
#                      Product  Required Quantity
# 3               Cobalt Ingot                 30
# 2         Cryptomeria Lumber                  9
# 10  Enchanted Hardsilver Ink                 18
# 1   Galvanized Garlond Steel                  9
# 8        High Mythrite Ingot                 12
# 4             Mythril Rivets                 30
# 7            Mythrite Rivets                 15
# 6        Pure Titanium Plate                  9
# 9                  Rhodonite                 12
# 0          Whale-Class Stern                  1
# 5              Wolfram Ingot                  9
