# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import generate_gathering_list
utils_dir = '../../utilities/'
data_dir = 'item_data/'
df_gathering_list = generate_gathering_list(
    total_csv=os.path.join(data_dir, 'modified_whale_class_pressure_hull_parts.csv'),
    recipe_book_csv=os.path.join(utils_dir, 'recipe_book.csv'),
    recipe_gathering_csv=os.path.join(utils_dir, 'recipe_gathering.csv'),
    output_csv=os.path.join(data_dir, 'gathering_list.csv')
)
df_gathering_list
# Out:
#                    Ingredient  Total Quantity  \
# 18               Ahriman Wing            24.0
# 11                  Beech Log            48.0
# 3                  Cobalt Ore            18.0
# 4                        Coke           162.0
# 7             Cryptomeria Log            27.0
# 12              Darksteel Ore            72.0
# 19             Dhalmel Saliva            60.0
# 33     Dravanian Spring Water            18.0
# 6               Earth Cluster            54.0
# 22              Earth Crystal            54.0
# 23             Eikon Mythrite            36.0
# 5                Fire Cluster           120.0
# 13               Fire Crystal           198.0
# 27                       Flax            60.0
# 8                Hardened Sap            81.0
# 32            Hardsilver Sand            72.0
# 10                Ice Crystal            54.0
# 24             Lumythrite Ore            54.0
# 25               Mythrite Ore            36.0
# 14               Platinum Ore            48.0
# 21          Pure Titanium Ore            27.0
# 26                  Raw Amber            60.0
# 30              Raw Rhodonite            45.0
# 15                   Raziqsap           216.0
# 2                  Sphalerite            18.0
# 31                Stiperstone            15.0
# 29                  Terebinth            30.0
# 1                   Vivianite            27.0
# 20              Water Crystal           120.0
# 28                Water Shard           240.0
# 0   Whale-Class Pressure Hull             1.0
# 16               Wind Cluster            48.0
# 9                Wind Crystal           180.0
# 17                Wyvern Wing            36.0
#
#                                         Location Info
# 18  Northern Thanalan ( 24 / 21 ), Dropped by vari...
# 11                        The Fringes ( 10.5 / 16.2 )
# 3                   Northern Thanalan ( 23.1 / 24.2 )
# 4        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 7   Nowhere ( 0.0 / 0.0 ), Collected from Submarin...
# 12  Coerthas Central Highlands ( 27.5 / 20.0 ), Ti...
# 19  The Sea of Clouds ( 17.3 / 32.2 ), Dropped by ...
# 33            The Dravanian Forelands ( 27.4 / 31.8 )
# 6                                                 NaN
# 22                                                NaN
# 23    Nowhere ( 0.0 / 0.0 ), Sold by Spoils Collector
# 5                                                 NaN
# 13                                                NaN
# 27                       South Shroud ( 17.6 / 28.6 )
# 8        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 32                 The Churning Mists ( 15.9 / 28.5 )
# 10                                                NaN
# 24  The Churning Mists ( 9.3 / 38.5 ), Timed at 2A...
# 25         Coerthas Western Highlands ( 31.2 / 12.8 )
# 14  Southern Thanalan ( 16.7 / 10.7 ), Timed at 4:...
# 21  Nowhere ( 0.0 / 0.0 ), Collected from Submarin...
# 26                   Eastern Thanalan ( 12.7 / 19.1 )
# 30      The Peaks ( 26.9 / 12.5 ), Timed at 8AM/PM ET
# 15       Nowhere ( 0.0 / 0.0 ), Sold for 250 GC Seals
# 2      Nowhere ( 0.0 / 0.0 ), Sold by NPCs for Scrips
# 31                          The Peaks ( 23.3 / 13.1 )
# 29      Nowhere ( 0.0 / 0.0 ), Sold by Main City NPCs
# 1   Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 20                                                NaN
# 28                                                NaN
# 0                                                 NaN
# 16                                                NaN
# 9                                                 NaN
# 17  The Churning Mists ( 24 / 28 ), Dropped by var...

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import get_crafting_recipes
data_dir = 'item_data/'
df_crafting_recipes = get_crafting_recipes(os.path.join(data_dir, 'modified_whale_class_pressure_hull_parts.csv'))
df_crafting_recipes
# Out:
#                       Product  Required Quantity
# 3                Beech Lumber                 12
# 2          Cryptomeria Lumber                  9
# 4            Darksteel Rivets                 24
# 11   Enchanted Hardsilver Ink                 18
# 1    Galvanized Garlond Steel                  9
# 8         High Mythrite Ingot                 18
# 5              Platinum Ingot                 24
# 7         Pure Titanium Plate                  9
# 10                  Rhodonite                 15
# 9                     Varnish                 30
# 0   Whale-Class Pressure Hull                  1
# 6                   Wing Glue                 12
