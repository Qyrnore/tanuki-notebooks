# %%
from modified_whale_class_sub_parts import generate_gathering_list

# Generate the gathering list and save to 'gathering_list.csv'
df_gathering_list = generate_gathering_list(
    total_csv='total_modified_whale_class_sub_parts.csv',
    recipe_book_csv='recipe_book.csv',
    recipe_gathering_csv='recipe_gathering.csv',
    output_csv='gathering_list.csv'
)

df_gathering_list  # Display the gathering list
# Out:
#                    Ingredient  Total Quantity  \
# 42               Ahriman Wing            24.0
# 0                   Beech Log            48.0
# 2                  Cobalt Ore           297.0
# 18                       Coke           648.0
# 7             Cryptomeria Log           108.0
# 10              Darksteel Ore           135.0
# 13             Dhalmel Saliva           168.0
# 14     Dravanian Spring Water            72.0
# 20              Earth Cluster           249.0
# 30              Earth Crystal           216.0
# 21             Eikon Mythrite           132.0
# 44                  Ferberite            45.0
# 19               Fire Cluster           468.0
# 11               Fire Crystal           621.0
# 5                  Fire Shard           690.0
# 34                       Flax            60.0
# 8                Hardened Sap           324.0
# 12            Hardsilver Sand           288.0
# 9                 Ice Crystal           351.0
# 6                   Ice Shard           300.0
# 3                    Iron Ore            90.0
# 4                    Iron Ore            90.0
# 22             Lumythrite Ore           198.0
# 24                Mythril Ore           135.0
# 23               Mythrite Ore           132.0
# 25              Mythrite Sand           225.0
# 26               Platinum Ore           108.0
# 29          Pure Titanium Ore           108.0
# 33                  Raw Amber            60.0
# 31              Raw Rhodonite           135.0
# 27                   Raziqsap           486.0
# 43                  Scheelite            45.0
# 17                 Sphalerite            72.0
# 32                Stiperstone            45.0
# 36                  Terebinth            30.0
# 16                  Vivianite           108.0
# 15              Water Crystal           336.0
# 35                Water Shard           240.0
# 37            Whale-Class Bow             1.0
# 38         Whale-Class Bridge             1.0
# 39  Whale-Class Pressure Hull             1.0
# 40          Whale-Class Stern             1.0
# 28               Wind Cluster           108.0
# 1                Wind Crystal           522.0
# 41                Wyvern Wing            36.0
#
#                                         Location Info
# 42  Northern Thanalan ( 24 / 21 ), Dropped by vari...
# 0                         The Fringes ( 10.5 / 16.2 )
# 2                   Northern Thanalan ( 23.1 / 24.2 )
# 18       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 7   Nowhere ( 0.0 / 0.0 ), Collected from Submarin...
# 10  Coerthas Central Highlands ( 27.5 / 20.0 ), Ti...
# 13  The Sea of Clouds ( 17.3 / 32.2 ), Dropped by ...
# 14            The Dravanian Forelands ( 27.4 / 31.8 )
# 20                                                NaN
# 30                                                NaN
# 21    Nowhere ( 0.0 / 0.0 ), Sold by Spoils Collector
# 44  Northern Thanalan ( 17.3 / 19.9 ), Timed at 3:...
# 19                                                NaN
# 11                                                NaN
# 5                                                 NaN
# 34                       South Shroud ( 17.6 / 28.6 )
# 8        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 12                 The Churning Mists ( 15.9 / 28.5 )
# 9                                                 NaN
# 6                                                 NaN
# 3                    Western Thanalan ( 27.2 / 17.4 )
# 4    Nowhere ( 0.0 / 0.0 ), Sold by Material Supplier
# 22  The Churning Mists ( 9.3 / 38.5 ), Timed at 2A...
# 24                  Southern Thanalan ( 25.2 / 39.9 )
# 23         Coerthas Western Highlands ( 31.2 / 12.8 )
# 25         Coerthas Western Highlands ( 16.6 / 13.1 )
# 26  Southern Thanalan ( 16.7 / 10.7 ), Timed at 4:...
# 29  Nowhere ( 0.0 / 0.0 ), Collected from Submarin...
# 33                   Eastern Thanalan ( 12.7 / 19.1 )
# 31      The Peaks ( 26.9 / 12.5 ), Timed at 8AM/PM ET
# 27       Nowhere ( 0.0 / 0.0 ), Sold for 250 GC Seals
# 43      Nowhere ( 0.0 / 0.0 ), Sold for 1500 GC Seals
# 17     Nowhere ( 0.0 / 0.0 ), Sold by NPCs for Scrips
# 32                          The Peaks ( 23.3 / 13.1 )
# 36      Nowhere ( 0.0 / 0.0 ), Sold by Main City NPCs
# 16  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 15                                                NaN
# 35                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 28                                                NaN
# 1                                                 NaN
# 41  The Churning Mists ( 24 / 28 ), Dropped by var...

# %%
from modified_whale_class_sub_parts import get_crafting_recipes

# Get the crafting recipes from total_modified_whale_class_sub_parts.csv
df_crafting_recipes = get_crafting_recipes('total_modified_whale_class_sub_parts.csv')
df_crafting_recipes  # Display the crafting recipes list
# Out:
#                       Product  Required Quantity                  2    3  \
# 0                Beech Lumber                 12          Beech Log  4.0
# 1                Cobalt Ingot                 30         Cobalt Ore  2.0
# 2          Cobalt Joint Plate                 60       Cobalt Ingot  1.0
# 3          Cryptomeria Lumber                 36    Cryptomeria Log  3.0
# 4            Darksteel Rivets                 45   Darksteel Nugget  1.0
# 5    Enchanted Hardsilver Ink                 72    Hardsilver Sand  4.0
# 6    Galvanized Garlond Steel                 36          Vivianite  3.0
# 7         High Mythrite Ingot                 66     Eikon Mythrite  2.0
# 8              Mythril Rivets                 30      Mythril Ingot  1.0
# 9             Mythrite Rivets                 45    Mythrite Nugget  1.0
# 10             Platinum Ingot                 54       Platinum Ore  2.0
# 11        Pure Titanium Plate                 36  Pure Titanium Ore  3.0
# 12                  Rhodonite                 45      Raw Rhodonite  3.0
# 13                    Varnish                 30          Raw Amber  2.0
# 14            Whale-Class Bow                  1               None  NaN
# 15         Whale-Class Bridge                  1               None  NaN
# 16  Whale-Class Pressure Hull                  1               None  NaN
# 17          Whale-Class Stern                  1               None  NaN
# 18                  Wing Glue                 12        Wyvern Wing  3.0
# 19              Wolfram Ingot                 45          Scheelite  1.0
#
#                  4    5                       6    7              8    9  \
# 0     Wind Crystal  3.0                    None  NaN           None  NaN
# 1         Iron Ore  1.0              Fire Shard  5.0           None  NaN
# 2        Ice Shard  5.0                    None  NaN           None  NaN
# 3     Hardened Sap  9.0            Wind Crystal  6.0    Ice Crystal  6.0
# 4     Fire Crystal  3.0                    None  NaN           None  NaN
# 5   Dhalmel Saliva  2.0  Dravanian Spring Water  1.0  Water Crystal  4.0
# 6       Sphalerite  2.0              Cobalt Ore  2.0           Coke  9.0
# 7   Lumythrite Ore  3.0            Mythrite Ore  2.0   Fire Cluster  3.0
# 8       Fire Shard  5.0                    None  NaN           None  NaN
# 9      Ice Crystal  3.0                    None  NaN           None  NaN
# 10        Raziqsap  9.0            Wind Cluster  2.0   Fire Cluster  2.0
# 11            Coke  9.0            Fire Crystal  6.0  Earth Crystal  6.0
# 12     Stiperstone  1.0            Wind Crystal  6.0           None  NaN
# 13     Linseed Oil  1.0               Terebinth  1.0    Water Shard  5.0
# 14            None  NaN                    None  NaN           None  NaN
# 15            None  NaN                    None  NaN           None  NaN
# 16            None  NaN                    None  NaN           None  NaN
# 17            None  NaN                    None  NaN           None  NaN
# 18    Ahriman Wing  2.0          Dhalmel Saliva  2.0  Water Crystal  4.0
# 19       Ferberite  1.0              Cobalt Ore  1.0   Fire Cluster  2.0
#
#                10   11             12   13
# 0            None  NaN           None  NaN
# 1            None  NaN           None  NaN
# 2            None  NaN           None  NaN
# 3            None  NaN           None  NaN
# 4            None  NaN           None  NaN
# 5            None  NaN           None  NaN
# 6    Fire Cluster  2.0  Earth Cluster  2.0
# 7   Earth Cluster  2.0           None  NaN
# 8            None  NaN           None  NaN
# 9            None  NaN           None  NaN
# 10           None  NaN           None  NaN
# 11           None  NaN           None  NaN
# 12           None  NaN           None  NaN
# 13           None  NaN           None  NaN
# 14           None  NaN           None  NaN
# 15           None  NaN           None  NaN
# 16           None  NaN           None  NaN
# 17           None  NaN           None  NaN
# 18           None  NaN           None  NaN
# 19  Earth Cluster  1.0           None  NaN

# %%
from modified_whale_class_sub_parts import fetch_market_data_for_subparts

# Combine items from the gathering list (from 'gathering_list.csv') and the crafting recipes (from 'recipe_book.csv'),
# fetch market data from the Universalis API, and save the results to 'sub_parts_market_data.csv'.
df_market_data = fetch_market_data_for_subparts(
    gathering_csv='gathering_list.csv',
    crafting_csv='recipe_book.csv', 
    item_ids_json='item_ids.json',
    output_csv='sub_parts_market_data.csv',
    world="Seraph"
)

df_market_data  # Display the market data for sub parts
# Out:
#                Item Name   Category Item ID minListing_world minListing_dc  \
# 0           Ahriman Wing  Gathering    5553              897            89
# 1              Beech Log  Gathering   19930              148           100
# 2             Cobalt Ore  Gathering    5116              200           200
# 3                   Coke  Gathering    5530              213           150
# 4        Cryptomeria Log  Gathering   26529             9992          8938
# ..                   ...        ...     ...              ...           ...
# 131  High Mythrite Ingot   Crafting   14146             6489          2499
# 132      Mythrite Rivets   Crafting   12528             2700          1840
# 133       Tempered Glass   Crafting   16908             None          8495
# 134            Wing Glue   Crafting    5507             2180          2000
# 135         Beech Lumber   Crafting   19925              375             9
#
#     recentPurchase_world recentPurchase_dc averageSalePrice_dc  \
# 0                    800               400          499.348571
# 1                     10               379           290.53048
# 2                    200               292          289.355514
# 3                    213               223          216.003922
# 4                   7297              7297         8284.764151
# ..                   ...               ...                 ...
# 131                 4008                 8         4307.168421
# 132                 2999               500         2251.882353
# 133                10000             15420               15420
# 134                 2190              2100         2934.185185
# 135                  399               949         1097.819231
#
#     dailySaleVelocity_dc
# 0              94.647015
# 1             208.493376
# 2           12305.678475
# 3           21306.789161
# 4              28.664261
# ..                   ...
# 131            25.682147
# 132             4.595743
# 133             2.703372
# 134            14.598175
# 135            70.287353
#
# [134 rows x 9 columns]
