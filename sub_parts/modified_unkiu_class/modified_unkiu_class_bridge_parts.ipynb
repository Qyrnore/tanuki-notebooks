# %%
from modified_unkiu_class_sub_parts import generate_gathering_list

# Generate the gathering list and save to 'gathering_list.csv'
df_gathering_list = generate_gathering_list(
    total_csv='modified_unkiu_class_bridge_parts.csv',
    recipe_book_csv='recipe_book.csv',
    recipe_gathering_csv='recipe_gathering.csv',
    output_csv='gathering_list.csv'
)

df_gathering_list  # Display the gathering list
# Out:
#                 Ingredient  Total Quantity  \
# 13              Cloud Mica            84.0
# 3               Cobalt Ore            18.0
# 4                     Coke           162.0
# 7          Cryptomeria Log            27.0
# 23       Dark Chestnut Log            18.0
# 31          Dhalmel Saliva            36.0
# 22             Dragon Skin            54.0
# 32  Dravanian Spring Water            18.0
# 6            Earth Cluster            18.0
# 21           Earth Crystal           144.0
# 5             Fire Cluster            18.0
# 18            Fire Crystal           297.0
# 12              Fire Shard           168.0
# 17             Grenade Ash            21.0
# 8             Hardened Sap            81.0
# 30         Hardsilver Sand            72.0
# 10             Ice Crystal           108.0
# 16                Iron Ore            21.0
# 15                Iron Ore            21.0
# 26       Lightning Cluster             9.0
# 11             Mythril Ore            81.0
# ...

# %%
from modified_unkiu_class_sub_parts import get_crafting_recipes

# Get the crafting recipes from total_modified_unkiu_class_sub_parts.csv
df_crafting_recipes = get_crafting_recipes('modified_unkiu_class_bridge_parts.csv')
df_crafting_recipes  # Display the crafting recipes list
# Out:
#                      Product  Required Quantity
# 2         Cryptomeria Lumber                  9
# 7             Dragon Leather                 18
# 10  Enchanted Hardsilver Ink                 18
# 8            Farreach Canvas                  9
# 1   Galvanized Garlond Steel                  9
# 3             Mythril Rivets                 21
# 5            Mythrite Rivets                 18
# 6        Pure Titanium Plate                  9
# 9                  Rhodonite                  6
# 4             Titanium Ingot                 21
# 0         Unkiu-Class Bridge                  1
