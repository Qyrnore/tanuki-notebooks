# %%
from modified_unkiu_class_sub_parts import generate_gathering_list

# Generate the gathering list and save to 'gathering_list.csv'
df_gathering_list = generate_gathering_list(
    total_csv='modified_unkiu_class_bow_parts.csv',
    recipe_book_csv='recipe_book.csv',
    recipe_gathering_csv='recipe_gathering.csv',
    output_csv='gathering_list.csv'
)

df_gathering_list  # Display the gathering list
# Out:
#                 Ingredient  Total Quantity  \
# 14                Bomb Ash            30.0
# 31            Carbon Fiber            30.0
# 3               Cobalt Ore            30.0
# 4                     Coke           162.0
# 7          Cryptomeria Log            27.0
# 41          Dhalmel Saliva            36.0
# 42  Dravanian Spring Water            18.0
# 6            Earth Cluster            66.0
# 23           Earth Crystal            54.0
# 33      Effervescent Water            30.0
# 11          Eikon Mythrite            36.0
# 20               Ferberite            12.0
# 5             Fire Cluster           162.0
# 22            Fire Crystal            54.0
# 17              Fire Shard            60.0
# 30             Glass Fiber            30.0
# 26                Gold Ore            30.0
# 8             Hardened Sap            81.0
# 40         Hardsilver Sand            72.0
# 10             Ice Crystal            54.0
# 18               Ice Shard            90.0
# 16                Iron Ore            60.0
# 15                Iron Ore            60.0
# 37       Lightning Crystal           210.0
# 12          Lumythrite Ore            54.0
# 13            Mythrite Ore            36.0
# 25             Native Gold            30.0
# 28            Platinum Ore            36.0
# 21       Pure Titanium Ore            27.0
# 38           Raw Rhodonite            36.0
# 24               Raziqsand            30.0
# 29                Raziqsap           162.0
# 34               Rock Salt            30.0
# 19               Scheelite            12.0
# 32                   Silex            90.0
# 2               Sphalerite            18.0
# 39             Stiperstone            12.0
# 0          Unkiu-Class Bow             1.0
# 1                Vivianite            27.0
# 36           Water Crystal           282.0
# 35             Water Shard            60.0
# 27            Wind Cluster            96.0
# 9             Wind Crystal           126.0
#
#                                         Location Info
# 14                  Southern Thanalan ( 22.2 / 29.9 )
# 31      Nowhere ( 0.0 / 0.0 ), Sold by Scrip Exchange
# 3                   Northern Thanalan ( 23.1 / 24.2 )
# 4        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 7   Nowhere ( 0.0 / 0.0 ), Collected from Submarin...
# 41  The Sea of Clouds ( 17.3 / 32.2 ), Dropped by ...
# 42            The Dravanian Forelands ( 27.4 / 31.8 )
# 6                                                 NaN
# 23                                                NaN
# 33                       South Shroud ( 16.0 / 19.7 )
# 11    Nowhere ( 0.0 / 0.0 ), Sold by Spoils Collector
# 20  Northern Thanalan ( 17.3 / 19.9 ), Timed at 3:...
# 5                                                 NaN
# 22                                                NaN
# 17                                                NaN
# 30  Nowhere ( 0.0 / 0.0 ), Sold for 7000 GC Seals ...
# 26  Eastern Thanalan ( 27.3 / 21.3 ), Timed at 10:...
# 8        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 40                 The Churning Mists ( 15.9 / 28.5 )
# 10                                                NaN
# 18                                                NaN
# 16   Nowhere ( 0.0 / 0.0 ), Sold by Material Supplier
# 15                   Western Thanalan ( 27.2 / 17.4 )
# 37                                                NaN
# 12  The Churning Mists ( 9.3 / 38.5 ), Timed at 2A...
# 13         Coerthas Western Highlands ( 31.2 / 12.8 )
# 25  Central Thanalan ( 25.2 / 15.8 ), Timed at 4:0...
# 28  Southern Thanalan ( 16.7 / 10.7 ), Timed at 4:...
# 21  Nowhere ( 0.0 / 0.0 ), Collected from Submarin...
# 38      The Peaks ( 26.9 / 12.5 ), Timed at 8AM/PM ET
# 24      Nowhere ( 0.0 / 0.0 ), Sold for 1500 GC Seals
# 29       Nowhere ( 0.0 / 0.0 ), Sold for 250 GC Seals
# 34                   Central Thanalan ( 14.5 / 22.7 )
# 19      Nowhere ( 0.0 / 0.0 ), Sold for 1500 GC Seals
# 32                  Southern Thanalan ( 22.4 / 29.7 )
# 2      Nowhere ( 0.0 / 0.0 ), Sold by NPCs for Scrips
# 39                          The Peaks ( 23.3 / 13.1 )
# 0                                                 NaN
# 1   Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 36                                                NaN
# 35                                                NaN
# 27                                                NaN
# 9                                                 NaN

# %%
from modified_unkiu_class_sub_parts import get_crafting_recipes

# Get the crafting recipes from total_modified_unkiu_class_sub_parts.csv
df_crafting_recipes = get_crafting_recipes('modified_unkiu_class_bow_parts.csv')
df_crafting_recipes  # Display the crafting recipes list
# Out:
#                      Product  Required Quantity
# 2         Cryptomeria Lumber                  9
# 11  Enchanted Hardsilver Ink                 18
# 1   Galvanized Garlond Steel                  9
# 7                 Gold Ingot                 30
# 3        High Mythrite Ingot                 18
# 8             Platinum Ingot                 18
# 6        Pure Titanium Plate                  9
# 10                 Rhodonite                 12
# 4          Steel Joint Plate                 30
# 9             Tempered Glass                 30
# 0            Unkiu-Class Bow                  1
# 5              Wolfram Ingot                 12
