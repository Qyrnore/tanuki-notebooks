# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import generate_gathering_list
utils_dir = '../../utilities/'
data_dir = 'item_data/'
df_gathering_list = generate_gathering_list(
    total_csv=os.path.join(data_dir, 'total_modified_unkiu_class_sub_parts.csv'),
    recipe_book_csv=os.path.join(utils_dir, 'recipe_book.csv'),
    recipe_gathering_csv=os.path.join(utils_dir, 'recipe_gathering.csv'),
    output_csv=os.path.join(data_dir, 'gathering_list.csv')
)
df_gathering_list
# Out:
#           Ingredient  Total Quantity  \
# 64      Ahriman Wing            32.0
# 0    Aurum Regis Ore            36.0
# 1   Aurum Regis Sand            90.0
# 48          Bomb Ash            54.0
# 50      Carbon Fiber            60.0
# ..               ...             ...
# 24     Water Crystal           772.0
# 54       Water Shard           120.0
# 6       Wind Cluster           234.0
# 3       Wind Crystal           720.0
# 63       Wyvern Wing            48.0
#
#                                         Location Info
# 64  Northern Thanalan ( 24 / 21 ), Dropped by vari...
# 0   The Churning Mists ( 9.3 / 38.5 ), Timed at 2A...
# 1                   The Sea of Clouds ( 34.8 / 30.5 )
# 48                  Southern Thanalan ( 22.2 / 29.9 )
# 50      Nowhere ( 0.0 / 0.0 ), Sold by Scrip Exchange
# ..                                                ...
# 24                                                NaN
# 54                                                NaN
# 6                                                 NaN
# 3                                                 NaN
# 63  The Churning Mists ( 24 / 28 ), Dropped by var...
#
# [67 rows x 3 columns]

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import get_crafting_recipes
data_dir = 'item_data/'
df_crafting_recipes = get_crafting_recipes(os.path.join(data_dir, 'total_modified_unkiu_class_sub_parts.csv'))
df_crafting_recipes
# Out:
#                       Product  Required Quantity                  2    3  \
# 0           Aurum Regis Ingot                 18    Aurum Regis Ore  2.0
# 1          Cobalt Joint Plate                 30       Cobalt Ingot  1.0
# 2                Cobalt Plate                 24       Cobalt Ingot  2.0
# 3          Cryptomeria Lumber                 36    Cryptomeria Log  3.0
# 4            Darksteel Rivets                 24   Darksteel Nugget  1.0
# 5              Dragon Leather                 18        Dragon Skin  3.0
# 6    Enchanted Hardsilver Ink                 72    Hardsilver Sand  4.0
# 7             Farreach Canvas                 18     Red Moko Grass  3.0
# 8              Gagana Leather                 24        Gagana Skin  3.0
# 9    Galvanized Garlond Steel                 36          Vivianite  3.0
# 10                 Gold Ingot                 60          Raziqsand  1.0
# 11        High Mythrite Ingot                 30     Eikon Mythrite  2.0
# 12             Mythril Rivets                 21      Mythril Ingot  1.0
# 13            Mythrite Rivets                 18    Mythrite Nugget  1.0
# 14             Platinum Ingot                 18       Platinum Ore  2.0
# 15        Pure Titanium Plate                 36  Pure Titanium Ore  3.0
# 16                  Rhodonite                 45      Raw Rhodonite  3.0
# 17            Rose Gold Ingot                 24   Rose Gold Nugget  2.0
# 18          Steel Joint Plate                 30        Steel Ingot  1.0
# 19               Steel Rivets                 24        Steel Ingot  1.0
# 20             Tempered Glass                 60        Glass Fiber  1.0
# 21             Titanium Ingot                 21         Cloud Mica  4.0
# 22            Unkiu-Class Bow                  1               None  NaN
# 23         Unkiu-Class Bridge                  1               None  NaN
# 24  Unkiu-Class Pressure Hull                  1               None  NaN
# 25          Unkiu-Class Stern                  1               None  NaN
# 26                  Wing Glue                 16        Wyvern Wing  3.0
# 27              Wolfram Ingot                 21          Scheelite  1.0
#
#                      4    5                       6    7              8    9  \
# 0   Aurum Regis Nugget  1.0           Violet Quartz  1.0      Raziqcoat  5.0
# 1            Ice Shard  5.0                    None  NaN           None  NaN
# 2            Ice Shard  5.0                    None  NaN           None  NaN
# 3         Hardened Sap  9.0            Wind Crystal  6.0    Ice Crystal  6.0
# 4         Fire Crystal  3.0                    None  NaN           None  NaN
# 5    Dark Chestnut Log  1.0           Earth Crystal  5.0           None  NaN
# 6       Dhalmel Saliva  2.0  Dravanian Spring Water  1.0  Water Crystal  4.0
# 7               Potash  9.0       Lightning Cluster  1.0   Wind Cluster  1.0
# 8   Gyr Abanian Alumen  1.0           Earth Crystal  3.0           None  NaN
# 9           Sphalerite  2.0              Cobalt Ore  2.0           Coke  9.0
# 10         Native Gold  1.0                Gold Ore  1.0   Wind Cluster  2.0
# 11      Lumythrite Ore  3.0            Mythrite Ore  2.0   Fire Cluster  3.0
# 12          Fire Shard  5.0                    None  NaN           None  NaN
# 13         Ice Crystal  3.0                    None  NaN           None  NaN
# 14            Raziqsap  9.0            Wind Cluster  2.0   Fire Cluster  2.0
# 15                Coke  9.0            Fire Crystal  6.0  Earth Crystal  6.0
# 16         Stiperstone  1.0            Wind Crystal  6.0           None  NaN
# 17         Peacock Ore  9.0            Wind Cluster  1.0           None  NaN
# 18           Ice Shard  3.0                    None  NaN           None  NaN
# 19          Fire Shard  3.0                    None  NaN           None  NaN
# 20        Carbon Fiber  1.0                   Silex  3.0         Natron  1.0
# 21     Titanium Nugget  1.0            Fire Crystal  5.0           None  NaN
# 22                None  NaN                    None  NaN           None  NaN
# 23                None  NaN                    None  NaN           None  NaN
# 24                None  NaN                    None  NaN           None  NaN
# 25                None  NaN                    None  NaN           None  NaN
# 26        Ahriman Wing  2.0          Dhalmel Saliva  2.0  Water Crystal  4.0
# 27           Ferberite  1.0              Cobalt Ore  1.0   Fire Cluster  2.0
#
#                10   11                 12   13
# 0    Wind Cluster  2.0       Fire Cluster  2.0
# 1            None  NaN               None  NaN
# 2            None  NaN               None  NaN
# 3            None  NaN               None  NaN
# 4            None  NaN               None  NaN
# 5            None  NaN               None  NaN
# 6            None  NaN               None  NaN
# 7            None  NaN               None  NaN
# 8            None  NaN               None  NaN
# 9    Fire Cluster  2.0      Earth Cluster  2.0
# 10   Fire Cluster  1.0               None  NaN
# 11  Earth Cluster  2.0               None  NaN
# 12           None  NaN               None  NaN
# 13           None  NaN               None  NaN
# 14           None  NaN               None  NaN
# 15           None  NaN               None  NaN
# 16           None  NaN               None  NaN
# 17           None  NaN               None  NaN
# 18           None  NaN               None  NaN
# 19           None  NaN               None  NaN
# 20  Water Crystal  7.0  Lightning Crystal  7.0
# 21           None  NaN               None  NaN
# 22           None  NaN               None  NaN
# 23           None  NaN               None  NaN
# 24           None  NaN               None  NaN
# 25           None  NaN               None  NaN
# 26           None  NaN               None  NaN
# 27  Earth Cluster  1.0               None  NaN

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import fetch_market_data_for_subparts
utils_dir = '../../utilities/'
data_dir = 'item_data/'
df_market_data = fetch_market_data_for_subparts(
    gathering_csv=os.path.join(data_dir, 'gathering_list.csv'),
    crafting_csv=os.path.join(utils_dir, 'recipe_book.csv'),
    item_ids_json=os.path.join(utils_dir, 'item_ids.json'),
    output_csv=os.path.join(data_dir, 'airship_parts_market_data.csv'),
    world="Seraph"
)
df_market_data
# Out:
#                         Item Name   Category Item ID minListing_world  \
# 0                    Ahriman Wing  Gathering    5553              897
# 1                 Aurum Regis Ore  Gathering   12536               45
# 2                Aurum Regis Sand  Gathering   12533              270
# 3                        Bomb Ash  Gathering    5528              400
# 4                    Carbon Fiber  Gathering    5339             2989
# ..                            ...        ...     ...              ...
# 166                  Cobalt Nails   Crafting    7020              250
# 167                  Cobalt Rings   Crafting    5084               37
# 168               Dhalmel Leather   Crafting   12564             5000
# 169  High Allagan Chimera Leather   Crafting   12233             1495
# 170            Amphiptere Leather   Crafting   12566              275
#
#     minListing_dc recentPurchase_world recentPurchase_dc averageSalePrice_dc  \
# 0              89                  800               400          474.615385
# 1              45                   92               100                None
# 2             132                  200               450          218.789157
# 3             199                  499               220          298.920598
# 4            2500                 2994              4996             5000.95
# ..            ...                  ...               ...                 ...
# 166            20                   90               800                None
# 167            37                  155               730          469.888889
# 168          2999                 4123              3000         2780.477273
# 169           493                 2000              1000          713.727273
# 170            50                  323               500          328.926471
#
#     dailySaleVelocity_dc
# 0              57.063717
# 1                   None
# 2             128.586456
# 3            3316.903622
# 4              25.820461
# ..                   ...
# 166                 None
# 167             4.646007
# 168            56.784403
# 169             2.839214
# 170            17.551465
#
# [169 rows x 9 columns]
