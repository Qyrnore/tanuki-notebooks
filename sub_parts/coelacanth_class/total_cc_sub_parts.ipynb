# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import generate_gathering_list
utils_dir = '../../utilities/'
data_dir = 'item_data/'
df_gathering_list = generate_gathering_list(
    total_csv=os.path.join(data_dir, 'total_coelacanth_class_sub_parts.csv'),
    recipe_book_csv=os.path.join(utils_dir, 'recipe_book.csv'),
    recipe_gathering_csv=os.path.join(utils_dir, 'recipe_gathering.csv'),
    output_csv=os.path.join(data_dir, 'gathering_list.csv')
)
df_gathering_list
# Out:
#            Ingredient  Total Quantity  \
# 9   Aqueous Whetstone            81.0
# 0    Aurum Regis Sand           240.0
# 27       Basilisk Egg            12.0
# 3          Cassia Log            54.0
# 4          Cassia Log            54.0
# 35         Cloud Mica           480.0
# 11         Cobalt Ore           831.0
# 19               Coke           243.0
# 33         Copper Ore            66.0
# 16  Dark Chestnut Log           150.0
# 17      Darksteel Ore           666.0
# 21      Earth Cluster             9.0
# 38              Emery             6.0
# 10       Fire Cluster            69.0
# 18       Fire Crystal          3276.0
# 14         Fire Shard          2610.0
# 40       Gelato Flesh            36.0
# 1            Gold Ore           261.0
# 37        Grenade Ash           120.0
# 5        Hardened Sap           162.0
# 24    Hardsilver Sand           240.0
# 7         Ice Cluster            18.0
# 15          Ice Shard          1080.0
# 12           Iron Ore           522.0
# 13           Iron Ore           522.0
# 31        Mythril Ore           162.0
# 29       Mythrite Ore           648.0
# 30      Mythrite Sand           810.0
# 23        Native Gold            15.0
# 34        Peacock Ore           162.0
# 32       Platinum Ore            36.0
# 41      Pudding Flesh            24.0
# 8       Raw Celestine            27.0
# 26        Raw Larimar            36.0
# 39          Raw Topaz             6.0
# 22          Raziqsand            15.0
# 25         Silver Ore            48.0
# 36       Titanium Ore           600.0
# 20          Vivianite            27.0
# 42      Water Crystal            36.0
# 6        Wind Cluster           129.0
# 2        Wind Crystal           798.0
# 28         Wind Shard            60.0
#
#                                         Location Info
# 9        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 0                   The Sea of Clouds ( 34.8 / 30.5 )
# 27                  Northern Thanalan ( 22.4 / 24.4 )
# 3   Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 4   Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 35                 The Churning Mists ( 27.6 / 19.2 )
# 11                  Northern Thanalan ( 23.1 / 24.2 )
# 19       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 33                   Central Thanalan ( 19.0 / 26.2 )
# 16            The Dravanian Forelands ( 26.6 / 27.1 )
# 17  Coerthas Central Highlands ( 27.5 / 20.0 ), Ti...
# 21                                                NaN
# 38      Nowhere ( 0.0 / 0.0 ), Sold for 1500 GC Seals
# 10                                                NaN
# 18                                                NaN
# 14                                                NaN
# 40  Coerthas Western Highlands ( 9.4 / 18.8 ),  Dr...
# 1   Eastern Thanalan ( 27.3 / 21.3 ), Timed at 10:...
# 37  Nowhere ( 0.0 / 0.0 ), Purchased from Z'ranmai...
# 5        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 24                 The Churning Mists ( 15.9 / 28.5 )
# 7                                                 NaN
# 15                                                NaN
# 12                   Western Thanalan ( 27.2 / 17.4 )
# 13   Nowhere ( 0.0 / 0.0 ), Sold by Material Supplier
# 31                  Southern Thanalan ( 25.2 / 39.9 )
# 29         Coerthas Western Highlands ( 31.2 / 12.8 )
# 30         Coerthas Western Highlands ( 16.6 / 13.1 )
# 23  Central Thanalan ( 25.2 / 15.8 ), Timed at 4:0...
# 34       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 32  Southern Thanalan ( 16.7 / 10.7 ), Timed at 4:...
# 41       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 8   Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 26         Coerthas Western Highlands ( 31.3 / 12.6 )
# 39  Northern Thanalan ( 18.0 / 20.0 ), Timed at 3:...
# 22      Nowhere ( 0.0 / 0.0 ), Sold for 1500 GC Seals
# 25                       South Shroud ( 16.1 / 19.7 )
# 36            The Dravanian Forelands ( 30.3 / 15.1 )
# 20  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 42                                                NaN
# 6                                                 NaN
# 2                                                 NaN
# 28                                                NaN

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import get_crafting_recipes
data_dir = 'item_data/'
df_crafting_recipes = get_crafting_recipes(os.path.join(data_dir, 'total_coelacanth_class_sub_parts.csv'))
df_crafting_recipes
# Out:
#                  Product  Required Quantity                  2  3  \
# 0     Aurum Regis Nugget                 48   Aurum Regis Sand  5
# 1          Cassia Lumber                 18         Cassia Log  3
# 2              Celestine                  9      Raw Celestine  3
# 3     Cobalt Joint Plate                150       Cobalt Ingot  1
# 4           Cobalt Plate                 66       Cobalt Ingot  2
# 5          Cobalt Rivets                120       Cobalt Ingot  1
# 6   Dark Chestnut Lumber                 30  Dark Chestnut Log  5
# 7        Darksteel Ingot                 18   Darksteel Nugget  2
# 8       Darksteel Rivets                186   Darksteel Nugget  1
# 9          Garlond Steel                  9          Vivianite  3
# 10            Gold Ingot                 15          Raziqsand  1
# 11     Hardsilver Nugget                 48    Hardsilver Sand  5
# 12               Larimar                 12        Raw Larimar  3
# 13        Mythrite Ingot                162       Mythrite Ore  4
# 14       Platinum Nugget                 12       Platinum Ore  3
# 15       Rose Gold Ingot                 18   Rose Gold Nugget  2
# 16      Rose Gold Nugget                 30           Gold Ore  3
# 17        Titanium Ingot                120         Cloud Mica  4
# 18                 Topaz                  6              Emery  1
# 19             Void Glue                 12       Gelato Flesh  3
#
#                      4  5              6    7             8    9  \
# 0             Gold Ore  1   Wind Crystal  5.0          None  NaN
# 1         Hardened Sap  9   Wind Cluster  2.0   Ice Cluster  1.0
# 2    Aqueous Whetstone  9   Wind Cluster  1.0  Fire Cluster  1.0
# 3            Ice Shard  5           None  NaN          None  NaN
# 4            Ice Shard  5           None  NaN          None  NaN
# 5           Fire Shard  5           None  NaN          None  NaN
# 6         Wind Crystal  4           None  NaN          None  NaN
# 7                 Coke  9   Fire Cluster  1.0          None  NaN
# 8         Fire Crystal  3           None  NaN          None  NaN
# 9                 Coke  9     Cobalt Ore  3.0  Fire Cluster  1.0
# 10         Native Gold  1       Gold Ore  1.0  Wind Cluster  2.0
# 11          Silver Ore  1   Wind Crystal  4.0          None  NaN
# 12  Basilisk Whetstone  1   Wind Crystal  4.0          None  NaN
# 13     Mythrite Nugget  1   Fire Crystal  3.0          None  NaN
# 14        Wind Cluster  2   Fire Cluster  1.0          None  NaN
# 15         Peacock Ore  9   Wind Cluster  1.0          None  NaN
# 16          Copper Ore  1   Wind Crystal  3.0          None  NaN
# 17     Titanium Nugget  1   Fire Crystal  5.0          None  NaN
# 18           Raw Topaz  1   Wind Cluster  2.0  Fire Cluster  1.0
# 19       Pudding Flesh  2  Water Crystal  3.0          None  NaN
#
#                10   11
# 0            None  NaN
# 1            None  NaN
# 2            None  NaN
# 3            None  NaN
# 4            None  NaN
# 5            None  NaN
# 6            None  NaN
# 7            None  NaN
# 8            None  NaN
# 9   Earth Cluster  1.0
# 10   Fire Cluster  1.0
# 11           None  NaN
# 12           None  NaN
# 13           None  NaN
# 14           None  NaN
# 15           None  NaN
# 16           None  NaN
# 17           None  NaN
# 18           None  NaN
# 19           None  NaN

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import fetch_market_data_for_subparts
utils_dir = '../../utilities/'
data_dir = 'item_data/'
df_market_data = fetch_market_data_for_subparts(
    gathering_csv=os.path.join(data_dir, 'gathering_list.csv'),
    crafting_csv=os.path.join(utils_dir, 'recipe_book.csv'),
    item_ids_json=os.path.join(utils_dir, 'item_ids.json'),
    output_csv=os.path.join(data_dir, 'airship_parts_market_data.csv'),
    world="Seraph"
)
df_market_data
# Out:
#                         Item Name   Category Item ID minListing_world  \
# 0               Aqueous Whetstone  Gathering    5261              441
# 1                Aurum Regis Sand  Gathering   12533              270
# 2                    Basilisk Egg  Gathering    5263              485
# 3                      Cassia Log  Gathering   12221               22
# 5                      Cloud Mica  Gathering   12539              245
# ..                            ...        ...     ...              ...
# 142                  Cobalt Nails   Crafting    7020              250
# 143                  Cobalt Rings   Crafting    5084               37
# 144               Dhalmel Leather   Crafting   12564             5000
# 145  High Allagan Chimera Leather   Crafting   12233             1495
# 146            Amphiptere Leather   Crafting   12566              275
#
#     minListing_dc recentPurchase_world recentPurchase_dc averageSalePrice_dc  \
# 0             274                  449               350          285.684545
# 1             132                  200               450          218.789157
# 2              80                  495               500          222.127932
# 3              22                   70               216          102.521587
# 5             145                  200               190           162.83871
# ..            ...                  ...               ...                 ...
# 142            20                   90               800                None
# 143            37                  155               730          469.888889
# 144          2999                 4123              3000         2780.477273
# 145           493                 2000              1000          713.727273
# 146            50                  323               500          328.926471
#
#     dailySaleVelocity_dc
# 0            2548.013635
# 1              128.17253
# 2             120.708411
# 3             220.569055
# 5             183.506881
# ..                   ...
# 142                 None
# 143             4.631325
# 144            56.604955
# 145             2.830242
# 146            17.496001
#
# [144 rows x 9 columns]
