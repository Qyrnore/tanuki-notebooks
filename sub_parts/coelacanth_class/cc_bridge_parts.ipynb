# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import generate_gathering_list
utils_dir = '../../utilities/'
data_dir = 'item_data/'
df_gathering_list = generate_gathering_list(
    total_csv=os.path.join(data_dir, 'coelacanth_class_bridge_parts.csv'),
    recipe_book_csv=os.path.join(utils_dir, 'recipe_book.csv'),
    recipe_gathering_csv=os.path.join(utils_dir, 'recipe_gathering.csv'),
    output_csv=os.path.join(data_dir, 'gathering_list.csv')
)
df_gathering_list
# Out:
#        Ingredient  Total Quantity  \
# 24   Basilisk Egg            12.0
# 20     Cassia Log            27.0
# 19     Cassia Log            27.0
# 15     Cloud Mica           120.0
# 0      Cobalt Ore           192.0
# 13     Copper Ore            30.0
# 11  Darksteel Ore           108.0
# 26          Emery             6.0
# 6    Fire Cluster            18.0
# 10   Fire Crystal           774.0
# 3      Fire Shard           630.0
# 12       Gold Ore            90.0
# 17    Grenade Ash            30.0
# 21   Hardened Sap            81.0
# 22    Ice Cluster             9.0
# 18      Ice Shard           240.0
# 2        Iron Ore           126.0
# 1        Iron Ore           126.0
# 9     Mythril Ore            48.0
# 7    Mythrite Ore           192.0
# 8   Mythrite Sand           240.0
# 4    Platinum Ore            36.0
# 23    Raw Larimar            36.0
# 27      Raw Topaz             6.0
# 16   Titanium Ore           150.0
# 5    Wind Cluster            54.0
# 14   Wind Crystal           138.0
# 25     Wind Shard            60.0
#
#                                         Location Info
# 24                  Northern Thanalan ( 22.4 / 24.4 )
# 20  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 19  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 15                 The Churning Mists ( 27.6 / 19.2 )
# 0                   Northern Thanalan ( 23.1 / 24.2 )
# 13                   Central Thanalan ( 19.0 / 26.2 )
# 11  Coerthas Central Highlands ( 27.5 / 20.0 ), Ti...
# 26      Nowhere ( 0.0 / 0.0 ), Sold for 1500 GC Seals
# 6                                                 NaN
# 10                                                NaN
# 3                                                 NaN
# 12  Eastern Thanalan ( 27.3 / 21.3 ), Timed at 10:...
# 17  Nowhere ( 0.0 / 0.0 ), Purchased from Z'ranmai...
# 21       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 22                                                NaN
# 18                                                NaN
# 2    Nowhere ( 0.0 / 0.0 ), Sold by Material Supplier
# 1                    Western Thanalan ( 27.2 / 17.4 )
# 9                   Southern Thanalan ( 25.2 / 39.9 )
# 7          Coerthas Western Highlands ( 31.2 / 12.8 )
# 8          Coerthas Western Highlands ( 16.6 / 13.1 )
# 4   Southern Thanalan ( 16.7 / 10.7 ), Timed at 4:...
# 23         Coerthas Western Highlands ( 31.3 / 12.6 )
# 27  Northern Thanalan ( 18.0 / 20.0 ), Timed at 3:...
# 16            The Dravanian Forelands ( 30.3 / 15.1 )
# 5                                                 NaN
# 14                                                NaN
# 25                                                NaN

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import get_crafting_recipes
data_dir = 'item_data/'
df_crafting_recipes = get_crafting_recipes(os.path.join(data_dir, 'coelacanth_class_bridge_parts.csv'))
df_crafting_recipes
# Out:
#                Product  Required Quantity
# 7        Cassia Lumber                  9
# 6   Cobalt Joint Plate                 30
# 8         Cobalt Plate                 18
# 0        Cobalt Rivets                 30
# 3     Darksteel Rivets                 36
# 9              Larimar                 12
# 2       Mythrite Ingot                 48
# 1      Platinum Nugget                 12
# 4     Rose Gold Nugget                 30
# 5       Titanium Ingot                 30
# 10               Topaz                  6
