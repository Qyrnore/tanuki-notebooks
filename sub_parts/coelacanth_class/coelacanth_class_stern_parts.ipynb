# %%
from coelacanth_class_sub_parts import generate_gathering_list

# Generate the gathering list and save to 'gathering_list.csv'
df_gathering_list = generate_gathering_list(
    total_csv='coelacanth_class_stern_parts.csv',
    recipe_book_csv='recipe_book.csv',
    recipe_gathering_csv='recipe_gathering.csv',
    output_csv='gathering_list.csv'
)

df_gathering_list  # Display the gathering list
# Out:
#            Ingredient  Total Quantity  \
# 5   Aqueous Whetstone            81.0
# 23   Aurum Regis Sand           150.0
# 16         Cloud Mica           120.0
# 0          Cobalt Ore           120.0
# 12      Darksteel Ore           180.0
# 7        Fire Cluster            24.0
# 11       Fire Crystal           918.0
# 3          Fire Shard           450.0
# 15           Gold Ore            45.0
# 18        Grenade Ash            30.0
# 20    Hardsilver Sand           150.0
# 19          Ice Shard           150.0
# 2            Iron Ore            90.0
# 1            Iron Ore            90.0
# 10        Mythril Ore            48.0
# 8        Mythrite Ore           192.0
# 9       Mythrite Sand           240.0
# 14        Native Gold            15.0
# 4       Raw Celestine            27.0
# 13          Raziqsand            15.0
# 21         Silver Ore            30.0
# 17       Titanium Ore           150.0
# 6        Wind Cluster            39.0
# 22       Wind Crystal           270.0
#
#                                         Location Info
# 5        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 23                  The Sea of Clouds ( 34.8 / 30.5 )
# 16                 The Churning Mists ( 27.6 / 19.2 )
# 0                   Northern Thanalan ( 23.1 / 24.2 )
# 12  Coerthas Central Highlands ( 27.5 / 20.0 ), Ti...
# 7                                                 NaN
# 11                                                NaN
# 3                                                 NaN
# 15  Eastern Thanalan ( 27.3 / 21.3 ), Timed at 10:...
# 18  Nowhere ( 0.0 / 0.0 ), Purchased from Z'ranmai...
# 20                 The Churning Mists ( 15.9 / 28.5 )
# 19                                                NaN
# 2    Nowhere ( 0.0 / 0.0 ), Sold by Material Supplier
# 1                    Western Thanalan ( 27.2 / 17.4 )
# 10                  Southern Thanalan ( 25.2 / 39.9 )
# 8          Coerthas Western Highlands ( 31.2 / 12.8 )
# 9          Coerthas Western Highlands ( 16.6 / 13.1 )
# 14  Central Thanalan ( 25.2 / 15.8 ), Timed at 4:0...
# 4   Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 13      Nowhere ( 0.0 / 0.0 ), Sold for 1500 GC Seals
# 21                       South Shroud ( 16.1 / 19.7 )
# 17            The Dravanian Forelands ( 30.3 / 15.1 )
# 6                                                 NaN
# 22                                                NaN

# %%
from coelacanth_class_sub_parts import get_crafting_recipes

# Get the crafting recipes from total_coelacanth_class_sub_parts.csv
df_crafting_recipes = get_crafting_recipes('coelacanth_class_stern_parts.csv')
df_crafting_recipes  # Display the crafting recipes list
# Out:
#               Product  Required Quantity
# 8  Aurum Regis Nugget                 30
# 1           Celestine                  9
# 6  Cobalt Joint Plate                 30
# 0       Cobalt Rivets                 30
# 3    Darksteel Rivets                 60
# 4          Gold Ingot                 15
# 7   Hardsilver Nugget                 30
# 2      Mythrite Ingot                 48
# 5      Titanium Ingot                 30
