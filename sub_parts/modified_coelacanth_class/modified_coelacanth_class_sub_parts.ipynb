# %%
from modified_coelacanth_class_sub_parts import generate_gathering_list

# Generate the gathering list and save to 'gathering_list.csv'
df_gathering_list = generate_gathering_list(
    total_csv='total_modified_coelacanth_class_sub_parts.csv',
    recipe_book_csv='recipe_book.csv',
    recipe_gathering_csv='recipe_gathering.csv',
    output_csv='gathering_list.csv'
)

df_gathering_list  # Display the gathering list
# Out:
#                         Ingredient  Total Quantity  \
# 43                    Ahriman Wing            24.0
# 0                 Aurum Regis Sand           240.0
# 3                       Cassia Log            54.0
# 4                       Cassia Log            54.0
# 25                      Cobalt Ore           174.0
# 8             Coelacanth-Class Bow             1.0
# 9          Coelacanth-Class Bridge             1.0
# 10  Coelacanth-Class Pressure Hull             1.0
# 11          Coelacanth-Class Stern             1.0
# 26                            Coke           648.0
# 32                      Copper Ore            36.0
# 12                 Cryptomeria Log           108.0
# 20                  Dhalmel Saliva           168.0
# 21          Dravanian Spring Water            72.0
# 27                   Earth Cluster           180.0
# 38                   Earth Crystal           216.0
# 14                     Eikon Metal            30.0
# 28                  Eikon Mythrite            96.0
# 45                       Ferberite            12.0
# 18                    Fire Cluster           270.0
# 34                    Fire Crystal          1044.0
# 1                         Gold Ore            48.0
# 5                     Hardened Sap           486.0
# 19                 Hardsilver Sand           288.0
# 7                      Ice Cluster            18.0
# 13                     Ice Crystal           594.0
# 16                        Iron Ore            45.0
# 17                        Iron Ore            45.0
# 31               Koppranickel Sand           144.0
# 29                  Lumythrite Ore           144.0
# 33                  Molybdenum Ore           360.0
# 36                     Mythril Ore           126.0
# 30                    Mythrite Ore            96.0
# 35                   Mythrite Sand           630.0
# 37               Pure Titanium Ore           108.0
# 39                   Raw Rhodonite           135.0
# 41                    Raw Triphane            18.0
# 44                       Scheelite            12.0
# 15                 Smithsonite Ore            45.0
# 24                      Sphalerite            72.0
# 40                     Stiperstone            51.0
# 23                       Vivianite           108.0
# 22                   Water Crystal           336.0
# 6                     Wind Cluster            81.0
# 2                     Wind Crystal           852.0
# 42                     Wyvern Wing            36.0
#
#                                         Location Info
# 43  Northern Thanalan ( 24 / 21 ), Dropped by vari...
# 0                   The Sea of Clouds ( 34.8 / 30.5 )
# 3   Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 4   Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 25                  Northern Thanalan ( 23.1 / 24.2 )
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 26       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 32                   Central Thanalan ( 19.0 / 26.2 )
# 12  Nowhere ( 0.0 / 0.0 ), Collected from Submarin...
# 20  The Sea of Clouds ( 17.3 / 32.2 ), Dropped by ...
# 21            The Dravanian Forelands ( 27.4 / 31.8 )
# 27                                                NaN
# 38                                                NaN
# 14          Idyllshire ( 5.7 / 5.2 ), Sold by Hismena
# 28    Nowhere ( 0.0 / 0.0 ), Sold by Spoils Collector
# 45  Northern Thanalan ( 17.3 / 19.9 ), Timed at 3:...
# 18                                                NaN
# 34                                                NaN
# 1   Eastern Thanalan ( 27.3 / 21.3 ), Timed at 10:...
# 5        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 19                 The Churning Mists ( 15.9 / 28.5 )
# 7                                                 NaN
# 13                                                NaN
# 16                   Western Thanalan ( 27.2 / 17.4 )
# 17   Nowhere ( 0.0 / 0.0 ), Sold by Material Supplier
# 31                          The Peaks ( 23.3 / 13.1 )
# 29  The Churning Mists ( 9.3 / 38.5 ), Timed at 2A...
# 33                          The Lochs ( 11.4 / 16.6 )
# 36                  Southern Thanalan ( 25.2 / 39.9 )
# 30         Coerthas Western Highlands ( 31.2 / 12.8 )
# 35         Coerthas Western Highlands ( 16.6 / 13.1 )
# 37  Nowhere ( 0.0 / 0.0 ), Collected from Submarin...
# 39      The Peaks ( 26.9 / 12.5 ), Timed at 8AM/PM ET
# 41        The Fringes ( 25.2 / 8.3 ), Timed at 2AM/PM
# 44      Nowhere ( 0.0 / 0.0 ), Sold for 1500 GC Seals
# 15  The Sea of Clouds ( 37.5 / 14.5 ), Timed at 8A...
# 24     Nowhere ( 0.0 / 0.0 ), Sold by NPCs for Scrips
# 40                          The Peaks ( 23.3 / 13.1 )
# 23  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 22                                                NaN
# 6                                                 NaN
# 2                                                 NaN
# 42  The Churning Mists ( 24 / 28 ), Dropped by var...

# %%
from modified_coelacanth_class_sub_parts import get_crafting_recipes

# Get the crafting recipes from total_modified_coelacanth_class_sub_parts.csv
df_crafting_recipes = get_crafting_recipes('total_modified_coelacanth_class_sub_parts.csv')
df_crafting_recipes  # Display the crafting recipes list
# Out:
#                            Product  Required Quantity                  2    3  \
# 0               Aurum Regis Nugget                 48   Aurum Regis Sand  5.0
# 1                    Cassia Lumber                 18         Cassia Log  3.0
# 2             Coelacanth-Class Bow                  1               None  NaN
# 3          Coelacanth-Class Bridge                  1               None  NaN
# 4   Coelacanth-Class Pressure Hull                  1               None  NaN
# 5           Coelacanth-Class Stern                  1               None  NaN
# 6               Cryptomeria Lumber                 36    Cryptomeria Log  3.0
# 7                 Eikon Iron Ingot                 15        Eikon Metal  2.0
# 8         Enchanted Hardsilver Ink                 72    Hardsilver Sand  4.0
# 9         Galvanized Garlond Steel                 36          Vivianite  3.0
# 10             High Mythrite Ingot                 48     Eikon Mythrite  2.0
# 11             Koppranickel Nugget                 36  Koppranickel Sand  4.0
# 12                Molybdenum Ingot                 90     Molybdenum Ore  4.0
# 13                 Mythrite Rivets                126      Mythril Ingot  1.0
# 14             Pure Titanium Plate                 36  Pure Titanium Ore  3.0
# 15                       Rhodonite                 45      Raw Rhodonite  3.0
# 16                        Triphane                  6       Raw Triphane  3.0
# 17                       Wing Glue                 12        Wyvern Wing  3.0
# 18                   Wolfram Ingot                 12          Scheelite  1.0
#
#                   4    5                       6    7              8    9  \
# 0          Gold Ore  1.0            Wind Crystal  5.0           None  NaN
# 1      Hardened Sap  9.0            Wind Cluster  2.0    Ice Cluster  1.0
# 2              None  NaN                    None  NaN           None  NaN
# 3              None  NaN                    None  NaN           None  NaN
# 4              None  NaN                    None  NaN           None  NaN
# 5              None  NaN                    None  NaN           None  NaN
# 6      Hardened Sap  9.0            Wind Crystal  6.0    Ice Crystal  6.0
# 7   Smithsonite Ore  3.0                Iron Ore  3.0   Wind Cluster  3.0
# 8    Dhalmel Saliva  2.0  Dravanian Spring Water  1.0  Water Crystal  4.0
# 9        Sphalerite  2.0              Cobalt Ore  2.0           Coke  9.0
# 10   Lumythrite Ore  3.0            Mythrite Ore  2.0   Fire Cluster  3.0
# 11       Copper Ore  1.0            Wind Crystal  3.0           None  NaN
# 12       Cobalt Ore  1.0            Fire Crystal  5.0           None  NaN
# 13       Fire Shard  5.0                    None  NaN           None  NaN
# 14             Coke  9.0            Fire Crystal  6.0  Earth Crystal  6.0
# 15      Stiperstone  1.0            Wind Crystal  6.0           None  NaN
# 16      Stiperstone  1.0            Wind Crystal  3.0           None  NaN
# 17     Ahriman Wing  2.0          Dhalmel Saliva  2.0  Water Crystal  4.0
# 18        Ferberite  1.0              Cobalt Ore  1.0   Fire Cluster  2.0
#
#                10   11             12   13
# 0            None  NaN           None  NaN
# 1            None  NaN           None  NaN
# 2            None  NaN           None  NaN
# 3            None  NaN           None  NaN
# 4            None  NaN           None  NaN
# 5            None  NaN           None  NaN
# 6            None  NaN           None  NaN
# 7    Fire Cluster  2.0           None  NaN
# 8            None  NaN           None  NaN
# 9    Fire Cluster  2.0  Earth Cluster  2.0
# 10  Earth Cluster  2.0           None  NaN
# 11           None  NaN           None  NaN
# 12           None  NaN           None  NaN
# 13           None  NaN           None  NaN
# 14           None  NaN           None  NaN
# 15           None  NaN           None  NaN
# 16           None  NaN           None  NaN
# 17           None  NaN           None  NaN
# 18  Earth Cluster  1.0           None  NaN

# %%
from modified_coelacanth_class_sub_parts import fetch_market_data_for_subparts

# Combine items from the gathering list (from 'gathering_list.csv') and the crafting recipes (from 'recipe_book.csv'),
# fetch market data from the Universalis API, and save the results to 'sub_parts_market_data.csv'.
df_market_data = fetch_market_data_for_subparts(
    gathering_csv='gathering_list.csv',
    crafting_csv='recipe_book.csv', 
    item_ids_json='item_ids.json',
    output_csv='sub_parts_market_data.csv',
    world="Seraph"
)

df_market_data  # Display the market data for sub parts
# Out:
#                 Item Name   Category Item ID minListing_world minListing_dc  \
# 0            Ahriman Wing  Gathering    5553              897            89
# 1        Aurum Regis Sand  Gathering   12533              270           132
# 2              Cassia Log  Gathering   12221               22            22
# 4              Cobalt Ore  Gathering    5116              200           200
# 5    Coelacanth-Class Bow  Gathering   23903             None       1499990
# ..                    ...        ...     ...              ...           ...
# 136          Beech Lumber   Crafting   19925              375             9
# 137      Eikon Iron Ingot   Crafting   14149              750           647
# 138   Koppranickel Nugget   Crafting   19938              579           150
# 139      Molybdenum Ingot   Crafting   19947              600           600
# 140              Triphane   Crafting   19962              200           200
#
#     recentPurchase_world recentPurchase_dc averageSalePrice_dc  \
# 0                    800               400          499.348571
# 1                    200               450          213.622764
# 2                     70               216           94.065175
# 4                    200               292          289.355514
# 5                1500000           1500000                None
# ..                   ...               ...                 ...
# 136                  399               949         1097.819231
# 137                 2099              2099                1637
# 138                  320               795          929.007117
# 139                  900               850          949.912844
# 140                  585               900          552.068493
#
#     dailySaleVelocity_dc
# 0              93.931332
# 1             165.050394
# 2             275.888485
# 4           12212.594777
# 5                   None
# ..                   ...
# 136            69.756171
# 137            19.585337
# 138            75.389964
# 139           116.974918
# 140            19.585207
#
# [138 rows x 9 columns]
