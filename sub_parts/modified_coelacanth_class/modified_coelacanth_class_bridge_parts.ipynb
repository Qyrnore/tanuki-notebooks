# %%
from modified_coelacanth_class_sub_parts import generate_gathering_list

# Generate the gathering list and save to 'gathering_list.csv'
df_gathering_list = generate_gathering_list(
    total_csv='modified_coelacanth_class_bridge_parts.csv',
    recipe_book_csv='recipe_book.csv',
    recipe_gathering_csv='recipe_gathering.csv',
    output_csv='gathering_list.csv'
)

df_gathering_list  # Display the gathering list
# Out:
#                  Ingredient  Total Quantity  \
# 12               Cassia Log            27.0
# 11               Cassia Log            27.0
# 3                Cobalt Ore            48.0
# 0   Coelacanth-Class Bridge             1.0
# 4                      Coke           162.0
# 7           Cryptomeria Log            27.0
# 28           Dhalmel Saliva            36.0
# 29   Dravanian Spring Water            18.0
# 6             Earth Cluster            54.0
# 22            Earth Crystal            54.0
# 15           Eikon Mythrite            36.0
# 5              Fire Cluster            72.0
# 20             Fire Crystal           258.0
# 8              Hardened Sap           162.0
# 27          Hardsilver Sand            72.0
# 14              Ice Cluster             9.0
# 10              Ice Crystal           108.0
# 16           Lumythrite Ore            54.0
# 23           Molybdenum Ore           120.0
# 19              Mythril Ore            18.0
# 17             Mythrite Ore            36.0
# 18            Mythrite Sand            90.0
# 21        Pure Titanium Ore            27.0
# 26            Raw Rhodonite            18.0
# 24             Raw Triphane            18.0
# 2                Sphalerite            18.0
# 25              Stiperstone            12.0
# 1                 Vivianite            27.0
# 30            Water Crystal            72.0
# 13             Wind Cluster            18.0
# 9              Wind Crystal           108.0
#
#                                         Location Info
# 12  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 11  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 3                   Northern Thanalan ( 23.1 / 24.2 )
# 0                                                 NaN
# 4        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 7   Nowhere ( 0.0 / 0.0 ), Collected from Submarin...
# 28  The Sea of Clouds ( 17.3 / 32.2 ), Dropped by ...
# 29            The Dravanian Forelands ( 27.4 / 31.8 )
# 6                                                 NaN
# 22                                                NaN
# 15    Nowhere ( 0.0 / 0.0 ), Sold by Spoils Collector
# 5                                                 NaN
# 20                                                NaN
# 8        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 27                 The Churning Mists ( 15.9 / 28.5 )
# 14                                                NaN
# 10                                                NaN
# 16  The Churning Mists ( 9.3 / 38.5 ), Timed at 2A...
# 23                          The Lochs ( 11.4 / 16.6 )
# 19                  Southern Thanalan ( 25.2 / 39.9 )
# 17         Coerthas Western Highlands ( 31.2 / 12.8 )
# 18         Coerthas Western Highlands ( 16.6 / 13.1 )
# 21  Nowhere ( 0.0 / 0.0 ), Collected from Submarin...
# 26      The Peaks ( 26.9 / 12.5 ), Timed at 8AM/PM ET
# 24        The Fringes ( 25.2 / 8.3 ), Timed at 2AM/PM
# 2      Nowhere ( 0.0 / 0.0 ), Sold by NPCs for Scrips
# 25                          The Peaks ( 23.3 / 13.1 )
# 1   Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 30                                                NaN
# 13                                                NaN
# 9                                                 NaN

# %%
from modified_coelacanth_class_sub_parts import get_crafting_recipes

# Get the crafting recipes from total_modified_coelacanth_class_sub_parts.csv
df_crafting_recipes = get_crafting_recipes('modified_coelacanth_class_bridge_parts.csv')
df_crafting_recipes  # Display the crafting recipes list
# Out:
#                      Product  Required Quantity
# 3              Cassia Lumber                  9
# 0    Coelacanth-Class Bridge                  1
# 2         Cryptomeria Lumber                  9
# 11  Enchanted Hardsilver Ink                 18
# 1   Galvanized Garlond Steel                  9
# 4        High Mythrite Ingot                 18
# 7           Molybdenum Ingot                 30
# 5            Mythrite Rivets                 18
# 8            Mythrite Rivets                 18
# 6        Pure Titanium Plate                  9
# 10                 Rhodonite                  6
# 9                   Triphane                  6
