# %%
from modified_coelacanth_class_sub_parts import generate_gathering_list

# Generate the gathering list and save to 'gathering_list.csv'
df_gathering_list = generate_gathering_list(
    total_csv='modified_coelacanth_class_stern_parts.csv',
    recipe_book_csv='recipe_book.csv',
    recipe_gathering_csv='recipe_gathering.csv',
    output_csv='gathering_list.csv'
)

df_gathering_list  # Display the gathering list
# Out:
#                 Ingredient  Total Quantity  \
# 20        Aurum Regis Sand           150.0
# 3               Cobalt Ore            48.0
# 0   Coelacanth-Class Stern             1.0
# 4                     Coke           162.0
# 15              Copper Ore            36.0
# 7          Cryptomeria Log            27.0
# 30          Dhalmel Saliva            36.0
# 31  Dravanian Spring Water            18.0
# 6            Earth Cluster            42.0
# 18           Earth Crystal            54.0
# 22             Eikon Metal            30.0
# 11          Eikon Mythrite            24.0
# 5             Fire Cluster            84.0
# 17            Fire Crystal           204.0
# 21                Gold Ore            30.0
# 8             Hardened Sap            81.0
# 29         Hardsilver Sand            72.0
# 10             Ice Crystal            54.0
# 25                Iron Ore            45.0
# 24                Iron Ore            45.0
# 14       Koppranickel Sand           144.0
# 12          Lumythrite Ore            36.0
# 19          Molybdenum Ore           120.0
# 13            Mythrite Ore            24.0
# 16       Pure Titanium Ore            27.0
# 27           Raw Rhodonite            36.0
# 23         Smithsonite Ore            45.0
# 2               Sphalerite            18.0
# 28             Stiperstone            12.0
# 1                Vivianite            27.0
# 32           Water Crystal            72.0
# 26            Wind Cluster            45.0
# 9             Wind Crystal           384.0
#
#                                         Location Info
# 20                  The Sea of Clouds ( 34.8 / 30.5 )
# 3                   Northern Thanalan ( 23.1 / 24.2 )
# 0                                                 NaN
# 4        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 15                   Central Thanalan ( 19.0 / 26.2 )
# 7   Nowhere ( 0.0 / 0.0 ), Collected from Submarin...
# 30  The Sea of Clouds ( 17.3 / 32.2 ), Dropped by ...
# 31            The Dravanian Forelands ( 27.4 / 31.8 )
# 6                                                 NaN
# 18                                                NaN
# 22          Idyllshire ( 5.7 / 5.2 ), Sold by Hismena
# 11    Nowhere ( 0.0 / 0.0 ), Sold by Spoils Collector
# 5                                                 NaN
# 17                                                NaN
# 21  Eastern Thanalan ( 27.3 / 21.3 ), Timed at 10:...
# 8        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 29                 The Churning Mists ( 15.9 / 28.5 )
# 10                                                NaN
# 25   Nowhere ( 0.0 / 0.0 ), Sold by Material Supplier
# 24                   Western Thanalan ( 27.2 / 17.4 )
# 14                          The Peaks ( 23.3 / 13.1 )
# 12  The Churning Mists ( 9.3 / 38.5 ), Timed at 2A...
# 19                          The Lochs ( 11.4 / 16.6 )
# 13         Coerthas Western Highlands ( 31.2 / 12.8 )
# 16  Nowhere ( 0.0 / 0.0 ), Collected from Submarin...
# 27      The Peaks ( 26.9 / 12.5 ), Timed at 8AM/PM ET
# 23  The Sea of Clouds ( 37.5 / 14.5 ), Timed at 8A...
# 2      Nowhere ( 0.0 / 0.0 ), Sold by NPCs for Scrips
# 28                          The Peaks ( 23.3 / 13.1 )
# 1   Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 32                                                NaN
# 26                                                NaN
# 9                                                 NaN

# %%
from modified_coelacanth_class_sub_parts import get_crafting_recipes

# Get the crafting recipes from total_modified_coelacanth_class_sub_parts.csv
df_crafting_recipes = get_crafting_recipes('modified_coelacanth_class_stern_parts.csv')
df_crafting_recipes  # Display the crafting recipes list
# Out:
#                      Product  Required Quantity
# 7         Aurum Regis Nugget                 30
# 0     Coelacanth-Class Stern                  1
# 2         Cryptomeria Lumber                  9
# 8           Eikon Iron Ingot                 15
# 10  Enchanted Hardsilver Ink                 18
# 1   Galvanized Garlond Steel                  9
# 3        High Mythrite Ingot                 12
# 4        Koppranickel Nugget                 36
# 6           Molybdenum Ingot                 30
# 5        Pure Titanium Plate                  9
# 9                  Rhodonite                 12
