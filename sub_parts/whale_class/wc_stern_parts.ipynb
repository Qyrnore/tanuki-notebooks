# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import generate_gathering_list
utils_dir = '../../utilities/'
data_dir = 'item_data/'
df_gathering_list = generate_gathering_list(
    total_csv=os.path.join(data_dir, 'whale_class_stern_parts.csv'),
    recipe_book_csv=os.path.join(utils_dir, 'recipe_book.csv'),
    recipe_gathering_csv=os.path.join(utils_dir, 'recipe_gathering.csv'),
    output_csv=os.path.join(data_dir, 'gathering_list.csv')
)
df_gathering_list
# Out:
#            Ingredient  Total Quantity  \
# 19  Aqueous Whetstone            81.0
# 4            Bomb Ash            90.0
# 11         Cobalt Ore            87.0
# 12               Coke           351.0
# 8       Darksteel Ore           306.0
# 15      Earth Cluster             9.0
# 13       Fire Cluster            48.0
# 9        Fire Crystal           414.0
# 7          Fire Shard           900.0
# 3         Ice Cluster            12.0
# 6            Iron Ore           210.0
# 5            Iron Ore           210.0
# 10        Mythril Ore           102.0
# 16       Mythrite Ore            48.0
# 17      Mythrite Sand            60.0
# 0       Petrified Log            12.0
# 18      Raw Celestine            27.0
# 1         Scarlet Sap            12.0
# 14          Vivianite            27.0
# 2        Wind Cluster            33.0
#
#                                         Location Info
# 19       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 4                   Southern Thanalan ( 22.2 / 29.9 )
# 11                  Northern Thanalan ( 23.1 / 24.2 )
# 12       Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 8   Coerthas Central Highlands ( 27.5 / 20.0 ), Ti...
# 15                                                NaN
# 13                                                NaN
# 9                                                 NaN
# 7                                                 NaN
# 3                                                 NaN
# 6    Nowhere ( 0.0 / 0.0 ), Sold by Material Supplier
# 5                    Western Thanalan ( 27.2 / 17.4 )
# 10                  Southern Thanalan ( 25.2 / 39.9 )
# 16         Coerthas Western Highlands ( 31.2 / 12.8 )
# 17         Coerthas Western Highlands ( 16.6 / 13.1 )
# 0       Nowhere ( 0.0 / 0.0 ), Sold for 1500 GC Seals
# 18  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 1       North Shroud ( 17.7 / 27.7 ), Timed at 1:00am
# 14  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 2                                                 NaN

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import get_crafting_recipes
data_dir = 'item_data/'
df_crafting_recipes = get_crafting_recipes(os.path.join(data_dir, 'whale_class_stern_parts.csv'))
df_crafting_recipes
# Out:
#              Product  Required Quantity
# 0     Ancient Lumber                 12
# 10         Celestine                  9
# 6      Cobalt Rivets                 30
# 7    Darksteel Ingot                 30
# 2   Darksteel Nugget                 30
# 11  Darksteel Rivets                 12
# 8      Garlond Steel                  9
# 3     Mythril Rivets                 30
# 9     Mythrite Ingot                 12
# 4        Steel Ingot                 30
# 1        Steel Nails                 30
# 5       Steel Rivets                 30
