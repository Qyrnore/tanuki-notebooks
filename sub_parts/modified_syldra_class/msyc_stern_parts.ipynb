# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import generate_gathering_list
utils_dir = '../../utilities/'
data_dir = 'item_data/'
df_gathering_list = generate_gathering_list(
    total_csv=os.path.join(data_dir, 'modified_syldra_class_stern_parts.csv'),
    recipe_book_csv=os.path.join(utils_dir, 'recipe_book.csv'),
    recipe_gathering_csv=os.path.join(utils_dir, 'recipe_gathering.csv'),
    output_csv=os.path.join(data_dir, 'gathering_list.csv')
)
df_gathering_list
# Out:
#                 Ingredient  Total Quantity  \
# 24          Adamantite Ore            75.0
# 30          Astral Moraine            12.0
# 11         Aurum Regis Ore            36.0
# 12        Aurum Regis Sand            90.0
# 31                Bear Fat             6.0
# 26              Cassia Log            18.0
# 27              Cassia Log            18.0
# 3               Cobalt Ore            18.0
# 4                     Coke           162.0
# 21              Copper Ore            18.0
# 7          Cryptomeria Log            27.0
# 25           Darksteel Ore            15.0
# 34    Dawnborne Aethersand             6.0
# 38          Dhalmel Saliva            36.0
# 39  Dravanian Spring Water            18.0
# 6            Earth Cluster            18.0
# 23           Earth Crystal            54.0
# 5             Fire Cluster            54.0
# 19            Fire Crystal            99.0
# 13                Gold Ore            18.0
# 8             Hardened Sap           135.0
# 37         Hardsilver Sand            72.0
# 28             Ice Cluster            12.0
# 10             Ice Crystal            99.0
# 20       Koppranickel Sand            72.0
# 33       Lightning Cluster             6.0
# 18             Mythril Ore            15.0
# 17           Mythrite Sand            75.0
# 22       Pure Titanium Ore            27.0
# 35           Raw Rhodonite            36.0
# 15               Raziqcoat            90.0
# 29          Seventh Heaven            12.0
# 2               Sphalerite            18.0
# 36             Stiperstone            12.0
# 0       Syldra-Class Stern             1.0
# 14           Violet Quartz            18.0
# 1                Vivianite            27.0
# 32           Water Cluster            12.0
# 40           Water Crystal            72.0
# 16            Wind Cluster            60.0
# 9             Wind Crystal           270.0
#
#                                         Location Info
# 24       Azys Lla ( 23.2 / 5.8 ), Timed at 12AM/PM ET
# 30  Coerthas Western Highlands ( 37.2 / 16.4 ), Ti...
# 11  The Churning Mists ( 9.3 / 38.5 ), Timed at 2A...
# 12                  The Sea of Clouds ( 34.8 / 30.5 )
# 31  The Dravanian Hinterlands ( 4.7 / 27.8 ), Drop...
# 26  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 27  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 3                   Northern Thanalan ( 23.1 / 24.2 )
# 4        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 21                   Central Thanalan ( 19.0 / 26.2 )
# 7   Nowhere ( 0.0 / 0.0 ), Collected from Submarin...
# 25  Coerthas Central Highlands ( 27.5 / 20.0 ), Ti...
# 34  Nowhere ( 0.0 / 0.0 ), Aetherial Reduction fro...
# 38  The Sea of Clouds ( 17.3 / 32.2 ), Dropped by ...
# 39            The Dravanian Forelands ( 27.4 / 31.8 )
# 6                                                 NaN
# 23                                                NaN
# 5                                                 NaN
# 19                                                NaN
# 13  Eastern Thanalan ( 27.3 / 21.3 ), Timed at 10:...
# 8        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 37                 The Churning Mists ( 15.9 / 28.5 )
# 28                                                NaN
# 10                                                NaN
# 20                          The Peaks ( 23.3 / 13.1 )
# 33                                                NaN
# 18                  Southern Thanalan ( 25.2 / 39.9 )
# 17         Coerthas Western Highlands ( 16.6 / 13.1 )
# 22  Nowhere ( 0.0 / 0.0 ), Collected from Submarin...
# 35      The Peaks ( 26.9 / 12.5 ), Timed at 8AM/PM ET
# 15  Nowhere ( 0.0 / 0.0 ), Sold by Scrip Exchange ...
# 29  The Churning Mists ( 16.7 / 36.8 ), Timed at 4...
# 2      Nowhere ( 0.0 / 0.0 ), Sold by NPCs for Scrips
# 36                          The Peaks ( 23.3 / 13.1 )
# 0                                                 NaN
# 14  Coerthas Western Highlands ( 37.3 / 18.7 ), Ti...
# 1   Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 32                                                NaN
# 40                                                NaN
# 16                                                NaN
# 9                                                 NaN

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import get_crafting_recipes
data_dir = 'item_data/'
df_crafting_recipes = get_crafting_recipes(os.path.join(data_dir, 'modified_syldra_class_stern_parts.csv'))
df_crafting_recipes
# Out:
#                      Product  Required Quantity
# 7          Adamantite Nugget                 15
# 3          Aurum Regis Ingot                 18
# 8               Cassia Block                  6
# 2         Cryptomeria Lumber                  9
# 10  Enchanted Hardsilver Ink                 18
# 1   Galvanized Garlond Steel                  9
# 5        Koppranickel Nugget                 18
# 4            Mythrite Rivets                 15
# 6        Pure Titanium Plate                  9
# 9                  Rhodonite                 12
# 0         Syldra-Class Stern                  1
