# %%
from modified_syldra_class_sub_parts import generate_gathering_list

# Generate the gathering list and save to 'gathering_list.csv'
df_gathering_list = generate_gathering_list(
    total_csv='modified_syldra_class_bow_parts.csv',
    recipe_book_csv='recipe_book.csv',
    recipe_gathering_csv='recipe_gathering.csv',
    output_csv='gathering_list.csv'
)

df_gathering_list  # Display the gathering list
# Out:
#                 Ingredient  Total Quantity  \
# 21          Adamantite Ore           150.0
# 3               Cobalt Ore            30.0
# 4                     Coke           162.0
# 17              Copper Ore            18.0
# 7          Cryptomeria Log            27.0
# 22           Darksteel Ore            30.0
# 26          Dhalmel Saliva            36.0
# 27  Dravanian Spring Water            18.0
# 6            Earth Cluster            66.0
# 20           Earth Crystal            54.0
# 13          Eikon Mythrite            36.0
# 12               Ferberite            12.0
# 5             Fire Cluster            96.0
# 19            Fire Crystal           129.0
# 8             Hardened Sap            81.0
# 25         Hardsilver Sand            72.0
# 10             Ice Crystal            54.0
# 16       Koppranickel Sand            72.0
# 14          Lumythrite Ore            54.0
# 15            Mythrite Ore            36.0
# 18       Pure Titanium Ore            27.0
# ...

# %%
from modified_syldra_class_sub_parts import get_crafting_recipes

# Get the crafting recipes from total_modified_syldra_class_sub_parts.csv
df_crafting_recipes = get_crafting_recipes('modified_syldra_class_bow_parts.csv')
df_crafting_recipes  # Display the crafting recipes list
# Out:
#                      Product  Required Quantity
# 7          Adamantite Nugget                 15
# 8          Adamantite Rivets                 15
# 2         Cryptomeria Lumber                  9
# 10  Enchanted Hardsilver Ink                 18
# 1   Galvanized Garlond Steel                  9
# 4        High Mythrite Ingot                 18
# 5        Koppranickel Nugget                 18
# 6        Pure Titanium Plate                  9
# 9                  Rhodonite                 12
# 0           Syldra-Class Bow                  1
# 3              Wolfram Ingot                 12
