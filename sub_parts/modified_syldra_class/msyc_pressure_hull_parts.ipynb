# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import generate_gathering_list
utils_dir = '../../utilities/'
data_dir = 'item_data/'
df_gathering_list = generate_gathering_list(
    total_csv=os.path.join(data_dir, 'modified_syldra_class_pressure_hull_parts.csv'),
    recipe_book_csv=os.path.join(utils_dir, 'recipe_book.csv'),
    recipe_gathering_csv=os.path.join(utils_dir, 'recipe_gathering.csv'),
    output_csv=os.path.join(data_dir, 'gathering_list.csv')
)
df_gathering_list
# Out:
#                     Ingredient  Total Quantity  \
# 16        Abalathian Mistletoe           120.0
# 15     Abalathian Spring Water           120.0
# 19                Ahriman Wing            24.0
# 31              Astral Moraine            12.0
# 32                    Bear Fat             6.0
# 27                  Cassia Log            18.0
# 26                  Cassia Log            18.0
# 3                   Cobalt Ore            18.0
# 4                         Coke           162.0
# 7              Cryptomeria Log            27.0
# 14           Dark Chestnut Log           150.0
# 35        Dawnborne Aethersand             6.0
# 20              Dhalmel Saliva            60.0
# 39      Dravanian Spring Water            18.0
# 6                Earth Cluster            54.0
# 23               Earth Crystal            54.0
# 11              Eikon Mythrite            36.0
# 5                 Fire Cluster            72.0
# 22                Fire Crystal           144.0
# 8                 Hardened Sap           135.0
# 38             Hardsilver Sand            72.0
# 29                 Ice Cluster            12.0
# 10                 Ice Crystal           144.0
# 34           Lightning Cluster             6.0
# 12              Lumythrite Ore            54.0
# 25                 Mythril Ore            30.0
# 13                Mythrite Ore            36.0
# 24               Mythrite Sand           150.0
# 21           Pure Titanium Ore            27.0
# 36               Raw Rhodonite            45.0
# 30              Seventh Heaven            12.0
# 2                   Sphalerite            18.0
# 37                 Stiperstone            15.0
# 0   Syldra-Class Pressure Hull             1.0
# 1                    Vivianite            27.0
# 33               Water Cluster            12.0
# 17               Water Crystal           420.0
# 28                Wind Cluster            24.0
# 9                 Wind Crystal           414.0
# 18                 Wyvern Wing            36.0
#
#                                         Location Info
# 16  The Sea of Clouds ( 35.8 / 21.4 ), Timed at 6A...
# 15                  The Sea of Clouds ( 34.8 / 30.5 )
# 19  Northern Thanalan ( 24 / 21 ), Dropped by vari...
# 31  Coerthas Western Highlands ( 37.2 / 16.4 ), Ti...
# 32  The Dravanian Hinterlands ( 4.7 / 27.8 ), Drop...
# 27  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 26  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 3                   Northern Thanalan ( 23.1 / 24.2 )
# 4        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 7   Nowhere ( 0.0 / 0.0 ), Collected from Submarin...
# 14            The Dravanian Forelands ( 26.6 / 27.1 )
# 35  Nowhere ( 0.0 / 0.0 ), Aetherial Reduction fro...
# 20  The Sea of Clouds ( 17.3 / 32.2 ), Dropped by ...
# 39            The Dravanian Forelands ( 27.4 / 31.8 )
# 6                                                 NaN
# 23                                                NaN
# 11    Nowhere ( 0.0 / 0.0 ), Sold by Spoils Collector
# 5                                                 NaN
# 22                                                NaN
# 8        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 38                 The Churning Mists ( 15.9 / 28.5 )
# 29                                                NaN
# 10                                                NaN
# 34                                                NaN
# 12  The Churning Mists ( 9.3 / 38.5 ), Timed at 2A...
# 25                  Southern Thanalan ( 25.2 / 39.9 )
# 13         Coerthas Western Highlands ( 31.2 / 12.8 )
# 24         Coerthas Western Highlands ( 16.6 / 13.1 )
# 21  Nowhere ( 0.0 / 0.0 ), Collected from Submarin...
# 36      The Peaks ( 26.9 / 12.5 ), Timed at 8AM/PM ET
# 30  The Churning Mists ( 16.7 / 36.8 ), Timed at 4...
# 2      Nowhere ( 0.0 / 0.0 ), Sold by NPCs for Scrips
# 37                          The Peaks ( 23.3 / 13.1 )
# 0                                                 NaN
# 1   Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 33                                                NaN
# 17                                                NaN
# 28                                                NaN
# 9                                                 NaN
# 18  The Churning Mists ( 24 / 28 ), Dropped by var...

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import get_crafting_recipes
data_dir = 'item_data/'
df_crafting_recipes = get_crafting_recipes(os.path.join(data_dir, 'modified_syldra_class_pressure_hull_parts.csv'))
df_crafting_recipes
# Out:
#                        Product  Required Quantity
# 8                 Cassia Block                  6
# 2           Cryptomeria Lumber                  9
# 10    Enchanted Hardsilver Ink                 18
# 1     Galvanized Garlond Steel                  9
# 4     Hallowed Chestnut Lumber                 30
# 3          High Mythrite Ingot                 18
# 7              Mythrite Rivets                 30
# 6          Pure Titanium Plate                  9
# 9                    Rhodonite                 15
# 0   Syldra-Class Pressure Hull                  1
# 5                    Wing Glue                 12
