# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import generate_gathering_list
utils_dir = '../../utilities/'
data_dir = 'item_data/'
df_gathering_list = generate_gathering_list(
    total_csv=os.path.join(data_dir, 'modified_syldra_class_bridge_parts.csv'),
    recipe_book_csv=os.path.join(utils_dir, 'recipe_book.csv'),
    recipe_gathering_csv=os.path.join(utils_dir, 'recipe_gathering.csv'),
    output_csv=os.path.join(data_dir, 'gathering_list.csv')
)
df_gathering_list
# Out:
#                 Ingredient  Total Quantity  \
# 29          Adamantite Ore            75.0
# 24          Astral Moraine            12.0
# 25                Bear Fat             6.0
# 21              Cassia Log            18.0
# 20              Cassia Log            18.0
# 3               Cobalt Ore            57.0
# 4                     Coke           162.0
# 7          Cryptomeria Log            27.0
# 30           Darksteel Ore            15.0
# 28    Dawnborne Aethersand             6.0
# 34          Dhalmel Saliva            36.0
# 35  Dravanian Spring Water            18.0
# 6            Earth Cluster            27.0
# 19           Earth Crystal            54.0
# 12               Ferberite             9.0
# 5             Fire Cluster            18.0
# 15            Fire Crystal           324.0
# 8             Hardened Sap           135.0
# 33         Hardsilver Sand            72.0
# 13             Ice Cluster            30.0
# 10             Ice Crystal            99.0
# 27       Lightning Cluster             6.0
# 14          Molybdenum Ore           120.0
# 17             Mythril Ore            15.0
# 16           Mythrite Sand            75.0
# 18       Pure Titanium Ore            27.0
# 31           Raw Rhodonite            18.0
# 11               Scheelite             9.0
# 23          Seventh Heaven            12.0
# 2               Sphalerite            18.0
# 32             Stiperstone             6.0
# 0      Syldra-Class Bridge             1.0
# 1                Vivianite            27.0
# 26           Water Cluster            12.0
# 36           Water Crystal            72.0
# 22            Wind Cluster            24.0
# 9             Wind Crystal            90.0
#
#                                         Location Info
# 29       Azys Lla ( 23.2 / 5.8 ), Timed at 12AM/PM ET
# 24  Coerthas Western Highlands ( 37.2 / 16.4 ), Ti...
# 25  The Dravanian Hinterlands ( 4.7 / 27.8 ), Drop...
# 21  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 20  Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 3                   Northern Thanalan ( 23.1 / 24.2 )
# 4        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 7   Nowhere ( 0.0 / 0.0 ), Collected from Submarin...
# 30  Coerthas Central Highlands ( 27.5 / 20.0 ), Ti...
# 28  Nowhere ( 0.0 / 0.0 ), Aetherial Reduction fro...
# 34  The Sea of Clouds ( 17.3 / 32.2 ), Dropped by ...
# 35            The Dravanian Forelands ( 27.4 / 31.8 )
# 6                                                 NaN
# 19                                                NaN
# 12  Northern Thanalan ( 17.3 / 19.9 ), Timed at 3:...
# 5                                                 NaN
# 15                                                NaN
# 8        Nowhere ( 0.0 / 0.0 ), Sold for 200 GC Seals
# 33                 The Churning Mists ( 15.9 / 28.5 )
# 13                                                NaN
# 10                                                NaN
# 27                                                NaN
# 14                          The Lochs ( 11.4 / 16.6 )
# 17                  Southern Thanalan ( 25.2 / 39.9 )
# 16         Coerthas Western Highlands ( 16.6 / 13.1 )
# 18  Nowhere ( 0.0 / 0.0 ), Collected from Submarin...
# 31      The Peaks ( 26.9 / 12.5 ), Timed at 8AM/PM ET
# 11      Nowhere ( 0.0 / 0.0 ), Sold for 1500 GC Seals
# 23  The Churning Mists ( 16.7 / 36.8 ), Timed at 4...
# 2      Nowhere ( 0.0 / 0.0 ), Sold by NPCs for Scrips
# 32                          The Peaks ( 23.3 / 13.1 )
# 0                                                 NaN
# 1   Nowhere ( 0.0 / 0.0 ), Collected from Company ...
# 26                                                NaN
# 36                                                NaN
# 22                                                NaN
# 9                                                 NaN

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../../'))
from workshop_projects import get_crafting_recipes
data_dir = 'item_data/'
df_crafting_recipes = get_crafting_recipes(os.path.join(data_dir, 'modified_syldra_class_bridge_parts.csv'))
df_crafting_recipes
# Out:
#                      Product  Required Quantity
# 8          Adamantite Rivets                 15
# 7               Cassia Block                  6
# 2         Cryptomeria Lumber                  9
# 10  Enchanted Hardsilver Ink                 18
# 1   Galvanized Garlond Steel                  9
# 4           Molybdenum Ingot                 30
# 5            Mythrite Rivets                 15
# 6        Pure Titanium Plate                  9
# 9                  Rhodonite                  6
# 0        Syldra-Class Bridge                  1
# 3             Wolfram Square                  9
